# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
city_data = []

# %%
#  Using NumPy to create random figures
np.random.uniform(-90, 90, size=1500)
# Out:
# array([ 34.34888282,  59.1703006 , -57.22702787, ..., -84.82276062,
#         48.65989322,  26.64037669])

# %%
# Adding Timeit
# %timeit np.random.uniform(-90, 90, size=1500)
# Out:
# 11.6 µs ± 38.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# defining random latitudes
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = np.random.randint(-90, 90) + np.random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 3.52 ms ± 64 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import Citipy
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 622

# %%
cities
# Out:
# ['amay',
#  'pevek',
#  'bluff',
#  'hasaki',
#  'los llanos de aridane',
#  'mataura',
#  'busselton',
#  'dingle',
#  'taolanaro',
#  'port lincoln',
#  'airai',
#  'zhigansk',
#  'grajau',
#  'hithadhoo',
#  'rikitea',
#  'sentyabrskiy',
#  'dwarka',
#  'opuwo',
#  'vilyuysk',
#  'vila velha',
#  'villamontes',
#  'beloha',
#  'cururupu',
#  'tsihombe',
#  'avarua',
#  'ostrovnoy',
#  'nizhneyansk',
#  'mys shmidta',
#  'northam',
#  'forest',
#  'port elizabeth',
#  'atuona',
#  'bambous virieux',
#  'salalah',
#  'chuy',
#  'belushya guba',
#  'yulara',
#  'port alfred',
#  'faanui',
#  'kawalu',
#  'kapaa',
#  'santa vitoria do palmar',
#  'ushuaia',
#  'tuktoyaktuk',
#  'punta arenas',
#  'hobart',
#  'gat',
#  'baykit',
#  'amnat charoen',
#  'mahebourg',
#  'barentu',
#  'sorong',
#  'mar del plata',
#  'vardo',
#  'saint george',
#  'georgetown',
#  'harper',
#  'new norfolk',
#  'gurgan',
#  'saint-pierre',
#  'westport',
#  'attawapiskat',
#  'abha',
#  'jalu',
#  'hermanus',
#  'carnarvon',
#  'kavieng',
#  'marawi',
#  'bafq',
#  'karamay',
#  'victoria',
#  'boali',
#  'camacha',
#  'bacolod',
#  'fare',
#  'ahipara',
#  'fairbanks',
#  'turayf',
#  'bredasdorp',
#  'upernavik',
#  'dikson',
#  'mitu',
#  'kenora',
#  'tuatapere',
#  'cape town',
#  'shawnee',
#  'galle',
#  'khatanga',
#  'sitka',
#  'severo-kurilsk',
#  'jamestown',
#  'provideniya',
#  'guerrero negro',
#  'sao luiz gonzaga',
#  'berlevag',
#  'amderma',
#  'barentsburg',
#  'east london',
#  'brcko',
#  'mzimba',
#  'saint-philippe',
#  'tiksi',
#  'beringovskiy',
#  'moose factory',
#  'san francisco',
#  'bandarbeyla',
#  'winnemucca',
#  'arraial do cabo',
#  'albany',
#  'puerto ayora',
#  'rocha',
#  'half moon bay',
#  'gorno-chuyskiy',
#  'cheuskiny',
#  'gwanda',
#  'bonavista',
#  'clyde river',
#  'iqaluit',
#  'ketchikan',
#  'castro',
#  'touros',
#  'pitimbu',
#  'kizukuri',
#  'hitoyoshi',
#  'poum',
#  'kahului',
#  'warri',
#  'teahupoo',
#  'weligama',
#  'namatanai',
#  'koslan',
#  'great falls',
#  'cidreira',
#  'wichita falls',
#  'bethlehem',
#  'udachnyy',
#  'aklavik',
#  'san pedro',
#  'abadan',
#  'daru',
#  'cherskiy',
#  'labuhan',
#  'illoqqortoormiut',
#  'paka',
#  'ipeti',
#  'sevenoaks',
#  'ewa beach',
#  'high level',
#  'vao',
#  'noumea',
#  'lixourion',
#  'grand river south east',
#  'bowen',
#  'quatre cocos',
#  'bethel',
#  'shkoder',
#  'cleethorpes',
#  'alyangula',
#  'khonuu',
#  'vaini',
#  'pandan',
#  'saldanha',
#  'ancud',
#  'gold coast',
#  'nova olimpia',
#  'yellowknife',
#  'petropavlovsk-kamchatskiy',
#  'vaitupu',
#  'hilo',
#  'sicamous',
#  'gaozhou',
#  'puerto rico',
#  'san lawrenz',
#  'butaritari',
#  'bajil',
#  'kruisfontein',
#  'hirara',
#  'katsuura',
#  'risor',
#  'kaeo',
#  'kailua',
#  'naze',
#  'ilulissat',
#  'along',
#  'nishihara',
#  'torbay',
#  'makat',
#  'salekhard',
#  'havoysund',
#  'lebu',
#  'ixtapa',
#  'atocha',
#  'chokurdakh',
#  'matara',
#  'nanortalik',
#  'isangel',
#  'carlsbad',
#  'araouane',
#  'rawson',
#  'alugan',
#  'keokuk',
#  'nikolskoye',
#  'atakpame',
#  'chimoio',
#  'kapit',
#  'cabot',
#  'kochki',
#  'alenquer',
#  'hami',
#  'kazachinskoye',
#  'kaitangata',
#  'achisay',
#  'shingu',
#  'mirnyy',
#  'karratha',
#  'concordia',
#  'algiers',
#  'grand gaube',
#  'saint-augustin',
#  'brae',
#  'yantarnyy',
#  'davila',
#  'kumluca',
#  'richards bay',
#  'hastings',
#  'ostrovskoye',
#  'floriano',
#  'adrar',
#  'qaanaaq',
#  'dehloran',
#  'dunmore',
#  'urzhum',
#  'nehe',
#  'tezu',
#  'san rafael del sur',
#  'bitung',
#  'acapulco',
#  'itarema',
#  'san quintin',
#  'chapais',
#  'lushunkou',
#  'maceio',
#  'kodiak',
#  'ponta do sol',
#  'lubango',
#  'esperance',
#  'morant bay',
#  'hamilton',
#  'sioux lookout',
#  'heinola',
#  'rosarito',
#  'manzil tamim',
#  'margate',
#  'luderitz',
#  'uyemskiy',
#  'korla',
#  'morondava',
#  'magadan',
#  'taraz',
#  'inirida',
#  'bougouni',
#  'mafinga',
#  'san cristobal',
#  'pagegiai',
#  'miandrivazo',
#  'hohhot',
#  'barrow',
#  'alice springs',
#  'roald',
#  'havelock',
#  'malangali',
#  'roma',
#  'sept-iles',
#  'talnakh',
#  'zalantun',
#  'port blair',
#  'thano bula khan',
#  'deputatskiy',
#  'sakakah',
#  'liling',
#  'fevralsk',
#  'maridi',
#  'umm lajj',
#  'grao mogol',
#  'saskylakh',
#  'copiapo',
#  'preobrazheniye',
#  'meadow lake',
#  'rolla',
#  'zarichne',
#  'baruun-urt',
#  'aykhal',
#  'clarence town',
#  'piracuruca',
#  'surin',
#  'narsaq',
#  'yanam',
#  'sao joao da barra',
#  'ribeira grande',
#  'qazanbulaq',
#  'cap malheureux',
#  'hervey bay',
#  'cabatuan',
#  'sekoma',
#  'bollnas',
#  'cabedelo',
#  'fortuna',
#  'barbar',
#  'port augusta',
#  'codrington',
#  'salta',
#  'veshkayma',
#  'tinskoy',
#  'marcona',
#  'mancora',
#  'carutapera',
#  'constitucion',
#  'cayenne',
#  'fort nelson',
#  'longyearbyen',
#  'stamsund',
#  'bolungarvik',
#  'rio cuarto',
#  'ruatoria',
#  'aksarka',
#  'golden',
#  'salmas',
#  'bridlington',
#  'slave lake',
#  'sainte-anne-des-monts',
#  'kungurtug',
#  'kharan',
#  'chernyshevskiy',
#  'merauke',
#  'hvide sande',
#  'thompson',
#  'maneadero',
#  'balabac',
#  'meget',
#  'guasdualito',
#  'ahuimanu',
#  'bokspits',
#  'rio gallegos',
#  'jabiru',
#  'nueva valencia',
#  'ayan',
#  'ovalle',
#  'monte aprazivel',
#  'raudeberg',
#  'mamallapuram',
#  'tarko-sale',
#  'williamsburg',
#  'west richland',
#  'sarahan',
#  'binzhou',
#  'atar',
#  'tasiilaq',
#  'vangaindrano',
#  'lagoa',
#  'sur',
#  'geraldton',
#  'norman wells',
#  'back mountain',
#  'udayagiri',
#  'pafos',
#  'aswan',
#  'la ronge',
#  'kloulklubed',
#  'ranong',
#  'huntington',
#  'cobija',
#  'elizabeth city',
#  'singapore',
#  'buala',
#  'the valley',
#  'pushkino',
#  'hay river',
#  'bundaberg',
#  'gunjur',
#  'solnechnyy',
#  'toliary',
#  'usakos',
#  'riyadh',
#  'khilok',
#  'dafeng',
#  'souillac',
#  'masvingo',
#  'coahuayana',
#  'huarmey',
#  'cabo san lucas',
#  'ulaangom',
#  'nome',
#  'maragogi',
#  'santa maria',
#  'donskoye',
#  'salinas',
#  'bystrzyca klodzka',
#  'guymon',
#  'acoyapa',
#  'lompoc',
#  'tumannyy',
#  'muroto',
#  'malinovoye ozero',
#  'annamalainagar',
#  'libreville',
#  'jatai',
#  'kalmar',
#  'coquimbo',
#  'mokhsogollokh',
#  'mollendo',
#  'tocopilla',
#  'goundam',
#  'wanaka',
#  'sena madureira',
#  'santo antonio do ica',
#  'amapa',
#  'coolum beach',
#  'coihaique',
#  'waitara',
#  'saleilua',
#  'haines junction',
#  'pangnirtung',
#  'broome',
#  'kedrovyy',
#  'portland',
#  'hofn',
#  'foam lake',
#  'dzheguta',
#  'wuda',
#  'acarau',
#  'nguiu',
#  'bengkulu',
#  'ahome',
#  'komsomolskiy',
#  'alta floresta',
#  'khandbari',
#  'saint combs',
#  'methoni',
#  'acari',
#  'ponta delgada',
#  'san ramon',
#  'sambava',
#  'tubruq',
#  'darhan',
#  'aitape',
#  'portel',
#  'bartica',
#  'dnestrovsc',
#  'cuamba',
#  'tiznit',
#  'wad madani',
#  'loiza',
#  'eureka',
#  'sungaipenuh',
#  'belaya gora',
#  'zhaoyang',
#  'champerico',
#  'axim',
#  'umzimvubu',
#  'la rioja',
#  'puerto quijarro',
#  'saryshagan',
#  'bardsir',
#  'ponferrada',
#  'ulladulla',
#  'tianpeng',
#  'port washington',
#  'farrukhnagar',
#  'ust-ishim',
#  'date',
#  'nola',
#  'bogotol',
#  'nongan',
#  'svetlyy',
#  'troitsko-pechorsk',
#  'sao filipe',
#  'bonthe',
#  'altay',
#  'muros',
#  'waipawa',
#  'huainan',
#  'lazaro cardenas',
#  'wakkanai',
#  'doctor pedro p. pena',
#  'laguna de duero',
#  'ornskoldsvik',
#  'kamenskoye',
#  'urozhayne',
#  'talcahuano',
#  'bargal',
#  'newport',
#  'qui nhon',
#  'salinopolis',
#  'seoul',
#  'les cayes',
#  'nouadhibou',
#  'innisfail',
#  'mossendjo',
#  'norden',
#  'umm jarr',
#  'north bay',
#  'comodoro rivadavia',
#  'kandi',
#  'bure',
#  'taltal',
#  'akhmim',
#  'san patricio',
#  'collie',
#  'dubai',
#  'dakar',
#  'genhe',
#  'jardim',
#  'evensk',
#  'tura',
#  'moree',
#  'carauari',
#  'dekoa',
#  'kirensk',
#  'wahran',
#  'nitra',
#  'ayer itam',
#  'palabuhanratu',
#  'wuwei',
#  'bathsheba',
#  'brightwater',
#  'tempoal',
#  'zabaykalsk',
#  'yashkul',
#  'oriximina',
#  'qaqortoq',
#  'port hardy',
#  'betera',
#  'nicoya',
#  'bontang',
#  'okhotsk',
#  'vila franca do campo',
#  'boa vista',
#  'ballina',
#  'miram shah',
#  'lensk',
#  'pisco',
#  'talesh',
#  'altamont',
#  'saint-joseph',
#  'cockburn town',
#  'sompeta',
#  'shizunai',
#  'tukrah',
#  'bocaranga',
#  'lavrentiya',
#  'skjervoy',
#  'boueni',
#  'ovre ardal',
#  'mana',
#  'san juan',
#  'la asuncion',
#  'lomovka',
#  'kassala',
#  'orcopampa',
#  'garissa',
#  'camopi',
#  'mount gambier',
#  'beira',
#  'stornoway',
#  'manyana',
#  'cloquet',
#  'klaksvik',
#  'sungurlu',
#  'maniitsoq',
#  'sindi',
#  'gimbi',
#  'kabanjahe',
#  'agboville',
#  'bosobolo',
#  'dekernes',
#  'luis correia',
#  'omboue',
#  'muravlenko',
#  'rio verde de mato grosso',
#  'plettenberg bay',
#  'basco',
#  'tabou',
#  'alofi',
#  'presidente franco',
#  'mayumba',
#  'ofaqim',
#  'dzaoudzi',
#  'sattahip',
#  'moron',
#  'leningradskiy',
#  'potenza',
#  'svetlaya',
#  'antofagasta',
#  'savannah bight',
#  'havre-saint-pierre',
#  'dalvik',
#  'hambantota',
#  'sumbe',
#  'ouro preto do oeste',
#  'sangar',
#  'shimoda',
#  'kaspiyskiy',
#  'vallenar',
#  'falam',
#  'solsvik',
#  'bagdarin',
#  'lodja',
#  'tocache',
#  'flinders',
#  'padang',
#  'nioro',
#  'shu',
#  'sirsi',
#  'yar-sale',
#  'kadyy',
#  'nelson bay',
#  'yarada',
#  'samusu',
#  'jabinyanah',
#  'jinchang',
#  'jacareacanga',
#  'grand-santi']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0857bafab7106fceacc87a5d7664babf

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amay
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | los llanos de aridane
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | dingle
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | zhigansk
# Processing Record 13 of Set 1 | grajau
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | dwarka
# Processing Record 18 of Set 1 | opuwo
# Processing Record 19 of Set 1 | vilyuysk
# Processing Record 20 of Set 1 | vila velha
# Processing Record 21 of Set 1 | villamontes
# Processing Record 22 of Set 1 | beloha
# Processing Record 23 of Set 1 | cururupu
# Processing Record 24 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | ostrovnoy
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | northam
# Processing Record 30 of Set 1 | forest
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | bambous virieux
# Processing Record 34 of Set 1 | salalah
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | yulara
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | kawalu
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | santa vitoria do palmar
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | gat
# Processing Record 48 of Set 1 | baykit
# Processing Record 49 of Set 1 | amnat charoen
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | barentu
# Processing Record 2 of Set 2 | sorong
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | vardo
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | harper
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 10 of Set 2 | saint-pierre
# Processing Record 11 of Set 2 | westport
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | abha
# Processing Record 14 of Set 2 | jalu
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | marawi
# Processing Record 19 of Set 2 | bafq
# Processing Record 20 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | boali
# Processing Record 23 of Set 2 | camacha
# Processing Record 24 of Set 2 | bacolod
# Processing Record 25 of Set 2 | fare
# Processing Record 26 of Set 2 | ahipara
# Processing Record 27 of Set 2 | fairbanks
# Processing Record 28 of Set 2 | turayf
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | mitu
# Processing Record 33 of Set 2 | kenora
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | shawnee
# Processing Record 37 of Set 2 | galle
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | provideniya
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | sao luiz gonzaga
# Processing Record 45 of Set 2 | berlevag
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | brcko
# Processing Record 50 of Set 2 | mzimba
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | beringovskiy
# Processing Record 4 of Set 3 | moose factory
# Processing Record 5 of Set 3 | san francisco
# Processing Record 6 of Set 3 | bandarbeyla
# Processing Record 7 of Set 3 | winnemucca
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | rocha
# Processing Record 12 of Set 3 | half moon bay
# Processing Record 13 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 15 of Set 3 | gwanda
# Processing Record 16 of Set 3 | bonavista
# Processing Record 17 of Set 3 | clyde river
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | ketchikan
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | touros
# Processing Record 22 of Set 3 | pitimbu
# Processing Record 23 of Set 3 | kizukuri
# Processing Record 24 of Set 3 | hitoyoshi
# Processing Record 25 of Set 3 | poum
# Processing Record 26 of Set 3 | kahului
# Processing Record 27 of Set 3 | warri
# Processing Record 28 of Set 3 | teahupoo
# Processing Record 29 of Set 3 | weligama
# Processing Record 30 of Set 3 | namatanai
# Processing Record 31 of Set 3 | koslan
# Processing Record 32 of Set 3 | great falls
# Processing Record 33 of Set 3 | cidreira
# Processing Record 34 of Set 3 | wichita falls
# Processing Record 35 of Set 3 | bethlehem
# Processing Record 36 of Set 3 | udachnyy
# Processing Record 37 of Set 3 | aklavik
# Processing Record 38 of Set 3 | san pedro
# Processing Record 39 of Set 3 | abadan
# Processing Record 40 of Set 3 | daru
# Processing Record 41 of Set 3 | cherskiy
# Processing Record 42 of Set 3 | labuhan
# Processing Record 43 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 3 | paka
# Processing Record 45 of Set 3 | ipeti
# City not found. Skipping...
# Processing Record 46 of Set 3 | sevenoaks
# Processing Record 47 of Set 3 | ewa beach
# Processing Record 48 of Set 3 | high level
# Processing Record 49 of Set 3 | vao
# Processing Record 50 of Set 3 | noumea
# Processing Record 1 of Set 4 | lixourion
# Processing Record 2 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 4 | bowen
# Processing Record 4 of Set 4 | quatre cocos
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | shkoder
# Processing Record 7 of Set 4 | cleethorpes
# Processing Record 8 of Set 4 | alyangula
# Processing Record 9 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 4 | vaini
# Processing Record 11 of Set 4 | pandan
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | gold coast
# Processing Record 15 of Set 4 | nova olimpia
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 4 | hilo
# Processing Record 20 of Set 4 | sicamous
# Processing Record 21 of Set 4 | gaozhou
# Processing Record 22 of Set 4 | puerto rico
# Processing Record 23 of Set 4 | san lawrenz
# Processing Record 24 of Set 4 | butaritari
# Processing Record 25 of Set 4 | bajil
# Processing Record 26 of Set 4 | kruisfontein
# Processing Record 27 of Set 4 | hirara
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | risor
# Processing Record 30 of Set 4 | kaeo
# Processing Record 31 of Set 4 | kailua
# Processing Record 32 of Set 4 | naze
# Processing Record 33 of Set 4 | ilulissat
# Processing Record 34 of Set 4 | along
# Processing Record 35 of Set 4 | nishihara
# Processing Record 36 of Set 4 | torbay
# Processing Record 37 of Set 4 | makat
# Processing Record 38 of Set 4 | salekhard
# Processing Record 39 of Set 4 | havoysund
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | ixtapa
# Processing Record 42 of Set 4 | atocha
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | matara
# Processing Record 45 of Set 4 | nanortalik
# Processing Record 46 of Set 4 | isangel
# Processing Record 47 of Set 4 | carlsbad
# Processing Record 48 of Set 4 | araouane
# Processing Record 49 of Set 4 | rawson
# Processing Record 50 of Set 4 | alugan
# Processing Record 1 of Set 5 | keokuk
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | atakpame
# Processing Record 4 of Set 5 | chimoio
# Processing Record 5 of Set 5 | kapit
# Processing Record 6 of Set 5 | cabot
# Processing Record 7 of Set 5 | kochki
# Processing Record 8 of Set 5 | alenquer
# Processing Record 9 of Set 5 | hami
# Processing Record 10 of Set 5 | kazachinskoye
# Processing Record 11 of Set 5 | kaitangata
# Processing Record 12 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 13 of Set 5 | shingu
# Processing Record 14 of Set 5 | mirnyy
# Processing Record 15 of Set 5 | karratha
# Processing Record 16 of Set 5 | concordia
# Processing Record 17 of Set 5 | algiers
# Processing Record 18 of Set 5 | grand gaube
# Processing Record 19 of Set 5 | saint-augustin
# Processing Record 20 of Set 5 | brae
# Processing Record 21 of Set 5 | yantarnyy
# Processing Record 22 of Set 5 | davila
# Processing Record 23 of Set 5 | kumluca
# Processing Record 24 of Set 5 | richards bay
# Processing Record 25 of Set 5 | hastings
# Processing Record 26 of Set 5 | ostrovskoye
# Processing Record 27 of Set 5 | floriano
# Processing Record 28 of Set 5 | adrar
# Processing Record 29 of Set 5 | qaanaaq
# Processing Record 30 of Set 5 | dehloran
# Processing Record 31 of Set 5 | dunmore
# Processing Record 32 of Set 5 | urzhum
# Processing Record 33 of Set 5 | nehe
# Processing Record 34 of Set 5 | tezu
# Processing Record 35 of Set 5 | san rafael del sur
# Processing Record 36 of Set 5 | bitung
# Processing Record 37 of Set 5 | acapulco
# Processing Record 38 of Set 5 | itarema
# Processing Record 39 of Set 5 | san quintin
# Processing Record 40 of Set 5 | chapais
# Processing Record 41 of Set 5 | lushunkou
# City not found. Skipping...
# Processing Record 42 of Set 5 | maceio
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | ponta do sol
# Processing Record 45 of Set 5 | lubango
# Processing Record 46 of Set 5 | esperance
# Processing Record 47 of Set 5 | morant bay
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | sioux lookout
# Processing Record 50 of Set 5 | heinola
# Processing Record 1 of Set 6 | rosarito
# Processing Record 2 of Set 6 | manzil tamim
# City not found. Skipping...
# Processing Record 3 of Set 6 | margate
# Processing Record 4 of Set 6 | luderitz
# Processing Record 5 of Set 6 | uyemskiy
# Processing Record 6 of Set 6 | korla
# Processing Record 7 of Set 6 | morondava
# Processing Record 8 of Set 6 | magadan
# Processing Record 9 of Set 6 | taraz
# Processing Record 10 of Set 6 | inirida
# Processing Record 11 of Set 6 | bougouni
# Processing Record 12 of Set 6 | mafinga
# Processing Record 13 of Set 6 | san cristobal
# Processing Record 14 of Set 6 | pagegiai
# Processing Record 15 of Set 6 | miandrivazo
# Processing Record 16 of Set 6 | hohhot
# Processing Record 17 of Set 6 | barrow
# Processing Record 18 of Set 6 | alice springs
# Processing Record 19 of Set 6 | roald
# Processing Record 20 of Set 6 | havelock
# Processing Record 21 of Set 6 | malangali
# Processing Record 22 of Set 6 | roma
# Processing Record 23 of Set 6 | sept-iles
# Processing Record 24 of Set 6 | talnakh
# Processing Record 25 of Set 6 | zalantun
# Processing Record 26 of Set 6 | port blair
# Processing Record 27 of Set 6 | thano bula khan
# City not found. Skipping...
# Processing Record 28 of Set 6 | deputatskiy
# Processing Record 29 of Set 6 | sakakah
# Processing Record 30 of Set 6 | liling
# Processing Record 31 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 6 | maridi
# Processing Record 33 of Set 6 | umm lajj
# Processing Record 34 of Set 6 | grao mogol
# Processing Record 35 of Set 6 | saskylakh
# Processing Record 36 of Set 6 | copiapo
# Processing Record 37 of Set 6 | preobrazheniye
# Processing Record 38 of Set 6 | meadow lake
# Processing Record 39 of Set 6 | rolla
# Processing Record 40 of Set 6 | zarichne
# Processing Record 41 of Set 6 | baruun-urt
# Processing Record 42 of Set 6 | aykhal
# Processing Record 43 of Set 6 | clarence town
# Processing Record 44 of Set 6 | piracuruca
# Processing Record 45 of Set 6 | surin
# Processing Record 46 of Set 6 | narsaq
# Processing Record 47 of Set 6 | yanam
# Processing Record 48 of Set 6 | sao joao da barra
# Processing Record 49 of Set 6 | ribeira grande
# Processing Record 50 of Set 6 | qazanbulaq
# Processing Record 1 of Set 7 | cap malheureux
# Processing Record 2 of Set 7 | hervey bay
# Processing Record 3 of Set 7 | cabatuan
# Processing Record 4 of Set 7 | sekoma
# Processing Record 5 of Set 7 | bollnas
# Processing Record 6 of Set 7 | cabedelo
# Processing Record 7 of Set 7 | fortuna
# Processing Record 8 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 7 | port augusta
# Processing Record 10 of Set 7 | codrington
# Processing Record 11 of Set 7 | salta
# Processing Record 12 of Set 7 | veshkayma
# Processing Record 13 of Set 7 | tinskoy
# Processing Record 14 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 7 | mancora
# Processing Record 16 of Set 7 | carutapera
# Processing Record 17 of Set 7 | constitucion
# Processing Record 18 of Set 7 | cayenne
# Processing Record 19 of Set 7 | fort nelson
# Processing Record 20 of Set 7 | longyearbyen
# Processing Record 21 of Set 7 | stamsund
# City not found. Skipping...
# Processing Record 22 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 7 | rio cuarto
# Processing Record 24 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 7 | aksarka
# Processing Record 26 of Set 7 | golden
# Processing Record 27 of Set 7 | salmas
# Processing Record 28 of Set 7 | bridlington
# Processing Record 29 of Set 7 | slave lake
# Processing Record 30 of Set 7 | sainte-anne-des-monts
# Processing Record 31 of Set 7 | kungurtug
# Processing Record 32 of Set 7 | kharan
# Processing Record 33 of Set 7 | chernyshevskiy
# Processing Record 34 of Set 7 | merauke
# Processing Record 35 of Set 7 | hvide sande
# Processing Record 36 of Set 7 | thompson
# Processing Record 37 of Set 7 | maneadero
# Processing Record 38 of Set 7 | balabac
# Processing Record 39 of Set 7 | meget
# Processing Record 40 of Set 7 | guasdualito
# Processing Record 41 of Set 7 | ahuimanu
# Processing Record 42 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 7 | rio gallegos
# Processing Record 44 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 7 | nueva valencia
# Processing Record 46 of Set 7 | ayan
# Processing Record 47 of Set 7 | ovalle
# Processing Record 48 of Set 7 | monte aprazivel
# Processing Record 49 of Set 7 | raudeberg
# Processing Record 50 of Set 7 | mamallapuram
# Processing Record 1 of Set 8 | tarko-sale
# Processing Record 2 of Set 8 | williamsburg
# Processing Record 3 of Set 8 | west richland
# Processing Record 4 of Set 8 | sarahan
# Processing Record 5 of Set 8 | binzhou
# Processing Record 6 of Set 8 | atar
# Processing Record 7 of Set 8 | tasiilaq
# Processing Record 8 of Set 8 | vangaindrano
# Processing Record 9 of Set 8 | lagoa
# Processing Record 10 of Set 8 | sur
# Processing Record 11 of Set 8 | geraldton
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | back mountain
# Processing Record 14 of Set 8 | udayagiri
# Processing Record 15 of Set 8 | pafos
# Processing Record 16 of Set 8 | aswan
# Processing Record 17 of Set 8 | la ronge
# Processing Record 18 of Set 8 | kloulklubed
# Processing Record 19 of Set 8 | ranong
# Processing Record 20 of Set 8 | huntington
# Processing Record 21 of Set 8 | cobija
# Processing Record 22 of Set 8 | elizabeth city
# Processing Record 23 of Set 8 | singapore
# Processing Record 24 of Set 8 | buala
# Processing Record 25 of Set 8 | the valley
# Processing Record 26 of Set 8 | pushkino
# Processing Record 27 of Set 8 | hay river
# Processing Record 28 of Set 8 | bundaberg
# Processing Record 29 of Set 8 | gunjur
# Processing Record 30 of Set 8 | solnechnyy
# Processing Record 31 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 8 | usakos
# Processing Record 33 of Set 8 | riyadh
# Processing Record 34 of Set 8 | khilok
# Processing Record 35 of Set 8 | dafeng
# Processing Record 36 of Set 8 | souillac
# Processing Record 37 of Set 8 | masvingo
# Processing Record 38 of Set 8 | coahuayana
# Processing Record 39 of Set 8 | huarmey
# Processing Record 40 of Set 8 | cabo san lucas
# Processing Record 41 of Set 8 | ulaangom
# Processing Record 42 of Set 8 | nome
# Processing Record 43 of Set 8 | maragogi
# Processing Record 44 of Set 8 | santa maria
# Processing Record 45 of Set 8 | donskoye
# Processing Record 46 of Set 8 | salinas
# Processing Record 47 of Set 8 | bystrzyca klodzka
# Processing Record 48 of Set 8 | guymon
# Processing Record 49 of Set 8 | acoyapa
# Processing Record 50 of Set 8 | lompoc
# Processing Record 1 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 9 | muroto
# Processing Record 3 of Set 9 | malinovoye ozero
# Processing Record 4 of Set 9 | annamalainagar
# Processing Record 5 of Set 9 | libreville
# Processing Record 6 of Set 9 | jatai
# Processing Record 7 of Set 9 | kalmar
# Processing Record 8 of Set 9 | coquimbo
# Processing Record 9 of Set 9 | mokhsogollokh
# Processing Record 10 of Set 9 | mollendo
# Processing Record 11 of Set 9 | tocopilla
# Processing Record 12 of Set 9 | goundam
# Processing Record 13 of Set 9 | wanaka
# Processing Record 14 of Set 9 | sena madureira
# Processing Record 15 of Set 9 | santo antonio do ica
# Processing Record 16 of Set 9 | amapa
# Processing Record 17 of Set 9 | coolum beach
# Processing Record 18 of Set 9 | coihaique
# Processing Record 19 of Set 9 | waitara
# Processing Record 20 of Set 9 | saleilua
# City not found. Skipping...
# Processing Record 21 of Set 9 | haines junction
# Processing Record 22 of Set 9 | pangnirtung
# Processing Record 23 of Set 9 | broome
# Processing Record 24 of Set 9 | kedrovyy
# Processing Record 25 of Set 9 | portland
# Processing Record 26 of Set 9 | hofn
# Processing Record 27 of Set 9 | foam lake
# Processing Record 28 of Set 9 | dzheguta
# Processing Record 29 of Set 9 | wuda
# Processing Record 30 of Set 9 | acarau
# Processing Record 31 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 9 | bengkulu
# Processing Record 33 of Set 9 | ahome
# Processing Record 34 of Set 9 | komsomolskiy
# Processing Record 35 of Set 9 | alta floresta
# Processing Record 36 of Set 9 | khandbari
# Processing Record 37 of Set 9 | saint combs
# City not found. Skipping...
# Processing Record 38 of Set 9 | methoni
# Processing Record 39 of Set 9 | acari
# Processing Record 40 of Set 9 | ponta delgada
# Processing Record 41 of Set 9 | san ramon
# Processing Record 42 of Set 9 | sambava
# Processing Record 43 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 44 of Set 9 | darhan
# Processing Record 45 of Set 9 | aitape
# Processing Record 46 of Set 9 | portel
# Processing Record 47 of Set 9 | bartica
# Processing Record 48 of Set 9 | dnestrovsc
# Processing Record 49 of Set 9 | cuamba
# Processing Record 50 of Set 9 | tiznit
# Processing Record 1 of Set 10 | wad madani
# Processing Record 2 of Set 10 | loiza
# Processing Record 3 of Set 10 | eureka
# Processing Record 4 of Set 10 | sungaipenuh
# Processing Record 5 of Set 10 | belaya gora
# Processing Record 6 of Set 10 | zhaoyang
# Processing Record 7 of Set 10 | champerico
# Processing Record 8 of Set 10 | axim
# Processing Record 9 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 10 | la rioja
# Processing Record 11 of Set 10 | puerto quijarro
# Processing Record 12 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 10 | bardsir
# Processing Record 14 of Set 10 | ponferrada
# Processing Record 15 of Set 10 | ulladulla
# Processing Record 16 of Set 10 | tianpeng
# Processing Record 17 of Set 10 | port washington
# Processing Record 18 of Set 10 | farrukhnagar
# Processing Record 19 of Set 10 | ust-ishim
# Processing Record 20 of Set 10 | date
# Processing Record 21 of Set 10 | nola
# Processing Record 22 of Set 10 | bogotol
# Processing Record 23 of Set 10 | nongan
# Processing Record 24 of Set 10 | svetlyy
# Processing Record 25 of Set 10 | troitsko-pechorsk
# Processing Record 26 of Set 10 | sao filipe
# Processing Record 27 of Set 10 | bonthe
# Processing Record 28 of Set 10 | altay
# Processing Record 29 of Set 10 | muros
# Processing Record 30 of Set 10 | waipawa
# Processing Record 31 of Set 10 | huainan
# Processing Record 32 of Set 10 | lazaro cardenas
# Processing Record 33 of Set 10 | wakkanai
# Processing Record 34 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 35 of Set 10 | laguna de duero
# Processing Record 36 of Set 10 | ornskoldsvik
# Processing Record 37 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 10 | urozhayne
# City not found. Skipping...
# Processing Record 39 of Set 10 | talcahuano
# Processing Record 40 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 10 | newport
# Processing Record 42 of Set 10 | qui nhon
# Processing Record 43 of Set 10 | salinopolis
# Processing Record 44 of Set 10 | seoul
# Processing Record 45 of Set 10 | les cayes
# Processing Record 46 of Set 10 | nouadhibou
# Processing Record 47 of Set 10 | innisfail
# Processing Record 48 of Set 10 | mossendjo
# Processing Record 49 of Set 10 | norden
# Processing Record 50 of Set 10 | umm jarr
# City not found. Skipping...
# Processing Record 1 of Set 11 | north bay
# Processing Record 2 of Set 11 | comodoro rivadavia
# Processing Record 3 of Set 11 | kandi
# Processing Record 4 of Set 11 | bure
# Processing Record 5 of Set 11 | taltal
# Processing Record 6 of Set 11 | akhmim
# Processing Record 7 of Set 11 | san patricio
# Processing Record 8 of Set 11 | collie
# Processing Record 9 of Set 11 | dubai
# Processing Record 10 of Set 11 | dakar
# Processing Record 11 of Set 11 | genhe
# Processing Record 12 of Set 11 | jardim
# Processing Record 13 of Set 11 | evensk
# Processing Record 14 of Set 11 | tura
# Processing Record 15 of Set 11 | moree
# Processing Record 16 of Set 11 | carauari
# Processing Record 17 of Set 11 | dekoa
# City not found. Skipping...
# Processing Record 18 of Set 11 | kirensk
# Processing Record 19 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 20 of Set 11 | nitra
# Processing Record 21 of Set 11 | ayer itam
# City not found. Skipping...
# Processing Record 22 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 11 | wuwei
# Processing Record 24 of Set 11 | bathsheba
# Processing Record 25 of Set 11 | brightwater
# Processing Record 26 of Set 11 | tempoal
# City not found. Skipping...
# Processing Record 27 of Set 11 | zabaykalsk
# Processing Record 28 of Set 11 | yashkul
# Processing Record 29 of Set 11 | oriximina
# Processing Record 30 of Set 11 | qaqortoq
# Processing Record 31 of Set 11 | port hardy
# Processing Record 32 of Set 11 | betera
# Processing Record 33 of Set 11 | nicoya
# Processing Record 34 of Set 11 | bontang
# Processing Record 35 of Set 11 | okhotsk
# Processing Record 36 of Set 11 | vila franca do campo
# Processing Record 37 of Set 11 | boa vista
# Processing Record 38 of Set 11 | ballina
# Processing Record 39 of Set 11 | miram shah
# Processing Record 40 of Set 11 | lensk
# Processing Record 41 of Set 11 | pisco
# Processing Record 42 of Set 11 | talesh
# City not found. Skipping...
# Processing Record 43 of Set 11 | altamont
# Processing Record 44 of Set 11 | saint-joseph
# Processing Record 45 of Set 11 | cockburn town
# Processing Record 46 of Set 11 | sompeta
# Processing Record 47 of Set 11 | shizunai
# Processing Record 48 of Set 11 | tukrah
# Processing Record 49 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 50 of Set 11 | lavrentiya
# Processing Record 1 of Set 12 | skjervoy
# Processing Record 2 of Set 12 | boueni
# Processing Record 3 of Set 12 | ovre ardal
# Processing Record 4 of Set 12 | mana
# Processing Record 5 of Set 12 | san juan
# Processing Record 6 of Set 12 | la asuncion
# Processing Record 7 of Set 12 | lomovka
# Processing Record 8 of Set 12 | kassala
# Processing Record 9 of Set 12 | orcopampa
# Processing Record 10 of Set 12 | garissa
# Processing Record 11 of Set 12 | camopi
# Processing Record 12 of Set 12 | mount gambier
# Processing Record 13 of Set 12 | beira
# Processing Record 14 of Set 12 | stornoway
# Processing Record 15 of Set 12 | manyana
# Processing Record 16 of Set 12 | cloquet
# Processing Record 17 of Set 12 | klaksvik
# Processing Record 18 of Set 12 | sungurlu
# Processing Record 19 of Set 12 | maniitsoq
# Processing Record 20 of Set 12 | sindi
# Processing Record 21 of Set 12 | gimbi
# Processing Record 22 of Set 12 | kabanjahe
# Processing Record 23 of Set 12 | agboville
# Processing Record 24 of Set 12 | bosobolo
# Processing Record 25 of Set 12 | dekernes
# Processing Record 26 of Set 12 | luis correia
# Processing Record 27 of Set 12 | omboue
# Processing Record 28 of Set 12 | muravlenko
# Processing Record 29 of Set 12 | rio verde de mato grosso
# Processing Record 30 of Set 12 | plettenberg bay
# Processing Record 31 of Set 12 | basco
# Processing Record 32 of Set 12 | tabou
# Processing Record 33 of Set 12 | alofi
# Processing Record 34 of Set 12 | presidente franco
# Processing Record 35 of Set 12 | mayumba
# Processing Record 36 of Set 12 | ofaqim
# Processing Record 37 of Set 12 | dzaoudzi
# Processing Record 38 of Set 12 | sattahip
# Processing Record 39 of Set 12 | moron
# Processing Record 40 of Set 12 | leningradskiy
# Processing Record 41 of Set 12 | potenza
# Processing Record 42 of Set 12 | svetlaya
# Processing Record 43 of Set 12 | antofagasta
# Processing Record 44 of Set 12 | savannah bight
# Processing Record 45 of Set 12 | havre-saint-pierre
# Processing Record 46 of Set 12 | dalvik
# Processing Record 47 of Set 12 | hambantota
# Processing Record 48 of Set 12 | sumbe
# Processing Record 49 of Set 12 | ouro preto do oeste
# Processing Record 50 of Set 12 | sangar
# Processing Record 1 of Set 13 | shimoda
# Processing Record 2 of Set 13 | kaspiyskiy
# Processing Record 3 of Set 13 | vallenar
# Processing Record 4 of Set 13 | falam
# Processing Record 5 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 6 of Set 13 | bagdarin
# Processing Record 7 of Set 13 | lodja
# Processing Record 8 of Set 13 | tocache
# Processing Record 9 of Set 13 | flinders
# Processing Record 10 of Set 13 | padang
# Processing Record 11 of Set 13 | nioro
# Processing Record 12 of Set 13 | shu
# Processing Record 13 of Set 13 | sirsi
# Processing Record 14 of Set 13 | yar-sale
# Processing Record 15 of Set 13 | kadyy
# Processing Record 16 of Set 13 | nelson bay
# Processing Record 17 of Set 13 | yarada
# Processing Record 18 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 13 | jabinyanah
# Processing Record 20 of Set 13 | jinchang
# Processing Record 21 of Set 13 | jacareacanga
# Processing Record 22 of Set 13 | grand-santi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Amay',
#   'Lat': 50.5483,
#   'Lng': 5.3097,
#   'Max Temp': 56.21,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'BE',
#   'Date': '2021-12-31 11:39:12'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -23.26,
#   'Humidity': 100,
#   'Cloudiness': 91,
#   'Wind Speed': 2.08,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:37:01'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 59.81,
#   'Humidity': 82,
#   'Cloudiness': 85,
#   'Wind Speed': 21.68,
#   'Country': 'NZ',
#   'Date': '2021-12-31 11:39:13'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 34.2,
#   'Humidity': 40,
#   'Cloudiness': 43,
#   'Wind Speed': 25.88,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:39:14'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 78.55,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'ES',
#   'Date': '2021-12-31 11:39:14'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 59.49,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 6.6,
#   'Country': 'NZ',
#   'Date': '2021-12-31 11:39:15'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 64.04,
#   'Humidity': 66,
#   'Cloudiness': 2,
#   'Wind Speed': 20.24,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:39:15'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 74.68,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 12.73,
#   'Country': 'PH',
#   'Date': '2021-12-31 11:39:16'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 70.05,
#   'Humidity': 62,
#   'Cloudiness': 81,
#   'Wind Speed': 5.06,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:39:17'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 61.29,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.39,
#   'Country': 'TL',
#   'Date': '2021-12-31 11:39:18'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': -35.45,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 10.74,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:39:18'},
#  {'City': 'Grajau',
#   'Lat': -5.8194,
#   'Lng': -46.1386,
#   'Max Temp': 75.6,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 7.05,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:39:19'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.11,
#   'Humidity': 70,
#   'Cloudiness': 2,
#   'Wind Speed': 7.78,
#   'Country': 'MV',
#   'Date': '2021-12-31 11:39:20'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.52,
#   'Humidity': 74,
#   'Cloudiness': 63,
#   'Wind Speed': 12.37,
#   'Country': 'PF',
#   'Date': '2021-12-31 11:39:20'},
#  {'City': 'Dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 73.49,
#   'Humidity': 49,
#   'Cloudiness': 3,
#   'Wind Speed': 18.34,
#   'Country': 'IN',
#   'Date': '2021-12-31 11:39:21'},
#  {'City': 'Opuwo',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 92.52,
#   'Humidity': 21,
#   'Cloudiness': 19,
#   'Wind Speed': 9.82,
#   'Country': 'NA',
#   'Date': '2021-12-31 11:39:22'},
#  {'City': 'Vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': -31.36,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 5.28,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:39:22'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 78.75,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 10,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:39:23'},
#  {'City': 'Villamontes',
#   'Lat': -21.25,
#   'Lng': -63.5,
#   'Max Temp': 78.24,
#   'Humidity': 83,
#   'Cloudiness': 52,
#   'Wind Speed': 0,
#   'Country': 'BO',
#   'Date': '2021-12-31 11:39:23'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 88.39,
#   'Humidity': 45,
#   'Cloudiness': 70,
#   'Wind Speed': 14.97,
#   'Country': 'MG',
#   'Date': '2021-12-31 11:39:24'},
#  {'City': 'Cururupu',
#   'Lat': -1.8283,
#   'Lng': -44.8683,
#   'Max Temp': 79.66,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 6.26,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:39:24'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 77.05,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'CK',
#   'Date': '2021-12-31 11:39:25'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 22.48,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:39:26'},
#  {'City': 'Northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 59.02,
#   'Humidity': 93,
#   'Cloudiness': 77,
#   'Wind Speed': 17.94,
#   'Country': 'GB',
#   'Date': '2021-12-31 11:39:28'},
#  {'City': 'Forest',
#   'Lat': 37.3638,
#   'Lng': -79.2897,
#   'Max Temp': 55.45,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-12-31 11:37:13'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 81.1,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:36:20'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.17,
#   'Humidity': 68,
#   'Cloudiness': 12,
#   'Wind Speed': 19.62,
#   'Country': 'PF',
#   'Date': '2021-12-31 11:39:29'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 82.65,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MU',
#   'Date': '2021-12-31 11:39:30'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 80.69,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'OM',
#   'Date': '2021-12-31 11:35:02'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 77.76,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 6.4,
#   'Country': 'UY',
#   'Date': '2021-12-31 11:39:31'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 82.24,
#   'Humidity': 26,
#   'Cloudiness': 51,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:39:32'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 71.73,
#   'Humidity': 70,
#   'Cloudiness': 71,
#   'Wind Speed': 21.56,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:39:32'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 80.13,
#   'Humidity': 77,
#   'Cloudiness': 67,
#   'Wind Speed': 14.94,
#   'Country': 'PF',
#   'Date': '2021-12-31 11:39:33'},
#  {'City': 'Kawalu',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 75.81,
#   'Humidity': 90,
#   'Cloudiness': 92,
#   'Wind Speed': 1.74,
#   'Country': 'ID',
#   'Date': '2021-12-31 11:39:33'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.18,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Date': '2021-12-31 11:39:34'},
#  {'City': 'Santa Vitoria Do Palmar',
#   'Lat': -33.5189,
#   'Lng': -53.3681,
#   'Max Temp': 77.81,
#   'Humidity': 66,
#   'Cloudiness': 72,
#   'Wind Speed': 4.81,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:39:35'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 49.66,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'AR',
#   'Date': '2021-12-31 11:39:35'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -21.69,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:39:36'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 50.02,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'CL',
#   'Date': '2021-12-31 11:39:36'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 62.46,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:39:37'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 68.77,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 11.18,
#   'Country': 'IL',
#   'Date': '2021-12-31 11:39:37'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': -15.57,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.49,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:39:38'},
#  {'City': 'Amnat Charoen',
#   'Lat': 15.9167,
#   'Lng': 104.75,
#   'Max Temp': 69.21,
#   'Humidity': 71,
#   'Cloudiness': 47,
#   'Wind Speed': 17.96,
#   'Country': 'TH',
#   'Date': '2021-12-31 11:39:38'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 82.69,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MU',
#   'Date': '2021-12-31 11:39:39'},
#  {'City': 'Barentu',
#   'Lat': 15.1139,
#   'Lng': 37.5928,
#   'Max Temp': 83.89,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 8.68,
#   'Country': 'ER',
#   'Date': '2021-12-31 11:40:39'},
#  {'City': 'Sorong',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 80.91,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Country': 'ID',
#   'Date': '2021-12-31 11:40:40'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 65.88,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 8.99,
#   'Country': 'AR',
#   'Date': '2021-12-31 11:37:52'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 23.2,
#   'Humidity': 51,
#   'Cloudiness': 97,
#   'Wind Speed': 16.22,
#   'Country': 'NO',
#   'Date': '2021-12-31 11:40:41'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 45.07,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2021-12-31 11:40:42'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 84.13,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 7,
#   'Country': 'MY',
#   'Date': '2021-12-31 11:40:42'},
#  {'City': 'Harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 83.55,
#   'Humidity': 73,
#   'Cloudiness': 66,
#   'Wind Speed': 9.19,
#   'Country': 'LR',
#   'Date': '2021-12-31 11:40:43'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 62.1,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 1.41,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:40:43'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 84.29,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'RE',
#   'Date': '2021-12-31 11:40:44'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 48.79,
#   'Humidity': 97,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-12-31 11:40:45'},
#  {'City': 'Abha',
#   'Lat': 18.2164,
#   'Lng': 42.5053,
#   'Max Temp': 60.62,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'SA',
#   'Date': '2021-12-31 11:40:46'},
#  {'City': 'Jalu',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 64.17,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 20.6,
#   'Country': 'LY',
#   'Date': '2021-12-31 11:40:47'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 81.9,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 9.78,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:40:47'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 77.07,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 24.16,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:40:48'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.28,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 10.04,
#   'Country': 'PG',
#   'Date': '2021-12-31 11:40:48'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 68.65,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Country': 'PH',
#   'Date': '2021-12-31 11:40:49'},
#  {'City': 'Bafq',
#   'Lat': 31.6128,
#   'Lng': 55.4107,
#   'Max Temp': 56.21,
#   'Humidity': 53,
#   'Cloudiness': 25,
#   'Wind Speed': 8.25,
#   'Country': 'IR',
#   'Date': '2021-12-31 11:40:49'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 65.25,
#   'Humidity': 78,
#   'Cloudiness': 7,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Date': '2021-12-31 11:40:03'},
#  {'City': 'Boali',
#   'Lat': 4.8005,
#   'Lng': 18.1275,
#   'Max Temp': 89.47,
#   'Humidity': 14,
#   'Cloudiness': 94,
#   'Wind Speed': 5.3,
#   'Country': 'CF',
#   'Date': '2021-12-31 11:40:51'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 72.36,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'PT',
#   'Date': '2021-12-31 11:40:52'},
#  {'City': 'Bacolod',
#   'Lat': 10.6667,
#   'Lng': 122.95,
#   'Max Temp': 76.64,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 17.72,
#   'Country': 'PH',
#   'Date': '2021-12-31 11:40:52'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 80.28,
#   'Humidity': 78,
#   'Cloudiness': 80,
#   'Wind Speed': 16.13,
#   'Country': 'PF',
#   'Date': '2021-12-31 11:40:53'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 61.5,
#   'Humidity': 81,
#   'Cloudiness': 13,
#   'Wind Speed': 9.51,
#   'Country': 'NZ',
#   'Date': '2021-12-31 11:40:53'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': -1.86,
#   'Humidity': 97,
#   'Cloudiness': 27,
#   'Wind Speed': 3.58,
#   'Country': 'US',
#   'Date': '2021-12-31 11:40:54'},
#  {'City': 'Turayf',
#   'Lat': 31.6725,
#   'Lng': 38.6637,
#   'Max Temp': 53.85,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'SA',
#   'Date': '2021-12-31 11:40:54'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 76.32,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:40:55'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -2.74,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 8.43,
#   'Country': 'GL',
#   'Date': '2021-12-31 11:40:55'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -9.51,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.95,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:40:56'},
#  {'City': 'Mitu',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 73.18,
#   'Humidity': 97,
#   'Cloudiness': 85,
#   'Wind Speed': 0.72,
#   'Country': 'CO',
#   'Date': '2021-12-31 11:40:57'},
#  {'City': 'Kenora',
#   'Lat': 49.8167,
#   'Lng': -94.4337,
#   'Max Temp': -12.03,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:40:57'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 59.83,
#   'Humidity': 87,
#   'Cloudiness': 83,
#   'Wind Speed': 3.76,
#   'Country': 'NZ',
#   'Date': '2021-12-31 11:40:58'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 82.11,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:40:41'},
#  {'City': 'Shawnee',
#   'Lat': 39.05,
#   'Lng': -95.7669,
#   'Max Temp': 39.99,
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-12-31 11:40:59'},
#  {'City': 'Galle',
#   'Lat': 6.0367,
#   'Lng': 80.217,
#   'Max Temp': 81.21,
#   'Humidity': 75,
#   'Cloudiness': 82,
#   'Wind Speed': 2.04,
#   'Country': 'LK',
#   'Date': '2021-12-31 11:40:59'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -34.13,
#   'Humidity': 95,
#   'Cloudiness': 15,
#   'Wind Speed': 10.85,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:36:56'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 33.69,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-12-31 11:41:00'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 32.13,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 17.54,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:38:20'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 44.29,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-12-31 11:41:01'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': -6.68,
#   'Humidity': 82,
#   'Cloudiness': 43,
#   'Wind Speed': 12.37,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:39:01'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 61.57,
#   'Humidity': 91,
#   'Cloudiness': 89,
#   'Wind Speed': 5.46,
#   'Country': 'MX',
#   'Date': '2021-12-31 11:41:02'},
#  {'City': 'Sao Luiz Gonzaga',
#   'Lat': -28.4083,
#   'Lng': -54.9608,
#   'Max Temp': 81.34,
#   'Humidity': 51,
#   'Cloudiness': 12,
#   'Wind Speed': 7.14,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:41:03'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 23.76,
#   'Humidity': 56,
#   'Cloudiness': 87,
#   'Wind Speed': 7.31,
#   'Country': 'NO',
#   'Date': '2021-12-31 11:41:03'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 70.74,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:41:05'},
#  {'City': 'Brcko',
#   'Lat': 44.8728,
#   'Lng': 18.8083,
#   'Max Temp': 58.14,
#   'Humidity': 59,
#   'Cloudiness': 14,
#   'Wind Speed': 2.75,
#   'Country': 'BA',
#   'Date': '2021-12-31 11:41:06'},
#  {'City': 'Mzimba',
#   'Lat': -11.9,
#   'Lng': 33.6,
#   'Max Temp': 84.97,
#   'Humidity': 36,
#   'Cloudiness': 99,
#   'Wind Speed': 12.35,
#   'Country': 'MW',
#   'Date': '2021-12-31 11:41:06'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 84.22,
#   'Humidity': 76,
#   'Cloudiness': 59,
#   'Wind Speed': 11.21,
#   'Country': 'RE',
#   'Date': '2021-12-31 11:42:07'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -35.3,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.15,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:38:26'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': -5.26,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 11.88,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:42:08'},
#  {'City': 'Moose Factory',
#   'Lat': 51.2585,
#   'Lng': -80.6094,
#   'Max Temp': 12.2,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:42:08'},
#  {'City': 'San Francisco',
#   'Lat': 37.7749,
#   'Lng': -122.4194,
#   'Max Temp': 46.98,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-12-31 11:40:58'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 80.15,
#   'Humidity': 68,
#   'Cloudiness': 23,
#   'Wind Speed': 15.01,
#   'Country': 'SO',
#   'Date': '2021-12-31 11:42:10'},
#  {'City': 'Winnemucca',
#   'Lat': 40.973,
#   'Lng': -117.7357,
#   'Max Temp': 28.45,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-12-31 11:42:10'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 76.86,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:42:11'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 42.8,
#   'Humidity': 95,
#   'Cloudiness': 85,
#   'Wind Speed': 2.13,
#   'Country': 'US',
#   'Date': '2021-12-31 11:42:11'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 68.54,
#   'Humidity': 90,
#   'Cloudiness': 36,
#   'Wind Speed': 7.94,
#   'Country': 'EC',
#   'Date': '2021-12-31 11:42:12'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 80.4,
#   'Humidity': 56,
#   'Cloudiness': 36,
#   'Wind Speed': 4.94,
#   'Country': 'UY',
#   'Date': '2021-12-31 11:40:19'},
#  {'City': 'Half Moon Bay',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 46.18,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-12-31 11:42:13'},
#  {'City': 'Gwanda',
#   'Lat': -20.9333,
#   'Lng': 29,
#   'Max Temp': 93.94,
#   'Humidity': 28,
#   'Cloudiness': 69,
#   'Wind Speed': 5.19,
#   'Country': 'ZW',
#   'Date': '2021-12-31 11:42:14'},
#  {'City': 'Bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 27.12,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 12.64,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:42:15'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -3.77,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:42:15'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 13.73,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:42:16'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 19.87,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-12-31 11:42:17'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 67.5,
#   'Humidity': 79,
#   'Cloudiness': 92,
#   'Wind Speed': 4.5,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:42:17'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 83.3,
#   'Humidity': 66,
#   'Cloudiness': 80,
#   'Wind Speed': 12.01,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:42:18'},
#  {'City': 'Pitimbu',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 82.99,
#   'Humidity': 64,
#   'Cloudiness': 74,
#   'Wind Speed': 10.85,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:42:18'},
#  {'City': 'Kizukuri',
#   'Lat': 40.8061,
#   'Lng': 140.3861,
#   'Max Temp': 20.95,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 22.64,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:42:19'},
#  {'City': 'Hitoyoshi',
#   'Lat': 32.2167,
#   'Lng': 130.75,
#   'Max Temp': 35.42,
#   'Humidity': 76,
#   'Cloudiness': 28,
#   'Wind Speed': 3.15,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:42:19'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 80.78,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 21.41,
#   'Country': 'NC',
#   'Date': '2021-12-31 11:42:20'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 75.85,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-12-31 11:42:20'},
#  {'City': 'Warri',
#   'Lat': 5.5167,
#   'Lng': 5.75,
#   'Max Temp': 101.1,
#   'Humidity': 26,
#   'Cloudiness': 30,
#   'Wind Speed': 1.74,
#   'Country': 'NG',
#   'Date': '2021-12-31 11:42:21'},
#  {'City': 'Teahupoo',
#   'Lat': -17.8333,
#   'Lng': -149.2667,
#   'Max Temp': 75.16,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 17.54,
#   'Country': 'PF',
#   'Date': '2021-12-31 11:42:22'},
#  {'City': 'Weligama',
#   'Lat': 5.9667,
#   'Lng': 80.4167,
#   'Max Temp': 80.74,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 7.25,
#   'Country': 'LK',
#   'Date': '2021-12-31 11:42:22'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 80.42,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'PG',
#   'Date': '2021-12-31 11:42:23'},
#  {'City': 'Koslan',
#   'Lat': 63.4564,
#   'Lng': 48.8989,
#   'Max Temp': 9.99,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.25,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:42:23'},
#  {'City': 'Great Falls',
#   'Lat': 47.5002,
#   'Lng': -111.3008,
#   'Max Temp': 0.55,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2021-12-31 11:40:05'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 76.86,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 8.66,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:42:24'},
#  {'City': 'Wichita Falls',
#   'Lat': 33.9137,
#   'Lng': -98.4934,
#   'Max Temp': 57.34,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2021-12-31 11:42:25'},
#  {'City': 'Bethlehem',
#   'Lat': -1.4558,
#   'Lng': -48.5044,
#   'Max Temp': 77.04,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:42:25'},
#  {'City': 'Udachnyy',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': -31.56,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.15,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:42:26'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -30.17,
#   'Humidity': 100,
#   'Cloudiness': 95,
#   'Wind Speed': 2.86,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:42:26'},
#  {'City': 'San Pedro',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 79.83,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'PH',
#   'Date': '2021-12-31 11:42:27'},
#  {'City': 'Abadan',
#   'Lat': 30.3392,
#   'Lng': 48.3043,
#   'Max Temp': 62.55,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'IR',
#   'Date': '2021-12-31 11:42:27'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 80.42,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Country': 'PG',
#   'Date': '2021-12-31 11:42:28'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -24.41,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:42:28'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 80.82,
#   'Humidity': 82,
#   'Cloudiness': 86,
#   'Wind Speed': 7.65,
#   'Country': 'ID',
#   'Date': '2021-12-31 11:42:29'},
#  {'City': 'Paka',
#   'Lat': 4.6374,
#   'Lng': 103.4368,
#   'Max Temp': 76.98,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'MY',
#   'Date': '2021-12-31 11:42:30'},
#  {'City': 'Sevenoaks',
#   'Lat': 51.27,
#   'Lng': 0.1928,
#   'Max Temp': 56.55,
#   'Humidity': 95,
#   'Cloudiness': 40,
#   'Wind Speed': 5.01,
#   'Country': 'GB',
#   'Date': '2021-12-31 11:42:31'},
#  {'City': 'Ewa Beach',
#   'Lat': 21.3156,
#   'Lng': -158.0072,
#   'Max Temp': 74.43,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-12-31 11:42:32'},
#  {'City': 'High Level',
#   'Lat': 58.5169,
#   'Lng': -117.136,
#   'Max Temp': -25.49,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:42:32'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 76.42,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 20.49,
#   'Country': 'NC',
#   'Date': '2021-12-31 11:42:33'},
#  {'City': 'Noumea',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 80.01,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 14.32,
#   'Country': 'NC',
#   'Date': '2021-12-31 11:41:55'},
#  {'City': 'Lixourion',
#   'Lat': 38.2019,
#   'Lng': 20.4314,
#   'Max Temp': 66.2,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'GR',
#   'Date': '2021-12-31 11:43:34'},
#  {'City': 'Bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 79.02,
#   'Humidity': 74,
#   'Cloudiness': 26,
#   'Wind Speed': 5.97,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:43:35'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 82.51,
#   'Humidity': 60,
#   'Cloudiness': 19,
#   'Wind Speed': 12.26,
#   'Country': 'MU',
#   'Date': '2021-12-31 11:43:36'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 47.1,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-12-31 11:43:36'},
#  {'City': 'Shkoder',
#   'Lat': 42.0683,
#   'Lng': 19.5126,
#   'Max Temp': 59.18,
#   'Humidity': 59,
#   'Cloudiness': 34,
#   'Wind Speed': 4,
#   'Country': 'AL',
#   'Date': '2021-12-31 11:41:01'},
#  {'City': 'Cleethorpes',
#   'Lat': 53.5605,
#   'Lng': -0.0323,
#   'Max Temp': 59.99,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 21.85,
#   'Country': 'GB',
#   'Date': '2021-12-31 11:43:33'},
#  {'City': 'Alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 84.07,
#   'Humidity': 89,
#   'Cloudiness': 77,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:43:38'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77.16,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Country': 'TO',
#   'Date': '2021-12-31 11:43:39'},
#  {'City': 'Pandan',
#   'Lat': 14.0453,
#   'Lng': 124.1694,
#   'Max Temp': 77.54,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 19.73,
#   'Country': 'PH',
#   'Date': '2021-12-31 11:43:39'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 77.05,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 14.63,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:43:40'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 54.23,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 15.82,
#   'Country': 'CL',
#   'Date': '2021-12-31 11:43:41'},
#  {'City': 'Gold Coast',
#   'Lat': -28,
#   'Lng': 153.4333,
#   'Max Temp': 75.27,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 8.99,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:43:41'},
#  {'City': 'Nova Olimpia',
#   'Lat': -14.7972,
#   'Lng': -57.2881,
#   'Max Temp': 77.99,
#   'Humidity': 87,
#   'Cloudiness': 89,
#   'Wind Speed': 3.8,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:43:42'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -25.08,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:43:42'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 34.39,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 20.13,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:43:14'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 71.26,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-12-31 11:42:15'},
#  {'City': 'Sicamous',
#   'Lat': 50.8331,
#   'Lng': -118.9856,
#   'Max Temp': 7.11,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 3.04,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:43:44'},
#  {'City': 'Gaozhou',
#   'Lat': 21.9392,
#   'Lng': 110.8461,
#   'Max Temp': 65.12,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 5.23,
#   'Country': 'CN',
#   'Date': '2021-12-31 11:43:45'},
#  {'City': 'Puerto Rico',
#   'Lat': -26.796,
#   'Lng': -55.024,
#   'Max Temp': 79.14,
#   'Humidity': 63,
#   'Cloudiness': 23,
#   'Wind Speed': 3.49,
#   'Country': 'AR',
#   'Date': '2021-12-31 11:43:45'},
#  {'City': 'San Lawrenz',
#   'Lat': 36.0553,
#   'Lng': 14.204,
#   'Max Temp': 63.81,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 5.23,
#   'Country': 'MT',
#   'Date': '2021-12-31 11:43:46'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.55,
#   'Humidity': 80,
#   'Cloudiness': 83,
#   'Wind Speed': 9.08,
#   'Country': 'KI',
#   'Date': '2021-12-31 11:43:46'},
#  {'City': 'Bajil',
#   'Lat': 15.0584,
#   'Lng': 43.2851,
#   'Max Temp': 88.02,
#   'Humidity': 43,
#   'Cloudiness': 89,
#   'Wind Speed': 10.69,
#   'Country': 'YE',
#   'Date': '2021-12-31 11:43:47'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 77.88,
#   'Humidity': 48,
#   'Cloudiness': 13,
#   'Wind Speed': 19.77,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:43:47'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 62.87,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:43:48'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 35.71,
#   'Humidity': 44,
#   'Cloudiness': 73,
#   'Wind Speed': 16.91,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:43:49'},
#  {'City': 'Risor',
#   'Lat': 58.7206,
#   'Lng': 9.2342,
#   'Max Temp': 36.16,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 9.89,
#   'Country': 'NO',
#   'Date': '2021-12-31 11:41:58'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 61.32,
#   'Humidity': 84,
#   'Cloudiness': 27,
#   'Wind Speed': 4.25,
#   'Country': 'NZ',
#   'Date': '2021-12-31 11:43:50'},
#  {'City': 'Kailua',
#   'Lat': 21.4022,
#   'Lng': -157.7394,
#   'Max Temp': 73.49,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-12-31 11:43:50'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 55.94,
#   'Humidity': 55,
#   'Cloudiness': 93,
#   'Wind Speed': 15.05,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:43:51'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 19.42,
#   'Humidity': 27,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'GL',
#   'Date': '2021-12-31 11:43:51'},
#  {'City': 'Along',
#   'Lat': 28.1667,
#   'Lng': 94.7667,
#   'Max Temp': 57.4,
#   'Humidity': 73,
#   'Cloudiness': 18,
#   'Wind Speed': 2.13,
#   'Country': 'IN',
#   'Date': '2021-12-31 11:43:52'},
#  {'City': 'Nishihara',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 60.08,
#   'Humidity': 63,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:43:52'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 26.58,
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:43:53'},
#  {'City': 'Makat',
#   'Lat': 47.6469,
#   'Lng': 53.3463,
#   'Max Temp': 30.22,
#   'Humidity': 91,
#   'Cloudiness': 88,
#   'Wind Speed': 6.08,
#   'Country': 'KZ',
#   'Date': '2021-12-31 11:43:53'},
#  {'City': 'Salekhard',
#   'Lat': 66.53,
#   'Lng': 66.6019,
#   'Max Temp': -10.19,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.91,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:43:54'},
#  {'City': 'Havoysund',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 26.83,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 20.8,
#   'Country': 'NO',
#   'Date': '2021-12-31 11:43:54'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 56.21,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 8.43,
#   'Country': 'CL',
#   'Date': '2021-12-31 11:43:55'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 67.23,
#   'Humidity': 83,
#   'Cloudiness': 26,
#   'Wind Speed': 2.73,
#   'Country': 'MX',
#   'Date': '2021-12-31 11:43:56'},
#  {'City': 'Atocha',
#   'Lat': -20.9333,
#   'Lng': -66.2333,
#   'Max Temp': 51.91,
#   'Humidity': 60,
#   'Cloudiness': 10,
#   'Wind Speed': 5.01,
#   'Country': 'BO',
#   'Date': '2021-12-31 11:43:56'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -32.35,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:43:57'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 81.27,
#   'Humidity': 75,
#   'Cloudiness': 42,
#   'Wind Speed': 11.3,
#   'Country': 'LK',
#   'Date': '2021-12-31 11:43:57'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 21.11,
#   'Humidity': 63,
#   'Cloudiness': 59,
#   'Wind Speed': 6.24,
#   'Country': 'GL',
#   'Date': '2021-12-31 11:43:58'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 79.36,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.55,
#   'Country': 'VU',
#   'Date': '2021-12-31 11:43:58'},
#  {'City': 'Carlsbad',
#   'Lat': 33.1581,
#   'Lng': -117.3506,
#   'Max Temp': 57.97,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-12-31 11:43:59'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 81.57,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 12.77,
#   'Country': 'ML',
#   'Date': '2021-12-31 11:43:59'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 68.31,
#   'Humidity': 28,
#   'Cloudiness': 9,
#   'Wind Speed': 16.84,
#   'Country': 'AR',
#   'Date': '2021-12-31 11:44:00'},
#  {'City': 'Alugan',
#   'Lat': 12.2188,
#   'Lng': 125.4808,
#   'Max Temp': 78.84,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 20.56,
#   'Country': 'PH',
#   'Date': '2021-12-31 11:44:00'},
#  {'City': 'Keokuk',
#   'Lat': 40.3973,
#   'Lng': -91.3849,
#   'Max Temp': 36.09,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-12-31 11:45:01'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 34.88,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.25,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:45:01'},
#  {'City': 'Atakpame',
#   'Lat': 7.5333,
#   'Lng': 1.1333,
#   'Max Temp': 93.4,
#   'Humidity': 29,
#   'Cloudiness': 15,
#   'Wind Speed': 4.7,
#   'Country': 'TG',
#   'Date': '2021-12-31 11:45:02'},
#  {'City': 'Chimoio',
#   'Lat': -19.1164,
#   'Lng': 33.4833,
#   'Max Temp': 85.95,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 8.99,
#   'Country': 'MZ',
#   'Date': '2021-12-31 11:45:03'},
#  {'City': 'Kapit',
#   'Lat': 2.0167,
#   'Lng': 112.9333,
#   'Max Temp': 76.71,
#   'Humidity': 94,
#   'Cloudiness': 94,
#   'Wind Speed': 1.74,
#   'Country': 'MY',
#   'Date': '2021-12-31 11:45:03'},
#  {'City': 'Cabot',
#   'Lat': 34.9745,
#   'Lng': -92.0165,
#   'Max Temp': 58.77,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-12-31 11:45:04'},
#  {'City': 'Kochki',
#   'Lat': 54.3358,
#   'Lng': 80.4806,
#   'Max Temp': 0.05,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:41:11'},
#  {'City': 'Alenquer',
#   'Lat': -1.9417,
#   'Lng': -54.7383,
#   'Max Temp': 77.34,
#   'Humidity': 87,
#   'Cloudiness': 93,
#   'Wind Speed': 2.48,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:45:05'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 21.47,
#   'Humidity': 56,
#   'Cloudiness': 2,
#   'Wind Speed': 2.73,
#   'Country': 'CN',
#   'Date': '2021-12-31 11:45:05'},
#  {'City': 'Kazachinskoye',
#   'Lat': 57.6953,
#   'Lng': 93.2761,
#   'Max Temp': 0.79,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.23,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:45:06'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 62.92,
#   'Humidity': 60,
#   'Cloudiness': 95,
#   'Wind Speed': 10.13,
#   'Country': 'NZ',
#   'Date': '2021-12-31 11:45:06'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 40.91,
#   'Humidity': 63,
#   'Cloudiness': 5,
#   'Wind Speed': 13.35,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:45:07'},
#  {'City': 'Mirnyy',
#   'Lat': 62.5353,
#   'Lng': 113.9611,
#   'Max Temp': -4.45,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:42:11'},
#  {'City': 'Karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 83.48,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 12.3,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:45:09'},
#  {'City': 'Concordia',
#   'Lat': -31.393,
#   'Lng': -58.0209,
#   'Max Temp': 89.58,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 3.76,
#   'Country': 'AR',
#   'Date': '2021-12-31 11:45:09'},
#  {'City': 'Algiers',
#   'Lat': 36.7525,
#   'Lng': 3.042,
#   'Max Temp': 58.82,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'DZ',
#   'Date': '2021-12-31 11:43:50'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 82.8,
#   'Humidity': 57,
#   'Cloudiness': 42,
#   'Wind Speed': 8.01,
#   'Country': 'MU',
#   'Date': '2021-12-31 11:45:10'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 17.58,
#   'Humidity': 94,
#   'Cloudiness': 91,
#   'Wind Speed': 3.47,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:45:11'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 46.31,
#   'Humidity': 88,
#   'Cloudiness': 87,
#   'Wind Speed': 17.02,
#   'Country': 'GB',
#   'Date': '2021-12-31 11:45:11'},
#  {'City': 'Yantarnyy',
#   'Lat': 54.8717,
#   'Lng': 19.9381,
#   'Max Temp': 44.46,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:45:12'},
#  {'City': 'Davila',
#   'Lat': 18.4726,
#   'Lng': 120.5763,
#   'Max Temp': 78.78,
#   'Humidity': 75,
#   'Cloudiness': 22,
#   'Wind Speed': 23.42,
#   'Country': 'PH',
#   'Date': '2021-12-31 11:45:12'},
#  {'City': 'Kumluca',
#   'Lat': 36.3703,
#   'Lng': 30.2869,
#   'Max Temp': 57.51,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 9.19,
#   'Country': 'TR',
#   'Date': '2021-12-31 11:45:13'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 69.98,
#   'Humidity': 93,
#   'Cloudiness': 95,
#   'Wind Speed': 9.19,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:45:13'},
#  {'City': 'Hastings',
#   'Lat': 50.8552,
#   'Lng': 0.5729,
#   'Max Temp': 56.98,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 20.71,
#   'Country': 'GB',
#   'Date': '2021-12-31 11:45:01'},
#  {'City': 'Ostrovskoye',
#   'Lat': 57.8057,
#   'Lng': 42.2433,
#   'Max Temp': 13.78,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 7.7,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:45:14'},
#  {'City': 'Floriano',
#   'Lat': -6.7669,
#   'Lng': -43.0225,
#   'Max Temp': 76.21,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 9.33,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:45:15'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 76.77,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 15.64,
#   'Country': 'MR',
#   'Date': '2021-12-31 11:45:15'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -9.67,
#   'Humidity': 68,
#   'Cloudiness': 97,
#   'Wind Speed': 7.07,
#   'Country': 'GL',
#   'Date': '2021-12-31 11:42:56'},
#  {'City': 'Dehloran',
#   'Lat': 32.6941,
#   'Lng': 47.2679,
#   'Max Temp': 59.68,
#   'Humidity': 56,
#   'Cloudiness': 99,
#   'Wind Speed': 4.54,
#   'Country': 'IR',
#   'Date': '2021-12-31 11:45:17'},
#  {'City': 'Dunmore',
#   'Lat': 41.4198,
#   'Lng': -75.6324,
#   'Max Temp': 48.56,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-12-31 11:45:17'},
#  {'City': 'Urzhum',
#   'Lat': 57.1141,
#   'Lng': 49.9996,
#   'Max Temp': 14.47,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 7.56,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:45:18'},
#  {'City': 'Nehe',
#   'Lat': 48.4833,
#   'Lng': 124.8333,
#   'Max Temp': -20.7,
#   'Humidity': 95,
#   'Cloudiness': 7,
#   'Wind Speed': 3.13,
#   'Country': 'CN',
#   'Date': '2021-12-31 11:45:18'},
#  {'City': 'Tezu',
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 61.29,
#   'Humidity': 63,
#   'Cloudiness': 2,
#   'Wind Speed': 4.25,
#   'Country': 'IN',
#   'Date': '2021-12-31 11:45:19'},
#  {'City': 'San Rafael Del Sur',
#   'Lat': 11.8485,
#   'Lng': -86.4384,
#   'Max Temp': 70.77,
#   'Humidity': 87,
#   'Cloudiness': 80,
#   'Wind Speed': 5.82,
#   'Country': 'NI',
#   'Date': '2021-12-31 11:45:19'},
#  {'City': 'Bitung',
#   'Lat': 1.4451,
#   'Lng': 125.1824,
#   'Max Temp': 76.05,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.13,
#   'Country': 'ID',
#   'Date': '2021-12-31 11:45:20'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 71.85,
#   'Humidity': 75,
#   'Cloudiness': 2,
#   'Wind Speed': 4.16,
#   'Country': 'MX',
#   'Date': '2021-12-31 11:45:20'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 83.43,
#   'Humidity': 66,
#   'Cloudiness': 99,
#   'Wind Speed': 7.34,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:45:21'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 58.86,
#   'Humidity': 77,
#   'Cloudiness': 97,
#   'Wind Speed': 3.09,
#   'Country': 'MX',
#   'Date': '2021-12-31 11:45:21'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': -6.02,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 4.25,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:45:22'},
#  {'City': 'Maceio',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 83.64,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:45:23'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 36.07,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Country': 'US',
#   'Date': '2021-12-31 11:45:24'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 76.12,
#   'Humidity': 32,
#   'Cloudiness': 89,
#   'Wind Speed': 11.59,
#   'Country': 'PT',
#   'Date': '2021-12-31 11:45:24'},
#  {'City': 'Lubango',
#   'Lat': -14.9172,
#   'Lng': 13.4925,
#   'Max Temp': 76.68,
#   'Humidity': 47,
#   'Cloudiness': 83,
#   'Wind Speed': 6.13,
#   'Country': 'AO',
#   'Date': '2021-12-31 11:45:25'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 66.04,
#   'Humidity': 84,
#   'Cloudiness': 65,
#   'Wind Speed': 18.19,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:45:25'},
#  {'City': 'Morant Bay',
#   'Lat': 17.8815,
#   'Lng': -76.4093,
#   'Max Temp': 74.82,
#   'Humidity': 82,
#   'Cloudiness': 6,
#   'Wind Speed': 7.87,
#   'Country': 'JM',
#   'Date': '2021-12-31 11:45:26'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 50.11,
#   'Humidity': 97,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-12-31 11:40:30'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': -12.62,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:45:28'},
#  {'City': 'Heinola',
#   'Lat': 61.2056,
#   'Lng': 26.0381,
#   'Max Temp': 30.29,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 8.84,
#   'Country': 'FI',
#   'Date': '2021-12-31 11:45:28'},
#  {'City': 'Rosarito',
#   'Lat': 32.3333,
#   'Lng': -117.0333,
#   'Max Temp': 56.14,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Country': 'MX',
#   'Date': '2021-12-31 11:46:29'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 57.69,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Country': 'GB',
#   'Date': '2021-12-31 11:46:30'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 72.25,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 18.21,
#   'Country': 'NA',
#   'Date': '2021-12-31 11:46:31'},
#  {'City': 'Uyemskiy',
#   'Lat': 64.4743,
#   'Lng': 40.8524,
#   'Max Temp': 14.05,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:46:32'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 22.5,
#   'Humidity': 60,
#   'Cloudiness': 27,
#   'Wind Speed': 2.53,
#   'Country': 'CN',
#   'Date': '2021-12-31 11:46:32'},
#  {'City': 'Morondava',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 86.32,
#   'Humidity': 66,
#   'Cloudiness': 95,
#   'Wind Speed': 14.63,
#   'Country': 'MG',
#   'Date': '2021-12-31 11:46:33'},
#  {'City': 'Magadan',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': -7.71,
#   'Humidity': 87,
#   'Cloudiness': 19,
#   'Wind Speed': 8.21,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:46:33'},
#  {'City': 'Taraz',
#   'Lat': 42.9,
#   'Lng': 71.3667,
#   'Max Temp': 47.28,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 11.18,
#   'Country': 'KZ',
#   'Date': '2021-12-31 11:46:34'},
#  {'City': 'Inirida',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 74.17,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 1.59,
#   'Country': 'CO',
#   'Date': '2021-12-31 11:46:35'},
#  {'City': 'Bougouni',
#   'Lat': 11.417,
#   'Lng': -7.479,
#   'Max Temp': 91.54,
#   'Humidity': 7,
#   'Cloudiness': 49,
#   'Wind Speed': 8.81,
#   'Country': 'ML',
#   'Date': '2021-12-31 11:46:35'},
#  {'City': 'Mafinga',
#   'Lat': -7.25,
#   'Lng': 35.0667,
#   'Max Temp': 88.92,
#   'Humidity': 32,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Country': 'TZ',
#   'Date': '2021-12-31 11:46:36'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 66.38,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 2.42,
#   'Country': 'VE',
#   'Date': '2021-12-31 11:46:36'},
#  {'City': 'Pagegiai',
#   'Lat': 55.1381,
#   'Lng': 21.9089,
#   'Max Temp': 38.44,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Country': 'LT',
#   'Date': '2021-12-31 11:46:37'},
#  {'City': 'Miandrivazo',
#   'Lat': -19.5167,
#   'Lng': 45.4667,
#   'Max Temp': 95.95,
#   'Humidity': 38,
#   'Cloudiness': 89,
#   'Wind Speed': 7.31,
#   'Country': 'MG',
#   'Date': '2021-12-31 11:46:37'},
#  {'City': 'Hohhot',
#   'Lat': 40.8106,
#   'Lng': 111.6522,
#   'Max Temp': 12.49,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'CN',
#   'Date': '2021-12-31 11:46:38'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -20.18,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-12-31 11:46:38'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 85.55,
#   'Humidity': 35,
#   'Cloudiness': 92,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:42:06'},
#  {'City': 'Roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 37.33,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'NO',
#   'Date': '2021-12-31 11:46:39'},
#  {'City': 'Havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 64.38,
#   'Humidity': 96,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-12-31 11:46:40'},
#  {'City': 'Malangali',
#   'Lat': -8.5667,
#   'Lng': 34.85,
#   'Max Temp': 80.11,
# ...
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 61.21,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 22.84,
#   'Country': 'PT',
#   'Date': '2021-12-31 11:58:09'},
#  {'City': 'Boa Vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 76.98,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:55:59'},
#  {'City': 'Ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 73.36,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:58:10'},
#  {'City': 'Miram Shah',
#   'Lat': 33.0086,
#   'Lng': 70.0697,
#   'Max Temp': 53.6,
#   'Humidity': 22,
#   'Cloudiness': 99,
#   'Wind Speed': 3.65,
#   'Country': 'PK',
#   'Date': '2021-12-31 11:58:11'},
#  {'City': 'Lensk',
#   'Lat': 60.7253,
#   'Lng': 114.9278,
#   'Max Temp': 4.6,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:57:43'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 66.25,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'PE',
#   'Date': '2021-12-31 11:58:12'},
#  {'City': 'Altamont',
#   'Lat': 42.2068,
#   'Lng': -121.7372,
#   'Max Temp': 8.35,
#   'Humidity': 99,
#   'Cloudiness': 78,
#   'Wind Speed': 1.9,
#   'Country': 'US',
#   'Date': '2021-12-31 11:58:13'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 83.21,
#   'Humidity': 72,
#   'Cloudiness': 36,
#   'Wind Speed': 10.38,
#   'Country': 'RE',
#   'Date': '2021-12-31 11:58:14'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 78.08,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 17.98,
#   'Country': 'TC',
#   'Date': '2021-12-31 11:56:30'},
#  {'City': 'Sompeta',
#   'Lat': 18.9333,
#   'Lng': 84.6,
#   'Max Temp': 72.39,
#   'Humidity': 74,
#   'Cloudiness': 12,
#   'Wind Speed': 8.28,
#   'Country': 'IN',
#   'Date': '2021-12-31 11:58:15'},
#  {'City': 'Shizunai',
#   'Lat': 42.3339,
#   'Lng': 142.3669,
#   'Max Temp': 19.26,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 19.6,
#   'Country': 'JP',
#   'Date': '2021-12-31 11:58:15'},
#  {'City': 'Tukrah',
#   'Lat': 32.5341,
#   'Lng': 20.5791,
#   'Max Temp': 61.48,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 26.24,
#   'Country': 'LY',
#   'Date': '2021-12-31 11:58:16'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': -18.62,
#   'Humidity': 95,
#   'Cloudiness': 30,
#   'Wind Speed': 10.02,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:58:00'},
#  {'City': 'Skjervoy',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 27.75,
#   'Humidity': 68,
#   'Cloudiness': 55,
#   'Wind Speed': 5.3,
#   'Country': 'NO',
#   'Date': '2021-12-31 11:59:17'},
#  {'City': 'Boueni',
#   'Lat': -12.9025,
#   'Lng': 45.0761,
#   'Max Temp': 85.98,
#   'Humidity': 67,
#   'Cloudiness': 94,
#   'Wind Speed': 0.56,
#   'Country': 'YT',
#   'Date': '2021-12-31 11:59:18'},
#  {'City': 'Ovre Ardal',
#   'Lat': 61.3167,
#   'Lng': 7.8,
#   'Max Temp': 38.88,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 8.48,
#   'Country': 'NO',
#   'Date': '2021-12-31 11:59:19'},
#  {'City': 'Mana',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 77.97,
#   'Humidity': 85,
#   'Cloudiness': 86,
#   'Wind Speed': 11.14,
#   'Country': 'GF',
#   'Date': '2021-12-31 11:59:20'},
#  {'City': 'San Juan',
#   'Lat': -31.5375,
#   'Lng': -68.5364,
#   'Max Temp': 79.25,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.03,
#   'Country': 'AR',
#   'Date': '2021-12-31 11:57:30'},
#  {'City': 'La Asuncion',
#   'Lat': 11.0333,
#   'Lng': -63.8628,
#   'Max Temp': 73.13,
#   'Humidity': 100,
#   'Cloudiness': 33,
#   'Wind Speed': 4.61,
#   'Country': 'VE',
#   'Date': '2021-12-31 11:59:21'},
#  {'City': 'Lomovka',
#   'Lat': 53.9194,
#   'Lng': 58.3672,
#   'Max Temp': 5.92,
#   'Humidity': 99,
#   'Cloudiness': 89,
#   'Wind Speed': 1.34,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:59:21'},
#  {'City': 'Kassala',
#   'Lat': 15.451,
#   'Lng': 36.4,
#   'Max Temp': 87.24,
#   'Humidity': 20,
#   'Cloudiness': 1,
#   'Wind Speed': 8.25,
#   'Country': 'SD',
#   'Date': '2021-12-31 11:56:28'},
#  {'City': 'Orcopampa',
#   'Lat': -15.2661,
#   'Lng': -72.3417,
#   'Max Temp': 51.85,
#   'Humidity': 58,
#   'Cloudiness': 55,
#   'Wind Speed': 5.73,
#   'Country': 'PE',
#   'Date': '2021-12-31 11:59:22'},
#  {'City': 'Garissa',
#   'Lat': -0.4536,
#   'Lng': 39.6401,
#   'Max Temp': 91.9,
#   'Humidity': 37,
#   'Cloudiness': 38,
#   'Wind Speed': 7.14,
#   'Country': 'KE',
#   'Date': '2021-12-31 11:59:23'},
#  {'City': 'Camopi',
#   'Lat': 3.1655,
#   'Lng': -52.3158,
#   'Max Temp': 75.72,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Country': 'GF',
#   'Date': '2021-12-31 11:59:23'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 64.31,
#   'Humidity': 72,
#   'Cloudiness': 2,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Date': '2021-12-31 11:59:24'},
#  {'City': 'Beira',
#   'Lat': -19.8436,
#   'Lng': 34.8389,
#   'Max Temp': 89.69,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 17,
#   'Country': 'MZ',
#   'Date': '2021-12-31 11:59:25'},
#  {'City': 'Stornoway',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 44.56,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Country': 'GB',
#   'Date': '2021-12-31 11:59:25'},
#  {'City': 'Manyana',
#   'Lat': -23.4,
#   'Lng': 21.7167,
#   'Max Temp': 95.92,
#   'Humidity': 10,
#   'Cloudiness': 9,
#   'Wind Speed': 9.55,
#   'Country': 'BW',
#   'Date': '2021-12-31 11:59:26'},
#  {'City': 'Cloquet',
#   'Lat': 46.7216,
#   'Lng': -92.4594,
#   'Max Temp': 12.38,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-12-31 11:59:26'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 38.32,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 15.93,
#   'Country': 'FO',
#   'Date': '2021-12-31 11:59:27'},
#  {'City': 'Sungurlu',
#   'Lat': 40.1675,
#   'Lng': 34.3739,
#   'Max Temp': 47.57,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 2.68,
#   'Country': 'TR',
#   'Date': '2021-12-31 11:59:27'},
#  {'City': 'Maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 13.78,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'GL',
#   'Date': '2021-12-31 11:59:28'},
#  {'City': 'Sindi',
#   'Lat': 20.8,
#   'Lng': 78.8667,
#   'Max Temp': 74.28,
#   'Humidity': 51,
#   'Cloudiness': 9,
#   'Wind Speed': 6.42,
#   'Country': 'IN',
#   'Date': '2021-12-31 11:59:28'},
#  {'City': 'Gimbi',
#   'Lat': 9.1667,
#   'Lng': 35.8333,
#   'Max Temp': 70.38,
#   'Humidity': 46,
#   'Cloudiness': 56,
#   'Wind Speed': 1.48,
#   'Country': 'ET',
#   'Date': '2021-12-31 11:59:29'},
#  {'City': 'Kabanjahe',
#   'Lat': 3.1001,
#   'Lng': 98.4908,
#   'Max Temp': 65.16,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.12,
#   'Country': 'ID',
#   'Date': '2021-12-31 11:59:29'},
#  {'City': 'Agboville',
#   'Lat': 5.928,
#   'Lng': -4.2132,
#   'Max Temp': 91.98,
#   'Humidity': 48,
#   'Cloudiness': 23,
#   'Wind Speed': 2.59,
#   'Country': 'CI',
#   'Date': '2021-12-31 11:59:30'},
#  {'City': 'Bosobolo',
#   'Lat': 4.1833,
#   'Lng': 19.9,
#   'Max Temp': 96.17,
#   'Humidity': 24,
#   'Cloudiness': 86,
#   'Wind Speed': 4.12,
#   'Country': 'CD',
#   'Date': '2021-12-31 11:59:30'},
#  {'City': 'Dekernes',
#   'Lat': 31.0876,
#   'Lng': 31.595,
#   'Max Temp': 60.19,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57,
#   'Country': 'EG',
#   'Date': '2021-12-31 11:59:31'},
#  {'City': 'Luis Correia',
#   'Lat': -2.8792,
#   'Lng': -41.6669,
#   'Max Temp': 82.4,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:59:31'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 82.42,
#   'Humidity': 74,
#   'Cloudiness': 58,
#   'Wind Speed': 10.69,
#   'Country': 'GA',
#   'Date': '2021-12-31 11:59:32'},
#  {'City': 'Muravlenko',
#   'Lat': 63.7898,
#   'Lng': 74.523,
#   'Max Temp': 1.92,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7.02,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:59:16'},
#  {'City': 'Rio Verde De Mato Grosso',
#   'Lat': -18.9181,
#   'Lng': -54.8442,
#   'Max Temp': 78.78,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 4.23,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:59:33'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 70.09,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 14.9,
#   'Country': 'ZA',
#   'Date': '2021-12-31 11:59:34'},
#  {'City': 'Basco',
#   'Lat': 20.4487,
#   'Lng': 121.9702,
#   'Max Temp': 73.96,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 25.57,
#   'Country': 'PH',
#   'Date': '2021-12-31 11:59:34'},
#  {'City': 'Tabou',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 83.23,
#   'Humidity': 73,
#   'Cloudiness': 48,
#   'Wind Speed': 7.94,
#   'Country': 'CI',
#   'Date': '2021-12-31 11:59:35'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 76.89,
#   'Humidity': 88,
#   'Cloudiness': 94,
#   'Wind Speed': 3.44,
#   'Country': 'NU',
#   'Date': '2021-12-31 11:58:55'},
#  {'City': 'Presidente Franco',
#   'Lat': -25.5333,
#   'Lng': -54.6167,
#   'Max Temp': 77.52,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'PY',
#   'Date': '2021-12-31 11:59:36'},
#  {'City': 'Mayumba',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 80.29,
#   'Humidity': 80,
#   'Cloudiness': 61,
#   'Wind Speed': 7.25,
#   'Country': 'GA',
#   'Date': '2021-12-31 11:59:36'},
#  {'City': 'Ofaqim',
#   'Lat': 31.3141,
#   'Lng': 34.6203,
#   'Max Temp': 68.7,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 11.14,
#   'Country': 'IL',
#   'Date': '2021-12-31 11:59:37'},
#  {'City': 'Dzaoudzi',
#   'Lat': -12.7887,
#   'Lng': 45.2699,
#   'Max Temp': 85.89,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'YT',
#   'Date': '2021-12-31 11:59:37'},
#  {'City': 'Sattahip',
#   'Lat': 12.6664,
#   'Lng': 100.9007,
#   'Max Temp': 86.99,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'TH',
#   'Date': '2021-12-31 11:59:38'},
#  {'City': 'Moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 80.01,
#   'Humidity': 75,
#   'Cloudiness': 2,
#   'Wind Speed': 4,
#   'Country': 'AR',
#   'Date': '2021-12-31 11:59:38'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -23.31,
#   'Humidity': 97,
#   'Cloudiness': 83,
#   'Wind Speed': 6.22,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:59:39'},
#  {'City': 'Potenza',
#   'Lat': 40.6443,
#   'Lng': 15.8086,
#   'Max Temp': 61.83,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.36,
#   'Country': 'IT',
#   'Date': '2021-12-31 11:59:40'},
#  {'City': 'Svetlaya',
#   'Lat': 46.5389,
#   'Lng': 138.3297,
#   'Max Temp': -0.9,
#   'Humidity': 62,
#   'Cloudiness': 70,
#   'Wind Speed': 14.81,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:59:40'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 65.48,
#   'Humidity': 78,
#   'Cloudiness': 57,
#   'Wind Speed': 3.27,
#   'Country': 'CL',
#   'Date': '2021-12-31 11:59:09'},
#  {'City': 'Savannah Bight',
#   'Lat': 16.45,
#   'Lng': -85.85,
#   'Max Temp': 79,
#   'Humidity': 78,
#   'Cloudiness': 33,
#   'Wind Speed': 18.32,
#   'Country': 'HN',
#   'Date': '2021-12-31 11:59:41'},
#  {'City': 'Havre-Saint-Pierre',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 28.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-12-31 11:59:42'},
#  {'City': 'Dalvik',
#   'Lat': 65.9702,
#   'Lng': -18.5286,
#   'Max Temp': 13.93,
#   'Humidity': 69,
#   'Cloudiness': 11,
#   'Wind Speed': 8.05,
#   'Country': 'IS',
#   'Date': '2021-12-31 11:59:42'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 80.67,
#   'Humidity': 78,
#   'Cloudiness': 72,
#   'Wind Speed': 16.08,
#   'Country': 'LK',
#   'Date': '2021-12-31 11:59:43'},
#  {'City': 'Sumbe',
#   'Lat': -11.2061,
#   'Lng': 13.8437,
#   'Max Temp': 77.61,
#   'Humidity': 82,
#   'Cloudiness': 96,
#   'Wind Speed': 2.84,
#   'Country': 'AO',
#   'Date': '2021-12-31 11:59:43'},
#  {'City': 'Ouro Preto Do Oeste',
#   'Lat': -10.7481,
#   'Lng': -62.2158,
#   'Max Temp': 75.29,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.24,
#   'Country': 'BR',
#   'Date': '2021-12-31 11:59:44'},
#  {'City': 'Sangar',
#   'Lat': 63.9242,
#   'Lng': 127.4739,
#   'Max Temp': -33.2,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 9.24,
#   'Country': 'RU',
#   'Date': '2021-12-31 11:59:44'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 40.55,
#   'Humidity': 45,
#   'Cloudiness': 4,
#   'Wind Speed': 21.23,
#   'Country': 'JP',
#   'Date': '2021-12-31 12:00:45'},
#  {'City': 'Kaspiyskiy',
#   'Lat': 45.3929,
#   'Lng': 47.3707,
#   'Max Temp': 42.28,
#   'Humidity': 77,
#   'Cloudiness': 97,
#   'Wind Speed': 12.21,
#   'Country': 'RU',
#   'Date': '2021-12-31 12:00:45'},
#  {'City': 'Vallenar',
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 61.86,
#   'Humidity': 83,
#   'Cloudiness': 56,
#   'Wind Speed': 6.11,
#   'Country': 'CL',
#   'Date': '2021-12-31 12:00:46'},
#  {'City': 'Falam',
#   'Lat': 22.9167,
#   'Lng': 93.6833,
#   'Max Temp': 50.88,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 1.39,
#   'Country': 'MM',
#   'Date': '2021-12-31 12:00:46'},
#  {'City': 'Bagdarin',
#   'Lat': 54.4333,
#   'Lng': 113.6,
#   'Max Temp': -3.89,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.67,
#   'Country': 'RU',
#   'Date': '2021-12-31 12:00:48'},
#  {'City': 'Lodja',
#   'Lat': -3.4833,
#   'Lng': 23.4333,
#   'Max Temp': 75.06,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.76,
#   'Country': 'CD',
#   'Date': '2021-12-31 12:00:48'},
#  {'City': 'Tocache',
#   'Lat': -8.1842,
#   'Lng': -76.5125,
#   'Max Temp': 71.69,
#   'Humidity': 93,
#   'Cloudiness': 86,
#   'Wind Speed': 0.56,
#   'Country': 'PE',
#   'Date': '2021-12-31 12:00:49'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 74.21,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 10.65,
#   'Country': 'AU',
#   'Date': '2021-12-31 12:00:49'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 78.3,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'ID',
#   'Date': '2021-12-31 12:00:50'},
#  {'City': 'Nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 94.6,
#   'Humidity': 8,
#   'Cloudiness': 52,
#   'Wind Speed': 13.4,
#   'Country': 'GM',
#   'Date': '2021-12-31 12:00:50'},
#  {'City': 'Shu',
#   'Lat': 43.5983,
#   'Lng': 73.7614,
#   'Max Temp': 32.23,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 5.17,
#   'Country': 'KZ',
#   'Date': '2021-12-31 12:00:51'},
#  {'City': 'Sirsi',
#   'Lat': 14.6167,
#   'Lng': 74.85,
#   'Max Temp': 76.01,
#   'Humidity': 59,
#   'Cloudiness': 71,
#   'Wind Speed': 8.28,
#   'Country': 'IN',
#   'Date': '2021-12-31 12:00:51'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': -15.68,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Country': 'RU',
#   'Date': '2021-12-31 12:00:52'},
#  {'City': 'Kadyy',
#   'Lat': 57.787,
#   'Lng': 43.1903,
#   'Max Temp': 13.26,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Date': '2021-12-31 12:00:52'},
#  {'City': 'Nelson Bay',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 73,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2021-12-31 12:00:53'},
#  {'City': 'Yarada',
#   'Lat': 17.65,
#   'Lng': 83.2667,
#   'Max Temp': 77.32,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'IN',
#   'Date': '2021-12-31 12:00:54'},
#  {'City': 'Jabinyanah',
#   'Lat': 35.035,
#   'Lng': 10.9081,
#   'Max Temp': 65.5,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 17.9,
#   'Country': 'TN',
#   'Date': '2021-12-31 12:00:55'},
#  {'City': 'Jinchang',
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp': 25.63,
#   'Humidity': 30,
#   'Cloudiness': 11,
#   'Wind Speed': 2.66,
#   'Country': 'CN',
#   'Date': '2021-12-31 12:00:55'},
#  {'City': 'Jacareacanga',
#   'Lat': -6.2222,
#   'Lng': -57.7528,
#   'Max Temp': 76.77,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 0.54,
#   'Country': 'BR',
#   'Date': '2021-12-31 12:00:56'},
#  {'City': 'Grand-Santi',
#   'Lat': 4.25,
#   'Lng': -54.3833,
#   'Max Temp': 74.07,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 3.11,
#   'Country': 'GF',
#   'Date': '2021-12-31 12:00:56'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                   Amay  50.5483    5.3097     56.21        82           0
# 1                  Pevek  69.7008  170.3133    -23.26       100          91
# 2                  Bluff -46.6000  168.3333     59.81        82          85
# 3                 Hasaki  35.7333  140.8333     34.20        40          43
# 4  Los Llanos De Aridane  28.6585  -17.9182     78.55        23           0
# 5                Mataura -46.1927  168.8643     59.49        63          90
# 6              Busselton -33.6500  115.3333     64.04        66           2
# 7                 Dingle  10.9995  122.6711     74.68        84         100
# 8           Port Lincoln -34.7333  135.8667     70.05        62          81
# 9                  Airai  -8.9266  125.4092     61.29        91         100
#
#    Wind Speed Country                 Date
# 0       10.36      BE  2021-12-31 11:39:12
# 1        2.08      RU  2021-12-31 11:37:01
# 2       21.68      NZ  2021-12-31 11:39:13
# 3       25.88      JP  2021-12-31 11:39:14
# 4       18.41      ES  2021-12-31 11:39:14
# 5        6.60      NZ  2021-12-31 11:39:15
# 6       20.24      AU  2021-12-31 11:39:15
# 7       12.73      PH  2021-12-31 11:39:16
# 8        5.06      AU  2021-12-31 11:39:17
# 9        1.39      TL  2021-12-31 11:39:18

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                       City Country                 Date      Lat       Lng  \
# 0                     Amay      BE  2021-12-31 11:39:12  50.5483    5.3097
# 1                    Pevek      RU  2021-12-31 11:37:01  69.7008  170.3133
# 2                    Bluff      NZ  2021-12-31 11:39:13 -46.6000  168.3333
# 3                   Hasaki      JP  2021-12-31 11:39:14  35.7333  140.8333
# 4    Los Llanos De Aridane      ES  2021-12-31 11:39:14  28.6585  -17.9182
# ..                     ...     ...                  ...      ...       ...
# 565                 Yarada      IN  2021-12-31 12:00:54  17.6500   83.2667
# 566             Jabinyanah      TN  2021-12-31 12:00:55  35.0350   10.9081
# 567               Jinchang      CN  2021-12-31 12:00:55  38.4953  102.1739
# 568           Jacareacanga      BR  2021-12-31 12:00:56  -6.2222  -57.7528
# 569            Grand-Santi      GF  2021-12-31 12:00:56   4.2500  -54.3833
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       56.21        82           0       10.36
# 1      -23.26       100          91        2.08
# 2       59.81        82          85       21.68
# 3       34.20        40          43       25.88
# 4       78.55        23           0       18.41
# ..        ...       ...         ...         ...
# 565     77.32        69          20        9.22
# 566     65.50        57           0       17.90
# 567     25.63        30          11        2.66
# 568     76.77        92          99        0.54
# 569     74.07        97          99        3.11
#
# [570 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
