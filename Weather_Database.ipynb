# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
city_database = []

# %%
#  Using NumPy to create random figures
np.random.uniform(-90, 90, size=15)
# Out:
# array([ 17.59915091, -50.47382341,  20.89079055,  33.92954976,
#        -73.74240383,  11.86974955,  53.26982489, -50.12677419,
#        -47.72655835,   0.19452727, -43.83447108,  74.12144431,
#         24.57688734, -33.68813819,  36.14249073])

# %%
# Adding Timeit
# %timeit np.random.uniform(-90, 90, size=15)
# Out:
# 2.2 µs ± 30.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# defining random latitudes
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = np.random.randint(-90, 90) + np.random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(15)
# Out:
# 33.3 µs ± 366 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=15)
lngs = np.random.uniform(low=-180.000, high=180.000, size=15)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import Citipy
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 14

# %%
cities
# Out:
# ['kruisfontein',
#  'hithadhoo',
#  'rikitea',
#  'vaini',
#  'hilo',
#  'comodoro rivadavia',
#  'anadyr',
#  'taolanaro',
#  'miri',
#  'ushuaia',
#  'guazacapan',
#  'nadym',
#  'tupik',
#  'uwayl']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]    
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_database.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kruisfontein
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | comodoro rivadavia
# Processing Record 7 of Set 1 | anadyr
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | miri
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | guazacapan
# Processing Record 12 of Set 1 | nadym
# Processing Record 13 of Set 1 | tupik
# Processing Record 14 of Set 1 | uwayl
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_database
# Out:
# [{'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 61.88,
#   'Humidity': 84,
#   'Cloudiness': 48,
#   'Wind Speed': 2.1,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:08:00'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.2,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 9.64,
#   'Country': 'MV',
#   'Date': '2022-01-02 20:08:01'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.47,
#   'Humidity': 71,
#   'Cloudiness': 19,
#   'Wind Speed': 9.26,
#   'Country': 'PF',
#   'Date': '2022-01-02 20:08:01'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.96,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'TO',
#   'Date': '2022-01-02 20:08:02'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 80.62,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-01-02 20:08:03'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 67.86,
#   'Humidity': 14,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:06:36'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 27.32,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.33,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:08:04'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 61.88,
#   'Humidity': 84,
#   'Cloudiness': 48,
#   'Wind Speed': 2.1,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:08:00'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.2,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 9.64,
#   'Country': 'MV',
#   'Date': '2022-01-02 20:08:01'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.47,
#   'Humidity': 71,
#   'Cloudiness': 19,
#   'Wind Speed': 9.26,
#   'Country': 'PF',
#   'Date': '2022-01-02 20:08:01'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.96,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'TO',
#   'Date': '2022-01-02 20:08:02'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 80.62,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-01-02 20:08:03'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 67.86,
#   'Humidity': 14,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:06:36'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 27.32,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.33,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:08:04'},
#  {'City': 'Miri',
#   'Lat': 4.4148,
#   'Lng': 114.0089,
#   'Max Temp': 75.31,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.41,
#   'Country': 'MY',
#   'Date': '2022-01-02 20:08:05'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.46,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 35.68,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:08:07'},
#  {'City': 'Guazacapan',
#   'Lat': 14.0742,
#   'Lng': -90.4167,
#   'Max Temp': 91.15,
#   'Humidity': 43,
#   'Cloudiness': 25,
#   'Wind Speed': 11.83,
#   'Country': 'GT',
#   'Date': '2022-01-02 20:08:07'},
#  {'City': 'Nadym',
#   'Lat': 65.5333,
#   'Lng': 72.5167,
#   'Max Temp': -11.11,
#   'Humidity': 98,
#   'Cloudiness': 94,
#   'Wind Speed': 9.24,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:08:08'},
#  {'City': 'Tupik',
#   'Lat': 54.4253,
#   'Lng': 119.9327,
#   'Max Temp': -27.02,
#   'Humidity': 95,
#   'Cloudiness': 12,
#   'Wind Speed': 3.04,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:08:09'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_database)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kruisfontein -34.0033   24.7314     61.88        84          48
# 1           Hithadhoo  -0.6000   73.0833     82.20        74          93
# 2             Rikitea -23.1203 -134.9692     77.47        71          19
# 3               Vaini -21.2000 -175.2000     78.96        94          75
# 4                Hilo  19.7297 -155.0900     80.62        77           1
# 5  Comodoro Rivadavia -45.8667  -67.5000     67.86        14          40
# 6              Anadyr  64.7500  177.4833     27.32        94         100
# 7        Kruisfontein -34.0033   24.7314     61.88        84          48
# 8           Hithadhoo  -0.6000   73.0833     82.20        74          93
# 9             Rikitea -23.1203 -134.9692     77.47        71          19
#
#    Wind Speed Country                 Date
# 0        2.10      ZA  2022-01-02 20:08:00
# 1        9.64      MV  2022-01-02 20:08:01
# 2        9.26      PF  2022-01-02 20:08:01
# 3        8.05      TO  2022-01-02 20:08:02
# 4       11.50      US  2022-01-02 20:08:03
# 5       20.71      AR  2022-01-02 20:06:36
# 6       10.33      RU  2022-01-02 20:08:04
# 7        2.10      ZA  2022-01-02 20:08:00
# 8        9.64      MV  2022-01-02 20:08:01
# 9        9.26      PF  2022-01-02 20:08:01

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
