# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
city_database = []

# %%
#  Using NumPy to create random figures
np.random.uniform(-90, 90, size=2000)
# Out:
# array([-17.51032109, -62.19218665,  23.42626651, ...,  23.87191364,
#        -15.21564061,  23.69865875])

# %%
# Adding Timeit
# %timeit np.random.uniform(-90, 90, size=2000)
# Out:
# 14.5 µs ± 163 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# defining random latitudes
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = np.random.randint(-90, 90) + np.random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(2000)
# Out:
# 4.56 ms ± 66.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import Citipy
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
cities
# Out:
# ['jamestown',
#  'buchanan',
#  'saint-philippe',
#  'tasiilaq',
#  'kleck',
#  'naze',
#  'port alfred',
#  'saint andrews',
#  'albany',
#  'busselton',
#  'gushi',
#  'puerto ayora',
#  'pratapgarh',
#  'mys shmidta',
#  'evensk',
#  'cabo san lucas',
#  'victoria',
#  'georgetown',
#  'birjand',
#  'cidreira',
#  'dikson',
#  'knysna',
#  'manambrag',
#  'saint-augustin',
#  'saskylakh',
#  'airai',
#  'ponta do sol',
#  'zhanakorgan',
#  'tazovskiy',
#  'argelia',
#  'hithadhoo',
#  'thompson',
#  'vaini',
#  'geraldton',
#  'klaksvik',
#  'ushuaia',
#  'maldonado',
#  'talnakh',
#  'souillac',
#  'illoqqortoormiut',
#  'ferndale',
#  'puerto del rosario',
#  'kingisepp',
#  'punta arenas',
#  'taganak',
#  'mataura',
#  'grand river south east',
#  'arraial do cabo',
#  'ijaki',
#  'broken hill',
#  'touros',
#  'marawi',
#  'kruisfontein',
#  'san patricio',
#  'faya',
#  'severodvinsk',
#  'rikitea',
#  'agadez',
#  'kahului',
#  'magalia',
#  'lebu',
#  'leningradskiy',
#  'komsomolskiy',
#  'sevsk',
#  'tiksi',
#  'sibiti',
#  'privokzalnyy',
#  'nacala',
#  'kodiak',
#  'khatanga',
#  'monroe',
#  'omboue',
#  'tigil',
#  'barrow',
#  'fortuna',
#  'borba',
#  'hilo',
#  'astipalaia',
#  'torbay',
#  'cape town',
#  'rio gallegos',
#  'arkhara',
#  'gumla',
#  'aktash',
#  'sao filipe',
#  'safranbolu',
#  'moussoro',
#  'tuatapere',
#  'grand gaube',
#  'nizhneyansk',
#  'tura',
#  'hermanus',
#  'palabuhanratu',
#  'narsaq',
#  'carnarvon',
#  'ribeira grande',
#  'saint george',
#  'manyana',
#  'qingdao',
#  'nouadhibou',
#  'nikolskoye',
#  'butaritari',
#  'taraz',
#  'cortez',
#  'calvia',
#  'hobart',
#  'palmares do sul',
#  'yasnyy',
#  'norman wells',
#  'feicheng',
#  'atar',
#  'suzu',
#  'alice springs',
#  'saldanha',
#  'chuy',
#  'sorland',
#  'berdigestyakh',
#  'uirauna',
#  'constitucion',
#  'sentyabrskiy',
#  'pusztaszabolcs',
#  'bambous virieux',
#  'jibuti',
#  'makakilo city',
#  'dzilam gonzalez',
#  'coihaique',
#  'strezhevoy',
#  'samarai',
#  'lorengau',
#  'kandrian',
#  'chapais',
#  'siderno',
#  'barinitas',
#  'belushya guba',
#  'chokurdakh',
#  'biltine',
#  'yellowknife',
#  'pangnirtung',
#  'kapaa',
#  'shambu',
#  'kralendijk',
#  'san carlos de bariloche',
#  'beringovskiy',
#  'dallas',
#  'brownwood',
#  'ketchikan',
#  'vaitupu',
#  'marsa matruh',
#  'kaitangata',
#  'macaboboni',
#  'ilulissat',
#  'east london',
#  'qaanaaq',
#  'orangeburg',
#  'isangel',
#  'port hawkesbury',
#  'luanda',
#  'nanortalik',
#  'barentsburg',
#  'bluff',
#  'castro',
#  'townsville',
#  'lasa',
#  'tuktoyaktuk',
#  'port lincoln',
#  'katherine',
#  'ganzhou',
#  'maun',
#  'aksha',
#  'mount gambier',
#  'bosaso',
#  'veraval',
#  'bredasdorp',
#  'ayan',
#  'ostrow mazowiecka',
#  'atuona',
#  'wucheng',
#  'tevaitoa',
#  'beyneu',
#  'lompoc',
#  'marcona',
#  'svetlyy',
#  'samalaeulu',
#  'tecoanapa',
#  'byron bay',
#  'santa cruz',
#  'hastings',
#  'tatvan',
#  'meulaboh',
#  'upernavik',
#  'axim',
#  'umzimvubu',
#  'attawapiskat',
#  'warrington',
#  'wulanhaote',
#  'new norfolk',
#  'port elizabeth',
#  'shirokiy',
#  'asau',
#  'santa cruz de la palma',
#  'praia da vitoria',
#  'olinda',
#  'sarangani',
#  'muros',
#  'porto novo',
#  'baoqing',
#  'amderma',
#  'grindavik',
#  'ciras',
#  'babanusah',
#  'north bend',
#  'bethel',
#  'penzance',
#  'rawson',
#  'antalaha',
#  'northam',
#  'bolungarvik',
#  'atbasar',
#  'atasu',
#  'campbellford',
#  'pisco',
#  'effingham',
#  'papara',
#  'hit',
#  'gazanjyk',
#  'shelburne',
#  'rumonge',
#  'menongue',
#  'san quintin',
#  'cherskiy',
#  'uglovskoye',
#  'kalmunai',
#  'ust-kamchatsk',
#  'vanimo',
#  'vytegra',
#  'ismailia',
#  'markova',
#  'pemangkat',
#  'ahipara',
#  'jindrichuv hradec',
#  'hudson bay',
#  'ust-ilimsk',
#  'agropoli',
#  'avarua',
#  'gouyave',
#  'camacha',
#  'roma',
#  'sabang',
#  'adrar',
#  'fairbanks',
#  'salinas',
#  'mount isa',
#  'nome',
#  'skagastrond',
#  'gornoye loo',
#  'cap-aux-meules',
#  'liverpool',
#  'pevek',
#  'vila velha',
#  'poninka',
#  'fort nelson',
#  'taolanaro',
#  'mizan teferi',
#  'alexandria',
#  'dargaville',
#  'ulaangom',
#  'maceio',
#  'sao lourenco do oeste',
#  'severo-kurilsk',
#  'zunyi',
#  'panacan',
#  'katsuura',
#  'chagda',
#  'yaan',
#  'ariquemes',
#  'yanam',
#  'dwarka',
#  'batagay',
#  'nautla',
#  'dukat',
#  'victor harbor',
#  'clyde river',
#  'wajima',
#  'tolyatti',
#  'novoanninskiy',
#  'charters towers',
#  'lalomanu',
#  'paucartambo',
#  'burnie',
#  'kavieng',
#  'mahebourg',
#  'rognan',
#  'oranjemund',
#  'bafq',
#  'bandar-e anzali',
#  'taoudenni',
#  'pyu',
#  'gweta',
#  'mandurah',
#  'coron',
#  'balatan',
#  'tharrawaddy',
#  'iquitos',
#  'codrington',
#  'beya',
#  'dzaoudzi',
#  'revda',
#  'abbeville',
#  'abu kamal',
#  'san ignacio',
#  'louisbourg',
#  'port jervis',
#  'linjiang',
#  'nuuk',
#  'inhambane',
#  'toda raisingh',
#  'paamiut',
#  'huainan',
#  'high level',
#  'manzhouli',
#  'miramar',
#  'homer',
#  'coahuayana',
#  'hammerfest',
#  'minab',
#  'kirksville',
#  'korla',
#  'taltal',
#  'ostrovnoy',
#  'wasilla',
#  'sao joao da barra',
#  'castelo branco',
#  'watsa',
#  'anadyr',
#  'dourbali',
#  'jerez',
#  'wismar',
#  'dingle',
#  'palu',
#  'salalah',
#  'paso de carrasco',
#  'seoul',
#  'calama',
#  'ancud',
#  'lazaro cardenas',
#  'galiwinku',
#  'palmer',
#  'stromness',
#  'tiarei',
#  'mayo',
#  'dalby',
#  'leshukonskoye',
#  'bengkulu',
#  'hasaki',
#  'acapulco',
#  'batsfjord',
#  'lund',
#  'skalistyy',
#  'blagoyevo',
#  'mandera',
#  'beidao',
#  'fare',
#  'ekhabi',
#  'russell',
#  'taonan',
#  'aksu',
#  'kargopol',
#  'deh rawud',
#  'fukue',
#  'san carlos',
#  'husavik',
#  'manono',
#  'luancheng',
#  'hobyo',
#  'yumen',
#  'mahibadhoo',
#  'quixeramobim',
#  'vila franca do campo',
#  'yuli',
#  'havoysund',
#  'yotoco',
#  'pangody',
#  'sann',
#  'wahran',
#  'lazdijai',
#  'kagalnitskaya',
#  'phalodi',
#  'shitanjing',
#  'yulara',
#  'kirkuk',
#  'tommot',
#  'warqla',
#  'roald',
#  'nhulunbuy',
#  'marzuq',
#  'petropavlovsk-kamchatskiy',
#  'sambava',
#  'nanganga',
#  'doka',
#  'falmouth',
#  'lisakovsk',
#  'ngukurr',
#  'tilichiki',
#  'provideniya',
#  'deputatskiy',
#  'panaba',
#  'marsh harbour',
#  'bilma',
#  'kedougou',
#  'vao',
#  'baiyin',
#  'hofn',
#  'ninghai',
#  'bathsheba',
#  'manadhoo',
#  'luderitz',
#  'beian',
#  'tsihombe',
#  'quatre cocos',
#  'trinidad',
#  'algiers',
#  'valea mare-pravat',
#  'panindicuaro',
#  'hualmay',
#  'esperance',
#  'namibe',
#  'sawakin',
#  'azimur',
#  'port hedland',
#  'khasan',
#  'juneau',
#  'qax',
#  'sainte-maxime',
#  'ukiah',
#  'dolores',
#  'las cruces',
#  'sur',
#  'san jeronimo',
#  'wattegama',
#  'saint-joseph',
#  'port hardy',
#  'krasnoselkup',
#  'sao domingos',
#  'songjianghe',
#  'morondava',
#  'kaoma',
#  'iqaluit',
#  'raudeberg',
#  'san salvo',
#  'kamaishi',
#  'kloulklubed',
#  'melfort',
#  'det udom',
#  'mentok',
#  'norton shores',
#  'black river',
#  'bamiantong',
#  'flinders',
#  'huarmey',
#  'wuzhou',
#  'iwanai',
#  'panguipulli',
#  'camana',
#  'saint-pierre',
#  'wanaraja',
#  'taburi',
#  'lavrentiya',
#  'broome',
#  'slave lake',
#  'srednekolymsk',
#  'marevo',
#  'halalo',
#  'kortkeros',
#  'sovetskiy',
#  'avera',
#  'betong',
#  'houma',
#  'iquique',
#  'lata',
#  'wanning',
#  'mabaruma',
#  'poltavka',
#  'kulhudhuffushi',
#  'pinawa',
#  'san jose',
#  'padang',
#  'kropotkin',
#  'gazli',
#  'merauke',
#  'satitoa',
#  'sydney',
#  'riyadh',
#  'chililabombwe',
#  'jimani',
#  'guiglo',
#  'mar del plata',
#  'kiama',
#  'lagoa',
#  'xai-xai',
#  'baker city',
#  'burley',
#  'eureka',
#  'vysokogornyy',
#  'ventspils',
#  'terrace bay',
#  'honningsvag',
#  'hovd',
#  'mantua',
#  'thiruvananthapuram',
#  'ust-tsilma',
#  'tual',
#  'ronneby',
#  'gilroy',
#  'faanui',
#  'jiroft',
#  'abong mbang',
#  'pop',
#  'rocha',
#  'samana',
#  'midland',
#  'koslan',
#  'paita',
#  'orcopampa',
#  'jabiru',
#  'gamba',
#  'goure',
#  'peniche',
#  'oyama',
#  'dipkarpaz',
#  'mareeba',
#  'goksun',
#  'bonavista',
#  'pangkalanbuun',
#  'shymkent',
#  'macusani',
#  'la ronge',
#  'liuhe',
#  'samusu',
#  'sairang',
#  'batemans bay',
#  'maniitsoq',
#  'ust-nera',
#  'cairns',
#  'nguru',
#  'sotouboua',
#  'manacapuru',
#  'badiraguato',
#  'minsk',
#  'temirtau',
#  'cozumel',
#  'kalakamati',
#  'teya',
#  'hami',
#  'vila do maio',
#  'longyearbyen',
#  'bontang',
#  'bandarbeyla',
#  'selcuk',
#  'qandahar',
#  'laguna',
#  'belen',
#  'sahuaripa',
#  'abu dhabi',
#  'surt',
#  'jiexiu',
#  'duz',
#  'iwaki',
#  'sinnamary',
#  'brae',
#  'namatanai',
#  'skelleftea',
#  'jiangmen',
#  'brookhaven',
#  'bonthe',
#  'sao felix do xingu',
#  'agapovka',
#  'kieta',
#  'charlottesville',
#  'sitka',
#  'tuim',
#  'vila',
#  'batticaloa',
#  'urbana',
#  'humboldt',
#  'glace bay',
#  'kavaratti',
#  'nortelandia',
#  'vadso',
#  'paka',
#  'skjervoy',
#  'uk',
#  'tautira',
#  'bahia blanca',
#  'umm lajj',
#  'yar-sale',
#  'mitzic',
#  'guerrero negro',
#  'kargasok',
#  'santa fe',
#  'panguna',
#  'spearfish',
#  'sulangan',
#  'port lavaca',
#  'glens falls',
#  'gat',
#  'bilibino',
#  'batagay-alyta',
#  'vetapalem',
#  'esna',
#  'lexington',
#  'coquimbo',
#  'artyk',
#  'mmabatho',
#  'terbuny',
#  'san juan',
#  'verkhoyansk',
#  'alta gracia',
#  'benguela',
#  'puerto maldonado',
#  'petatlan',
#  'port augusta',
#  'payson',
#  'yefimovskiy',
#  'morristown',
#  'vestmannaeyjar',
#  'portland',
#  'rudbar',
#  'tecalitlan',
#  'may pen',
#  'enumclaw',
#  'lukulu',
#  'bara',
#  'aswan',
#  'kuche',
#  'ardistan',
#  'gangotri',
#  'clinton',
#  'hamilton',
#  'maniwaki',
#  'churapcha',
#  'bang saphan',
#  'pacific grove',
#  'randvere',
#  'finnsnes',
#  'grootfontein',
#  'mingguang',
#  'madoc',
#  'muscat',
#  'gulbarga',
#  'midyat',
#  'skibbereen',
#  'bhinga',
#  'great bend',
#  'eufaula',
#  'gorno-chuyskiy',
#  'maarianhamina',
#  'iracoubo',
#  'florence',
#  'makokou',
#  'bela',
#  'werda',
#  'hambantota',
#  'petukhovo',
#  'diffa',
#  'aracataca',
#  'maragogi',
#  'nampula',
#  'shinichi',
#  'margate',
#  'oxelosund',
#  'hervey bay',
#  'hay river',
#  'birao',
#  'melfi',
#  'santiago',
#  'vestmanna',
#  'altay',
#  'fallon',
#  'bousso',
#  'yago',
#  'valparaiso',
#  'lahaina',
#  'aybak',
#  'maiduguri',
#  'ranong',
#  'karratha',
#  'mnogovershinnyy',
#  'el bagre',
#  'iznik',
#  'kudahuvadhoo',
#  'sakaiminato',
#  'havre-saint-pierre',
#  'garowe',
#  'mackenzie',
#  'wilmington',
#  'hudiksvall',
#  'arman',
#  'maneadero',
#  'kununurra',
#  'carauari',
#  'araucaria',
#  'teguldet',
#  'sola',
#  'ahuimanu',
#  'kangavar',
#  'soubre',
#  'bridlington',
#  'mahajanga',
#  'kashi',
#  'walvis bay',
#  'canto do buriti',
#  'chiang klang',
#  'yerbogachen',
#  'okhotsk',
#  'tukrah',
#  'tarudant',
#  'siavonga',
#  'richards bay',
#  'berlevag',
#  'mawlaik',
#  'bongor',
#  'emerald',
#  'college',
#  'sept-iles',
#  'uvalde',
#  'bend',
#  'porgera',
#  'usinsk',
#  'leninsk',
#  'beira',
#  'rabat',
#  'vardo',
#  'saleaula',
#  'prince rupert',
#  'tadine',
#  'grasse',
#  'hailar',
#  'kawalu',
#  'jumla',
#  'bembereke',
#  'omsukchan',
#  'labuhan',
#  'lakes entrance',
#  'tsybli',
#  'eyl',
#  'alianca',
#  'lhuntshi',
#  'lianzhou',
#  'comodoro rivadavia',
#  'zaysan',
#  'gravdal',
#  'corrales',
#  'nizhniy baskunchak',
#  'bukama',
#  'olafsvik',
#  'alofi',
#  'tahta',
#  'sri aman']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0857bafab7106fceacc87a5d7664babf'

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]    
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        #It was impossible to retrieve the weahter description
        #city_description = city_weather["weahter"]["description"]
        city_wind = city_weather["wind"]["speed"]
  
        # Append the city information into city_data list.
        city_database.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          #"Description": city_description,
                          "Wind Speed": city_wind})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | buchanan
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | kleck
# City not found. Skipping...
# Processing Record 6 of Set 1 | naze
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | saint andrews
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | gushi
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | pratapgarh
# Processing Record 14 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 1 | evensk
# Processing Record 16 of Set 1 | cabo san lucas
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | birjand
# Processing Record 20 of Set 1 | cidreira
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | knysna
# Processing Record 23 of Set 1 | manambrag
# City not found. Skipping...
# Processing Record 24 of Set 1 | saint-augustin
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | zhanakorgan
# Processing Record 29 of Set 1 | tazovskiy
# Processing Record 30 of Set 1 | argelia
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | maldonado
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | ferndale
# Processing Record 42 of Set 1 | puerto del rosario
# Processing Record 43 of Set 1 | kingisepp
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | taganak
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 1 | broken hill
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | marawi
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | san patricio
# Processing Record 5 of Set 2 | faya
# Processing Record 6 of Set 2 | severodvinsk
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | agadez
# Processing Record 9 of Set 2 | kahului
# Processing Record 10 of Set 2 | magalia
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | leningradskiy
# Processing Record 13 of Set 2 | komsomolskiy
# Processing Record 14 of Set 2 | sevsk
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | sibiti
# Processing Record 17 of Set 2 | privokzalnyy
# City not found. Skipping...
# Processing Record 18 of Set 2 | nacala
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | monroe
# Processing Record 22 of Set 2 | omboue
# Processing Record 23 of Set 2 | tigil
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | borba
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | astipalaia
# City not found. Skipping...
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | rio gallegos
# Processing Record 32 of Set 2 | arkhara
# Processing Record 33 of Set 2 | gumla
# Processing Record 34 of Set 2 | aktash
# Processing Record 35 of Set 2 | sao filipe
# Processing Record 36 of Set 2 | safranbolu
# Processing Record 37 of Set 2 | moussoro
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | grand gaube
# Processing Record 40 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 2 | tura
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | manyana
# Processing Record 49 of Set 2 | qingdao
# Processing Record 50 of Set 2 | nouadhibou
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | taraz
# Processing Record 4 of Set 3 | cortez
# Processing Record 5 of Set 3 | calvia
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | palmares do sul
# Processing Record 8 of Set 3 | yasnyy
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | feicheng
# Processing Record 11 of Set 3 | atar
# Processing Record 12 of Set 3 | suzu
# City not found. Skipping...
# Processing Record 13 of Set 3 | alice springs
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | sorland
# Processing Record 17 of Set 3 | berdigestyakh
# Processing Record 18 of Set 3 | uirauna
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | pusztaszabolcs
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | jibuti
# Processing Record 24 of Set 3 | makakilo city
# Processing Record 25 of Set 3 | dzilam gonzalez
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | strezhevoy
# Processing Record 28 of Set 3 | samarai
# Processing Record 29 of Set 3 | lorengau
# Processing Record 30 of Set 3 | kandrian
# Processing Record 31 of Set 3 | chapais
# Processing Record 32 of Set 3 | siderno
# Processing Record 33 of Set 3 | barinitas
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | biltine
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | pangnirtung
# Processing Record 39 of Set 3 | kapaa
# Processing Record 40 of Set 3 | shambu
# Processing Record 41 of Set 3 | kralendijk
# Processing Record 42 of Set 3 | san carlos de bariloche
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | dallas
# Processing Record 45 of Set 3 | brownwood
# Processing Record 46 of Set 3 | ketchikan
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 3 | marsa matruh
# Processing Record 49 of Set 3 | kaitangata
# Processing Record 50 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | orangeburg
# Processing Record 5 of Set 4 | isangel
# Processing Record 6 of Set 4 | port hawkesbury
# Processing Record 7 of Set 4 | luanda
# Processing Record 8 of Set 4 | nanortalik
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | bluff
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | townsville
# Processing Record 13 of Set 4 | lasa
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | port lincoln
# Processing Record 16 of Set 4 | katherine
# Processing Record 17 of Set 4 | ganzhou
# Processing Record 18 of Set 4 | maun
# Processing Record 19 of Set 4 | aksha
# Processing Record 20 of Set 4 | mount gambier
# Processing Record 21 of Set 4 | bosaso
# Processing Record 22 of Set 4 | veraval
# Processing Record 23 of Set 4 | bredasdorp
# Processing Record 24 of Set 4 | ayan
# Processing Record 25 of Set 4 | ostrow mazowiecka
# Processing Record 26 of Set 4 | atuona
# Processing Record 27 of Set 4 | wucheng
# Processing Record 28 of Set 4 | tevaitoa
# Processing Record 29 of Set 4 | beyneu
# Processing Record 30 of Set 4 | lompoc
# Processing Record 31 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 4 | svetlyy
# Processing Record 33 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 4 | tecoanapa
# Processing Record 35 of Set 4 | byron bay
# Processing Record 36 of Set 4 | santa cruz
# Processing Record 37 of Set 4 | hastings
# Processing Record 38 of Set 4 | tatvan
# Processing Record 39 of Set 4 | meulaboh
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | axim
# Processing Record 42 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 4 | warrington
# Processing Record 45 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 46 of Set 4 | new norfolk
# Processing Record 47 of Set 4 | port elizabeth
# Processing Record 48 of Set 4 | shirokiy
# Processing Record 49 of Set 4 | asau
# Processing Record 50 of Set 4 | santa cruz de la palma
# Processing Record 1 of Set 5 | praia da vitoria
# Processing Record 2 of Set 5 | olinda
# Processing Record 3 of Set 5 | sarangani
# Processing Record 4 of Set 5 | muros
# Processing Record 5 of Set 5 | porto novo
# Processing Record 6 of Set 5 | baoqing
# Processing Record 7 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 5 | grindavik
# Processing Record 9 of Set 5 | ciras
# City not found. Skipping...
# Processing Record 10 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 5 | north bend
# Processing Record 12 of Set 5 | bethel
# Processing Record 13 of Set 5 | penzance
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | antalaha
# Processing Record 16 of Set 5 | northam
# Processing Record 17 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 5 | atbasar
# Processing Record 19 of Set 5 | atasu
# Processing Record 20 of Set 5 | campbellford
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | effingham
# Processing Record 23 of Set 5 | papara
# Processing Record 24 of Set 5 | hit
# Processing Record 25 of Set 5 | gazanjyk
# Processing Record 26 of Set 5 | shelburne
# Processing Record 27 of Set 5 | rumonge
# Processing Record 28 of Set 5 | menongue
# Processing Record 29 of Set 5 | san quintin
# Processing Record 30 of Set 5 | cherskiy
# Processing Record 31 of Set 5 | uglovskoye
# Processing Record 32 of Set 5 | kalmunai
# Processing Record 33 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 5 | vanimo
# Processing Record 35 of Set 5 | vytegra
# Processing Record 36 of Set 5 | ismailia
# Processing Record 37 of Set 5 | markova
# Processing Record 38 of Set 5 | pemangkat
# Processing Record 39 of Set 5 | ahipara
# Processing Record 40 of Set 5 | jindrichuv hradec
# Processing Record 41 of Set 5 | hudson bay
# Processing Record 42 of Set 5 | ust-ilimsk
# Processing Record 43 of Set 5 | agropoli
# Processing Record 44 of Set 5 | avarua
# Processing Record 45 of Set 5 | gouyave
# Processing Record 46 of Set 5 | camacha
# Processing Record 47 of Set 5 | roma
# Processing Record 48 of Set 5 | sabang
# Processing Record 49 of Set 5 | adrar
# Processing Record 50 of Set 5 | fairbanks
# Processing Record 1 of Set 6 | salinas
# Processing Record 2 of Set 6 | mount isa
# Processing Record 3 of Set 6 | nome
# Processing Record 4 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 5 of Set 6 | gornoye loo
# Processing Record 6 of Set 6 | cap-aux-meules
# Processing Record 7 of Set 6 | liverpool
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | vila velha
# Processing Record 10 of Set 6 | poninka
# Processing Record 11 of Set 6 | fort nelson
# Processing Record 12 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 6 | mizan teferi
# Processing Record 14 of Set 6 | alexandria
# Processing Record 15 of Set 6 | dargaville
# Processing Record 16 of Set 6 | ulaangom
# Processing Record 17 of Set 6 | maceio
# Processing Record 18 of Set 6 | sao lourenco do oeste
# Processing Record 19 of Set 6 | severo-kurilsk
# Processing Record 20 of Set 6 | zunyi
# Processing Record 21 of Set 6 | panacan
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 6 | yaan
# Processing Record 25 of Set 6 | ariquemes
# Processing Record 26 of Set 6 | yanam
# Processing Record 27 of Set 6 | dwarka
# Processing Record 28 of Set 6 | batagay
# Processing Record 29 of Set 6 | nautla
# Processing Record 30 of Set 6 | dukat
# Processing Record 31 of Set 6 | victor harbor
# Processing Record 32 of Set 6 | clyde river
# Processing Record 33 of Set 6 | wajima
# Processing Record 34 of Set 6 | tolyatti
# Processing Record 35 of Set 6 | novoanninskiy
# Processing Record 36 of Set 6 | charters towers
# Processing Record 37 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 38 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 39 of Set 6 | burnie
# Processing Record 40 of Set 6 | kavieng
# Processing Record 41 of Set 6 | mahebourg
# Processing Record 42 of Set 6 | rognan
# Processing Record 43 of Set 6 | oranjemund
# Processing Record 44 of Set 6 | bafq
# Processing Record 45 of Set 6 | bandar-e anzali
# Processing Record 46 of Set 6 | taoudenni
# Processing Record 47 of Set 6 | pyu
# Processing Record 48 of Set 6 | gweta
# Processing Record 49 of Set 6 | mandurah
# Processing Record 50 of Set 6 | coron
# Processing Record 1 of Set 7 | balatan
# Processing Record 2 of Set 7 | tharrawaddy
# City not found. Skipping...
# Processing Record 3 of Set 7 | iquitos
# Processing Record 4 of Set 7 | codrington
# Processing Record 5 of Set 7 | beya
# Processing Record 6 of Set 7 | dzaoudzi
# Processing Record 7 of Set 7 | revda
# Processing Record 8 of Set 7 | abbeville
# Processing Record 9 of Set 7 | abu kamal
# Processing Record 10 of Set 7 | san ignacio
# Processing Record 11 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 7 | port jervis
# Processing Record 13 of Set 7 | linjiang
# Processing Record 14 of Set 7 | nuuk
# Processing Record 15 of Set 7 | inhambane
# Processing Record 16 of Set 7 | toda raisingh
# Processing Record 17 of Set 7 | paamiut
# Processing Record 18 of Set 7 | huainan
# Processing Record 19 of Set 7 | high level
# Processing Record 20 of Set 7 | manzhouli
# Processing Record 21 of Set 7 | miramar
# Processing Record 22 of Set 7 | homer
# Processing Record 23 of Set 7 | coahuayana
# Processing Record 24 of Set 7 | hammerfest
# Processing Record 25 of Set 7 | minab
# Processing Record 26 of Set 7 | kirksville
# Processing Record 27 of Set 7 | korla
# Processing Record 28 of Set 7 | taltal
# Processing Record 29 of Set 7 | ostrovnoy
# Processing Record 30 of Set 7 | wasilla
# Processing Record 31 of Set 7 | sao joao da barra
# Processing Record 32 of Set 7 | castelo branco
# Processing Record 33 of Set 7 | watsa
# Processing Record 34 of Set 7 | anadyr
# Processing Record 35 of Set 7 | dourbali
# Processing Record 36 of Set 7 | jerez
# Processing Record 37 of Set 7 | wismar
# Processing Record 38 of Set 7 | dingle
# Processing Record 39 of Set 7 | palu
# Processing Record 40 of Set 7 | salalah
# Processing Record 41 of Set 7 | paso de carrasco
# Processing Record 42 of Set 7 | seoul
# Processing Record 43 of Set 7 | calama
# Processing Record 44 of Set 7 | ancud
# Processing Record 45 of Set 7 | lazaro cardenas
# Processing Record 46 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 47 of Set 7 | palmer
# Processing Record 48 of Set 7 | stromness
# Processing Record 49 of Set 7 | tiarei
# Processing Record 50 of Set 7 | mayo
# Processing Record 1 of Set 8 | dalby
# Processing Record 2 of Set 8 | leshukonskoye
# Processing Record 3 of Set 8 | bengkulu
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | acapulco
# Processing Record 6 of Set 8 | batsfjord
# Processing Record 7 of Set 8 | lund
# Processing Record 8 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 8 | blagoyevo
# Processing Record 10 of Set 8 | mandera
# Processing Record 11 of Set 8 | beidao
# Processing Record 12 of Set 8 | fare
# Processing Record 13 of Set 8 | ekhabi
# Processing Record 14 of Set 8 | russell
# Processing Record 15 of Set 8 | taonan
# Processing Record 16 of Set 8 | aksu
# Processing Record 17 of Set 8 | kargopol
# Processing Record 18 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 19 of Set 8 | fukue
# Processing Record 20 of Set 8 | san carlos
# Processing Record 21 of Set 8 | husavik
# Processing Record 22 of Set 8 | manono
# Processing Record 23 of Set 8 | luancheng
# Processing Record 24 of Set 8 | hobyo
# Processing Record 25 of Set 8 | yumen
# Processing Record 26 of Set 8 | mahibadhoo
# Processing Record 27 of Set 8 | quixeramobim
# Processing Record 28 of Set 8 | vila franca do campo
# Processing Record 29 of Set 8 | yuli
# Processing Record 30 of Set 8 | havoysund
# Processing Record 31 of Set 8 | yotoco
# Processing Record 32 of Set 8 | pangody
# Processing Record 33 of Set 8 | sann
# Processing Record 34 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 8 | lazdijai
# Processing Record 36 of Set 8 | kagalnitskaya
# Processing Record 37 of Set 8 | phalodi
# Processing Record 38 of Set 8 | shitanjing
# Processing Record 39 of Set 8 | yulara
# Processing Record 40 of Set 8 | kirkuk
# Processing Record 41 of Set 8 | tommot
# Processing Record 42 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 8 | roald
# Processing Record 44 of Set 8 | nhulunbuy
# Processing Record 45 of Set 8 | marzuq
# Processing Record 46 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 8 | sambava
# Processing Record 48 of Set 8 | nanganga
# Processing Record 49 of Set 8 | doka
# Processing Record 50 of Set 8 | falmouth
# Processing Record 1 of Set 9 | lisakovsk
# Processing Record 2 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 9 | tilichiki
# Processing Record 4 of Set 9 | provideniya
# Processing Record 5 of Set 9 | deputatskiy
# Processing Record 6 of Set 9 | panaba
# Processing Record 7 of Set 9 | marsh harbour
# Processing Record 8 of Set 9 | bilma
# Processing Record 9 of Set 9 | kedougou
# Processing Record 10 of Set 9 | vao
# Processing Record 11 of Set 9 | baiyin
# Processing Record 12 of Set 9 | hofn
# Processing Record 13 of Set 9 | ninghai
# Processing Record 14 of Set 9 | bathsheba
# Processing Record 15 of Set 9 | manadhoo
# Processing Record 16 of Set 9 | luderitz
# Processing Record 17 of Set 9 | beian
# Processing Record 18 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 9 | quatre cocos
# Processing Record 20 of Set 9 | trinidad
# Processing Record 21 of Set 9 | algiers
# Processing Record 22 of Set 9 | valea mare-pravat
# City not found. Skipping...
# Processing Record 23 of Set 9 | panindicuaro
# Processing Record 24 of Set 9 | hualmay
# Processing Record 25 of Set 9 | esperance
# Processing Record 26 of Set 9 | namibe
# Processing Record 27 of Set 9 | sawakin
# Processing Record 28 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 29 of Set 9 | port hedland
# Processing Record 30 of Set 9 | khasan
# Processing Record 31 of Set 9 | juneau
# Processing Record 32 of Set 9 | qax
# Processing Record 33 of Set 9 | sainte-maxime
# Processing Record 34 of Set 9 | ukiah
# Processing Record 35 of Set 9 | dolores
# Processing Record 36 of Set 9 | las cruces
# Processing Record 37 of Set 9 | sur
# Processing Record 38 of Set 9 | san jeronimo
# Processing Record 39 of Set 9 | wattegama
# Processing Record 40 of Set 9 | saint-joseph
# Processing Record 41 of Set 9 | port hardy
# Processing Record 42 of Set 9 | krasnoselkup
# Processing Record 43 of Set 9 | sao domingos
# Processing Record 44 of Set 9 | songjianghe
# Processing Record 45 of Set 9 | morondava
# Processing Record 46 of Set 9 | kaoma
# Processing Record 47 of Set 9 | iqaluit
# Processing Record 48 of Set 9 | raudeberg
# Processing Record 49 of Set 9 | san salvo
# Processing Record 50 of Set 9 | kamaishi
# Processing Record 1 of Set 10 | kloulklubed
# Processing Record 2 of Set 10 | melfort
# Processing Record 3 of Set 10 | det udom
# Processing Record 4 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 5 of Set 10 | norton shores
# Processing Record 6 of Set 10 | black river
# Processing Record 7 of Set 10 | bamiantong
# Processing Record 8 of Set 10 | flinders
# Processing Record 9 of Set 10 | huarmey
# Processing Record 10 of Set 10 | wuzhou
# Processing Record 11 of Set 10 | iwanai
# Processing Record 12 of Set 10 | panguipulli
# Processing Record 13 of Set 10 | camana
# Processing Record 14 of Set 10 | saint-pierre
# Processing Record 15 of Set 10 | wanaraja
# Processing Record 16 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 17 of Set 10 | lavrentiya
# Processing Record 18 of Set 10 | broome
# Processing Record 19 of Set 10 | slave lake
# Processing Record 20 of Set 10 | srednekolymsk
# Processing Record 21 of Set 10 | marevo
# Processing Record 22 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 10 | kortkeros
# Processing Record 24 of Set 10 | sovetskiy
# Processing Record 25 of Set 10 | avera
# Processing Record 26 of Set 10 | betong
# Processing Record 27 of Set 10 | houma
# Processing Record 28 of Set 10 | iquique
# Processing Record 29 of Set 10 | lata
# Processing Record 30 of Set 10 | wanning
# Processing Record 31 of Set 10 | mabaruma
# Processing Record 32 of Set 10 | poltavka
# Processing Record 33 of Set 10 | kulhudhuffushi
# Processing Record 34 of Set 10 | pinawa
# Processing Record 35 of Set 10 | san jose
# Processing Record 36 of Set 10 | padang
# Processing Record 37 of Set 10 | kropotkin
# Processing Record 38 of Set 10 | gazli
# Processing Record 39 of Set 10 | merauke
# Processing Record 40 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 10 | sydney
# Processing Record 42 of Set 10 | riyadh
# Processing Record 43 of Set 10 | chililabombwe
# Processing Record 44 of Set 10 | jimani
# Processing Record 45 of Set 10 | guiglo
# Processing Record 46 of Set 10 | mar del plata
# Processing Record 47 of Set 10 | kiama
# Processing Record 48 of Set 10 | lagoa
# Processing Record 49 of Set 10 | xai-xai
# Processing Record 50 of Set 10 | baker city
# Processing Record 1 of Set 11 | burley
# Processing Record 2 of Set 11 | eureka
# Processing Record 3 of Set 11 | vysokogornyy
# Processing Record 4 of Set 11 | ventspils
# Processing Record 5 of Set 11 | terrace bay
# Processing Record 6 of Set 11 | honningsvag
# Processing Record 7 of Set 11 | hovd
# Processing Record 8 of Set 11 | mantua
# Processing Record 9 of Set 11 | thiruvananthapuram
# Processing Record 10 of Set 11 | ust-tsilma
# Processing Record 11 of Set 11 | tual
# Processing Record 12 of Set 11 | ronneby
# Processing Record 13 of Set 11 | gilroy
# Processing Record 14 of Set 11 | faanui
# Processing Record 15 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 11 | abong mbang
# Processing Record 17 of Set 11 | pop
# Processing Record 18 of Set 11 | rocha
# Processing Record 19 of Set 11 | samana
# Processing Record 20 of Set 11 | midland
# Processing Record 21 of Set 11 | koslan
# Processing Record 22 of Set 11 | paita
# Processing Record 23 of Set 11 | orcopampa
# Processing Record 24 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 11 | gamba
# Processing Record 26 of Set 11 | goure
# Processing Record 27 of Set 11 | peniche
# Processing Record 28 of Set 11 | oyama
# Processing Record 29 of Set 11 | dipkarpaz
# City not found. Skipping...
# Processing Record 30 of Set 11 | mareeba
# Processing Record 31 of Set 11 | goksun
# Processing Record 32 of Set 11 | bonavista
# Processing Record 33 of Set 11 | pangkalanbuun
# Processing Record 34 of Set 11 | shymkent
# Processing Record 35 of Set 11 | macusani
# Processing Record 36 of Set 11 | la ronge
# Processing Record 37 of Set 11 | liuhe
# Processing Record 38 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 11 | sairang
# Processing Record 40 of Set 11 | batemans bay
# Processing Record 41 of Set 11 | maniitsoq
# Processing Record 42 of Set 11 | ust-nera
# Processing Record 43 of Set 11 | cairns
# Processing Record 44 of Set 11 | nguru
# Processing Record 45 of Set 11 | sotouboua
# Processing Record 46 of Set 11 | manacapuru
# Processing Record 47 of Set 11 | badiraguato
# Processing Record 48 of Set 11 | minsk
# Processing Record 49 of Set 11 | temirtau
# Processing Record 50 of Set 11 | cozumel
# Processing Record 1 of Set 12 | kalakamati
# Processing Record 2 of Set 12 | teya
# Processing Record 3 of Set 12 | hami
# Processing Record 4 of Set 12 | vila do maio
# Processing Record 5 of Set 12 | longyearbyen
# Processing Record 6 of Set 12 | bontang
# Processing Record 7 of Set 12 | bandarbeyla
# Processing Record 8 of Set 12 | selcuk
# Processing Record 9 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 10 of Set 12 | laguna
# Processing Record 11 of Set 12 | belen
# Processing Record 12 of Set 12 | sahuaripa
# Processing Record 13 of Set 12 | abu dhabi
# Processing Record 14 of Set 12 | surt
# Processing Record 15 of Set 12 | jiexiu
# Processing Record 16 of Set 12 | duz
# City not found. Skipping...
# Processing Record 17 of Set 12 | iwaki
# Processing Record 18 of Set 12 | sinnamary
# Processing Record 19 of Set 12 | brae
# Processing Record 20 of Set 12 | namatanai
# Processing Record 21 of Set 12 | skelleftea
# Processing Record 22 of Set 12 | jiangmen
# Processing Record 23 of Set 12 | brookhaven
# Processing Record 24 of Set 12 | bonthe
# Processing Record 25 of Set 12 | sao felix do xingu
# Processing Record 26 of Set 12 | agapovka
# Processing Record 27 of Set 12 | kieta
# Processing Record 28 of Set 12 | charlottesville
# Processing Record 29 of Set 12 | sitka
# Processing Record 30 of Set 12 | tuim
# Processing Record 31 of Set 12 | vila
# Processing Record 32 of Set 12 | batticaloa
# Processing Record 33 of Set 12 | urbana
# Processing Record 34 of Set 12 | humboldt
# Processing Record 35 of Set 12 | glace bay
# Processing Record 36 of Set 12 | kavaratti
# Processing Record 37 of Set 12 | nortelandia
# Processing Record 38 of Set 12 | vadso
# Processing Record 39 of Set 12 | paka
# Processing Record 40 of Set 12 | skjervoy
# Processing Record 41 of Set 12 | uk
# City not found. Skipping...
# Processing Record 42 of Set 12 | tautira
# Processing Record 43 of Set 12 | bahia blanca
# Processing Record 44 of Set 12 | umm lajj
# Processing Record 45 of Set 12 | yar-sale
# Processing Record 46 of Set 12 | mitzic
# Processing Record 47 of Set 12 | guerrero negro
# Processing Record 48 of Set 12 | kargasok
# Processing Record 49 of Set 12 | santa fe
# Processing Record 50 of Set 12 | panguna
# Processing Record 1 of Set 13 | spearfish
# Processing Record 2 of Set 13 | sulangan
# Processing Record 3 of Set 13 | port lavaca
# Processing Record 4 of Set 13 | glens falls
# Processing Record 5 of Set 13 | gat
# Processing Record 6 of Set 13 | bilibino
# Processing Record 7 of Set 13 | batagay-alyta
# Processing Record 8 of Set 13 | vetapalem
# Processing Record 9 of Set 13 | esna
# Processing Record 10 of Set 13 | lexington
# Processing Record 11 of Set 13 | coquimbo
# Processing Record 12 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 13 | mmabatho
# Processing Record 14 of Set 13 | terbuny
# Processing Record 15 of Set 13 | san juan
# Processing Record 16 of Set 13 | verkhoyansk
# Processing Record 17 of Set 13 | alta gracia
# Processing Record 18 of Set 13 | benguela
# Processing Record 19 of Set 13 | puerto maldonado
# Processing Record 20 of Set 13 | petatlan
# Processing Record 21 of Set 13 | port augusta
# Processing Record 22 of Set 13 | payson
# Processing Record 23 of Set 13 | yefimovskiy
# City not found. Skipping...
# Processing Record 24 of Set 13 | morristown
# Processing Record 25 of Set 13 | vestmannaeyjar
# Processing Record 26 of Set 13 | portland
# Processing Record 27 of Set 13 | rudbar
# Processing Record 28 of Set 13 | tecalitlan
# Processing Record 29 of Set 13 | may pen
# Processing Record 30 of Set 13 | enumclaw
# Processing Record 31 of Set 13 | lukulu
# Processing Record 32 of Set 13 | bara
# Processing Record 33 of Set 13 | aswan
# Processing Record 34 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 36 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 37 of Set 13 | clinton
# Processing Record 38 of Set 13 | hamilton
# Processing Record 39 of Set 13 | maniwaki
# Processing Record 40 of Set 13 | churapcha
# Processing Record 41 of Set 13 | bang saphan
# Processing Record 42 of Set 13 | pacific grove
# Processing Record 43 of Set 13 | randvere
# City not found. Skipping...
# Processing Record 44 of Set 13 | finnsnes
# Processing Record 45 of Set 13 | grootfontein
# Processing Record 46 of Set 13 | mingguang
# Processing Record 47 of Set 13 | madoc
# Processing Record 48 of Set 13 | muscat
# Processing Record 49 of Set 13 | gulbarga
# Processing Record 50 of Set 13 | midyat
# Processing Record 1 of Set 14 | skibbereen
# Processing Record 2 of Set 14 | bhinga
# Processing Record 3 of Set 14 | great bend
# Processing Record 4 of Set 14 | eufaula
# Processing Record 5 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 6 of Set 14 | maarianhamina
# Processing Record 7 of Set 14 | iracoubo
# Processing Record 8 of Set 14 | florence
# Processing Record 9 of Set 14 | makokou
# Processing Record 10 of Set 14 | bela
# Processing Record 11 of Set 14 | werda
# Processing Record 12 of Set 14 | hambantota
# Processing Record 13 of Set 14 | petukhovo
# Processing Record 14 of Set 14 | diffa
# Processing Record 15 of Set 14 | aracataca
# Processing Record 16 of Set 14 | maragogi
# Processing Record 17 of Set 14 | nampula
# Processing Record 18 of Set 14 | shinichi
# Processing Record 19 of Set 14 | margate
# Processing Record 20 of Set 14 | oxelosund
# Processing Record 21 of Set 14 | hervey bay
# Processing Record 22 of Set 14 | hay river
# Processing Record 23 of Set 14 | birao
# Processing Record 24 of Set 14 | melfi
# Processing Record 25 of Set 14 | santiago
# Processing Record 26 of Set 14 | vestmanna
# Processing Record 27 of Set 14 | altay
# Processing Record 28 of Set 14 | fallon
# Processing Record 29 of Set 14 | bousso
# Processing Record 30 of Set 14 | yago
# Processing Record 31 of Set 14 | valparaiso
# Processing Record 32 of Set 14 | lahaina
# Processing Record 33 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 34 of Set 14 | maiduguri
# Processing Record 35 of Set 14 | ranong
# Processing Record 36 of Set 14 | karratha
# Processing Record 37 of Set 14 | mnogovershinnyy
# Processing Record 38 of Set 14 | el bagre
# Processing Record 39 of Set 14 | iznik
# Processing Record 40 of Set 14 | kudahuvadhoo
# Processing Record 41 of Set 14 | sakaiminato
# Processing Record 42 of Set 14 | havre-saint-pierre
# Processing Record 43 of Set 14 | garowe
# Processing Record 44 of Set 14 | mackenzie
# Processing Record 45 of Set 14 | wilmington
# Processing Record 46 of Set 14 | hudiksvall
# Processing Record 47 of Set 14 | arman
# Processing Record 48 of Set 14 | maneadero
# Processing Record 49 of Set 14 | kununurra
# Processing Record 50 of Set 14 | carauari
# Processing Record 1 of Set 15 | araucaria
# Processing Record 2 of Set 15 | teguldet
# Processing Record 3 of Set 15 | sola
# Processing Record 4 of Set 15 | ahuimanu
# Processing Record 5 of Set 15 | kangavar
# Processing Record 6 of Set 15 | soubre
# Processing Record 7 of Set 15 | bridlington
# Processing Record 8 of Set 15 | mahajanga
# Processing Record 9 of Set 15 | kashi
# Processing Record 10 of Set 15 | walvis bay
# Processing Record 11 of Set 15 | canto do buriti
# Processing Record 12 of Set 15 | chiang klang
# Processing Record 13 of Set 15 | yerbogachen
# Processing Record 14 of Set 15 | okhotsk
# Processing Record 15 of Set 15 | tukrah
# Processing Record 16 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 15 | siavonga
# Processing Record 18 of Set 15 | richards bay
# Processing Record 19 of Set 15 | berlevag
# Processing Record 20 of Set 15 | mawlaik
# Processing Record 21 of Set 15 | bongor
# Processing Record 22 of Set 15 | emerald
# Processing Record 23 of Set 15 | college
# Processing Record 24 of Set 15 | sept-iles
# Processing Record 25 of Set 15 | uvalde
# Processing Record 26 of Set 15 | bend
# Processing Record 27 of Set 15 | porgera
# Processing Record 28 of Set 15 | usinsk
# Processing Record 29 of Set 15 | leninsk
# Processing Record 30 of Set 15 | beira
# Processing Record 31 of Set 15 | rabat
# Processing Record 32 of Set 15 | vardo
# Processing Record 33 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 15 | prince rupert
# Processing Record 35 of Set 15 | tadine
# Processing Record 36 of Set 15 | grasse
# Processing Record 37 of Set 15 | hailar
# Processing Record 38 of Set 15 | kawalu
# Processing Record 39 of Set 15 | jumla
# Processing Record 40 of Set 15 | bembereke
# Processing Record 41 of Set 15 | omsukchan
# Processing Record 42 of Set 15 | labuhan
# Processing Record 43 of Set 15 | lakes entrance
# Processing Record 44 of Set 15 | tsybli
# Processing Record 45 of Set 15 | eyl
# Processing Record 46 of Set 15 | alianca
# City not found. Skipping...
# Processing Record 47 of Set 15 | lhuntshi
# City not found. Skipping...
# Processing Record 48 of Set 15 | lianzhou
# Processing Record 49 of Set 15 | comodoro rivadavia
# Processing Record 50 of Set 15 | zaysan
# Processing Record 1 of Set 16 | gravdal
# Processing Record 2 of Set 16 | corrales
# Processing Record 3 of Set 16 | nizhniy baskunchak
# Processing Record 4 of Set 16 | bukama
# Processing Record 5 of Set 16 | olafsvik
# Processing Record 6 of Set 16 | alofi
# Processing Record 7 of Set 16 | tahta
# Processing Record 8 of Set 16 | sri aman
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_database
# Out:
# [{'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 26.1,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 7},
#  {'City': 'Buchanan',
#   'Country': 'LR',
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp': 79.2,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 7.18},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 74.79,
#   'Humidity': 75,
#   'Cloudiness': 38,
#   'Wind Speed': 6.6},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 6.96,
#   'Humidity': 61,
#   'Cloudiness': 99,
#   'Wind Speed': 8.37},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 59.92,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 10.67},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 63.59,
#   'Humidity': 79,
#   'Cloudiness': 58,
#   'Wind Speed': 3.27},
#  {'City': 'Saint Andrews',
#   'Country': 'US',
#   'Lat': 34.0454,
#   'Lng': -81.1293,
#   'Max Temp': 61.32,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 31.08,
#   'Humidity': 85,
#   'Cloudiness': 92,
#   'Wind Speed': 8.99},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 77.81,
#   'Humidity': 44,
#   'Cloudiness': 4,
#   'Wind Speed': 6.11},
#  {'City': 'Gushi',
#   'Country': 'CN',
#   'Lat': 34.6425,
#   'Lng': 109.5843,
#   'Max Temp': 38.52,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 0.58},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 69.8,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.95},
#  {'City': 'Pratapgarh',
#   'Country': 'IN',
#   'Lat': 24.0333,
#   'Lng': 74.7833,
#   'Max Temp': 55.44,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67},
#  {'City': 'Evensk',
#   'Country': 'RU',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': 35.4,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 25.43},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 72.52,
#   'Humidity': 73,
#   'Cloudiness': 19,
#   'Wind Speed': 2.44},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 69.94,
#   'Humidity': 81,
#   'Cloudiness': 69,
#   'Wind Speed': 1.01},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 82.33,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99},
#  {'City': 'Birjand',
#   'Country': 'IR',
#   'Lat': 32.8663,
#   'Lng': 59.2211,
#   'Max Temp': 52.27,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 73.53,
#   'Humidity': 95,
#   'Cloudiness': 82,
#   'Wind Speed': 16.84},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -40.45,
#   'Humidity': 94,
#   'Cloudiness': 74,
#   'Wind Speed': 7.54},
#  {'City': 'Knysna',
#   'Country': 'ZA',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp': 57.58,
#   'Humidity': 83,
#   'Cloudiness': 85,
#   'Wind Speed': 2.01},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 13.32,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 20},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -51.32,
#   'Humidity': 100,
#   'Cloudiness': 61,
#   'Wind Speed': 3.29},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 72.95,
#   'Humidity': 69,
#   'Cloudiness': 76,
#   'Wind Speed': 1.95},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 70.12,
#   'Humidity': 17,
#   'Cloudiness': 30,
#   'Wind Speed': 3.71},
#  {'City': 'Zhanakorgan',
#   'Country': 'KZ',
#   'Lat': 43.9098,
#   'Lng': 67.2495,
#   'Max Temp': 40.68,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 14.43},
#  {'City': 'Tazovskiy',
#   'Country': 'RU',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': -25.64,
#   'Humidity': 98,
#   'Cloudiness': 75,
#   'Wind Speed': 9.13},
#  {'City': 'Argelia',
#   'Country': 'CO',
#   'Lat': 2.2556,
#   'Lng': -77.2488,
#   'Max Temp': 66.72,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.75,
#   'Humidity': 75,
#   'Cloudiness': 37,
#   'Wind Speed': 5.44},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -20.04,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 82.56,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 79.21,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 31.12,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 36.95},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 40.66,
#   'Humidity': 56,
#   'Cloudiness': 75,
#   'Wind Speed': 28.77},
#  {'City': 'Maldonado',
#   'Country': 'UY',
#   'Lat': -34.6667,
#   'Lng': -54.9167,
#   'Max Temp': 72.79,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.11},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -35.3,
#   'Humidity': 94,
#   'Cloudiness': 12,
#   'Wind Speed': 3.85},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 73.36,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91},
#  {'City': 'Ferndale',
#   'Country': 'US',
#   'Lat': 42.4606,
#   'Lng': -83.1347,
#   'Max Temp': 21.99,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44},
#  {'City': 'Puerto Del Rosario',
#   'Country': 'ES',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp': 60.55,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75},
#  {'City': 'Kingisepp',
#   'Country': 'RU',
#   'Lat': 59.3733,
#   'Lng': 28.6134,
#   'Max Temp': 20.37,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 44.71,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 23.02},
#  {'City': 'Taganak',
#   'Country': 'PH',
#   'Lat': 6.0833,
#   'Lng': 118.3,
#   'Max Temp': 77.14,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 68.49,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 1.25},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.25,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 17.9},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 83.91,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 81.5,
#   'Humidity': 77,
#   'Cloudiness': 17,
#   'Wind Speed': 12.55},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 72.64,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 59.88,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 49.86,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 10.94},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 53.71,
#   'Humidity': 91,
#   'Cloudiness': 64,
#   'Wind Speed': 6.91},
#  {'City': 'Severodvinsk',
#   'Country': 'RU',
#   'Lat': 64.5635,
#   'Lng': 39.8302,
#   'Max Temp': 12.31,
#   'Humidity': 86,
#   'Cloudiness': 92,
#   'Wind Speed': 8.55},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.67,
#   'Humidity': 69,
#   'Cloudiness': 51,
#   'Wind Speed': 7.11},
#  {'City': 'Agadez',
#   'Country': 'NE',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 54.3,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 80.83,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11},
#  {'City': 'Magalia',
#   'Country': 'US',
#   'Lat': 39.8121,
#   'Lng': -121.5783,
#   'Max Temp': 40.55,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 59.09,
#   'Humidity': 96,
#   'Cloudiness': 42,
#   'Wind Speed': 8.25},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 18.46,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.93},
#  {'City': 'Komsomolskiy',
#   'Country': 'UZ',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 33.22,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61},
#  {'City': 'Sevsk',
#   'Country': 'RU',
#   'Lat': 52.1491,
#   'Lng': 34.4926,
#   'Max Temp': 21.33,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 14.63},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -32.6,
#   'Humidity': 100,
#   'Cloudiness': 89,
#   'Wind Speed': 2.71},
#  {'City': 'Sibiti',
#   'Country': 'CG',
#   'Lat': -3.6819,
#   'Lng': 13.3499,
#   'Max Temp': 69.4,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.95},
#  {'City': 'Nacala',
#   'Country': 'MZ',
#   'Lat': -14.5428,
#   'Lng': 40.6728,
#   'Max Temp': 78.39,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 5.44},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 17.13,
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 32.75},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -50.98,
#   'Humidity': 99,
#   'Cloudiness': 77,
#   'Wind Speed': 3.4},
#  {'City': 'Monroe',
#   'Country': 'US',
#   'Lat': 43.1501,
#   'Lng': -77.6831,
#   'Max Temp': 25.18,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75},
#  {'City': 'Omboue',
#   'Country': 'GA',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 76.44,
#   'Humidity': 90,
#   'Cloudiness': 95,
#   'Wind Speed': 4.79},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 25.09,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.14},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -21.98,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 50.34,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 8.01},
#  {'City': 'Borba',
#   'Country': 'BR',
#   'Lat': -4.3878,
#   'Lng': -59.5939,
#   'Max Temp': 75.11,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 78.8,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 43.29,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 41.43},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 62.89,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 48.25,
#   'Humidity': 34,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57},
#  {'City': 'Arkhara',
#   'Country': 'RU',
#   'Lat': 49.4212,
#   'Lng': 130.0842,
#   'Max Temp': -15.81,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 4.29},
#  {'City': 'Gumla',
#   'Country': 'IN',
#   'Lat': 23.05,
#   'Lng': 84.55,
#   'Max Temp': 52.74,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 3.58},
#  {'City': 'Aktash',
#   'Country': 'RU',
#   'Lat': 50.3,
#   'Lng': 87.7333,
#   'Max Temp': -8.23,
#   'Humidity': 88,
#   'Cloudiness': 37,
#   'Wind Speed': 5.3},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 76.21,
#   'Humidity': 62,
#   'Cloudiness': 39,
#   'Wind Speed': 9.53},
#  {'City': 'Safranbolu',
#   'Country': 'TR',
#   'Lat': 41.2508,
#   'Lng': 32.6942,
#   'Max Temp': 32.54,
#   'Humidity': 87,
#   'Cloudiness': 16,
#   'Wind Speed': 2.13},
#  {'City': 'Moussoro',
#   'Country': 'TD',
#   'Lat': 13.6408,
#   'Lng': 16.4901,
#   'Max Temp': 61.38,
#   'Humidity': 40,
#   'Cloudiness': 29,
#   'Wind Speed': 17.56},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 68.83,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 0.72},
#  {'City': 'Grand Gaube',
#   'Country': 'MU',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 73.38,
#   'Humidity': 73,
#   'Cloudiness': 11,
#   'Wind Speed': 3},
#  {'City': 'Tura',
#   'Country': 'IN',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 60.06,
#   'Humidity': 59,
#   'Cloudiness': 81,
#   'Wind Speed': 2.19},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 58.89,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 6.02},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 23.31,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 11.25},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 78.87,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 57.63,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 22.12},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 41.47,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 3},
#  {'City': 'Manyana',
#   'Country': 'BW',
#   'Lat': -23.4,
#   'Lng': 21.7167,
#   'Max Temp': 74.8,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 5.84},
#  {'City': 'Qingdao',
#   'Country': 'CN',
#   'Lat': 36.0986,
#   'Lng': 120.3719,
#   'Max Temp': 28,
#   'Humidity': 80,
#   'Cloudiness': 4,
#   'Wind Speed': 2.24},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 69.78,
#   'Humidity': 37,
#   'Cloudiness': 9,
#   'Wind Speed': 14.97},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 19.4,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.08},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.89,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68},
#  {'City': 'Taraz',
#   'Country': 'KZ',
#   'Lat': 42.9,
#   'Lng': 71.3667,
#   'Max Temp': 43.29,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 6.71},
#  {'City': 'Cortez',
#   'Country': 'US',
#   'Lat': 37.3489,
#   'Lng': -108.5859,
#   'Max Temp': 23.41,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44},
#  {'City': 'Calvia',
#   'Country': 'ES',
#   'Lat': 39.5657,
#   'Lng': 2.5062,
#   'Max Temp': 53.42,
#   'Humidity': 89,
#   'Cloudiness': 47,
#   'Wind Speed': 1.01},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 70.02,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01},
#  {'City': 'Palmares Do Sul',
#   'Country': 'BR',
#   'Lat': -30.2578,
#   'Lng': -50.5097,
#   'Max Temp': 73.58,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 10.56},
#  {'City': 'Yasnyy',
#   'Country': 'RU',
#   'Lat': 51.0333,
#   'Lng': 59.8742,
#   'Max Temp': 27.59,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 15.82},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -29.16,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66},
#  {'City': 'Feicheng',
#   'Country': 'CN',
#   'Lat': 35.2606,
#   'Lng': 117.9675,
#   'Max Temp': 37.96,
#   'Humidity': 61,
#   'Cloudiness': 4,
#   'Wind Speed': 3.42},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 63.07,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 10.49},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 99.95,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 59.05,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 18.77},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 74.64,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 7.14},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 40.41,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 29.1},
#  {'City': 'Berdigestyakh',
#   'Country': 'RU',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': -32.55,
#   'Humidity': 100,
#   'Cloudiness': 72,
#   'Wind Speed': 4.81},
#  {'City': 'Uirauna',
#   'Country': 'BR',
#   'Lat': -6.5183,
#   'Lng': -38.4122,
#   'Max Temp': 77.68,
#   'Humidity': 69,
#   'Cloudiness': 13,
#   'Wind Speed': 4.94},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 59.58,
#   'Humidity': 94,
#   'Cloudiness': 5,
#   'Wind Speed': 5.59},
#  {'City': 'Pusztaszabolcs',
#   'Country': 'HU',
#   'Lat': 47.1372,
#   'Lng': 18.767,
#   'Max Temp': 39.69,
#   'Humidity': 79,
#   'Cloudiness': 66,
#   'Wind Speed': 8.5},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 73.22,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91},
#  {'City': 'Jibuti',
#   'Country': 'DJ',
#   'Lat': 11.5,
#   'Lng': 42.5,
#   'Max Temp': 74.62,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 7.9},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 70.02,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05},
#  {'City': 'Dzilam Gonzalez',
#   'Country': 'MX',
#   'Lat': 21.2833,
#   'Lng': -88.9333,
#   'Max Temp': 76.08,
#   'Humidity': 86,
#   'Cloudiness': 81,
#   'Wind Speed': 6.35},
#  {'City': 'Coihaique',
#   'Country': 'CL',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 47.01,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84},
#  {'City': 'Strezhevoy',
#   'Country': 'RU',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': 13.98,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.08},
#  {'City': 'Samarai',
#   'Country': 'PG',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 85.32,
#   'Humidity': 69,
#   'Cloudiness': 82,
#   'Wind Speed': 6.89},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 83.39,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36},
#  {'City': 'Kandrian',
#   'Country': 'PG',
#   'Lat': -6.2167,
#   'Lng': 149.55,
#   'Max Temp': 86.4,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 7.4},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': -13.22,
#   'Humidity': 100,
#   'Cloudiness': 82,
#   'Wind Speed': 3.47},
#  {'City': 'Siderno',
#   'Country': 'IT',
#   'Lat': 38.2779,
#   'Lng': 16.302,
#   'Max Temp': 57.79,
#   'Humidity': 85,
#   'Cloudiness': 27,
#   'Wind Speed': 11.9},
#  {'City': 'Barinitas',
#   'Country': 'VE',
#   'Lat': 8.7622,
#   'Lng': -70.4111,
#   'Max Temp': 71.67,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 5.41},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -31.4,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 4.07},
#  {'City': 'Biltine',
#   'Country': 'TD',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 58.89,
#   'Humidity': 45,
#   'Cloudiness': 95,
#   'Wind Speed': 16.35},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -30.59,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 14.49,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.25},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 78.78,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99},
#  {'City': 'Shambu',
#   'Country': 'ET',
#   'Lat': 9.5667,
#   'Lng': 37.1,
#   'Max Temp': 50.61,
#   'Humidity': 85,
#   'Cloudiness': 45,
#   'Wind Speed': 1.28},
#  {'City': 'Kralendijk',
#   'Country': 'BQ',
#   'Lat': 12.15,
#   'Lng': -68.2667,
#   'Max Temp': 80.58,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11},
#  {'City': 'San Carlos De Bariloche',
#   'Country': 'AR',
#   'Lat': -41.1456,
#   'Lng': -71.3082,
#   'Max Temp': 51.55,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 26.02,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.31},
#  {'City': 'Dallas',
#   'Country': 'US',
#   'Lat': 32.7668,
#   'Lng': -96.7836,
#   'Max Temp': 36,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01},
#  {'City': 'Brownwood',
#   'Country': 'US',
#   'Lat': 31.7093,
#   'Lng': -98.9912,
#   'Max Temp': 35.37,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 5.66},
#  {'City': 'Ketchikan',
#   'Country': 'US',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 35.58,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57},
#  {'City': 'Marsa Matruh',
#   'Country': 'EG',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 61,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 67.93,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 9.75},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 15.82,
#   'Humidity': 38,
#   'Cloudiness': 96,
#   'Wind Speed': 3.44},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 65.23,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 5.55},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -4.05,
#   'Humidity': 69,
#   'Cloudiness': 37,
#   'Wind Speed': 7.52},
#  {'City': 'Orangeburg',
#   'Country': 'US',
#   'Lat': 33.4918,
#   'Lng': -80.8557,
#   'Max Temp': 61.09,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 82.51,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61},
#  {'City': 'Port Hawkesbury',
#   'Country': 'CA',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 35.58,
#   'Humidity': 99,
#   'Cloudiness': 90,
#   'Wind Speed': 5.99},
#  {'City': 'Luanda',
#   'Country': 'AO',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 76.33,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.37},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 29.61,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 22.91},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 68.81,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 6.11},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 64.65,
#   'Humidity': 85,
#   'Cloudiness': 30,
#   'Wind Speed': 3.67},
#  {'City': 'Townsville',
#   'Country': 'AU',
#   'Lat': -19.25,
#   'Lng': 146.8,
#   'Max Temp': 88.68,
#   'Humidity': 74,
#   'Cloudiness': 18,
#   'Wind Speed': 8.05},
#  {'City': 'Lasa',
#   'Country': 'IT',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 41.88,
#   'Humidity': 73,
#   'Cloudiness': 51,
#   'Wind Speed': 5.55},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -22,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 66.36,
#   'Humidity': 55,
#   'Cloudiness': 8,
#   'Wind Speed': 12.59},
#  {'City': 'Katherine',
#   'Country': 'AU',
#   'Lat': -14.4667,
#   'Lng': 132.2667,
#   'Max Temp': 92.86,
#   'Humidity': 52,
#   'Cloudiness': 93,
#   'Wind Speed': 5.88},
#  {'City': 'Ganzhou',
#   'Country': 'CN',
#   'Lat': 28.8184,
#   'Lng': 115.4327,
#   'Max Temp': 53.71,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 2.13},
#  {'City': 'Maun',
#   'Country': 'BW',
#   'Lat': -19.9833,
#   'Lng': 23.4167,
#   'Max Temp': 73.04,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 3.53},
#  {'City': 'Aksha',
#   'Country': 'RU',
#   'Lat': 50.2814,
#   'Lng': 113.2867,
#   'Max Temp': 1.04,
#   'Humidity': 85,
#   'Cloudiness': 23,
#   'Wind Speed': 3.11},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 67.91,
#   'Humidity': 52,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41},
#  {'City': 'Bosaso',
#   'Country': 'SO',
#   'Lat': 11.2842,
#   'Lng': 49.1816,
#   'Max Temp': 73.35,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 8.77},
#  {'City': 'Veraval',
#   'Country': 'IN',
#   'Lat': 20.9,
#   'Lng': 70.3667,
#   'Max Temp': 70.43,
#   'Humidity': 66,
#   'Cloudiness': 5,
#   'Wind Speed': 10.56},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 54.72,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44},
#  {'City': 'Ayan',
#   'Country': 'RU',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': -13.97,
#   'Humidity': 68,
#   'Cloudiness': 89,
#   'Wind Speed': 11.92},
#  {'City': 'Ostrow Mazowiecka',
#   'Country': 'PL',
#   'Lat': 52.8024,
#   'Lng': 21.8951,
#   'Max Temp': 49.62,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 20.65},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 79.2,
#   'Humidity': 67,
#   'Cloudiness': 23,
#   'Wind Speed': 18.01},
#  {'City': 'Wucheng',
#   'Country': 'CN',
#   'Lat': 29.6008,
#   'Lng': 118.175,
#   'Max Temp': 52.65,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 0.22},
#  {'City': 'Tevaitoa',
#   'Country': 'PF',
#   'Lat': -16.7833,
#   'Lng': -151.5,
#   'Max Temp': 75.54,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 14.14},
#  {'City': 'Beyneu',
#   'Country': 'KZ',
#   'Lat': 45.3167,
#   'Lng': 55.2,
#   'Max Temp': 34.97,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.15},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 55.71,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44},
#  {'City': 'Svetlyy',
#   'Country': 'RU',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 44.65,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 19.3},
#  {'City': 'Tecoanapa',
#   'Country': 'MX',
#   'Lat': 16.5167,
#   'Lng': -98.75,
#   'Max Temp': 77.74,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 4.5},
#  {'City': 'Byron Bay',
#   'Country': 'AU',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 83.05,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 22.17},
#  {'City': 'Santa Cruz',
#   'Country': 'BO',
#   'Lat': -17.8,
#   'Lng': -63.1667,
#   'Max Temp': 80.06,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05},
#  {'City': 'Hastings',
#   'Country': 'GB',
#   'Lat': 50.8552,
#   'Lng': 0.5729,
#   'Max Temp': 53.38,
#   'Humidity': 79,
#   'Cloudiness': 28,
#   'Wind Speed': 27.4},
#  {'City': 'Tatvan',
#   'Country': 'TR',
#   'Lat': 38.5067,
#   'Lng': 42.2817,
#   'Max Temp': 17.78,
#   'Humidity': 97,
#   'Cloudiness': 95,
#   'Wind Speed': 2.37},
#  {'City': 'Meulaboh',
#   'Country': 'ID',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 77.79,
#   'Humidity': 84,
#   'Cloudiness': 83,
#   'Wind Speed': 1.81},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -2.92,
#   'Humidity': 83,
#   'Cloudiness': 46,
#   'Wind Speed': 7.76},
#  {'City': 'Axim',
#   'Country': 'GH',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 79.02,
#   'Humidity': 82,
#   'Cloudiness': 18,
#   'Wind Speed': 3.06},
#  {'City': 'Warrington',
#   'Country': 'GB',
#   'Lat': 53.3925,
#   'Lng': -2.5802,
#   'Max Temp': 50.92,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 5.99},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 69.66,
#   'Humidity': 40,
#   'Cloudiness': 99,
#   'Wind Speed': 3.51},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 62.89,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61},
#  {'City': 'Shirokiy',
#   'Country': 'RU',
#   'Lat': 49.758,
#   'Lng': 129.523,
#   'Max Temp': -13.11,
#   'Humidity': 90,
#   'Cloudiness': 82,
#   'Wind Speed': 7.29},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 31.12,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.61},
#  {'City': 'Santa Cruz De La Palma',
#   'Country': 'ES',
#   'Lat': 28.6835,
#   'Lng': -17.7642,
#   'Max Temp': 75.15,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05},
#  {'City': 'Praia Da Vitoria',
#   'Country': 'PT',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 58.75,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 15.73},
#  {'City': 'Olinda',
#   'Country': 'BR',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 80.33,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91},
#  {'City': 'Sarangani',
#   'Country': 'PH',
#   'Lat': 5.4033,
#   'Lng': 125.4636,
#   'Max Temp': 80.24,
#   'Humidity': 81,
#   'Cloudiness': 51,
#   'Wind Speed': 21.99},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 58.08,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.02},
#  {'City': 'Porto Novo',
#   'Country': 'BJ',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 82.22,
#   'Humidity': 80,
#   'Cloudiness': 13,
#   'Wind Speed': 3.22},
#  {'City': 'Baoqing',
#   'Country': 'CN',
#   'Lat': 46.3317,
#   'Lng': 132.2111,
#   'Max Temp': 3.45,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 10.6},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 23.47,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36},
#  {'City': 'North Bend',
#   'Country': 'US',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 52.92,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 40.5,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99},
#  {'City': 'Penzance',
#   'Country': 'GB',
#   'Lat': 50.1186,
#   'Lng': -5.5371,
#   'Max Temp': 52.81,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 28.83},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 65.71,
#   'Humidity': 25,
#   'Cloudiness': 90,
#   'Wind Speed': 11.81},
#  {'City': 'Antalaha',
#   'Country': 'MG',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 74.71,
#   'Humidity': 89,
#   'Cloudiness': 49,
#   'Wind Speed': 3.67},
#  {'City': 'Northam',
#   'Country': 'GB',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 52.43,
#   'Humidity': 90,
#   'Cloudiness': 15,
#   'Wind Speed': 24},
#  {'City': 'Atbasar',
#   'Country': 'KZ',
#   'Lat': 51.8,
#   'Lng': 68.3333,
#   'Max Temp': 13.44,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.11},
#  {'City': 'Atasu',
#   'Country': 'KZ',
#   'Lat': 48.6814,
#   'Lng': 71.6433,
#   'Max Temp': 19.02,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 6.04},
#  {'City': 'Campbellford',
#   'Country': 'CA',
#   'Lat': 44.3084,
#   'Lng': -77.7995,
#   'Max Temp': 16.68,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 7.05},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 69.85,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5},
#  {'City': 'Effingham',
#   'Country': 'US',
#   'Lat': 32.3669,
#   'Lng': -81.3332,
#   'Max Temp': 74.86,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.48},
#  {'City': 'Papara',
#   'Country': 'BR',
#   'Lat': -3.9839,
#   'Lng': -38.7273,
#   'Max Temp': 79.68,
#   'Humidity': 92,
#   'Cloudiness': 82,
#   'Wind Speed': 3.11},
#  {'City': 'Hit',
#   'Country': 'IQ',
#   'Lat': 33.6416,
#   'Lng': 42.8251,
#   'Max Temp': 51.22,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 5.39},
#  {'City': 'Gazanjyk',
#   'Country': 'TM',
#   'Lat': 39.2446,
#   'Lng': 55.5154,
#   'Max Temp': 43.84,
#   'Humidity': 67,
#   'Cloudiness': 99,
#   'Wind Speed': 3.4},
#  {'City': 'Shelburne',
#   'Country': 'CA',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 12.18,
#   'Humidity': 89,
#   'Cloudiness': 86,
#   'Wind Speed': 7.56},
#  {'City': 'Rumonge',
#   'Country': 'BI',
#   'Lat': -3.9736,
#   'Lng': 29.4386,
#   'Max Temp': 70.41,
#   'Humidity': 83,
#   'Cloudiness': 57,
#   'Wind Speed': 4.25},
#  {'City': 'Menongue',
#   'Country': 'AO',
#   'Lat': -14.6585,
#   'Lng': 17.691,
#   'Max Temp': 62.06,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 56.91,
#   'Humidity': 50,
#   'Cloudiness': 50,
#   'Wind Speed': 6.91},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 4.26,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.88},
#  {'City': 'Uglovskoye',
#   'Country': 'RU',
#   'Lat': 51.3557,
#   'Lng': 80.1942,
#   'Max Temp': 18.66,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9},
#  {'City': 'Kalmunai',
#   'Country': 'LK',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 76.71,
#   'Humidity': 88,
#   'Cloudiness': 47,
#   'Wind Speed': 5.77},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 80.01,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.07},
#  {'City': 'Vytegra',
#   'Country': 'RU',
#   'Lat': 61.0064,
#   'Lng': 36.4481,
#   'Max Temp': -5.69,
#   'Humidity': 100,
#   'Cloudiness': 88,
#   'Wind Speed': 1.68},
#  {'City': 'Ismailia',
#   'Country': 'EG',
#   'Lat': 30.6043,
#   'Lng': 32.2723,
#   'Max Temp': 54.66,
#   'Humidity': 87,
#   'Cloudiness': 4,
#   'Wind Speed': 8.52},
#  {'City': 'Markova',
#   'Country': 'UA',
#   'Lat': 48.6758,
#   'Lng': 24.4138,
#   'Max Temp': 44.78,
#   'Humidity': 78,
#   'Cloudiness': 83,
#   'Wind Speed': 13.76},
#  {'City': 'Pemangkat',
#   'Country': 'ID',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 77.4,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.67},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 73.67,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 1.05},
#  {'City': 'Jindrichuv Hradec',
#   'Country': 'CZ',
#   'Lat': 49.144,
#   'Lng': 15.003,
#   'Max Temp': 48.04,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4},
#  {'City': 'Hudson Bay',
#   'Country': 'CA',
#   'Lat': 52.85,
#   'Lng': -102.3842,
#   'Max Temp': 1.71,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.23},
#  {'City': 'Ust-Ilimsk',
#   'Country': 'RU',
#   'Lat': 58.0006,
#   'Lng': 102.6619,
#   'Max Temp': 10.35,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59},
#  {'City': 'Agropoli',
#   'Country': 'IT',
#   'Lat': 40.3469,
#   'Lng': 14.9966,
#   'Max Temp': 55.29,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 82.45,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41},
#  {'City': 'Gouyave',
#   'Country': 'GD',
#   'Lat': 12.1646,
#   'Lng': -61.7296,
#   'Max Temp': 77.77,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66},
#  {'City': 'Camacha',
#   'Country': 'PT',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 65.16,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44},
#  {'City': 'Roma',
#   'Country': 'US',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 24.84,
#   'Humidity': 89,
#   'Cloudiness': 32,
#   'Wind Speed': 5.01},
#  {'City': 'Sabang',
#   'Country': 'ID',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 80.73,
#   'Humidity': 76,
#   'Cloudiness': 12,
#   'Wind Speed': 19.1},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 59.45,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 11.48},
#  {'City': 'Fairbanks',
#   'Country': 'US',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': -29.51,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 0},
#  {'City': 'Salinas',
#   'Country': 'US',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Max Temp': 54.5,
#   'Humidity': 73,
#   'Cloudiness': 3,
#   'Wind Speed': 1.12},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 98.37,
#   'Humidity': 34,
#   'Cloudiness': 11,
#   'Wind Speed': 9.22},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': -14.84,
#   'Humidity': 77,
#   'Cloudiness': 15,
#   'Wind Speed': 3.76},
#  {'City': 'Gornoye Loo',
#   'Country': 'RU',
#   'Lat': 43.7129,
#   'Lng': 39.6049,
#   'Max Temp': 33.58,
#   'Humidity': 69,
#   'Cloudiness': 45,
#   'Wind Speed': 5.99},
#  {'City': 'Cap-Aux-Meules',
#   'Country': 'CA',
#   'Lat': 47.3821,
#   'Lng': -61.8597,
#   'Max Temp': 28.45,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 25.32},
#  {'City': 'Liverpool',
#   'Country': 'GB',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 50.77,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 3},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 25.29,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 19.73},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 76.95,
#   'Humidity': 91,
#   'Cloudiness': 40,
#   'Wind Speed': 5.01},
#  {'City': 'Poninka',
#   'Country': 'UA',
#   'Lat': 50.1849,
#   'Lng': 27.5363,
#   'Max Temp': 40.98,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 16.89},
#  {'City': 'Fort Nelson',
#   'Country': 'CA',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': -18.81,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75},
#  {'City': 'Mizan Teferi',
#   'Country': 'ET',
#   'Lat': 6.9833,
#   'Lng': 35.5833,
#   'Max Temp': 63.79,
#   'Humidity': 71,
#   'Cloudiness': 36,
#   'Wind Speed': 2.77},
#  {'City': 'Alexandria',
#   'Country': 'EG',
#   'Lat': 31.2156,
#   'Lng': 29.9553,
#   'Max Temp': 57.16,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61},
#  {'City': 'Dargaville',
#   'Country': 'NZ',
#   'Lat': -35.9333,
#   'Lng': 173.8833,
#   'Max Temp': 77.02,
#   'Humidity': 43,
#   'Cloudiness': 88,
#   'Wind Speed': 8.28},
#  {'City': 'Ulaangom',
#   'Country': 'MN',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': -19.61,
#   'Humidity': 95,
#   'Cloudiness': 88,
#   'Wind Speed': 2.71},
#  {'City': 'Maceio',
#   'Country': 'BR',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 78.24,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61},
#  {'City': 'Sao Lourenco Do Oeste',
#   'Country': 'BR',
#   'Lat': -26.3592,
#   'Lng': -52.8511,
#   'Max Temp': 66.47,
#   'Humidity': 80,
#   'Cloudiness': 41,
#   'Wind Speed': 5.61},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 27.37,
#   'Humidity': 58,
#   'Cloudiness': 35,
#   'Wind Speed': 1.72},
#  {'City': 'Zunyi',
#   'Country': 'CN',
#   'Lat': 27.6867,
#   'Lng': 106.9072,
#   'Max Temp': 43.2,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08},
#  {'City': 'Panacan',
#   'Country': 'PH',
#   'Lat': 9.2463,
#   'Lng': 118.4082,
#   'Max Temp': 78.26,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 15.41},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 46.51,
#   'Humidity': 47,
#   'Cloudiness': 38,
#   'Wind Speed': 9.89},
#  {'City': 'Yaan',
#   'Country': 'NG',
#   'Lat': 7.3833,
#   'Lng': 8.5667,
#   'Max Temp': 76.57,
#   'Humidity': 24,
#   'Cloudiness': 9,
#   'Wind Speed': 8.05},
#  {'City': 'Ariquemes',
#   'Country': 'BR',
#   'Lat': -9.9133,
#   'Lng': -63.0408,
#   'Max Temp': 73.17,
#   'Humidity': 99,
#   'Cloudiness': 20,
#   'Wind Speed': 2.89},
#  {'City': 'Yanam',
#   'Country': 'IN',
#   'Lat': 16.7333,
#   'Lng': 82.2167,
#   'Max Temp': 73.8,
#   'Humidity': 80,
#   'Cloudiness': 16,
#   'Wind Speed': 5.46},
#  {'City': 'Dwarka',
#   'Country': 'IN',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 70.32,
#   'Humidity': 73,
#   'Cloudiness': 10,
#   'Wind Speed': 10.83},
#  {'City': 'Batagay',
#   'Country': 'RU',
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': -54,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.05},
#  {'City': 'Nautla',
#   'Country': 'MX',
#   'Lat': 20.2167,
#   'Lng': -96.7833,
#   'Max Temp': 62.73,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 17.09},
#  {'City': 'Dukat',
#   'Country': 'RU',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': -0.92,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84},
#  {'City': 'Victor Harbor',
#   'Country': 'AU',
#   'Lat': -35.5667,
#   'Lng': 138.6167,
#   'Max Temp': 77.72,
#   'Humidity': 63,
#   'Cloudiness': 47,
#   'Wind Speed': 1.01},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -3.77,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 16.11},
#  {'City': 'Wajima',
#   'Country': 'JP',
#   'Lat': 37.4,
#   'Lng': 136.9,
#   'Max Temp': 36.28,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44},
#  {'City': 'Tolyatti',
#   'Country': 'RU',
#   'Lat': 53.5303,
#   'Lng': 49.3461,
#   'Max Temp': 17.96,
#   'Humidity': 95,
#   'Cloudiness': 40,
#   'Wind Speed': 6.02},
#  {'City': 'Novoanninskiy',
#   'Country': 'RU',
#   'Lat': 50.5287,
#   'Lng': 42.6747,
#   'Max Temp': -5.24,
#   'Humidity': 100,
#   'Cloudiness': 59,
#   'Wind Speed': 5.5},
#  {'City': 'Charters Towers',
#   'Country': 'AU',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 97.16,
#   'Humidity': 28,
#   'Cloudiness': 56,
#   'Wind Speed': 7.14},
#  {'City': 'Burnie',
#   'Country': 'AU',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 66.11,
#   'Humidity': 64,
#   'Cloudiness': 86,
#   'Wind Speed': 7.47},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.01,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 13.69},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 73.26,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91},
#  {'City': 'Rognan',
#   'Country': 'NO',
#   'Lat': 67.0953,
#   'Lng': 15.3878,
#   'Max Temp': 39.34,
#   'Humidity': 85,
#   'Cloudiness': 76,
#   'Wind Speed': 11.03},
#  {'City': 'Oranjemund',
#   'Country': 'NA',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 61.36,
#   'Humidity': 88,
#   'Cloudiness': 4,
#   'Wind Speed': 16.62},
#  {'City': 'Bafq',
#   'Country': 'IR',
#   'Lat': 31.6128,
#   'Lng': 55.4107,
#   'Max Temp': 53.15,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15},
#  {'City': 'Bandar-E Anzali',
#   'Country': 'IR',
#   'Lat': 37.4727,
#   'Lng': 49.4622,
#   'Max Temp': 51.3,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 15.26},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 63.12,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 13.42},
#  {'City': 'Pyu',
#   'Country': 'MM',
#   'Lat': 18.4833,
#   'Lng': 96.4333,
#   'Max Temp': 71.04,
#   'Humidity': 60,
#   'Cloudiness': 39,
#   'Wind Speed': 4.52},
#  {'City': 'Gweta',
#   'Country': 'BW',
#   'Lat': -20.1833,
#   'Lng': 25.2333,
#   'Max Temp': 76.87,
#   'Humidity': 59,
#   'Cloudiness': 94,
#   'Wind Speed': 8.01},
#  {'City': 'Mandurah',
#   'Country': 'AU',
#   'Lat': -32.55,
#   'Lng': 115.7,
#   'Max Temp': 83.16,
#   'Humidity': 48,
#   'Cloudiness': 6,
#   'Wind Speed': 9.86},
#  {'City': 'Coron',
#   'Country': 'PH',
#   'Lat': 11.9986,
#   'Lng': 120.2043,
#   'Max Temp': 79.57,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 12.06},
#  {'City': 'Balatan',
#   'Country': 'PH',
#   'Lat': 13.3211,
#   'Lng': 123.2333,
#   'Max Temp': 79.97,
#   'Humidity': 67,
#   'Cloudiness': 98,
#   'Wind Speed': 7.72},
#  {'City': 'Iquitos',
#   'Country': 'PE',
#   'Lat': -3.7481,
#   'Lng': -73.2472,
#   'Max Temp': 78.84,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 0},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 65.82,
#   'Humidity': 47,
#   'Cloudiness': 37,
#   'Wind Speed': 14.74},
#  {'City': 'Beya',
#   'Country': 'RU',
#   'Lat': 53.0533,
#   'Lng': 90.9139,
#   'Max Temp': 22.53,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 4.79},
#  {'City': 'Dzaoudzi',
#   'Country': 'YT',
#   'Lat': -12.7887,
#   'Lng': 45.2699,
#   'Max Temp': 78.69,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3},
#  {'City': 'Revda',
#   'Country': 'RU',
#   'Lat': 56.801,
#   'Lng': 59.9303,
#   'Max Temp': 22.12,
#   'Humidity': 89,
#   'Cloudiness': 94,
#   'Wind Speed': 10.4},
#  {'City': 'Abbeville',
#   'Country': 'FR',
#   'Lat': 50.1,
#   'Lng': 1.8333,
#   'Max Temp': 51.76,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 20.18},
#  {'City': 'Abu Kamal',
#   'Country': 'SY',
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp': 49.06,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38},
#  {'City': 'San Ignacio',
#   'Country': 'BZ',
#   'Lat': 17.1561,
#   'Lng': -89.0714,
#   'Max Temp': 74.19,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.99},
#  {'City': 'Port Jervis',
#   'Country': 'US',
#   'Lat': 41.3751,
#   'Lng': -74.6927,
#   'Max Temp': 36.61,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 12.39},
#  {'City': 'Linjiang',
#   'Country': 'CN',
#   'Lat': 41.8069,
#   'Lng': 126.9078,
#   'Max Temp': 12.25,
#   'Humidity': 63,
#   'Cloudiness': 79,
#   'Wind Speed': 2.73},
#  {'City': 'Nuuk',
#   'Country': 'GL',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 20.39,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 12.24},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 77.68,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 4.74},
#  {'City': 'Toda Raisingh',
#   'Country': 'IN',
#   'Lat': 26.0252,
#   'Lng': 75.4849,
#   'Max Temp': 52.68,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62},
#  {'City': 'Paamiut',
#   'Country': 'GL',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 32.02,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 30.71},
#  {'City': 'Huainan',
#   'Country': 'CN',
#   'Lat': 32.6264,
#   'Lng': 116.9969,
#   'Max Temp': 45.73,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 3.53},
#  {'City': 'High Level',
#   'Country': 'CA',
#   'Lat': 58.5169,
#   'Lng': -117.136,
#   'Max Temp': -20.09,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57},
#  {'City': 'Manzhouli',
#   'Country': 'CN',
#   'Lat': 49.6,
#   'Lng': 117.4333,
#   'Max Temp': -4.43,
#   'Humidity': 90,
#   'Cloudiness': 9,
#   'Wind Speed': 8.79},
#  {'City': 'Miramar',
#   'Country': 'US',
#   'Lat': 25.9873,
#   'Lng': -80.2323,
#   'Max Temp': 77.02,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 9.55},
#  {'City': 'Homer',
#   'Country': 'US',
#   'Lat': 59.6425,
#   'Lng': -151.5483,
#   'Max Temp': 6.76,
#   'Humidity': 60,
#   'Cloudiness': 16,
#   'Wind Speed': 18.61},
#  {'City': 'Coahuayana',
#   'Country': 'MX',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 73.67,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 3.11},
#  {'City': 'Hammerfest',
#   'Country': 'NO',
#   'Lat': 70.6634,
#   'Lng': 23.6821,
#   'Max Temp': 18.05,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 25.32},
#  {'City': 'Minab',
#   'Country': 'IR',
#   'Lat': 27.1467,
#   'Lng': 57.0801,
#   'Max Temp': 65.7,
#   'Humidity': 78,
#   'Cloudiness': 69,
#   'Wind Speed': 19.46},
#  {'City': 'Kirksville',
#   'Country': 'US',
#   'Lat': 40.1948,
#   'Lng': -92.5833,
#   'Max Temp': 1.58,
#   'Humidity': 97,
#   'Cloudiness': 5,
#   'Wind Speed': 4.61},
#  {'City': 'Korla',
#   'Country': 'CN',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 19.27,
#   'Humidity': 67,
#   'Cloudiness': 18,
#   'Wind Speed': 1.43},
#  {'City': 'Taltal',
#   'Country': 'CL',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 67.32,
#   'Humidity': 78,
#   'Cloudiness': 2,
#   'Wind Speed': 4.32},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 16.21,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 17.43},
#  {'City': 'Wasilla',
#   'Country': 'US',
#   'Lat': 61.5814,
#   'Lng': -149.4394,
#   'Max Temp': -3.6,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.94},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 74.91,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.91},
#  {'City': 'Castelo Branco',
#   'Country': 'PT',
#   'Lat': 39.8222,
#   'Lng': -7.4909,
#   'Max Temp': 47.12,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74},
#  {'City': 'Watsa',
#   'Country': 'CD',
#   'Lat': 3.0372,
#   'Lng': 29.5355,
#   'Max Temp': 66,
#   'Humidity': 78,
#   'Cloudiness': 58,
#   'Wind Speed': 1.34},
#  {'City': 'Anadyr',
# ...
#   'Max Temp': 49.42,
#   'Humidity': 72,
#   'Cloudiness': 3,
#   'Wind Speed': 5.99},
#  {'City': 'Great Bend',
#   'Country': 'US',
#   'Lat': 38.3645,
#   'Lng': -98.7648,
#   'Max Temp': 20.03,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22},
#  {'City': 'Eufaula',
#   'Country': 'US',
#   'Lat': 31.8913,
#   'Lng': -85.1455,
#   'Max Temp': 66.63,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 0},
#  {'City': 'Maarianhamina',
#   'Country': 'AX',
#   'Lat': 60.0973,
#   'Lng': 19.9348,
#   'Max Temp': 35.46,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44},
#  {'City': 'Iracoubo',
#   'Country': 'GF',
#   'Lat': 5.4802,
#   'Lng': -53.2011,
#   'Max Temp': 76.59,
#   'Humidity': 87,
#   'Cloudiness': 23,
#   'Wind Speed': 10.76},
#  {'City': 'Florence',
#   'Country': 'IT',
#   'Lat': 43.7667,
#   'Lng': 11.25,
#   'Max Temp': 53.65,
#   'Humidity': 95,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61},
#  {'City': 'Makokou',
#   'Country': 'GA',
#   'Lat': 0.5738,
#   'Lng': 12.8642,
#   'Max Temp': 71.82,
#   'Humidity': 90,
#   'Cloudiness': 95,
#   'Wind Speed': 1.16},
#  {'City': 'Bela',
#   'Country': 'IN',
#   'Lat': 25.9333,
#   'Lng': 81.9833,
#   'Max Temp': 50.67,
#   'Humidity': 65,
#   'Cloudiness': 25,
#   'Wind Speed': 5.1},
#  {'City': 'Werda',
#   'Country': 'BW',
#   'Lat': -25.2667,
#   'Lng': 23.2833,
#   'Max Temp': 72.7,
#   'Humidity': 18,
#   'Cloudiness': 26,
#   'Wind Speed': 7.02},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 75.54,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75},
#  {'City': 'Petukhovo',
#   'Country': 'RU',
#   'Lat': 55.0692,
#   'Lng': 67.9019,
#   'Max Temp': 17.53,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 13.71},
#  {'City': 'Diffa',
#   'Country': 'NE',
#   'Lat': 13.3154,
#   'Lng': 12.6113,
#   'Max Temp': 63.32,
#   'Humidity': 48,
#   'Cloudiness': 71,
#   'Wind Speed': 12.33},
#  {'City': 'Aracataca',
#   'Country': 'CO',
#   'Lat': 10.5918,
#   'Lng': -74.1898,
#   'Max Temp': 82.71,
#   'Humidity': 65,
#   'Cloudiness': 22,
#   'Wind Speed': 2.91},
#  {'City': 'Maragogi',
#   'Country': 'BR',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 77.47,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 8.61},
#  {'City': 'Nampula',
#   'Country': 'MZ',
#   'Lat': -15.1165,
#   'Lng': 39.2666,
#   'Max Temp': 73.35,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61},
#  {'City': 'Shinichi',
#   'Country': 'JP',
#   'Lat': 34.55,
#   'Lng': 133.2667,
#   'Max Temp': 48.94,
#   'Humidity': 47,
#   'Cloudiness': 97,
#   'Wind Speed': 8.12},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 51.89,
#   'Humidity': 82,
#   'Cloudiness': 16,
#   'Wind Speed': 4},
#  {'City': 'Oxelosund',
#   'Country': 'SE',
#   'Lat': 58.6706,
#   'Lng': 17.1015,
#   'Max Temp': 40.93,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22},
#  {'City': 'Hervey Bay',
#   'Country': 'AU',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 87.91,
#   'Humidity': 54,
#   'Cloudiness': 8,
#   'Wind Speed': 5.99},
#  {'City': 'Hay River',
#   'Country': 'CA',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': -15.47,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26},
#  {'City': 'Birao',
#   'Country': 'CF',
#   'Lat': 10.2849,
#   'Lng': 22.7882,
#   'Max Temp': 70.45,
#   'Humidity': 23,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16},
#  {'City': 'Melfi',
#   'Country': 'IT',
#   'Lat': 40.9965,
#   'Lng': 15.6514,
#   'Max Temp': 48.4,
#   'Humidity': 89,
#   'Cloudiness': 61,
#   'Wind Speed': 7.38},
#  {'City': 'Santiago',
#   'Country': 'CL',
#   'Lat': -33.4569,
#   'Lng': -70.6483,
#   'Max Temp': 73.85,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 31.12,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 28.77},
#  {'City': 'Altay',
#   'Country': 'CN',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 12.63,
#   'Humidity': 69,
#   'Cloudiness': 18,
#   'Wind Speed': 7.36},
#  {'City': 'Fallon',
#   'Country': 'US',
#   'Lat': 39.4735,
#   'Lng': -118.7774,
#   'Max Temp': 34.43,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61},
#  {'City': 'Bousso',
#   'Country': 'TD',
#   'Lat': 10.4795,
#   'Lng': 16.7117,
#   'Max Temp': 66.15,
#   'Humidity': 25,
#   'Cloudiness': 14,
#   'Wind Speed': 9.93},
#  {'City': 'Yago',
#   'Country': 'MX',
#   'Lat': 21.8333,
#   'Lng': -105.0667,
#   'Max Temp': 66.43,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 1.21},
#  {'City': 'Valparaiso',
#   'Country': 'CL',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 64.04,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91},
#  {'City': 'Lahaina',
#   'Country': 'US',
#   'Lat': 20.8783,
#   'Lng': -156.6825,
#   'Max Temp': 80.6,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.84},
#  {'City': 'Maiduguri',
#   'Country': 'NG',
#   'Lat': 11.8464,
#   'Lng': 13.1603,
#   'Max Temp': 62.62,
#   'Humidity': 55,
#   'Cloudiness': 97,
#   'Wind Speed': 9.31},
#  {'City': 'Ranong',
#   'Country': 'TH',
#   'Lat': 9.9658,
#   'Lng': 98.6348,
#   'Max Temp': 80.74,
#   'Humidity': 71,
#   'Cloudiness': 70,
#   'Wind Speed': 9.44},
#  {'City': 'Karratha',
#   'Country': 'AU',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 91.56,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 10.13},
#  {'City': 'Mnogovershinnyy',
#   'Country': 'RU',
#   'Lat': 53.9353,
#   'Lng': 139.9242,
#   'Max Temp': -15.23,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 3.74},
#  {'City': 'El Bagre',
#   'Country': 'CO',
#   'Lat': 7.5927,
#   'Lng': -74.8086,
#   'Max Temp': 74.48,
#   'Humidity': 99,
#   'Cloudiness': 28,
#   'Wind Speed': 0.78},
#  {'City': 'Iznik',
#   'Country': 'TR',
#   'Lat': 40.4286,
#   'Lng': 29.7211,
#   'Max Temp': 47.98,
#   'Humidity': 86,
#   'Cloudiness': 12,
#   'Wind Speed': 4.63},
#  {'City': 'Kudahuvadhoo',
#   'Country': 'MV',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 81.3,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 12.1},
#  {'City': 'Sakaiminato',
#   'Country': 'JP',
#   'Lat': 35.55,
#   'Lng': 133.2333,
#   'Max Temp': 47.34,
#   'Humidity': 57,
#   'Cloudiness': 32,
#   'Wind Speed': 13.29},
#  {'City': 'Havre-Saint-Pierre',
#   'Country': 'CA',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 10.4,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 11.18},
#  {'City': 'Garowe',
#   'Country': 'SO',
#   'Lat': 8.4054,
#   'Lng': 48.4845,
#   'Max Temp': 64.74,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 6.55},
#  {'City': 'Mackenzie',
#   'Country': 'CA',
#   'Lat': 55.2999,
#   'Lng': -123.1698,
#   'Max Temp': -11.54,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 11.3},
#  {'City': 'Wilmington',
#   'Country': 'US',
#   'Lat': 34.2257,
#   'Lng': -77.9447,
#   'Max Temp': 64.9,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 0},
#  {'City': 'Hudiksvall',
#   'Country': 'SE',
#   'Lat': 61.729,
#   'Lng': 17.1036,
#   'Max Temp': 29.03,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.58},
#  {'City': 'Arman',
#   'Country': 'RU',
#   'Lat': 59.7,
#   'Lng': 150.1667,
#   'Max Temp': 5.02,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32},
#  {'City': 'Maneadero',
#   'Country': 'MX',
#   'Lat': 31.7167,
#   'Lng': -116.5667,
#   'Max Temp': 56.1,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 94.98,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75},
#  {'City': 'Carauari',
#   'Country': 'BR',
#   'Lat': -4.8828,
#   'Lng': -66.8958,
#   'Max Temp': 74.16,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71},
#  {'City': 'Araucaria',
#   'Country': 'BR',
#   'Lat': -25.5931,
#   'Lng': -49.4103,
#   'Max Temp': 69.91,
#   'Humidity': 94,
#   'Cloudiness': 2,
#   'Wind Speed': 1.99},
#  {'City': 'Teguldet',
#   'Country': 'RU',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp': 9.16,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 6.6},
#  {'City': 'Sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 82.81,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 15.32},
#  {'City': 'Ahuimanu',
#   'Country': 'US',
#   'Lat': 21.4447,
#   'Lng': -157.8378,
#   'Max Temp': 71.31,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44},
#  {'City': 'Kangavar',
#   'Country': 'IR',
#   'Lat': 34.5043,
#   'Lng': 47.9653,
#   'Max Temp': 36.1,
#   'Humidity': 81,
#   'Cloudiness': 47,
#   'Wind Speed': 3.02},
#  {'City': 'Soubre',
#   'Country': 'CI',
#   'Lat': 5.7856,
#   'Lng': -6.6083,
#   'Max Temp': 76.3,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 2.28},
#  {'City': 'Bridlington',
#   'Country': 'GB',
#   'Lat': 54.0831,
#   'Lng': -0.1919,
#   'Max Temp': 49.01,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 24.09},
#  {'City': 'Mahajanga',
#   'Country': 'MG',
#   'Lat': -15.7167,
#   'Lng': 46.3167,
#   'Max Temp': 73.42,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61},
#  {'City': 'Kashi',
#   'Country': 'CN',
#   'Lat': 39.4547,
#   'Lng': 75.9797,
#   'Max Temp': 21.25,
#   'Humidity': 63,
#   'Cloudiness': 83,
#   'Wind Speed': 0.96},
#  {'City': 'Walvis Bay',
#   'Country': 'NA',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 62.1,
#   'Humidity': 95,
#   'Cloudiness': 11,
#   'Wind Speed': 2.19},
#  {'City': 'Canto Do Buriti',
#   'Country': 'BR',
#   'Lat': -8.11,
#   'Lng': -42.9444,
#   'Max Temp': 72.72,
#   'Humidity': 93,
#   'Cloudiness': 88,
#   'Wind Speed': 1.3},
#  {'City': 'Chiang Klang',
#   'Country': 'TH',
#   'Lat': 19.2938,
#   'Lng': 100.8617,
#   'Max Temp': 73,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 0.69},
#  {'City': 'Yerbogachen',
#   'Country': 'RU',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': -14.13,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28},
#  {'City': 'Okhotsk',
#   'Country': 'RU',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': -0.71,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.05},
#  {'City': 'Tukrah',
#   'Country': 'LY',
#   'Lat': 32.5341,
#   'Lng': 20.5791,
#   'Max Temp': 56.77,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 4.34},
#  {'City': 'Siavonga',
#   'Country': 'ZM',
#   'Lat': -16.5382,
#   'Lng': 28.7088,
#   'Max Temp': 72.46,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 2.77},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 70.88,
#   'Humidity': 95,
#   'Cloudiness': 96,
#   'Wind Speed': 3.89},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 19.45,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 15.55},
#  {'City': 'Mawlaik',
#   'Country': 'MM',
#   'Lat': 23.6333,
#   'Lng': 94.4167,
#   'Max Temp': 63.18,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01},
#  {'City': 'Bongor',
#   'Country': 'TD',
#   'Lat': 10.2806,
#   'Lng': 15.3722,
#   'Max Temp': 65.68,
#   'Humidity': 25,
#   'Cloudiness': 6,
#   'Wind Speed': 9.66},
#  {'City': 'Emerald',
#   'Country': 'AU',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 97.34,
#   'Humidity': 26,
#   'Cloudiness': 4,
#   'Wind Speed': 10.04},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -30.53,
#   'Humidity': 75,
#   'Cloudiness': 20,
#   'Wind Speed': 0},
#  {'City': 'Sept-Iles',
#   'Country': 'CA',
#   'Lat': 50.2001,
#   'Lng': -66.3821,
#   'Max Temp': 3.06,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01},
#  {'City': 'Uvalde',
#   'Country': 'US',
#   'Lat': 29.3669,
#   'Lng': -99.767,
#   'Max Temp': 39.13,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 0},
#  {'City': 'Bend',
#   'Country': 'US',
#   'Lat': 44.0582,
#   'Lng': -121.3153,
#   'Max Temp': 38.48,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99},
#  {'City': 'Porgera',
#   'Country': 'PG',
#   'Lat': -5.4667,
#   'Lng': 143.2,
#   'Max Temp': 50.31,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08},
#  {'City': 'Usinsk',
#   'Country': 'RU',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 3.6,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.83},
#  {'City': 'Leninsk',
#   'Country': 'RU',
#   'Lat': 48.7119,
#   'Lng': 45.1994,
#   'Max Temp': 12.06,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 14.34},
#  {'City': 'Beira',
#   'Country': 'MZ',
#   'Lat': -19.8436,
#   'Lng': 34.8389,
#   'Max Temp': 78.96,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.44},
#  {'City': 'Rabat',
#   'Country': 'MA',
#   'Lat': 33.9911,
#   'Lng': -6.8401,
#   'Max Temp': 54.16,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 0},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 22.42,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 13.2},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 32.86,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79},
#  {'City': 'Tadine',
#   'Country': 'NC',
#   'Lat': -21.55,
#   'Lng': 167.8833,
#   'Max Temp': 81.03,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 14.23},
#  {'City': 'Grasse',
#   'Country': 'FR',
#   'Lat': 43.6667,
#   'Lng': 6.9167,
#   'Max Temp': 48.79,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61},
#  {'City': 'Hailar',
#   'Country': 'CN',
#   'Lat': 49.2,
#   'Lng': 119.7,
#   'Max Temp': -8.73,
#   'Humidity': 97,
#   'Cloudiness': 18,
#   'Wind Speed': 5.7},
#  {'City': 'Kawalu',
#   'Country': 'ID',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 79.81,
#   'Humidity': 76,
#   'Cloudiness': 97,
#   'Wind Speed': 3.62},
#  {'City': 'Jumla',
#   'Country': 'NP',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 31.21,
#   'Humidity': 60,
#   'Cloudiness': 88,
#   'Wind Speed': 4.76},
#  {'City': 'Bembereke',
#   'Country': 'BJ',
#   'Lat': 10.2283,
#   'Lng': 2.6634,
#   'Max Temp': 67.91,
#   'Humidity': 26,
#   'Cloudiness': 62,
#   'Wind Speed': 5.53},
#  {'City': 'Omsukchan',
#   'Country': 'RU',
#   'Lat': 62.5333,
#   'Lng': 155.8,
#   'Max Temp': 5.92,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 82,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind Speed': 9.57},
#  {'City': 'Lakes Entrance',
#   'Country': 'AU',
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp': 70.16,
#   'Humidity': 62,
#   'Cloudiness': 50,
#   'Wind Speed': 9.35},
#  {'City': 'Tsybli',
#   'Country': 'UA',
#   'Lat': 49.9948,
#   'Lng': 31.5628,
#   'Max Temp': 33.93,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 20.74},
#  {'City': 'Eyl',
#   'Country': 'SO',
#   'Lat': 7.9803,
#   'Lng': 49.8164,
#   'Max Temp': 73.69,
#   'Humidity': 84,
#   'Cloudiness': 4,
#   'Wind Speed': 7.67},
#  {'City': 'Lianzhou',
#   'Country': 'CN',
#   'Lat': 24.7811,
#   'Lng': 112.3825,
#   'Max Temp': 60.55,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 0.72},
#  {'City': 'Comodoro Rivadavia',
#   'Country': 'AR',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 60.66,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41},
#  {'City': 'Zaysan',
#   'Country': 'KZ',
#   'Lat': 47.4667,
#   'Lng': 84.8667,
#   'Max Temp': 6.82,
#   'Humidity': 81,
#   'Cloudiness': 77,
#   'Wind Speed': 3.15},
#  {'City': 'Gravdal',
#   'Country': 'NO',
#   'Lat': 68.1214,
#   'Lng': 13.5031,
#   'Max Temp': 31.39,
#   'Humidity': 95,
#   'Cloudiness': 97,
#   'Wind Speed': 26.51},
#  {'City': 'Corrales',
#   'Country': 'US',
#   'Lat': 35.2378,
#   'Lng': -106.6067,
#   'Max Temp': 31.66,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 3},
#  {'City': 'Nizhniy Baskunchak',
#   'Country': 'RU',
#   'Lat': 48.2198,
#   'Lng': 46.8311,
#   'Max Temp': 19.96,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 17.38},
#  {'City': 'Bukama',
#   'Country': 'CD',
#   'Lat': -9.2,
#   'Lng': 25.85,
#   'Max Temp': 67.84,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 27.32,
#   'Humidity': 59,
#   'Cloudiness': 52,
#   'Wind Speed': 6.98},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 76.78,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 15.37},
#  {'City': 'Tahta',
#   'Country': 'EG',
#   'Lat': 26.7693,
#   'Lng': 31.5021,
#   'Max Temp': 53.17,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.98},
#  {'City': 'Sri Aman',
#   'Country': 'MY',
#   'Lat': 1.2376,
#   'Lng': 111.4621,
#   'Max Temp': 79.23,
#   'Humidity': 85,
#   'Cloudiness': 97,
#   'Wind Speed': 0.54}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_database)
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Jamestown      US  42.0970  -79.2353     26.10        69
# 1          Buchanan      LR   5.8808  -10.0467     79.20        84
# 2    Saint-Philippe      RE -21.3585   55.7679     74.79        75
# 3          Tasiilaq      GL  65.6145  -37.6368      6.96        61
# 4              Naze      JP  28.3667  129.4833     59.92        69
# ..              ...     ...      ...       ...       ...       ...
# 688          Bukama      CD  -9.2000   25.8500     67.84        98
# 689        Olafsvik      IS  64.8945  -23.7142     27.32        59
# 690           Alofi      NU -19.0595 -169.9187     76.78        84
# 691           Tahta      EG  26.7693   31.5021     53.17        76
# 692        Sri Aman      MY   1.2376  111.4621     79.23        85
#
#      Cloudiness  Wind Speed
# 0            90        7.00
# 1            97        7.18
# 2            38        6.60
# 3            99        8.37
# 4           100       10.67
# ..          ...         ...
# 688         100        1.68
# 689          52        6.98
# 690         100       15.37
# 691           0        6.98
# 692          97        0.54
#
# [693 rows x 8 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
