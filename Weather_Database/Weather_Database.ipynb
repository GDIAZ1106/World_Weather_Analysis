# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
city_database = []

# %%
#  Using NumPy to create random figures
np.random.uniform(-90, 90, size=2000)
# Out:
# array([-48.12617191, -42.02573093, -61.7867369 , ...,  59.10513186,
#         16.50698353, -82.34439433])

# %%
# Adding Timeit
# %timeit np.random.uniform(-90, 90, size=2000)
# Out:
# 16.4 µs ± 195 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# defining random latitudes
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = np.random.randint(-90, 90) + np.random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(2000)
# Out:
# 5.08 ms ± 262 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import Citipy
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
cities
# Out:
# ['marquette',
#  'albany',
#  'butaritari',
#  'iquique',
#  'rikitea',
#  'tuatapere',
#  'aktash',
#  'menongue',
#  'tasiilaq',
#  'rudnogorsk',
#  'jamestown',
#  'pevek',
#  'cidreira',
#  'punta arenas',
#  'xuddur',
#  'atuona',
#  'hasaki',
#  'bristol',
#  'fortuna',
#  'nanortalik',
#  'griffith',
#  'thompson',
#  'tumannyy',
#  'prado',
#  'noshiro',
#  'cabo san lucas',
#  'kinston',
#  'sokolo',
#  'coron',
#  'mataura',
#  'carnarvon',
#  'east london',
#  'chokurdakh',
#  'hilo',
#  'dhidhdhoo',
#  'mabaruma',
#  'georgetown',
#  'glenwood springs',
#  'carman',
#  'vanderhoof',
#  'tsihombe',
#  'upernavik',
#  'sistranda',
#  'kholmy',
#  'taolanaro',
#  'faanui',
#  'jiddah',
#  'bredasdorp',
#  'magalia',
#  'spornoye',
#  'kavieng',
#  'dunedin',
#  'touros',
#  'souillac',
#  'bluff',
#  'nikolskoye',
#  'illoqqortoormiut',
#  'nizhneyansk',
#  'mahebourg',
#  'sur',
#  'saint-augustin',
#  'amderma',
#  'guadalajara',
#  'sao filipe',
#  'chulman',
#  'port alfred',
#  'provideniya',
#  'candelaria',
#  'severo-kurilsk',
#  'gigante',
#  'kapaa',
#  'xinzhi',
#  'budhlada',
#  'attawapiskat',
#  'itarema',
#  'ushuaia',
#  'honningsvag',
#  'rio gallegos',
#  'young',
#  'vaini',
#  'muros',
#  'nguiu',
#  'arraial do cabo',
#  'junin',
#  'puerto ayora',
#  'hermanus',
#  'port elizabeth',
#  'madang',
#  'mar del plata',
#  'khani',
#  'dolbeau',
#  'dzilam gonzalez',
#  'saldanha',
#  'santa fe',
#  'ketchikan',
#  'new norfolk',
#  'goderich',
#  'emba',
#  'kaitangata',
#  'prainha',
#  'padang',
#  'oranjemund',
#  'ponta do sol',
#  'sentyabrskiy',
#  'busselton',
#  'chuy',
#  'victoria',
#  'avarua',
#  'udachnyy',
#  'barawe',
#  'mount gambier',
#  'saint anthony',
#  'sidi ali',
#  'arbuzynka',
#  'kodiak',
#  'vidim',
#  'cherskiy',
#  'berdigestyakh',
#  'lasa',
#  'coihaique',
#  'vaitupu',
#  'tomigusuku',
#  'tramore',
#  'ceuta',
#  'esperance',
#  'troitskoye',
#  'acapulco',
#  'san patricio',
#  'tuktoyaktuk',
#  'bandarbeyla',
#  'hobart',
#  'mitsamiouli',
#  'save',
#  'marsa matruh',
#  'jiwani',
#  'te anau',
#  'asau',
#  'baykit',
#  'avera',
#  'xining',
#  'kysyl-syr',
#  'huarmey',
#  'sainte-maxime',
#  'barrow',
#  'longyearbyen',
#  'faya',
#  'mayo',
#  'san juan',
#  'matara',
#  'port hedland',
#  'gat',
#  'svetlogorsk',
#  'cape town',
#  'komsomolskiy',
#  'sechura',
#  'sangar',
#  'hithadhoo',
#  'port macquarie',
#  'sinnamary',
#  'araouane',
#  'leningradskiy',
#  'bubaque',
#  'lompoc',
#  'vila real',
#  'tomra',
#  'lavrentiya',
#  'russell',
#  'katsuura',
#  'humaita',
#  'batagay',
#  'kutum',
#  'genhe',
#  'saint george',
#  'khatanga',
#  'barcelos',
#  'sao joao da barra',
#  'tanda',
#  'ankara',
#  'thohoyandou',
#  'marcona',
#  'tabiauea',
#  'makakilo city',
#  'leon',
#  'aleksandrovsk-sakhalinskiy',
#  'narva-joesuu',
#  'kirkwall',
#  'castro',
#  'abu kamal',
#  'comodoro rivadavia',
#  'hami',
#  'marienburg',
#  'aden',
#  'husavik',
#  'solsvik',
#  'natal',
#  'hirara',
#  'walvis bay',
#  'lagoa',
#  'airai',
#  'malayal',
#  'swellendam',
#  'kuche',
#  'barentsburg',
#  'fort saint john',
#  'korla',
#  'saint-louis',
#  'hofn',
#  'el ocotito',
#  'nushki',
#  'bambous virieux',
#  'tamandare',
#  'sao felix do xingu',
#  'hay river',
#  'marfino',
#  'naze',
#  'antalaha',
#  'challapata',
#  'izmir',
#  'esso',
#  'manokwari',
#  'andarab',
#  'tonota',
#  'berlevag',
#  'belushya guba',
#  'bengkulu',
#  'flinders',
#  'kuvshinovo',
#  'warqla',
#  'dikson',
#  'slovenska bistrica',
#  'baruun-urt',
#  'duz',
#  'quatre cocos',
#  'san luis',
#  'portland',
#  'polyarnyye zori',
#  'salme',
#  'sobolevo',
#  'qaanaaq',
#  'tura',
#  'iroquois falls',
#  'gizo',
#  'isangel',
#  'margate',
#  'andreapol',
#  'karauzyak',
#  'grand gaube',
#  'hihifo',
#  'saint-francois',
#  'anton lizardo',
#  'port augusta',
#  'lorengau',
#  'malkapur',
#  'ormara',
#  'sao jose da coroa grande',
#  'yulara',
#  'thinadhoo',
#  'sisimiut',
#  'half moon bay',
#  'bethel',
#  'san felipe',
#  'iracoubo',
#  'zeya',
#  'raudeberg',
#  'road town',
#  'teseney',
#  'saskylakh',
#  'rungata',
#  'iqaluit',
#  'pathein',
#  'tan an',
#  'mys shmidta',
#  'yenagoa',
#  'shingu',
#  'novoalekseyevskaya',
#  'karratha',
#  'luis correia',
#  'muromtsevo',
#  'pisco',
#  'bay city',
#  'callaway',
#  'shimoda',
#  'ishigaki',
#  'cassilandia',
#  'shu',
#  'abu samrah',
#  'bilibino',
#  'migori',
#  'porto walter',
#  'mandalgovi',
#  'anadyr',
#  'sola',
#  'tir pol',
#  'ilulissat',
#  'jalu',
#  'aklavik',
#  'ancud',
#  'indianola',
#  'fuerte olimpo',
#  'bandarban',
#  'freetown',
#  'honiara',
#  'vao',
#  'praia da vitoria',
#  'luanda',
#  'hurricane',
#  'sibu',
#  'hambantota',
#  'filadelfia',
#  'nenjiang',
#  'yellowknife',
#  'phrai bung',
#  'fez',
#  'vostok',
#  'sabrum',
#  'atar',
#  'constitucion',
#  'geraldton',
#  'nipawin',
#  'tazovskiy',
#  'olga',
#  'vestmanna',
#  'vero beach',
#  'narasaraopet',
#  'aripuana',
#  'khonuu',
#  'kavaratti',
#  'tecoanapa',
#  'camacha',
#  'buariki',
#  'brownsburg',
#  'huamachuco',
#  'luebo',
#  'alofi',
#  'ust-barguzin',
#  'arman',
#  'socorro',
#  'olinda',
#  'san carlos de bariloche',
#  'kaduna',
#  'luderitz',
#  'kribi',
#  'toliary',
#  'mattru',
#  'porto novo',
#  'ayan',
#  'namibe',
#  'rawson',
#  'vila velha',
#  'barroualie',
#  'alcudia',
#  'ranong',
#  'cairns',
#  'chapais',
#  'necochea',
#  'turayf',
#  'verkhoyansk',
#  'goedereede',
#  'mahibadhoo',
#  'gorebridge',
#  'borlange',
#  'clyde river',
#  'henties bay',
#  'san quintin',
#  'iyo',
#  'talnakh',
#  'sinjah',
#  'yar-sale',
#  'lloydminster',
#  'balakhta',
#  'bud',
#  'hualmay',
#  'torbay',
#  'hobyo',
#  'cabra',
#  'santana do livramento',
#  'bambanglipuro',
#  'zaraza',
#  'koksovyy',
#  'nakusp',
#  'black diamond',
#  'beyneu',
#  'treinta y tres',
#  'llata',
#  'saint-philippe',
#  'college',
#  'nkwerre',
#  'siaya',
#  'lashio',
#  'muncar',
#  'ostrovnoy',
#  'borger',
#  'zambezi',
#  'lazaro cardenas',
#  'lugovoy',
#  'vestmannaeyjar',
#  'matagami',
#  'tigil',
#  'aykhal',
#  'el rincon',
#  'quilmana',
#  'marzuq',
#  'palabuhanratu',
#  'rochegda',
#  'tiksi',
#  'ngaoundere',
#  'batagay-alyta',
#  'nome',
#  'vilhena',
#  'port hardy',
#  'jinchang',
#  'lebu',
#  'ngukurr',
#  'san vicente',
#  'petropavlovsk-kamchatskiy',
#  'dubi',
#  'sakaiminato',
#  'kruisfontein',
#  'alyangula',
#  'tsiroanomandidy',
#  'the valley',
#  'hamilton',
#  'maraa',
#  'beckley',
#  'zhigansk',
#  'paamiut',
#  'otradnoye',
#  'formoso do araguaia',
#  'hurghada',
#  'andros',
#  'akcaabat',
#  'kouango',
#  'tilichiki',
#  'tiznit',
#  'samarinda',
#  'saleaula',
#  'vardo',
#  'alice springs',
#  'anage',
#  'puerto leguizamo',
#  'kirakira',
#  'coolum beach',
#  'esperanca',
#  'lata',
#  'ribeira grande',
#  'samarai',
#  'ust-kamchatsk',
#  'port lincoln',
#  'meulaboh',
#  'sioux lookout',
#  'buritis',
#  'fortuna foothills',
#  'nakuru',
#  'kansanshi',
#  'bolungarvik',
#  'bluefields',
#  'hokitika',
#  'roma',
#  'asasa',
#  'tucumcari',
#  'narsaq',
#  'chimbote',
#  'tocopilla',
#  'kenai',
#  'mount isa',
#  'auki',
#  'aguimes',
#  'elektrenai',
#  'ulladulla',
#  'maniitsoq',
#  'norman wells',
#  'havre-saint-pierre',
#  'cayenne',
#  'syracuse',
#  'havelock',
#  'elban',
#  'novooleksiyivka',
#  'tarudant',
#  'agua buena',
#  'itamaraca',
#  'klaksvik',
#  'bairiki',
#  'iberia',
#  'alotau',
#  'yangjiang',
#  'los llanos de aridane',
#  'biltine',
#  'himora',
#  'lakes entrance',
#  'atyrau',
#  'gushikawa',
#  'abu dhabi',
#  'ust-tsilma',
#  'high prairie',
#  'velasco ibarra',
#  'torrington',
#  'tungkang',
#  'gladstone',
#  'san cristobal',
#  'bilma',
#  'halalo',
#  'changji',
#  'mumbwa',
#  'sorland',
#  'batesville',
#  'mentok',
#  'torbat-e jam',
#  'da lat',
#  'pandan',
#  'maxixe',
#  'fairbanks',
#  'ojinaga',
#  'twin falls',
#  'jinxiang',
#  'colares',
#  'labuhan',
#  'bahia honda',
#  'skjervoy',
#  'vaitape',
#  'leh',
#  'zilair',
#  'aitape',
#  'skiathos',
#  'soyo',
#  'northam',
#  'tuscaloosa',
#  'beringovskiy',
#  'guerrero negro',
#  'wawa',
#  'sovetskaya',
#  'ixtapa',
#  'lolua',
#  'myaundzha',
#  'steamboat springs',
#  'teguise',
#  'catalao',
#  'orange cove',
#  'kaeo',
#  'bingol',
#  'caramay',
#  'bowen',
#  'talmenka',
#  'chany',
#  'skagastrond',
#  'cap malheureux',
#  'lagos',
#  'ende',
#  'sao sebastiao',
#  'emerald',
#  'igarka',
#  'muroto',
#  'saint-joseph',
#  'mwandiga',
#  'adrar',
#  'salalah',
#  'nishihara',
#  'tonj',
#  'guangyuan',
#  'kununurra',
#  'sitka',
#  'weligama',
#  'vung tau',
#  'yuzhno-yeniseyskiy',
#  'jiroft',
#  'thoen',
#  'kamina',
#  'matay',
#  'gawler',
#  'namie',
#  'scarborough',
#  'lalibela',
#  'acari',
#  'terrak',
#  'inhambane',
#  'mehamn',
#  'namtsy',
#  'vesyegonsk',
#  'gornopravdinsk',
#  'hvittingfoss',
#  'micheweni',
#  'verkhovyna',
#  'mogadishu',
#  'monticello',
#  'chahuites',
#  'glendive',
#  'formosa',
#  'el balyana',
#  'ponta delgada',
#  'phan rang',
#  'gander',
#  'gunjur',
#  'tambopata',
#  'chillicothe',
#  'calvinia',
#  'nanhai',
#  'jiazi',
#  'ust-maya',
#  'wanaka',
#  'salekhard',
#  'soc trang',
#  'barela',
#  'pouembout',
#  'sibi',
#  'morant bay',
#  'tha chang',
#  'ozinki',
#  'hunza',
#  'golden rock',
#  'samusu',
#  'mudyuga',
#  'outjo',
#  'ciudad bolivar',
#  'chicama',
#  'schladming',
#  'khomeynishahr',
#  'sembe',
#  'bitkine',
#  'stephenville',
#  'pinehurst',
#  'chapada dos guimaraes',
#  'brufut',
#  'mecca',
#  'kieta',
#  'ukiah',
#  'baisha',
#  'benguela',
#  'pingliang',
#  'kyren',
#  'luganville',
#  'tutoia',
#  'aktas',
#  'grand river south east',
#  'cockburn town',
#  'epe',
#  'nara',
#  'plouzane',
#  'velvary',
#  'presidencia roque saenz pena',
#  'det udom',
#  'ucluelet',
#  'buraydah',
#  'ilhabela',
#  'kaseda',
#  'balabac',
#  'erzin',
#  'blagoyevo',
#  'tarakan',
#  'tautira',
#  'porto seguro',
#  'ula',
#  'boca do acre',
#  'bathsheba',
#  'langfang',
#  'christchurch',
#  'semnan',
#  'sitangkai',
#  'tachi',
#  'sanbu',
#  'tumbi',
#  'ahipara',
#  'lukovetskiy',
#  'bereda',
#  'nouadhibou',
#  'verkhneyarkeyevo',
#  'santa cruz del sur',
#  'dwarka',
#  'mosquera',
#  'harnosand',
#  'takanabe',
#  'tongliao',
#  'louisbourg',
#  'changde',
#  'kurumkan',
#  'carndonagh',
#  'wladyslawowo',
#  'new ulm',
#  'doka',
#  'flin flon',
#  'mulchen',
#  'leticia',
#  'tomatlan',
#  'khandyga',
#  'kamojima',
#  'bosaso',
#  'whitehorse',
#  'banjarmasin',
#  'rafai',
#  'mega',
#  'nemuro',
#  'beruwala',
#  'orocue',
#  'diofior',
#  'srednekolymsk',
#  'ghanaur',
#  'loubomo',
#  'satitoa',
#  'manutuke',
#  'nador',
#  'jacareacanga',
#  'mikhaylovka',
#  'goreloye',
#  'hargeysa',
#  'honghu',
#  'cabo rojo',
#  'tsuchiura',
#  'eydhafushi',
#  'villazon',
#  'bestobe',
#  'vila franca do campo',
#  'guarapari',
#  'praia',
#  'riosucio',
#  'ourossogui',
#  'puerto madryn',
#  'lushunkou',
#  'tarko-sale',
#  'burns lake',
#  'karwar',
#  'broken hill',
#  'patnanungan',
#  'ballina',
#  'wanning',
#  'verkhnyaya inta',
#  'buta',
#  'miri',
#  'aberdeen',
#  'nantucket',
#  'thunder bay',
#  'avrameni',
#  'seryshevo',
#  'izhma',
#  'fort frances',
#  'pacific grove',
#  'opelousas',
#  'damghan',
#  'swan hill',
#  'neepawa',
#  'codrington',
#  'soledade',
#  'kota kinabalu',
#  'conceicao do araguaia',
#  'huilong',
#  'the pas',
#  'gimli',
#  'coburg',
#  'vershino-darasunskiy']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0857bafab7106fceacc87a5d7664babf'

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]    
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        #It was impossible to retrieve the weahter description
        #city_description = city_weather["weahter"]["description"]
        city_wind = city_weather["wind"]["speed"]
  
        # Append the city information into city_data list.
        city_database.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          #"Description": city_description,
                          "Wind Speed": city_wind})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | marquette
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | iquique
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | tuatapere
# Processing Record 7 of Set 1 | aktash
# Processing Record 8 of Set 1 | menongue
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | rudnogorsk
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | cidreira
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | xuddur
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | bristol
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | nanortalik
# Processing Record 21 of Set 1 | griffith
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 1 | prado
# Processing Record 25 of Set 1 | noshiro
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | kinston
# Processing Record 28 of Set 1 | sokolo
# Processing Record 29 of Set 1 | coron
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | dhidhdhoo
# Processing Record 36 of Set 1 | mabaruma
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | glenwood springs
# Processing Record 39 of Set 1 | carman
# Processing Record 40 of Set 1 | vanderhoof
# Processing Record 41 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | sistranda
# Processing Record 44 of Set 1 | kholmy
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | magalia
# Processing Record 50 of Set 1 | spornoye
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | dunedin
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | sur
# Processing Record 11 of Set 2 | saint-augustin
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | guadalajara
# Processing Record 14 of Set 2 | sao filipe
# Processing Record 15 of Set 2 | chulman
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | candelaria
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | gigante
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | xinzhi
# Processing Record 23 of Set 2 | budhlada
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | itarema
# Processing Record 26 of Set 2 | ushuaia
# Processing Record 27 of Set 2 | honningsvag
# Processing Record 28 of Set 2 | rio gallegos
# Processing Record 29 of Set 2 | young
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | muros
# Processing Record 32 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | junin
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | madang
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | khani
# Processing Record 41 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 2 | dzilam gonzalez
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | santa fe
# Processing Record 45 of Set 2 | ketchikan
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | goderich
# Processing Record 48 of Set 2 | emba
# Processing Record 49 of Set 2 | kaitangata
# Processing Record 50 of Set 2 | prainha
# Processing Record 1 of Set 3 | padang
# Processing Record 2 of Set 3 | oranjemund
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | busselton
# Processing Record 6 of Set 3 | chuy
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | udachnyy
# Processing Record 10 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 3 | mount gambier
# Processing Record 12 of Set 3 | saint anthony
# Processing Record 13 of Set 3 | sidi ali
# Processing Record 14 of Set 3 | arbuzynka
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | vidim
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | berdigestyakh
# Processing Record 19 of Set 3 | lasa
# Processing Record 20 of Set 3 | coihaique
# Processing Record 21 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 3 | tomigusuku
# Processing Record 23 of Set 3 | tramore
# Processing Record 24 of Set 3 | ceuta
# Processing Record 25 of Set 3 | esperance
# Processing Record 26 of Set 3 | troitskoye
# Processing Record 27 of Set 3 | acapulco
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | bandarbeyla
# Processing Record 31 of Set 3 | hobart
# Processing Record 32 of Set 3 | mitsamiouli
# Processing Record 33 of Set 3 | save
# Processing Record 34 of Set 3 | marsa matruh
# Processing Record 35 of Set 3 | jiwani
# Processing Record 36 of Set 3 | te anau
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | baykit
# Processing Record 39 of Set 3 | avera
# Processing Record 40 of Set 3 | xining
# Processing Record 41 of Set 3 | kysyl-syr
# Processing Record 42 of Set 3 | huarmey
# Processing Record 43 of Set 3 | sainte-maxime
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | longyearbyen
# Processing Record 46 of Set 3 | faya
# Processing Record 47 of Set 3 | mayo
# Processing Record 48 of Set 3 | san juan
# Processing Record 49 of Set 3 | matara
# Processing Record 50 of Set 3 | port hedland
# Processing Record 1 of Set 4 | gat
# Processing Record 2 of Set 4 | svetlogorsk
# Processing Record 3 of Set 4 | cape town
# Processing Record 4 of Set 4 | komsomolskiy
# Processing Record 5 of Set 4 | sechura
# Processing Record 6 of Set 4 | sangar
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | port macquarie
# Processing Record 9 of Set 4 | sinnamary
# Processing Record 10 of Set 4 | araouane
# Processing Record 11 of Set 4 | leningradskiy
# Processing Record 12 of Set 4 | bubaque
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | vila real
# Processing Record 15 of Set 4 | tomra
# Processing Record 16 of Set 4 | lavrentiya
# Processing Record 17 of Set 4 | russell
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | humaita
# Processing Record 20 of Set 4 | batagay
# Processing Record 21 of Set 4 | kutum
# Processing Record 22 of Set 4 | genhe
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | khatanga
# Processing Record 25 of Set 4 | barcelos
# Processing Record 26 of Set 4 | sao joao da barra
# Processing Record 27 of Set 4 | tanda
# Processing Record 28 of Set 4 | ankara
# Processing Record 29 of Set 4 | thohoyandou
# Processing Record 30 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 4 | makakilo city
# Processing Record 33 of Set 4 | leon
# Processing Record 34 of Set 4 | aleksandrovsk-sakhalinskiy
# Processing Record 35 of Set 4 | narva-joesuu
# Processing Record 36 of Set 4 | kirkwall
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | abu kamal
# Processing Record 39 of Set 4 | comodoro rivadavia
# Processing Record 40 of Set 4 | hami
# Processing Record 41 of Set 4 | marienburg
# Processing Record 42 of Set 4 | aden
# Processing Record 43 of Set 4 | husavik
# Processing Record 44 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 45 of Set 4 | natal
# Processing Record 46 of Set 4 | hirara
# Processing Record 47 of Set 4 | walvis bay
# Processing Record 48 of Set 4 | lagoa
# Processing Record 49 of Set 4 | airai
# Processing Record 50 of Set 4 | malayal
# Processing Record 1 of Set 5 | swellendam
# Processing Record 2 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 5 | korla
# Processing Record 6 of Set 5 | saint-louis
# Processing Record 7 of Set 5 | hofn
# Processing Record 8 of Set 5 | el ocotito
# Processing Record 9 of Set 5 | nushki
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | tamandare
# Processing Record 12 of Set 5 | sao felix do xingu
# Processing Record 13 of Set 5 | hay river
# Processing Record 14 of Set 5 | marfino
# Processing Record 15 of Set 5 | naze
# Processing Record 16 of Set 5 | antalaha
# Processing Record 17 of Set 5 | challapata
# Processing Record 18 of Set 5 | izmir
# Processing Record 19 of Set 5 | esso
# Processing Record 20 of Set 5 | manokwari
# Processing Record 21 of Set 5 | andarab
# City not found. Skipping...
# Processing Record 22 of Set 5 | tonota
# Processing Record 23 of Set 5 | berlevag
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | bengkulu
# Processing Record 26 of Set 5 | flinders
# Processing Record 27 of Set 5 | kuvshinovo
# Processing Record 28 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 5 | dikson
# Processing Record 30 of Set 5 | slovenska bistrica
# Processing Record 31 of Set 5 | baruun-urt
# Processing Record 32 of Set 5 | duz
# City not found. Skipping...
# Processing Record 33 of Set 5 | quatre cocos
# Processing Record 34 of Set 5 | san luis
# Processing Record 35 of Set 5 | portland
# Processing Record 36 of Set 5 | polyarnyye zori
# Processing Record 37 of Set 5 | salme
# Processing Record 38 of Set 5 | sobolevo
# Processing Record 39 of Set 5 | qaanaaq
# Processing Record 40 of Set 5 | tura
# Processing Record 41 of Set 5 | iroquois falls
# Processing Record 42 of Set 5 | gizo
# Processing Record 43 of Set 5 | isangel
# Processing Record 44 of Set 5 | margate
# Processing Record 45 of Set 5 | andreapol
# Processing Record 46 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 5 | grand gaube
# Processing Record 48 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 5 | saint-francois
# Processing Record 50 of Set 5 | anton lizardo
# Processing Record 1 of Set 6 | port augusta
# Processing Record 2 of Set 6 | lorengau
# Processing Record 3 of Set 6 | malkapur
# Processing Record 4 of Set 6 | ormara
# Processing Record 5 of Set 6 | sao jose da coroa grande
# Processing Record 6 of Set 6 | yulara
# Processing Record 7 of Set 6 | thinadhoo
# Processing Record 8 of Set 6 | sisimiut
# Processing Record 9 of Set 6 | half moon bay
# Processing Record 10 of Set 6 | bethel
# Processing Record 11 of Set 6 | san felipe
# Processing Record 12 of Set 6 | iracoubo
# Processing Record 13 of Set 6 | zeya
# Processing Record 14 of Set 6 | raudeberg
# Processing Record 15 of Set 6 | road town
# Processing Record 16 of Set 6 | teseney
# Processing Record 17 of Set 6 | saskylakh
# Processing Record 18 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 6 | iqaluit
# Processing Record 20 of Set 6 | pathein
# Processing Record 21 of Set 6 | tan an
# Processing Record 22 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 6 | yenagoa
# Processing Record 24 of Set 6 | shingu
# Processing Record 25 of Set 6 | novoalekseyevskaya
# Processing Record 26 of Set 6 | karratha
# Processing Record 27 of Set 6 | luis correia
# Processing Record 28 of Set 6 | muromtsevo
# Processing Record 29 of Set 6 | pisco
# Processing Record 30 of Set 6 | bay city
# Processing Record 31 of Set 6 | callaway
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | ishigaki
# Processing Record 34 of Set 6 | cassilandia
# Processing Record 35 of Set 6 | shu
# Processing Record 36 of Set 6 | abu samrah
# Processing Record 37 of Set 6 | bilibino
# Processing Record 38 of Set 6 | migori
# Processing Record 39 of Set 6 | porto walter
# Processing Record 40 of Set 6 | mandalgovi
# Processing Record 41 of Set 6 | anadyr
# Processing Record 42 of Set 6 | sola
# Processing Record 43 of Set 6 | tir pol
# City not found. Skipping...
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | jalu
# Processing Record 46 of Set 6 | aklavik
# Processing Record 47 of Set 6 | ancud
# Processing Record 48 of Set 6 | indianola
# Processing Record 49 of Set 6 | fuerte olimpo
# Processing Record 50 of Set 6 | bandarban
# Processing Record 1 of Set 7 | freetown
# Processing Record 2 of Set 7 | honiara
# Processing Record 3 of Set 7 | vao
# Processing Record 4 of Set 7 | praia da vitoria
# Processing Record 5 of Set 7 | luanda
# Processing Record 6 of Set 7 | hurricane
# Processing Record 7 of Set 7 | sibu
# Processing Record 8 of Set 7 | hambantota
# Processing Record 9 of Set 7 | filadelfia
# Processing Record 10 of Set 7 | nenjiang
# Processing Record 11 of Set 7 | yellowknife
# Processing Record 12 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 13 of Set 7 | fez
# Processing Record 14 of Set 7 | vostok
# Processing Record 15 of Set 7 | sabrum
# Processing Record 16 of Set 7 | atar
# Processing Record 17 of Set 7 | constitucion
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | nipawin
# Processing Record 20 of Set 7 | tazovskiy
# Processing Record 21 of Set 7 | olga
# Processing Record 22 of Set 7 | vestmanna
# Processing Record 23 of Set 7 | vero beach
# Processing Record 24 of Set 7 | narasaraopet
# Processing Record 25 of Set 7 | aripuana
# Processing Record 26 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 7 | kavaratti
# Processing Record 28 of Set 7 | tecoanapa
# Processing Record 29 of Set 7 | camacha
# Processing Record 30 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 31 of Set 7 | brownsburg
# Processing Record 32 of Set 7 | huamachuco
# Processing Record 33 of Set 7 | luebo
# Processing Record 34 of Set 7 | alofi
# Processing Record 35 of Set 7 | ust-barguzin
# Processing Record 36 of Set 7 | arman
# Processing Record 37 of Set 7 | socorro
# Processing Record 38 of Set 7 | olinda
# Processing Record 39 of Set 7 | san carlos de bariloche
# Processing Record 40 of Set 7 | kaduna
# Processing Record 41 of Set 7 | luderitz
# Processing Record 42 of Set 7 | kribi
# Processing Record 43 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 7 | mattru
# Processing Record 45 of Set 7 | porto novo
# Processing Record 46 of Set 7 | ayan
# Processing Record 47 of Set 7 | namibe
# Processing Record 48 of Set 7 | rawson
# Processing Record 49 of Set 7 | vila velha
# Processing Record 50 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 1 of Set 8 | alcudia
# Processing Record 2 of Set 8 | ranong
# Processing Record 3 of Set 8 | cairns
# Processing Record 4 of Set 8 | chapais
# Processing Record 5 of Set 8 | necochea
# Processing Record 6 of Set 8 | turayf
# Processing Record 7 of Set 8 | verkhoyansk
# Processing Record 8 of Set 8 | goedereede
# Processing Record 9 of Set 8 | mahibadhoo
# Processing Record 10 of Set 8 | gorebridge
# Processing Record 11 of Set 8 | borlange
# City not found. Skipping...
# Processing Record 12 of Set 8 | clyde river
# Processing Record 13 of Set 8 | henties bay
# Processing Record 14 of Set 8 | san quintin
# Processing Record 15 of Set 8 | iyo
# Processing Record 16 of Set 8 | talnakh
# Processing Record 17 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 18 of Set 8 | yar-sale
# Processing Record 19 of Set 8 | lloydminster
# Processing Record 20 of Set 8 | balakhta
# Processing Record 21 of Set 8 | bud
# Processing Record 22 of Set 8 | hualmay
# Processing Record 23 of Set 8 | torbay
# Processing Record 24 of Set 8 | hobyo
# Processing Record 25 of Set 8 | cabra
# Processing Record 26 of Set 8 | santana do livramento
# Processing Record 27 of Set 8 | bambanglipuro
# Processing Record 28 of Set 8 | zaraza
# Processing Record 29 of Set 8 | koksovyy
# Processing Record 30 of Set 8 | nakusp
# Processing Record 31 of Set 8 | black diamond
# Processing Record 32 of Set 8 | beyneu
# Processing Record 33 of Set 8 | treinta y tres
# Processing Record 34 of Set 8 | llata
# Processing Record 35 of Set 8 | saint-philippe
# Processing Record 36 of Set 8 | college
# Processing Record 37 of Set 8 | nkwerre
# Processing Record 38 of Set 8 | siaya
# Processing Record 39 of Set 8 | lashio
# Processing Record 40 of Set 8 | muncar
# Processing Record 41 of Set 8 | ostrovnoy
# Processing Record 42 of Set 8 | borger
# Processing Record 43 of Set 8 | zambezi
# Processing Record 44 of Set 8 | lazaro cardenas
# Processing Record 45 of Set 8 | lugovoy
# Processing Record 46 of Set 8 | vestmannaeyjar
# Processing Record 47 of Set 8 | matagami
# Processing Record 48 of Set 8 | tigil
# Processing Record 49 of Set 8 | aykhal
# Processing Record 50 of Set 8 | el rincon
# Processing Record 1 of Set 9 | quilmana
# Processing Record 2 of Set 9 | marzuq
# Processing Record 3 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 9 | rochegda
# Processing Record 5 of Set 9 | tiksi
# Processing Record 6 of Set 9 | ngaoundere
# Processing Record 7 of Set 9 | batagay-alyta
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | vilhena
# Processing Record 10 of Set 9 | port hardy
# Processing Record 11 of Set 9 | jinchang
# Processing Record 12 of Set 9 | lebu
# Processing Record 13 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 9 | san vicente
# Processing Record 15 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 9 | dubi
# Processing Record 17 of Set 9 | sakaiminato
# Processing Record 18 of Set 9 | kruisfontein
# Processing Record 19 of Set 9 | alyangula
# Processing Record 20 of Set 9 | tsiroanomandidy
# Processing Record 21 of Set 9 | the valley
# Processing Record 22 of Set 9 | hamilton
# Processing Record 23 of Set 9 | maraa
# Processing Record 24 of Set 9 | beckley
# Processing Record 25 of Set 9 | zhigansk
# Processing Record 26 of Set 9 | paamiut
# Processing Record 27 of Set 9 | otradnoye
# Processing Record 28 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 9 | hurghada
# Processing Record 30 of Set 9 | andros
# Processing Record 31 of Set 9 | akcaabat
# Processing Record 32 of Set 9 | kouango
# Processing Record 33 of Set 9 | tilichiki
# Processing Record 34 of Set 9 | tiznit
# Processing Record 35 of Set 9 | samarinda
# Processing Record 36 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 9 | vardo
# Processing Record 38 of Set 9 | alice springs
# Processing Record 39 of Set 9 | anage
# Processing Record 40 of Set 9 | puerto leguizamo
# Processing Record 41 of Set 9 | kirakira
# Processing Record 42 of Set 9 | coolum beach
# Processing Record 43 of Set 9 | esperanca
# Processing Record 44 of Set 9 | lata
# Processing Record 45 of Set 9 | ribeira grande
# Processing Record 46 of Set 9 | samarai
# Processing Record 47 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 9 | port lincoln
# Processing Record 49 of Set 9 | meulaboh
# Processing Record 50 of Set 9 | sioux lookout
# Processing Record 1 of Set 10 | buritis
# Processing Record 2 of Set 10 | fortuna foothills
# Processing Record 3 of Set 10 | nakuru
# Processing Record 4 of Set 10 | kansanshi
# Processing Record 5 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 10 | bluefields
# Processing Record 7 of Set 10 | hokitika
# Processing Record 8 of Set 10 | roma
# Processing Record 9 of Set 10 | asasa
# Processing Record 10 of Set 10 | tucumcari
# Processing Record 11 of Set 10 | narsaq
# Processing Record 12 of Set 10 | chimbote
# Processing Record 13 of Set 10 | tocopilla
# Processing Record 14 of Set 10 | kenai
# Processing Record 15 of Set 10 | mount isa
# Processing Record 16 of Set 10 | auki
# Processing Record 17 of Set 10 | aguimes
# Processing Record 18 of Set 10 | elektrenai
# Processing Record 19 of Set 10 | ulladulla
# Processing Record 20 of Set 10 | maniitsoq
# Processing Record 21 of Set 10 | norman wells
# Processing Record 22 of Set 10 | havre-saint-pierre
# Processing Record 23 of Set 10 | cayenne
# Processing Record 24 of Set 10 | syracuse
# Processing Record 25 of Set 10 | havelock
# Processing Record 26 of Set 10 | elban
# Processing Record 27 of Set 10 | novooleksiyivka
# Processing Record 28 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 10 | agua buena
# Processing Record 30 of Set 10 | itamaraca
# Processing Record 31 of Set 10 | klaksvik
# Processing Record 32 of Set 10 | bairiki
# Processing Record 33 of Set 10 | iberia
# Processing Record 34 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 10 | yangjiang
# Processing Record 36 of Set 10 | los llanos de aridane
# Processing Record 37 of Set 10 | biltine
# Processing Record 38 of Set 10 | himora
# City not found. Skipping...
# Processing Record 39 of Set 10 | lakes entrance
# Processing Record 40 of Set 10 | atyrau
# Processing Record 41 of Set 10 | gushikawa
# Processing Record 42 of Set 10 | abu dhabi
# Processing Record 43 of Set 10 | ust-tsilma
# Processing Record 44 of Set 10 | high prairie
# Processing Record 45 of Set 10 | velasco ibarra
# Processing Record 46 of Set 10 | torrington
# Processing Record 47 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 48 of Set 10 | gladstone
# Processing Record 49 of Set 10 | san cristobal
# Processing Record 50 of Set 10 | bilma
# Processing Record 1 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 11 | changji
# Processing Record 3 of Set 11 | mumbwa
# Processing Record 4 of Set 11 | sorland
# Processing Record 5 of Set 11 | batesville
# Processing Record 6 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 11 | torbat-e jam
# Processing Record 8 of Set 11 | da lat
# Processing Record 9 of Set 11 | pandan
# Processing Record 10 of Set 11 | maxixe
# Processing Record 11 of Set 11 | fairbanks
# Processing Record 12 of Set 11 | ojinaga
# Processing Record 13 of Set 11 | twin falls
# Processing Record 14 of Set 11 | jinxiang
# Processing Record 15 of Set 11 | colares
# Processing Record 16 of Set 11 | labuhan
# Processing Record 17 of Set 11 | bahia honda
# Processing Record 18 of Set 11 | skjervoy
# Processing Record 19 of Set 11 | vaitape
# Processing Record 20 of Set 11 | leh
# Processing Record 21 of Set 11 | zilair
# Processing Record 22 of Set 11 | aitape
# Processing Record 23 of Set 11 | skiathos
# Processing Record 24 of Set 11 | soyo
# Processing Record 25 of Set 11 | northam
# City not found. Skipping...
# Processing Record 26 of Set 11 | tuscaloosa
# City not found. Skipping...
# Processing Record 27 of Set 11 | beringovskiy
# City not found. Skipping...
# Processing Record 28 of Set 11 | guerrero negro
# City not found. Skipping...
# Processing Record 29 of Set 11 | wawa
# City not found. Skipping...
# Processing Record 30 of Set 11 | sovetskaya
# City not found. Skipping...
# Processing Record 31 of Set 11 | ixtapa
# City not found. Skipping...
# Processing Record 32 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 11 | myaundzha
# City not found. Skipping...
# Processing Record 34 of Set 11 | steamboat springs
# City not found. Skipping...
# Processing Record 35 of Set 11 | teguise
# City not found. Skipping...
# Processing Record 36 of Set 11 | catalao
# City not found. Skipping...
# Processing Record 37 of Set 11 | orange cove
# City not found. Skipping...
# Processing Record 38 of Set 11 | kaeo
# City not found. Skipping...
# Processing Record 39 of Set 11 | bingol
# City not found. Skipping...
# Processing Record 40 of Set 11 | caramay
# City not found. Skipping...
# Processing Record 41 of Set 11 | bowen
# City not found. Skipping...
# Processing Record 42 of Set 11 | talmenka
# City not found. Skipping...
# Processing Record 43 of Set 11 | chany
# City not found. Skipping...
# Processing Record 44 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 11 | cap malheureux
# City not found. Skipping...
# Processing Record 46 of Set 11 | lagos
# City not found. Skipping...
# Processing Record 47 of Set 11 | ende
# City not found. Skipping...
# Processing Record 48 of Set 11 | sao sebastiao
# City not found. Skipping...
# Processing Record 49 of Set 11 | emerald
# City not found. Skipping...
# Processing Record 50 of Set 11 | igarka
# City not found. Skipping...
# Processing Record 1 of Set 12 | muroto
# Processing Record 2 of Set 12 | saint-joseph
# Processing Record 3 of Set 12 | mwandiga
# Processing Record 4 of Set 12 | adrar
# Processing Record 5 of Set 12 | salalah
# Processing Record 6 of Set 12 | nishihara
# Processing Record 7 of Set 12 | tonj
# Processing Record 8 of Set 12 | guangyuan
# Processing Record 9 of Set 12 | kununurra
# Processing Record 10 of Set 12 | sitka
# Processing Record 11 of Set 12 | weligama
# Processing Record 12 of Set 12 | vung tau
# Processing Record 13 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 14 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 15 of Set 12 | thoen
# Processing Record 16 of Set 12 | kamina
# Processing Record 17 of Set 12 | matay
# Processing Record 18 of Set 12 | gawler
# Processing Record 19 of Set 12 | namie
# Processing Record 20 of Set 12 | scarborough
# Processing Record 21 of Set 12 | lalibela
# Processing Record 22 of Set 12 | acari
# Processing Record 23 of Set 12 | terrak
# Processing Record 24 of Set 12 | inhambane
# Processing Record 25 of Set 12 | mehamn
# Processing Record 26 of Set 12 | namtsy
# Processing Record 27 of Set 12 | vesyegonsk
# Processing Record 28 of Set 12 | gornopravdinsk
# Processing Record 29 of Set 12 | hvittingfoss
# Processing Record 30 of Set 12 | micheweni
# Processing Record 31 of Set 12 | verkhovyna
# Processing Record 32 of Set 12 | mogadishu
# Processing Record 33 of Set 12 | monticello
# Processing Record 34 of Set 12 | chahuites
# Processing Record 35 of Set 12 | glendive
# Processing Record 36 of Set 12 | formosa
# Processing Record 37 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 38 of Set 12 | ponta delgada
# Processing Record 39 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 12 | gander
# Processing Record 41 of Set 12 | gunjur
# Processing Record 42 of Set 12 | tambopata
# Processing Record 43 of Set 12 | chillicothe
# Processing Record 44 of Set 12 | calvinia
# Processing Record 45 of Set 12 | nanhai
# Processing Record 46 of Set 12 | jiazi
# Processing Record 47 of Set 12 | ust-maya
# Processing Record 48 of Set 12 | wanaka
# Processing Record 49 of Set 12 | salekhard
# Processing Record 50 of Set 12 | soc trang
# Processing Record 1 of Set 13 | barela
# Processing Record 2 of Set 13 | pouembout
# Processing Record 3 of Set 13 | sibi
# Processing Record 4 of Set 13 | morant bay
# Processing Record 5 of Set 13 | tha chang
# Processing Record 6 of Set 13 | ozinki
# Processing Record 7 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 13 | golden rock
# City not found. Skipping...
# Processing Record 9 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 11 of Set 13 | outjo
# Processing Record 12 of Set 13 | ciudad bolivar
# Processing Record 13 of Set 13 | chicama
# Processing Record 14 of Set 13 | schladming
# Processing Record 15 of Set 13 | khomeynishahr
# City not found. Skipping...
# Processing Record 16 of Set 13 | sembe
# Processing Record 17 of Set 13 | bitkine
# Processing Record 18 of Set 13 | stephenville
# Processing Record 19 of Set 13 | pinehurst
# Processing Record 20 of Set 13 | chapada dos guimaraes
# Processing Record 21 of Set 13 | brufut
# Processing Record 22 of Set 13 | mecca
# Processing Record 23 of Set 13 | kieta
# Processing Record 24 of Set 13 | ukiah
# Processing Record 25 of Set 13 | baisha
# Processing Record 26 of Set 13 | benguela
# Processing Record 27 of Set 13 | pingliang
# Processing Record 28 of Set 13 | kyren
# Processing Record 29 of Set 13 | luganville
# Processing Record 30 of Set 13 | tutoia
# Processing Record 31 of Set 13 | aktas
# Processing Record 32 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 13 | cockburn town
# Processing Record 34 of Set 13 | epe
# Processing Record 35 of Set 13 | nara
# Processing Record 36 of Set 13 | plouzane
# Processing Record 37 of Set 13 | velvary
# Processing Record 38 of Set 13 | presidencia roque saenz pena
# Processing Record 39 of Set 13 | det udom
# Processing Record 40 of Set 13 | ucluelet
# Processing Record 41 of Set 13 | buraydah
# Processing Record 42 of Set 13 | ilhabela
# Processing Record 43 of Set 13 | kaseda
# Processing Record 44 of Set 13 | balabac
# Processing Record 45 of Set 13 | erzin
# Processing Record 46 of Set 13 | blagoyevo
# Processing Record 47 of Set 13 | tarakan
# Processing Record 48 of Set 13 | tautira
# Processing Record 49 of Set 13 | porto seguro
# Processing Record 50 of Set 13 | ula
# Processing Record 1 of Set 14 | boca do acre
# Processing Record 2 of Set 14 | bathsheba
# Processing Record 3 of Set 14 | langfang
# Processing Record 4 of Set 14 | christchurch
# Processing Record 5 of Set 14 | semnan
# Processing Record 6 of Set 14 | sitangkai
# Processing Record 7 of Set 14 | tachi
# City not found. Skipping...
# Processing Record 8 of Set 14 | sanbu
# Processing Record 9 of Set 14 | tumbi
# Processing Record 10 of Set 14 | ahipara
# Processing Record 11 of Set 14 | lukovetskiy
# Processing Record 12 of Set 14 | bereda
# Processing Record 13 of Set 14 | nouadhibou
# Processing Record 14 of Set 14 | verkhneyarkeyevo
# Processing Record 15 of Set 14 | santa cruz del sur
# Processing Record 16 of Set 14 | dwarka
# Processing Record 17 of Set 14 | mosquera
# Processing Record 18 of Set 14 | harnosand
# Processing Record 19 of Set 14 | takanabe
# Processing Record 20 of Set 14 | tongliao
# Processing Record 21 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 14 | changde
# Processing Record 23 of Set 14 | kurumkan
# Processing Record 24 of Set 14 | carndonagh
# Processing Record 25 of Set 14 | wladyslawowo
# Processing Record 26 of Set 14 | new ulm
# Processing Record 27 of Set 14 | doka
# Processing Record 28 of Set 14 | flin flon
# Processing Record 29 of Set 14 | mulchen
# Processing Record 30 of Set 14 | leticia
# Processing Record 31 of Set 14 | tomatlan
# Processing Record 32 of Set 14 | khandyga
# Processing Record 33 of Set 14 | kamojima
# Processing Record 34 of Set 14 | bosaso
# Processing Record 35 of Set 14 | whitehorse
# Processing Record 36 of Set 14 | banjarmasin
# Processing Record 37 of Set 14 | rafai
# Processing Record 38 of Set 14 | mega
# Processing Record 39 of Set 14 | nemuro
# Processing Record 40 of Set 14 | beruwala
# Processing Record 41 of Set 14 | orocue
# Processing Record 42 of Set 14 | diofior
# Processing Record 43 of Set 14 | srednekolymsk
# Processing Record 44 of Set 14 | ghanaur
# Processing Record 45 of Set 14 | loubomo
# Processing Record 46 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 14 | manutuke
# Processing Record 48 of Set 14 | nador
# Processing Record 49 of Set 14 | jacareacanga
# Processing Record 50 of Set 14 | mikhaylovka
# Processing Record 1 of Set 15 | goreloye
# Processing Record 2 of Set 15 | hargeysa
# Processing Record 3 of Set 15 | honghu
# Processing Record 4 of Set 15 | cabo rojo
# Processing Record 5 of Set 15 | tsuchiura
# Processing Record 6 of Set 15 | eydhafushi
# Processing Record 7 of Set 15 | villazon
# Processing Record 8 of Set 15 | bestobe
# Processing Record 9 of Set 15 | vila franca do campo
# Processing Record 10 of Set 15 | guarapari
# Processing Record 11 of Set 15 | praia
# Processing Record 12 of Set 15 | riosucio
# Processing Record 13 of Set 15 | ourossogui
# Processing Record 14 of Set 15 | puerto madryn
# Processing Record 15 of Set 15 | lushunkou
# City not found. Skipping...
# Processing Record 16 of Set 15 | tarko-sale
# Processing Record 17 of Set 15 | burns lake
# Processing Record 18 of Set 15 | karwar
# Processing Record 19 of Set 15 | broken hill
# Processing Record 20 of Set 15 | patnanungan
# Processing Record 21 of Set 15 | ballina
# Processing Record 22 of Set 15 | wanning
# Processing Record 23 of Set 15 | verkhnyaya inta
# Processing Record 24 of Set 15 | buta
# Processing Record 25 of Set 15 | miri
# Processing Record 26 of Set 15 | aberdeen
# Processing Record 27 of Set 15 | nantucket
# Processing Record 28 of Set 15 | thunder bay
# Processing Record 29 of Set 15 | avrameni
# Processing Record 30 of Set 15 | seryshevo
# Processing Record 31 of Set 15 | izhma
# Processing Record 32 of Set 15 | fort frances
# Processing Record 33 of Set 15 | pacific grove
# Processing Record 34 of Set 15 | opelousas
# Processing Record 35 of Set 15 | damghan
# Processing Record 36 of Set 15 | swan hill
# Processing Record 37 of Set 15 | neepawa
# Processing Record 38 of Set 15 | codrington
# Processing Record 39 of Set 15 | soledade
# Processing Record 40 of Set 15 | kota kinabalu
# Processing Record 41 of Set 15 | conceicao do araguaia
# Processing Record 42 of Set 15 | huilong
# Processing Record 43 of Set 15 | the pas
# Processing Record 44 of Set 15 | gimli
# Processing Record 45 of Set 15 | coburg
# Processing Record 46 of Set 15 | vershino-darasunskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_database
# Out:
# [{'City': 'Marquette',
#   'Country': 'US',
#   'Lat': 46.5333,
#   'Lng': -87.6335,
#   'Max Temp': 22.68,
#   'Humidity': 49,
#   'Cloudiness': 94,
#   'Wind Speed': 9.51},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 23.09,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.85,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 13.4},
#  {'City': 'Iquique',
#   'Country': 'CL',
#   'Lat': -20.2208,
#   'Lng': -70.1431,
#   'Max Temp': 73.26,
#   'Humidity': 66,
#   'Cloudiness': 9,
#   'Wind Speed': 9.04},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.16,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 6.53},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 59.83,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83},
#  {'City': 'Aktash',
#   'Country': 'RU',
#   'Lat': 50.3,
#   'Lng': 87.7333,
#   'Max Temp': -5.15,
#   'Humidity': 82,
#   'Cloudiness': 89,
#   'Wind Speed': 4.85},
#  {'City': 'Menongue',
#   'Country': 'AO',
#   'Lat': -14.6585,
#   'Lng': 17.691,
#   'Max Temp': 69.13,
#   'Humidity': 76,
#   'Cloudiness': 88,
#   'Wind Speed': 4.03},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 15.03,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21},
#  {'City': 'Rudnogorsk',
#   'Country': 'RU',
#   'Lat': 57.2639,
#   'Lng': 103.7519,
#   'Max Temp': 6.44,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 4.25},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 24.08,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 4},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 29.07,
#   'Humidity': 72,
#   'Cloudiness': 95,
#   'Wind Speed': 28.83},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 79.81,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 12.71},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 50.02,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5},
#  {'City': 'Xuddur',
#   'Country': 'SO',
#   'Lat': 4.1213,
#   'Lng': 43.8894,
#   'Max Temp': 80.74,
#   'Humidity': 35,
#   'Cloudiness': 47,
#   'Wind Speed': 8.61},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.64,
#   'Humidity': 68,
#   'Cloudiness': 23,
#   'Wind Speed': 18.68},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 27,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 9.91},
#  {'City': 'Bristol',
#   'Country': 'US',
#   'Lat': 41.8334,
#   'Lng': -71.1662,
#   'Max Temp': 32.09,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 5.99},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 52.66,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 3},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 33.39,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 30.91},
#  {'City': 'Griffith',
#   'Country': 'US',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 23.11,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -21.84,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36},
#  {'City': 'Prado',
#   'Country': 'BR',
#   'Lat': -17.3411,
#   'Lng': -39.2208,
#   'Max Temp': 80.19,
#   'Humidity': 72,
#   'Cloudiness': 43,
#   'Wind Speed': 9.75},
#  {'City': 'Noshiro',
#   'Country': 'JP',
#   'Lat': 40.2039,
#   'Lng': 140.0242,
#   'Max Temp': 29.95,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 20.67},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 76.6,
#   'Humidity': 72,
#   'Cloudiness': 4,
#   'Wind Speed': 5.01},
#  {'City': 'Kinston',
#   'Country': 'US',
#   'Lat': 35.2627,
#   'Lng': -77.5816,
#   'Max Temp': 44.51,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11},
#  {'City': 'Sokolo',
#   'Country': 'ML',
#   'Lat': 14.7328,
#   'Lng': -6.1219,
#   'Max Temp': 77.79,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 8.79},
#  {'City': 'Coron',
#   'Country': 'PH',
#   'Lat': 11.9986,
#   'Lng': 120.2043,
#   'Max Temp': 75.88,
#   'Humidity': 78,
#   'Cloudiness': 96,
#   'Wind Speed': 8.52},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 59.49,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 1.05},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 75.27,
#   'Humidity': 78,
#   'Cloudiness': 3,
#   'Wind Speed': 18.41},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 72.54,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -19.39,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.1},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 79.61,
#   'Humidity': 78,
#   'Cloudiness': 93,
#   'Wind Speed': 3},
#  {'City': 'Dhidhdhoo',
#   'Country': 'MV',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 82.22,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 8.99},
#  {'City': 'Mabaruma',
#   'Country': 'GY',
#   'Lat': 8.2,
#   'Lng': -59.7833,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 79.95,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 0},
#  {'City': 'Glenwood Springs',
#   'Country': 'US',
#   'Lat': 39.5505,
#   'Lng': -107.3248,
#   'Max Temp': 36.63,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5},
#  {'City': 'Carman',
#   'Country': 'CA',
#   'Lat': 49.4992,
#   'Lng': -98.0016,
#   'Max Temp': 2.71,
#   'Humidity': 78,
#   'Cloudiness': 62,
#   'Wind Speed': 6.91},
#  {'City': 'Vanderhoof',
#   'Country': 'CA',
#   'Lat': 54.0166,
#   'Lng': -124.0198,
#   'Max Temp': -9.8,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.11},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -9.04,
#   'Humidity': 91,
#   'Cloudiness': 22,
#   'Wind Speed': 5.93},
#  {'City': 'Sistranda',
#   'Country': 'NO',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 34.9,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 11.88},
#  {'City': 'Kholmy',
#   'Country': 'UA',
#   'Lat': 51.871,
#   'Lng': 32.6006,
#   'Max Temp': 28.87,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 80.31,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 12.33},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 65.28,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61},
#  {'City': 'Magalia',
#   'Country': 'US',
#   'Lat': 39.8121,
#   'Lng': -121.5783,
#   'Max Temp': 42.22,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4},
#  {'City': 'Spornoye',
#   'Country': 'RU',
#   'Lat': 50.8448,
#   'Lng': 37.2913,
#   'Max Temp': 35.62,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 12.17},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 80.31,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 7.27},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 61.34,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 85.1,
#   'Humidity': 67,
#   'Cloudiness': 94,
#   'Wind Speed': 13.62},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 79.18,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 59.81,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.24},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 21.4,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 79.09,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 76.19,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 15.68},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 3.2,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 17.74},
#  {'City': 'Guadalajara',
#   'Country': 'MX',
#   'Lat': 20.6667,
#   'Lng': -103.3333,
#   'Max Temp': 77.83,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 1.52},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 75.31,
#   'Humidity': 61,
#   'Cloudiness': 5,
#   'Wind Speed': 6.55},
#  {'City': 'Chulman',
#   'Country': 'RU',
#   'Lat': 56.8479,
#   'Lng': 124.9104,
#   'Max Temp': -46.53,
#   'Humidity': 100,
#   'Cloudiness': 73,
#   'Wind Speed': 1.7},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 70.5,
#   'Humidity': 90,
#   'Cloudiness': 74,
#   'Wind Speed': 17.07},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 6.51,
#   'Humidity': 97,
#   'Cloudiness': 17,
#   'Wind Speed': 2.71},
#  {'City': 'Candelaria',
#   'Country': 'PH',
#   'Lat': 13.9311,
#   'Lng': 121.4233,
#   'Max Temp': 74.39,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.49},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 28.18,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 23.91},
#  {'City': 'Gigante',
#   'Country': 'CO',
#   'Lat': 2.3868,
#   'Lng': -75.5453,
#   'Max Temp': 85.08,
#   'Humidity': 59,
#   'Cloudiness': 80,
#   'Wind Speed': 4.72},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 71.58,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91},
#  {'City': 'Xinzhi',
#   'Country': 'CN',
#   'Lat': 36.4989,
#   'Lng': 111.7047,
#   'Max Temp': 35.64,
#   'Humidity': 33,
#   'Cloudiness': 6,
#   'Wind Speed': 2.55},
#  {'City': 'Budhlada',
#   'Country': 'IN',
#   'Lat': 29.9333,
#   'Lng': 75.5667,
#   'Max Temp': 56.08,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 84.29,
#   'Humidity': 67,
#   'Cloudiness': 45,
#   'Wind Speed': 16.93},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.42,
#   'Humidity': 43,
#   'Cloudiness': 75,
#   'Wind Speed': 29.93},
#  {'City': 'Honningsvag',
#   'Country': 'NO',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 22.42,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 30.27},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 51.85,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91},
#  {'City': 'Young',
#   'Country': 'UY',
#   'Lat': -32.6833,
#   'Lng': -57.6333,
#   'Max Temp': 100.94,
#   'Humidity': 21,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.96,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 59.85,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 23.47},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 85.96,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66},
#  {'City': 'Junin',
#   'Country': 'AR',
#   'Lat': -34.5838,
#   'Lng': -60.9433,
#   'Max Temp': 97.45,
#   'Humidity': 27,
#   'Cloudiness': 35,
#   'Wind Speed': 3.91},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 80.56,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 65.89,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 71.1,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91},
#  {'City': 'Madang',
#   'Country': 'PG',
#   'Lat': -5.2246,
#   'Lng': 145.7966,
#   'Max Temp': 75.47,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 6.96},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 78.82,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99},
#  {'City': 'Khani',
#   'Country': 'GE',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 29.77,
#   'Humidity': 84,
#   'Cloudiness': 41,
#   'Wind Speed': 6.51},
#  {'City': 'Dzilam Gonzalez',
#   'Country': 'MX',
#   'Lat': 21.2833,
#   'Lng': -88.9333,
#   'Max Temp': 73.09,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 11.3},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 66.25,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 22.3},
#  {'City': 'Santa Fe',
#   'Country': 'AR',
#   'Lat': -31.6333,
#   'Lng': -60.7,
#   'Max Temp': 102.74,
#   'Humidity': 30,
#   'Cloudiness': 97,
#   'Wind Speed': 1.01},
#  {'City': 'Ketchikan',
#   'Country': 'US',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 30.18,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 56.7,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.3},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 23.92,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66},
#  {'City': 'Emba',
#   'Country': 'KZ',
#   'Lat': 48.8264,
#   'Lng': 58.1442,
#   'Max Temp': 7.18,
#   'Humidity': 98,
#   'Cloudiness': 95,
#   'Wind Speed': 8.75},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 59.88,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57},
#  {'City': 'Prainha',
#   'Country': 'BR',
#   'Lat': -1.8,
#   'Lng': -53.48,
#   'Max Temp': 82.69,
#   'Humidity': 78,
#   'Cloudiness': 84,
#   'Wind Speed': 2.3},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 76.35,
#   'Humidity': 89,
#   'Cloudiness': 30,
#   'Wind Speed': 4.14},
#  {'City': 'Oranjemund',
#   'Country': 'NA',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 62.62,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 10.78},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 70,
#   'Humidity': 23,
#   'Cloudiness': 6,
#   'Wind Speed': 0.74},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 58.89,
#   'Humidity': 85,
#   'Cloudiness': 12,
#   'Wind Speed': 13.44},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 89.87,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 15.99},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 65.95,
#   'Humidity': 79,
#   'Cloudiness': 6,
#   'Wind Speed': 5.01},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 80.65,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11},
#  {'City': 'Udachnyy',
#   'Country': 'RU',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': -46.55,
#   'Humidity': 80,
#   'Cloudiness': 67,
#   'Wind Speed': 1.57},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 57.11,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5},
#  {'City': 'Saint Anthony',
#   'Country': 'US',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 27.12,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01},
#  {'City': 'Sidi Ali',
#   'Country': 'DZ',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 56.12,
#   'Humidity': 55,
#   'Cloudiness': 5,
#   'Wind Speed': 0.81},
#  {'City': 'Arbuzynka',
#   'Country': 'UA',
#   'Lat': 47.9097,
#   'Lng': 31.3196,
#   'Max Temp': 41.81,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 17.56},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 16.84,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 23.06},
#  {'City': 'Vidim',
#   'Country': 'RU',
#   'Lat': 56.4088,
#   'Lng': 103.1106,
#   'Max Temp': 11.95,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 6.26},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 23.58,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 11.43},
#  {'City': 'Berdigestyakh',
#   'Country': 'RU',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': -43.47,
#   'Humidity': 100,
#   'Cloudiness': 89,
#   'Wind Speed': 1.95},
#  {'City': 'Lasa',
#   'Country': 'IT',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 36.34,
#   'Humidity': 74,
#   'Cloudiness': 81,
#   'Wind Speed': 2.86},
#  {'City': 'Coihaique',
#   'Country': 'CL',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 54.21,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61},
#  {'City': 'Tomigusuku',
#   'Country': 'JP',
#   'Lat': 26.185,
#   'Lng': 127.675,
#   'Max Temp': 60.57,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14},
#  {'City': 'Tramore',
#   'Country': 'IE',
#   'Lat': 52.1624,
#   'Lng': -7.1524,
#   'Max Temp': 48.09,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 3},
#  {'City': 'Ceuta',
#   'Country': 'ES',
#   'Lat': 35.8903,
#   'Lng': -5.3075,
#   'Max Temp': 55.51,
#   'Humidity': 74,
#   'Cloudiness': 6,
#   'Wind Speed': 3.69},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 64.24,
#   'Humidity': 84,
#   'Cloudiness': 30,
#   'Wind Speed': 11.25},
#  {'City': 'Troitskoye',
#   'Country': 'RU',
#   'Lat': 52.9821,
#   'Lng': 84.6757,
#   'Max Temp': 23.09,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 84.72,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.86},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 54.88,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 3.06},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -22,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 77.99,
#   'Humidity': 82,
#   'Cloudiness': 31,
#   'Wind Speed': 6.04},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 57.06,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01},
#  {'City': 'Mitsamiouli',
#   'Country': 'KM',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 84.49,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75},
#  {'City': 'Save',
#   'Country': 'BJ',
#   'Lat': 8.0425,
#   'Lng': 2.486,
#   'Max Temp': 89.46,
#   'Humidity': 16,
#   'Cloudiness': 77,
#   'Wind Speed': 2.35},
#  {'City': 'Marsa Matruh',
#   'Country': 'EG',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 59.2,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05},
#  {'City': 'Jiwani',
#   'Country': 'PK',
#   'Lat': 25.05,
#   'Lng': 61.7417,
#   'Max Temp': 74.73,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 17.07},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 58.84,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 0.38},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 48.96,
#   'Humidity': 63,
#   'Cloudiness': 39,
#   'Wind Speed': 16.44},
#  {'City': 'Baykit',
#   'Country': 'RU',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': -8.43,
#   'Humidity': 100,
#   'Cloudiness': 98,
#   'Wind Speed': 1.74},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 54.91,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 7.96},
#  {'City': 'Xining',
#   'Country': 'CN',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 21.42,
#   'Humidity': 39,
#   'Cloudiness': 8,
#   'Wind Speed': 1.07},
#  {'City': 'Kysyl-Syr',
#   'Country': 'RU',
#   'Lat': 63.8986,
#   'Lng': 122.7617,
#   'Max Temp': -46.71,
#   'Humidity': 100,
#   'Cloudiness': 94,
#   'Wind Speed': 1.36},
#  {'City': 'Huarmey',
#   'Country': 'PE',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 74.57,
#   'Humidity': 75,
#   'Cloudiness': 50,
#   'Wind Speed': 10.69},
#  {'City': 'Sainte-Maxime',
#   'Country': 'FR',
#   'Lat': 43.3,
#   'Lng': 6.6333,
#   'Max Temp': 58.95,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 8.63},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -23.75,
#   'Humidity': 99,
#   'Cloudiness': 26,
#   'Wind Speed': 7.92},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 3.04,
#   'Humidity': 60,
#   'Cloudiness': 60,
#   'Wind Speed': 20.71},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 54.12,
#   'Humidity': 86,
#   'Cloudiness': 96,
#   'Wind Speed': 6.08},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 31.37,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99},
#  {'City': 'San Juan',
#   'Country': 'AR',
#   'Lat': -31.5375,
#   'Lng': -68.5364,
#   'Max Temp': 93.92,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 7.52},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 74.71,
#   'Humidity': 88,
#   'Cloudiness': 77,
#   'Wind Speed': 8.19},
#  {'City': 'Port Hedland',
#   'Country': 'AU',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 84.25,
#   'Humidity': 79,
#   'Cloudiness': 94,
#   'Wind Speed': 5.75},
#  {'City': 'Gat',
#   'Country': 'IL',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 56.39,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 4.92},
#  {'City': 'Svetlogorsk',
#   'Country': 'BY',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 34.68,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.08},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 66.61,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4},
#  {'City': 'Komsomolskiy',
#   'Country': 'UZ',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 39.92,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3},
#  {'City': 'Sechura',
#   'Country': 'PE',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 79.83,
#   'Humidity': 56,
#   'Cloudiness': 96,
#   'Wind Speed': 13.47},
#  {'City': 'Sangar',
#   'Country': 'RU',
#   'Lat': 63.9242,
#   'Lng': 127.4739,
#   'Max Temp': -45.26,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.27,
#   'Humidity': 73,
#   'Cloudiness': 14,
#   'Wind Speed': 5.99},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 69.69,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 80.22,
#   'Humidity': 71,
#   'Cloudiness': 29,
#   'Wind Speed': 12.48},
#  {'City': 'Araouane',
#   'Country': 'ML',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 67.14,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 9.69},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 31.55,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8},
#  {'City': 'Bubaque',
#   'Country': 'GW',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 80.28,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 10.47},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 62.13,
#   'Humidity': 69,
#   'Cloudiness': 2,
#   'Wind Speed': 5.99},
#  {'City': 'Vila Real',
#   'Country': 'PT',
#   'Lat': 41.3006,
#   'Lng': -7.7441,
#   'Max Temp': 52.12,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4},
#  {'City': 'Tomra',
#   'Country': 'NO',
#   'Lat': 62.5833,
#   'Lng': 6.9333,
#   'Max Temp': 36.18,
#   'Humidity': 84,
#   'Cloudiness': 63,
#   'Wind Speed': 9.44},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': -1.91,
#   'Humidity': 99,
#   'Cloudiness': 36,
#   'Wind Speed': 2.37},
#  {'City': 'Russell',
#   'Country': 'US',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 42.06,
#   'Humidity': 72,
#   'Cloudiness': 6,
#   'Wind Speed': 11.32},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 47.19,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 20.58},
#  {'City': 'Humaita',
#   'Country': 'BR',
#   'Lat': -7.5061,
#   'Lng': -63.0208,
#   'Max Temp': 75.38,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33},
#  {'City': 'Batagay',
#   'Country': 'RU',
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': -34.6,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 57.38,
#   'Humidity': 35,
#   'Cloudiness': 98,
#   'Wind Speed': 13.27},
#  {'City': 'Genhe',
#   'Country': 'CN',
#   'Lat': 50.7833,
#   'Lng': 121.5167,
#   'Max Temp': -27.08,
#   'Humidity': 100,
#   'Cloudiness': 5,
#   'Wind Speed': 1.72},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 51.53,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 3},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -55.8,
#   'Humidity': 99,
#   'Cloudiness': 53,
#   'Wind Speed': 3.94},
#  {'City': 'Barcelos',
#   'Country': 'PT',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 58.28,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.07},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 80.69,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 14.9},
#  {'City': 'Tanda',
#   'Country': 'IN',
#   'Lat': 26.55,
#   'Lng': 82.65,
#   'Max Temp': 53.98,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 5.5},
#  {'City': 'Ankara',
#   'Country': 'TR',
#   'Lat': 39.9199,
#   'Lng': 32.8543,
#   'Max Temp': 39.2,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3},
#  {'City': 'Thohoyandou',
#   'Country': 'ZA',
#   'Lat': -22.9456,
#   'Lng': 30.485,
#   'Max Temp': 72.54,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 2.84},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 69.55,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 0},
#  {'City': 'Leon',
#   'Country': 'MX',
#   'Lat': 21.1167,
#   'Lng': -101.6667,
#   'Max Temp': 71.82,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 5.59},
#  {'City': 'Aleksandrovsk-Sakhalinskiy',
#   'Country': 'RU',
#   'Lat': 50.8975,
#   'Lng': 142.1561,
#   'Max Temp': -5.94,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 14.36},
#  {'City': 'Narva-Joesuu',
#   'Country': 'EE',
#   'Lat': 59.4589,
#   'Lng': 28.0408,
#   'Max Temp': 23.43,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57},
#  {'City': 'Kirkwall',
#   'Country': 'GB',
#   'Lat': 58.9848,
#   'Lng': -2.9587,
#   'Max Temp': 37.45,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 84.33,
#   'Humidity': 41,
#   'Cloudiness': 87,
#   'Wind Speed': 5.7},
#  {'City': 'Abu Kamal',
#   'Country': 'SY',
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp': 46.89,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 8.19},
#  {'City': 'Comodoro Rivadavia',
#   'Country': 'AR',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 78.66,
#   'Humidity': 13,
#   'Cloudiness': 6,
#   'Wind Speed': 43.73},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 21.52,
#   'Humidity': 49,
#   'Cloudiness': 3,
#   'Wind Speed': 3.4},
#  {'City': 'Marienburg',
#   'Country': 'PL',
#   'Lat': 54.0359,
#   'Lng': 19.0266,
#   'Max Temp': 44.26,
#   'Humidity': 81,
#   'Cloudiness': 87,
#   'Wind Speed': 13.11},
#  {'City': 'Aden',
#   'Country': 'YE',
#   'Lat': 12.7794,
#   'Lng': 45.0367,
#   'Max Temp': 77.85,
#   'Humidity': 75,
#   'Cloudiness': 5,
#   'Wind Speed': 11.32},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 28.31,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 20.02},
#  {'City': 'Natal',
#   'Country': 'BR',
#   'Lat': -5.795,
#   'Lng': -35.2094,
#   'Max Temp': 86.22,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27},
#  {'City': 'Hirara',
#   'Country': 'JP',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 68.56,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 14.7},
#  {'City': 'Walvis Bay',
#   'Country': 'NA',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 63.55,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 56.64,
#   'Humidity': 55,
#   'Cloudiness': 5,
#   'Wind Speed': 11.9},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 61.34,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32},
#  {'City': 'Malayal',
#   'Country': 'PH',
#   'Lat': 7.208,
#   'Lng': 121.942,
#   'Max Temp': 76.8,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3},
#  {'City': 'Swellendam',
#   'Country': 'ZA',
#   'Lat': -34.0226,
#   'Lng': 20.4417,
#   'Max Temp': 62.98,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94},
#  {'City': 'Korla',
#   'Country': 'CN',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 19.47,
#   'Humidity': 74,
#   'Cloudiness': 11,
#   'Wind Speed': 4.54},
#  {'City': 'Saint-Louis',
#   'Country': 'SN',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 77.83,
#   'Humidity': 11,
#   'Cloudiness': 80,
#   'Wind Speed': 8.41},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 30.22,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 31.07},
#  {'City': 'El Ocotito',
#   'Country': 'MX',
#   'Lat': 17.25,
#   'Lng': -99.5667,
#   'Max Temp': 89.89,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 2.8},
#  {'City': 'Nushki',
#   'Country': 'PK',
#   'Lat': 29.5542,
#   'Lng': 66.0215,
#   'Max Temp': 55.58,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79.05,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5},
#  {'City': 'Tamandare',
#   'Country': 'BR',
#   'Lat': -8.7597,
#   'Lng': -35.1047,
#   'Max Temp': 82.49,
#   'Humidity': 66,
#   'Cloudiness': 22,
#   'Wind Speed': 9.82},
#  {'City': 'Sao Felix Do Xingu',
#   'Country': 'BR',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 73.31,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.59},
#  {'City': 'Hay River',
#   'Country': 'CA',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': -27.42,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66},
#  {'City': 'Marfino',
#   'Country': 'RU',
#   'Lat': 55.7028,
#   'Lng': 37.3822,
#   'Max Temp': 17.85,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 6.71},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 56.41,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 8.57},
#  {'City': 'Antalaha',
#   'Country': 'MG',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 76.87,
#   'Humidity': 84,
#   'Cloudiness': 82,
#   'Wind Speed': 2.8},
#  {'City': 'Challapata',
#   'Country': 'BO',
#   'Lat': -18.9,
#   'Lng': -66.7667,
#   'Max Temp': 59.52,
#   'Humidity': 40,
#   'Cloudiness': 71,
#   'Wind Speed': 3.67},
#  {'City': 'Izmir',
#   'Country': 'TR',
#   'Lat': 38.4622,
#   'Lng': 27.0923,
#   'Max Temp': 45.91,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3},
#  {'City': 'Esso',
#   'Country': 'RU',
#   'Lat': 55.9333,
#   'Lng': 158.7,
#   'Max Temp': 9.72,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 78.08,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97},
#  {'City': 'Tonota',
#   'Country': 'BW',
#   'Lat': -21.4833,
#   'Lng': 27.4833,
#   'Max Temp': 79.99,
#   'Humidity': 54,
#   'Cloudiness': 71,
#   'Wind Speed': 15.68},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 15.75,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.29,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 69.21,
#   'Humidity': 85,
#   'Cloudiness': 51,
#   'Wind Speed': 1.01},
#  {'City': 'Kuvshinovo',
#   'Country': 'RU',
#   'Lat': 57.0295,
#   'Lng': 34.1725,
#   'Max Temp': 9.91,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -35.5,
#   'Humidity': 93,
#   'Cloudiness': 31,
#   'Wind Speed': 6.64},
#  {'City': 'Slovenska Bistrica',
#   'Country': 'SI',
#   'Lat': 46.3928,
#   'Lng': 15.5744,
#   'Max Temp': 48.11,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44},
#  {'City': 'Baruun-Urt',
#   'Country': 'MN',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': -5.21,
#   'Humidity': 92,
#   'Cloudiness': 12,
#   'Wind Speed': 4.7},
#  {'City': 'Quatre Cocos',
#   'Country': 'MU',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 78.91,
#   'Humidity': 78,
#   'Cloudiness': 85,
#   'Wind Speed': 8.12},
#  {'City': 'San Luis',
#   'Country': 'AR',
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp': 95.41,
#   'Humidity': 22,
#   'Cloudiness': 45,
#   'Wind Speed': 16.42},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 41.36,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4},
#  {'City': 'Polyarnyye Zori',
#   'Country': 'RU',
#   'Lat': 67.3661,
#   'Lng': 32.4981,
#   'Max Temp': -7.08,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 2.53},
#  {'City': 'Salme',
#   'Country': 'NP',
#   'Lat': 28.0369,
#   'Lng': 85.0942,
#   'Max Temp': 39.49,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 6.31},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 9.27,
#   'Humidity': 98,
#   'Cloudiness': 86,
#   'Wind Speed': 3.02},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -4.36,
#   'Humidity': 63,
#   'Cloudiness': 61,
#   'Wind Speed': 8.12},
#  {'City': 'Tura',
#   'Country': 'IN',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 55.76,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 2.55},
#  {'City': 'Iroquois Falls',
#   'Country': 'CA',
#   'Lat': 48.7669,
#   'Lng': -80.6831,
#   'Max Temp': 8.74,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.07},
#  {'City': 'Gizo',
#   'Country': 'SB',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 83.97,
#   'Humidity': 72,
#   'Cloudiness': 97,
#   'Wind Speed': 12.55},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 79.7,
#   'Humidity': 81,
#   'Cloudiness': 87,
#   'Wind Speed': 9.44},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 50.88,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3},
#  {'City': 'Andreapol',
#   'Country': 'RU',
#   'Lat': 56.6513,
#   'Lng': 32.2664,
#   'Max Temp': 13.71,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.76},
#  {'City': 'Grand Gaube',
#   'Country': 'MU',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 79.2,
#   'Humidity': 76,
#   'Cloudiness': 38,
#   'Wind Speed': 3},
#  {'City': 'Saint-Francois',
#   'Country': 'FR',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 52.68,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91},
#  {'City': 'Anton Lizardo',
#   'Country': 'MX',
#   'Lat': 19.05,
#   'Lng': -95.9833,
#   'Max Temp': 72.21,
#   'Humidity': 63,
#   'Cloudiness': 83,
#   'Wind Speed': 25.81},
#  {'City': 'Port Augusta',
#   'Country': 'AU',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 61.21,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 13.56},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.61,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 11.32},
#  {'City': 'Malkapur',
#   'Country': 'IN',
#   'Lat': 20.8833,
#   'Lng': 76.2,
#   'Max Temp': 69.71,
#   'Humidity': 56,
#   'Cloudiness': 2,
#   'Wind Speed': 3.13},
#  {'City': 'Ormara',
#   'Country': 'PK',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 72.45,
#   'Humidity': 62,
#   'Cloudiness': 52,
#   'Wind Speed': 7.67},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Country': 'BR',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 82.29,
#   'Humidity': 67,
#   'Cloudiness': 28,
#   'Wind Speed': 10.65},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 83.41,
#   'Humidity': 26,
#   'Cloudiness': 14,
#   'Wind Speed': 19.64},
#  {'City': 'Thinadhoo',
#   'Country': 'MV',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 81.03,
#   'Humidity': 76,
#   'Cloudiness': 43,
#   'Wind Speed': 2.75},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 20.19,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 7.83},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 55.78,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 30.56,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01},
#  {'City': 'San Felipe',
#   'Country': 'VE',
#   'Lat': 10.3399,
#   'Lng': -68.7425,
#   'Max Temp': 86,
#   'Humidity': 46,
#   'Cloudiness': 14,
#   'Wind Speed': 10.56},
#  {'City': 'Iracoubo',
#   'Country': 'GF',
#   'Lat': 5.4802,
#   'Lng': -53.2011,
#   'Max Temp': 79.65,
#   'Humidity': 74,
#   'Cloudiness': 58,
#   'Wind Speed': 11.59},
#  {'City': 'Zeya',
#   'Country': 'RU',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': -16.8,
#   'Humidity': 92,
#   'Cloudiness': 13,
#   'Wind Speed': 2.77},
#  {'City': 'Raudeberg',
#   'Country': 'NO',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 34.2,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01},
#  {'City': 'Road Town',
#   'Country': 'VG',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 84.24,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22},
#  {'City': 'Teseney',
#   'Country': 'ER',
#   'Lat': 15.11,
#   'Lng': 36.6575,
#   'Max Temp': 71.89,
#   'Humidity': 22,
#   'Cloudiness': 37,
#   'Wind Speed': 10.25},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -52.4,
#   'Humidity': 100,
#   'Cloudiness': 64,
#   'Wind Speed': 2.8},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 7.7,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 18.01},
#  {'City': 'Pathein',
#   'Country': 'MM',
#   'Lat': 16.7833,
#   'Lng': 94.7333,
#   'Max Temp': 70.09,
#   'Humidity': 82,
#   'Cloudiness': 3,
#   'Wind Speed': 4.25},
#  {'City': 'Tan An',
#   'Country': 'VN',
#   'Lat': 10.5333,
#   'Lng': 106.4167,
#   'Max Temp': 77.02,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45},
#  {'City': 'Yenagoa',
#   'Country': 'NG',
#   'Lat': 4.9247,
#   'Lng': 6.2642,
#   'Max Temp': 82.44,
#   'Humidity': 70,
#   'Cloudiness': 33,
#   'Wind Speed': 7.63},
#  {'City': 'Shingu',
#   'Country': 'JP',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 45.91,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 11.81},
#  {'City': 'Novoalekseyevskaya',
#   'Country': 'RU',
#   'Lat': 44.8189,
#   'Lng': 40.9339,
#   'Max Temp': 36.37,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72},
#  {'City': 'Karratha',
#   'Country': 'AU',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 85.05,
#   'Humidity': 44,
#   'Cloudiness': 46,
#   'Wind Speed': 13.44},
#  {'City': 'Luis Correia',
#   'Country': 'BR',
#   'Lat': -2.8792,
#   'Lng': -41.6669,
#   'Max Temp': 83.23,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 12.59},
#  {'City': 'Muromtsevo',
#   'Country': 'RU',
#   'Lat': 56.3724,
#   'Lng': 75.2418,
#   'Max Temp': 16.27,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.82},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 76.01,
#   'Humidity': 77,
#   'Cloudiness': 9,
#   'Wind Speed': 7.74},
#  {'City': 'Bay City',
#   'Country': 'US',
#   'Lat': 43.5945,
#   'Lng': -83.8889,
#   'Max Temp': 27.16,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 8.99},
#  {'City': 'Callaway',
#   'Country': 'US',
#   'Lat': 30.153,
#   'Lng': -85.5699,
#   'Max Temp': 43.92,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8},
#  {'City': 'Shimoda',
#   'Country': 'JP',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 43.11,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 28.45},
#  {'City': 'Ishigaki',
#   'Country': 'JP',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 70.21,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 16.96},
#  {'City': 'Cassilandia',
#   'Country': 'BR',
#   'Lat': -19.1133,
#   'Lng': -51.7342,
#   'Max Temp': 84.29,
#   'Humidity': 63,
#   'Cloudiness': 28,
#   'Wind Speed': 5.75},
#  {'City': 'Shu',
#   'Country': 'KZ',
#   'Lat': 43.5983,
#   'Lng': 73.7614,
#   'Max Temp': 34.05,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61},
#  {'City': 'Abu Samrah',
#   'Country': 'SY',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 46.81,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 6.13},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 12.52,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4},
#  {'City': 'Migori',
#   'Country': 'KE',
#   'Lat': -1.0634,
#   'Lng': 34.4731,
#   'Max Temp': 68.23,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.95},
#  {'City': 'Porto Walter',
#   'Country': 'BR',
#   'Lat': -8.2686,
#   'Lng': -72.7439,
#   'Max Temp': 90.09,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 4.41},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 9.45,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 8.79},
#  {'City': 'Anadyr',
#   'Country': 'RU',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 26.01,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 25.99},
#  {'City': 'Sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 82.69,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 11.43},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 26.62,
#   'Humidity': 46,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8},
#  {'City': 'Jalu',
#   'Country': 'LY',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 58.59,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -17.68,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.85},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 56.23,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 14.56},
#  {'City': 'Indianola',
#   'Country': 'US',
#   'Lat': 41.3581,
#   'Lng': -93.5574,
#   'Max Temp': 33.91,
#   'Humidity': 62,
#   'Cloudiness': 11,
#   'Wind Speed': 11.72},
#  {'City': 'Fuerte Olimpo',
#   'Country': 'PY',
#   'Lat': -21.0415,
#   'Lng': -57.8738,
#   'Max Temp': 100.22,
#   'Humidity': 29,
#   'Cloudiness': 90,
#   'Wind Speed': 10.8},
#  {'City': 'Bandarban',
#   'Country': 'BD',
#   'Lat': 22.1965,
#   'Lng': 92.2262,
#   'Max Temp': 56.77,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 1.95},
#  {'City': 'Freetown',
#   'Country': 'SL',
#   'Lat': 8.484,
#   'Lng': -13.2299,
#   'Max Temp': 80.38,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01},
#  {'City': 'Honiara',
#   'Country': 'SB',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 77.49,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 7.85},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 78.51,
#   'Humidity': 80,
#   'Cloudiness': 86,
#   'Wind Speed': 19.3},
#  {'City': 'Praia Da Vitoria',
#   'Country': 'PT',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 56.75,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 12.12},
#  {'City': 'Luanda',
#   'Country': 'AO',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 77.65,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 7.63},
#  {'City': 'Hurricane',
#   'Country': 'US',
#   'Lat': 37.1753,
#   'Lng': -113.2899,
#   'Max Temp': 49.59,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 3.76},
#  {'City': 'Sibu',
#   'Country': 'MY',
#   'Lat': 2.3,
#   'Lng': 111.8167,
#   'Max Temp': 74.03,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 77.34,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91},
#  {'City': 'Filadelfia',
#   'Country': 'US',
#   'Lat': 39.9523,
#   'Lng': -75.1638,
#   'Max Temp': 32.7,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3},
#  {'City': 'Nenjiang',
#   'Country': 'CN',
#   'Lat': 49.1833,
#   'Lng': 125.2167,
#   'Max Temp': -22.7,
#   'Humidity': 89,
#   'Cloudiness': 31,
#   'Wind Speed': 1.61},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -32.58,
#   'Humidity': 86,
#   'Cloudiness': 79,
#   'Wind Speed': 9.55},
#  {'City': 'Fez',
#   'Country': 'MA',
#   'Lat': 34.0372,
#   'Lng': -4.9998,
#   'Max Temp': 55.65,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': -13.29,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.29},
#  {'City': 'Sabrum',
#   'Country': 'IN',
#   'Lat': 23,
#   'Lng': 91.7319,
#   'Max Temp': 56.88,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 2.75},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 72.03,
#   'Humidity': 17,
#   'Cloudiness': 7,
#   'Wind Speed': 10.09},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 68.76,
#   'Humidity': 72,
#   'Cloudiness': 21,
#   'Wind Speed': 13.4},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 70.21,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8},
#  {'City': 'Nipawin',
#   'Country': 'CA',
#   'Lat': 53.3668,
#   'Lng': -104.0009,
#   'Max Temp': -9.92,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.36},
#  {'City': 'Tazovskiy',
#   'Country': 'RU',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': -14.13,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 14.83},
#  {'City': 'Olga',
#   'Country': 'RU',
#   'Lat': 43.7444,
#   'Lng': 135.2892,
#   'Max Temp': 8.65,
#   'Humidity': 54,
#   'Cloudiness': 8,
#   'Wind Speed': 12.93},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 34.72,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 58.7},
#  {'City': 'Vero Beach',
#   'Country': 'US',
#   'Lat': 27.6386,
#   'Lng': -80.3973,
#   'Max Temp': 75.02,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 4},
#  {'City': 'Narasaraopet',
#   'Country': 'IN',
#   'Lat': 16.25,
#   'Lng': 80.0667,
#   'Max Temp': 66.69,
#   'Humidity': 92,
#   'Cloudiness': 6,
#   'Wind Speed': 2.64},
#  {'City': 'Aripuana',
#   'Country': 'BR',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 82.13,
#   'Humidity': 90,
#   'Cloudiness': 39,
#   'Wind Speed': 4.47},
#  {'City': 'Kavaratti',
#   'Country': 'IN',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 81.84,
#   'Humidity': 70,
#   'Cloudiness': 8,
#   'Wind Speed': 7.61},
#  {'City': 'Tecoanapa',
#   'Country': 'MX',
#   'Lat': 16.5167,
#   'Lng': -98.75,
#   'Max Temp': 83.79,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 9.69},
#  {'City': 'Camacha',
#   'Country': 'PT',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 65.53,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44},
#  {'City': 'Brownsburg',
#   'Country': 'US',
#   'Lat': 39.8434,
#   'Lng': -86.3978,
#   'Max Temp': 31.87,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 3},
#  {'City': 'Huamachuco',
#   'Country': 'PE',
#   'Lat': -7.8,
#   'Lng': -78.0667,
# ...
#   'Country': 'JP',
#   'Lat': 31.4167,
#   'Lng': 130.3167,
#   'Max Temp': 43.84,
#   'Humidity': 62,
#   'Cloudiness': 5,
#   'Wind Speed': 15.03},
#  {'City': 'Balabac',
#   'Country': 'PH',
#   'Lat': 7.9868,
#   'Lng': 117.0645,
#   'Max Temp': 78.28,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 17.07},
#  {'City': 'Erzin',
#   'Country': 'TR',
#   'Lat': 36.9559,
#   'Lng': 36.2,
#   'Max Temp': 50.72,
#   'Humidity': 42,
#   'Cloudiness': 69,
#   'Wind Speed': 1.68},
#  {'City': 'Blagoyevo',
#   'Country': 'RU',
#   'Lat': 63.3667,
#   'Lng': 47.9167,
#   'Max Temp': 3,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 4.88},
#  {'City': 'Tarakan',
#   'Country': 'ID',
#   'Lat': 3.3,
#   'Lng': 117.6333,
#   'Max Temp': 76.5,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75},
#  {'City': 'Tautira',
#   'Country': 'PF',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 84.22,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 17.13},
#  {'City': 'Porto Seguro',
#   'Country': 'BR',
#   'Lat': -16.4497,
#   'Lng': -39.0647,
#   'Max Temp': 82.92,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97},
#  {'City': 'Ula',
#   'Country': 'IN',
#   'Lat': 22.7225,
#   'Lng': 88.5556,
#   'Max Temp': 58.98,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75},
#  {'City': 'Boca Do Acre',
#   'Country': 'BR',
#   'Lat': -8.7522,
#   'Lng': -67.3978,
#   'Max Temp': 88.65,
#   'Humidity': 58,
#   'Cloudiness': 89,
#   'Wind Speed': 4.72},
#  {'City': 'Bathsheba',
#   'Country': 'BB',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 84.81,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 23.02},
#  {'City': 'Langfang',
#   'Country': 'CN',
#   'Lat': 39.5097,
#   'Lng': 116.6947,
#   'Max Temp': 14.25,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 2.42},
#  {'City': 'Christchurch',
#   'Country': 'NZ',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 67.03,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99},
#  {'City': 'Semnan',
#   'Country': 'IR',
#   'Lat': 35.5729,
#   'Lng': 53.3971,
#   'Max Temp': 42.67,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08},
#  {'City': 'Sitangkai',
#   'Country': 'PH',
#   'Lat': 4.6628,
#   'Lng': 119.3928,
#   'Max Temp': 79.68,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 9.1},
#  {'City': 'Sanbu',
#   'Country': 'CN',
#   'Lat': 33.4594,
#   'Lng': 119.1453,
#   'Max Temp': 36.59,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 7},
#  {'City': 'Tumbi',
#   'Country': 'TZ',
#   'Lat': -5.0667,
#   'Lng': 32.7333,
#   'Max Temp': 66.94,
#   'Humidity': 93,
#   'Cloudiness': 96,
#   'Wind Speed': 3.51},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 65.39,
#   'Humidity': 72,
#   'Cloudiness': 47,
#   'Wind Speed': 3.04},
#  {'City': 'Lukovetskiy',
#   'Country': 'RU',
#   'Lat': 64.2956,
#   'Lng': 41.9211,
#   'Max Temp': -2.02,
#   'Humidity': 98,
#   'Cloudiness': 56,
#   'Wind Speed': 4.41},
#  {'City': 'Bereda',
#   'Country': 'ES',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 58.91,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 10.92},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 69.78,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5},
#  {'City': 'Verkhneyarkeyevo',
#   'Country': 'RU',
#   'Lat': 55.4505,
#   'Lng': 54.3145,
#   'Max Temp': 0.16,
#   'Humidity': 97,
#   'Cloudiness': 83,
#   'Wind Speed': 10.07},
#  {'City': 'Santa Cruz Del Sur',
#   'Country': 'CU',
#   'Lat': 20.7147,
#   'Lng': -77.9956,
#   'Max Temp': 82.36,
#   'Humidity': 53,
#   'Cloudiness': 89,
#   'Wind Speed': 10.02},
#  {'City': 'Dwarka',
#   'Country': 'IN',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 72.66,
#   'Humidity': 70,
#   'Cloudiness': 64,
#   'Wind Speed': 8.12},
#  {'City': 'Mosquera',
#   'Country': 'CO',
#   'Lat': 4.7059,
#   'Lng': -74.2302,
#   'Max Temp': 71.69,
#   'Humidity': 24,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91},
#  {'City': 'Harnosand',
#   'Country': 'SE',
#   'Lat': 62.6323,
#   'Lng': 17.9379,
#   'Max Temp': 28.42,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.22},
#  {'City': 'Takanabe',
#   'Country': 'JP',
#   'Lat': 32.1333,
#   'Lng': 131.5,
#   'Max Temp': 39.67,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 7.85},
#  {'City': 'Tongliao',
#   'Country': 'CN',
#   'Lat': 43.6125,
#   'Lng': 122.2653,
#   'Max Temp': -7.08,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 4.74},
#  {'City': 'Changde',
#   'Country': 'CN',
#   'Lat': 29.0464,
#   'Lng': 111.6783,
#   'Max Temp': 48.79,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44},
#  {'City': 'Kurumkan',
#   'Country': 'RU',
#   'Lat': 54.3,
#   'Lng': 110.3,
#   'Max Temp': -7.53,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81},
#  {'City': 'Carndonagh',
#   'Country': 'IE',
#   'Lat': 55.25,
#   'Lng': -7.2667,
#   'Max Temp': 40.62,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 13.6},
#  {'City': 'Wladyslawowo',
#   'Country': 'PL',
#   'Lat': 54.7909,
#   'Lng': 18.4009,
#   'Max Temp': 44.94,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 21.5},
#  {'City': 'New Ulm',
#   'Country': 'US',
#   'Lat': 44.3125,
#   'Lng': -94.4605,
#   'Max Temp': 33.57,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61},
#  {'City': 'Doka',
#   'Country': 'SD',
#   'Lat': 13.5167,
#   'Lng': 35.7667,
#   'Max Temp': 74.73,
#   'Humidity': 22,
#   'Cloudiness': 94,
#   'Wind Speed': 14.07},
#  {'City': 'Flin Flon',
#   'Country': 'CA',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': -16.76,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61},
#  {'City': 'Mulchen',
#   'Country': 'CL',
#   'Lat': -37.7167,
#   'Lng': -72.2333,
#   'Max Temp': 71.46,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01},
#  {'City': 'Leticia',
#   'Country': 'CO',
#   'Lat': -4.2153,
#   'Lng': -69.9406,
#   'Max Temp': 82.45,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 0},
#  {'City': 'Tomatlan',
#   'Country': 'MX',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 90.16,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 7.14},
#  {'City': 'Khandyga',
#   'Country': 'RU',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Max Temp': -42.09,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82},
#  {'City': 'Kamojima',
#   'Country': 'JP',
#   'Lat': 34.0667,
#   'Lng': 134.35,
#   'Max Temp': 47.41,
#   'Humidity': 64,
#   'Cloudiness': 25,
#   'Wind Speed': 12.68},
#  {'City': 'Bosaso',
#   'Country': 'SO',
#   'Lat': 11.2842,
#   'Lng': 49.1816,
#   'Max Temp': 76.23,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 3.18},
#  {'City': 'Whitehorse',
#   'Country': 'CA',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': -17.63,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 8.01},
#  {'City': 'Banjarmasin',
#   'Country': 'ID',
#   'Lat': -3.3244,
#   'Lng': 114.591,
#   'Max Temp': 75.34,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.17},
#  {'City': 'Rafai',
#   'Country': 'CF',
#   'Lat': 4.95,
#   'Lng': 23.9167,
#   'Max Temp': 77.92,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 3.04},
#  {'City': 'Mega',
#   'Country': 'ET',
#   'Lat': 4.05,
#   'Lng': 38.3,
#   'Max Temp': 66.04,
#   'Humidity': 42,
#   'Cloudiness': 2,
#   'Wind Speed': 12.95},
#  {'City': 'Nemuro',
#   'Country': 'JP',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 18.61,
#   'Humidity': 67,
#   'Cloudiness': 12,
#   'Wind Speed': 20.87},
#  {'City': 'Beruwala',
#   'Country': 'LK',
#   'Lat': 6.4788,
#   'Lng': 79.9828,
#   'Max Temp': 75.52,
#   'Humidity': 90,
#   'Cloudiness': 61,
#   'Wind Speed': 4.85},
#  {'City': 'Orocue',
#   'Country': 'CO',
#   'Lat': 4.7912,
#   'Lng': -71.3354,
#   'Max Temp': 95.83,
#   'Humidity': 28,
#   'Cloudiness': 99,
#   'Wind Speed': 15.03},
#  {'City': 'Diofior',
#   'Country': 'SN',
#   'Lat': 14.1833,
#   'Lng': -16.6667,
#   'Max Temp': 87.75,
#   'Humidity': 19,
#   'Cloudiness': 36,
#   'Wind Speed': 6.42},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -28.25,
#   'Humidity': 94,
#   'Cloudiness': 10,
#   'Wind Speed': 7.92},
#  {'City': 'Ghanaur',
#   'Country': 'IN',
#   'Lat': 30.3322,
#   'Lng': 76.6072,
#   'Max Temp': 56.05,
#   'Humidity': 46,
#   'Cloudiness': 97,
#   'Wind Speed': 4.61},
#  {'City': 'Loubomo',
#   'Country': 'CG',
#   'Lat': -4.1997,
#   'Lng': 12.6739,
#   'Max Temp': 72.66,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27},
#  {'City': 'Manutuke',
#   'Country': 'NZ',
#   'Lat': -38.6833,
#   'Lng': 177.9167,
#   'Max Temp': 62.98,
#   'Humidity': 78,
#   'Cloudiness': 94,
#   'Wind Speed': 5.79},
#  {'City': 'Nador',
#   'Country': 'MA',
#   'Lat': 35.174,
#   'Lng': -2.9287,
#   'Max Temp': 53.85,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44},
#  {'City': 'Jacareacanga',
#   'Country': 'BR',
#   'Lat': -6.2222,
#   'Lng': -57.7528,
#   'Max Temp': 80.91,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44},
#  {'City': 'Mikhaylovka',
#   'Country': 'RU',
#   'Lat': 50.06,
#   'Lng': 43.2379,
#   'Max Temp': 25.79,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 16.69},
#  {'City': 'Goreloye',
#   'Country': 'RU',
#   'Lat': 52.937,
#   'Lng': 41.5043,
#   'Max Temp': 16.74,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.56},
#  {'City': 'Hargeysa',
#   'Country': 'SO',
#   'Lat': 9.56,
#   'Lng': 44.065,
#   'Max Temp': 65.28,
#   'Humidity': 89,
#   'Cloudiness': 36,
#   'Wind Speed': 7.81},
#  {'City': 'Honghu',
#   'Country': 'CN',
#   'Lat': 29.8206,
#   'Lng': 113.4621,
#   'Max Temp': 54.59,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38},
#  {'City': 'Cabo Rojo',
#   'Country': 'PR',
#   'Lat': 18.0866,
#   'Lng': -67.1457,
#   'Max Temp': 84.38,
#   'Humidity': 70,
#   'Cloudiness': 53,
#   'Wind Speed': 9.22},
#  {'City': 'Tsuchiura',
#   'Country': 'JP',
#   'Lat': 36.0905,
#   'Lng': 140.2105,
#   'Max Temp': 42.01,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 4.05},
#  {'City': 'Eydhafushi',
#   'Country': 'MV',
#   'Lat': 5.1033,
#   'Lng': 73.0708,
#   'Max Temp': 82.17,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 14.94},
#  {'City': 'Villazon',
#   'Country': 'BO',
#   'Lat': -22.0866,
#   'Lng': -65.5942,
#   'Max Temp': 72.27,
#   'Humidity': 19,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46},
#  {'City': 'Bestobe',
#   'Country': 'KZ',
#   'Lat': 52.4994,
#   'Lng': 73.0975,
#   'Max Temp': 24.42,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 12.5},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 57.2,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 9.86},
#  {'City': 'Guarapari',
#   'Country': 'BR',
#   'Lat': -20.6667,
#   'Lng': -40.4975,
#   'Max Temp': 82.29,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.69},
#  {'City': 'Praia',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 77.54,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8},
#  {'City': 'Riosucio',
#   'Country': 'CO',
#   'Lat': 5.4216,
#   'Lng': -75.7032,
#   'Max Temp': 72.03,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 1.16},
#  {'City': 'Ourossogui',
#   'Country': 'SN',
#   'Lat': 15.6064,
#   'Lng': -13.3211,
#   'Max Temp': 80.1,
#   'Humidity': 12,
#   'Cloudiness': 100,
#   'Wind Speed': 9.19},
#  {'City': 'Puerto Madryn',
#   'Country': 'AR',
#   'Lat': -42.7692,
#   'Lng': -65.0385,
#   'Max Temp': 83.21,
#   'Humidity': 25,
#   'Cloudiness': 100,
#   'Wind Speed': 39.26},
#  {'City': 'Tarko-Sale',
#   'Country': 'RU',
#   'Lat': 64.9225,
#   'Lng': 77.785,
#   'Max Temp': 12.49,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 13.87},
#  {'City': 'Burns Lake',
#   'Country': 'CA',
#   'Lat': 54.2331,
#   'Lng': -125.7533,
#   'Max Temp': -4.58,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.5},
#  {'City': 'Karwar',
#   'Country': 'IN',
#   'Lat': 14.8,
#   'Lng': 74.1333,
#   'Max Temp': 75.18,
#   'Humidity': 59,
#   'Cloudiness': 81,
#   'Wind Speed': 5.41},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 60.46,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 16.02},
#  {'City': 'Patnanungan',
#   'Country': 'PH',
#   'Lat': 14.7833,
#   'Lng': 122.1833,
#   'Max Temp': 76.6,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 21.65},
#  {'City': 'Ballina',
#   'Country': 'AU',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 71.78,
#   'Humidity': 95,
#   'Cloudiness': 76,
#   'Wind Speed': 20.4},
#  {'City': 'Wanning',
#   'Country': 'CN',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 69.24,
#   'Humidity': 83,
#   'Cloudiness': 85,
#   'Wind Speed': 6.78},
#  {'City': 'Verkhnyaya Inta',
#   'Country': 'RU',
#   'Lat': 65.9811,
#   'Lng': 60.3094,
#   'Max Temp': 2.21,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28},
#  {'City': 'Buta',
#   'Country': 'CD',
#   'Lat': 2.7858,
#   'Lng': 24.73,
#   'Max Temp': 74.7,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 1.43},
#  {'City': 'Miri',
#   'Country': 'MY',
#   'Lat': 4.4148,
#   'Lng': 114.0089,
#   'Max Temp': 75.34,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61},
#  {'City': 'Aberdeen',
#   'Country': 'GB',
#   'Lat': 57.1437,
#   'Lng': -2.0981,
#   'Max Temp': 36.5,
#   'Humidity': 76,
#   'Cloudiness': 4,
#   'Wind Speed': 11.5},
#  {'City': 'Nantucket',
#   'Country': 'US',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 35.15,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 31.52},
#  {'City': 'Thunder Bay',
#   'Country': 'CA',
#   'Lat': 48.4001,
#   'Lng': -89.3168,
#   'Max Temp': 18.55,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66},
#  {'City': 'Avrameni',
#   'Country': 'RO',
#   'Lat': 48.0167,
#   'Lng': 26.95,
#   'Max Temp': 44.98,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27},
#  {'City': 'Seryshevo',
#   'Country': 'RU',
#   'Lat': 51.0933,
#   'Lng': 128.3786,
#   'Max Temp': -26.25,
#   'Humidity': 100,
#   'Cloudiness': 25,
#   'Wind Speed': 3},
#  {'City': 'Izhma',
#   'Country': 'RU',
#   'Lat': 65.0083,
#   'Lng': 53.9113,
#   'Max Temp': 2.71,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.84},
#  {'City': 'Fort Frances',
#   'Country': 'CA',
#   'Lat': 48.5999,
#   'Lng': -93.4003,
#   'Max Temp': 7.02,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 56.66,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99},
#  {'City': 'Opelousas',
#   'Country': 'US',
#   'Lat': 30.5335,
#   'Lng': -92.0815,
#   'Max Temp': 46.53,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05},
#  {'City': 'Damghan',
#   'Country': 'IR',
#   'Lat': 36.1683,
#   'Lng': 54.348,
#   'Max Temp': 39.6,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64},
#  {'City': 'Swan Hill',
#   'Country': 'AU',
#   'Lat': -35.3378,
#   'Lng': 143.5544,
#   'Max Temp': 57.34,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.27},
#  {'City': 'Neepawa',
#   'Country': 'CA',
#   'Lat': 50.2289,
#   'Lng': -99.4664,
#   'Max Temp': -1.19,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 10.31},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 58.41,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 14.81},
#  {'City': 'Soledade',
#   'Country': 'BR',
#   'Lat': -28.8183,
#   'Lng': -52.5103,
#   'Max Temp': 87.8,
#   'Humidity': 34,
#   'Cloudiness': 70,
#   'Wind Speed': 7.31},
#  {'City': 'Kota Kinabalu',
#   'Country': 'MY',
#   'Lat': 5.9749,
#   'Lng': 116.0724,
#   'Max Temp': 75.18,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44},
#  {'City': 'Conceicao Do Araguaia',
#   'Country': 'BR',
#   'Lat': -8.2578,
#   'Lng': -49.2647,
#   'Max Temp': 76.24,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 5.44},
#  {'City': 'Huilong',
#   'Country': 'CN',
#   'Lat': 31.8111,
#   'Lng': 121.655,
#   'Max Temp': 47.03,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 6.35},
#  {'City': 'The Pas',
#   'Country': 'CA',
#   'Lat': 53.8251,
#   'Lng': -101.2541,
#   'Max Temp': -12.98,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75},
#  {'City': 'Gimli',
#   'Country': 'CA',
#   'Lat': 50.6336,
#   'Lng': -96.9907,
#   'Max Temp': 3.22,
#   'Humidity': 66,
#   'Cloudiness': 57,
#   'Wind Speed': 8.05},
#  {'City': 'Coburg',
#   'Country': 'DE',
#   'Lat': 50.2667,
#   'Lng': 10.9667,
#   'Max Temp': 47.98,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4},
#  {'City': 'Vershino-Darasunskiy',
#   'Country': 'RU',
#   'Lat': 52.35,
#   'Lng': 115.5167,
#   'Max Temp': -19.89,
#   'Humidity': 99,
#   'Cloudiness': 18,
#   'Wind Speed': 2.66}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_database)
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Marquette      US  46.5333  -87.6335     22.68        49
# 1                  Albany      US  42.6001  -73.9662     23.09        77
# 2              Butaritari      KI   3.0707  172.7902     80.85        65
# 3                 Iquique      CL -20.2208  -70.1431     73.26        66
# 4                 Rikitea      PF -23.1203 -134.9692     77.16        70
# ..                    ...     ...      ...       ...       ...       ...
# 654               Huilong      CN  31.8111  121.6550     47.03        85
# 655               The Pas      CA  53.8251 -101.2541    -12.98        77
# 656                 Gimli      CA  50.6336  -96.9907      3.22        66
# 657                Coburg      DE  50.2667   10.9667     47.98        94
# 658  Vershino-Darasunskiy      RU  52.3500  115.5167    -19.89        99
#
#      Cloudiness  Wind Speed
# 0            94        9.51
# 1           100        1.01
# 2           100       13.40
# 3             9        9.04
# 4           100        6.53
# ..          ...         ...
# 654           0        6.35
# 655           1        5.75
# 656          57        8.05
# 657         100        4.00
# 658          18        2.66
#
# [659 rows x 8 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
