# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
city_database = []

# %%
#  Using NumPy to create random figures
np.random.uniform(-90, 90, size=2000)
# Out:
# array([ 87.72912531,  69.10940348,   3.31670889, ...,  26.49700861,
#         65.4081682 , -77.59480708])

# %%
# Adding Timeit
# %timeit np.random.uniform(-90, 90, size=2000)
# Out:
# 14.5 µs ± 128 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# defining random latitudes
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = np.random.randint(-90, 90) + np.random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(2000)
# Out:
# 4.45 ms ± 40.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import Citipy
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
cities
# Out:
# ['te anau',
#  'ucluelet',
#  'mataura',
#  'kidal',
#  'iracoubo',
#  'hilo',
#  'rikitea',
#  'new norfolk',
#  'cidreira',
#  'kulhudhuffushi',
#  'atuona',
#  'mackay',
#  'kincardine',
#  'kachikau',
#  'loiza',
#  'saint-georges',
#  'egvekinot',
#  'grande prairie',
#  'butaritari',
#  'saldanha',
#  'susurluk',
#  'iowa city',
#  'sabang',
#  'bilma',
#  'san patricio',
#  'vaitupu',
#  'toliary',
#  'khatanga',
#  'dikson',
#  'nanortalik',
#  'gat',
#  'kulu',
#  'balikpapan',
#  'paranaiba',
#  'saint anthony',
#  'palmer',
#  'busselton',
#  'lagoa',
#  'mahebourg',
#  'ushuaia',
#  'ancud',
#  'esperance',
#  'altay',
#  'shingu',
#  'jamestown',
#  'georgetown',
#  'albany',
#  'cockburn town',
#  'saint-philippe',
#  'vaini',
#  'baruun-urt',
#  'severo-kurilsk',
#  'wasilla',
#  'tandalti',
#  'quatre cocos',
#  'kaitangata',
#  'kutum',
#  'reynosa',
#  'le port',
#  'hobart',
#  'tasbuget',
#  'bambous virieux',
#  'chipinge',
#  'bluff',
#  'athabasca',
#  'puerto narino',
#  'faanui',
#  'tuktoyaktuk',
#  'arraial do cabo',
#  'barrow',
#  'vardo',
#  'bac lieu',
#  'tarudant',
#  'ust-ilimsk',
#  'bredasdorp',
#  'melfort',
#  'satitoa',
#  'mys shmidta',
#  'debre zeyit',
#  'zhigansk',
#  'yellowknife',
#  'novopskov',
#  'turbat',
#  'piedras negras',
#  'torbay',
#  'mutoko',
#  'goderich',
#  'tiznit',
#  'kapaa',
#  'smithers',
#  'ewa beach',
#  'cape town',
#  'itaituba',
#  'naze',
#  'east london',
#  'hasaki',
#  'roma',
#  'kilrush',
#  'pevek',
#  'arandis',
#  'kavieng',
#  'obregon',
#  'port elizabeth',
#  'barranca',
#  'itarema',
#  'muisne',
#  'oltu',
#  'samusu',
#  'upernavik',
#  'crab hill',
#  'lompoc',
#  'ribeira grande',
#  'geresk',
#  'ilulissat',
#  'barentsburg',
#  'adilcevaz',
#  'sao joao da barra',
#  'fort abbas',
#  'pacific grove',
#  'taolanaro',
#  'avarua',
#  'puerto ayora',
#  'leningradskiy',
#  'norman wells',
#  'labutta',
#  'klaksvik',
#  'punta arenas',
#  'port hardy',
#  'arlit',
#  'matadi',
#  'acapulco',
#  'attawapiskat',
#  'hithadhoo',
#  'illoqqortoormiut',
#  'carnarvon',
#  'hohhot',
#  'alofi',
#  'fortuna',
#  'maykain',
#  'erdemli',
#  'alice springs',
#  'rio gallegos',
#  'nantucket',
#  'carutapera',
#  'varkaus',
#  'qaanaaq',
#  'jay',
#  'victoria',
#  'tsihombe',
#  'toba',
#  'bilibino',
#  'saskylakh',
#  'port alfred',
#  'vitimskiy',
#  'tumannyy',
#  'shelburne',
#  'cardoso',
#  'pisco',
#  'oranjestad',
#  'oriximina',
#  'aykhal',
#  'yulara',
#  'cherskiy',
#  'melville',
#  'sao filipe',
#  'salalah',
#  'mumford',
#  'dubuque',
#  'shebalino',
#  'cabo san lucas',
#  'guerrero negro',
#  'nemuro',
#  'rancho cucamonga',
#  'luau',
#  'konakovo',
#  'broken hill',
#  'chumikan',
#  'shieli',
#  'anadyr',
#  'saint george',
#  'ushtobe',
#  'katsuura',
#  'vila',
#  'grand centre',
#  'iqaluit',
#  'sovetskiy',
#  'safaqis',
#  'nortelandia',
#  'treinta y tres',
#  'makakilo city',
#  'shimoda',
#  'comodoro rivadavia',
#  'vilsbiburg',
#  'carballo',
#  'talnakh',
#  'telsiai',
#  'luderitz',
#  'grahamstown',
#  'pokhara',
#  'geraldton',
#  'hays',
#  'mar del plata',
#  'port hedland',
#  'nizhneyansk',
#  'thompson',
#  'sioux lookout',
#  'nikolskoye',
#  'grand river south east',
#  'la asuncion',
#  'nagornyy',
#  'amderma',
#  'indramayu',
#  'mayumba',
#  'high level',
#  'asau',
#  'teguldet',
#  'orlik',
#  'nouadhibou',
#  'tbilisskaya',
#  'calabozo',
#  'kodiak',
#  'yar-sale',
#  'kota kinabalu',
#  'labuhan',
#  'benghazi',
#  'parangan',
#  'coahuayana',
#  'chara',
#  'piotrkow trybunalski',
#  'hirado',
#  'belushya guba',
#  'sao sebastiao',
#  'tanshui',
#  'san quintin',
#  'raozan',
#  'berlevag',
#  'ranau',
#  'halifax',
#  'talaya',
#  'araouane',
#  'christchurch',
#  'hermanus',
#  'sokolo',
#  'tadine',
#  'san julian',
#  'faya',
#  'tolaga bay',
#  'la grande',
#  'bathsheba',
#  'corinto',
#  'olafsvik',
#  'whitehorse',
#  'nurota',
#  'alta floresta',
#  'dukat',
#  'neuquen',
#  'marcona',
#  'kamenka',
#  'darhan',
#  'helena',
#  'hirara',
#  'mponela',
#  'katangli',
#  'rio grande',
#  'tautira',
#  'kamenskoye',
#  'kahului',
#  'puerto escondido',
#  'soavinandriana',
#  'ca mau',
#  'forio',
#  'kannangad',
#  'ulladulla',
#  'north platte',
#  'gushikawa',
#  'provideniya',
#  'manono',
#  'pemba',
#  'aberdeen',
#  'yerbogachen',
#  'pangody',
#  'pangnirtung',
#  'kjollefjord',
#  'gafanha da encarnacao',
#  'souillac',
#  'dudinka',
#  'ternate',
#  'awbari',
#  'scottsburgh',
#  'buraydah',
#  'gorom-gorom',
#  'muros',
#  'kenai',
#  'berdigestyakh',
#  'moose factory',
#  'luganville',
#  'dickinson',
#  'dunedin',
#  'ambodifototra',
#  'marsh harbour',
#  'mlonggo',
#  'shakawe',
#  'bandarbeyla',
#  'mrakovo',
#  'tuatapere',
#  'allapalli',
#  'ixtapa',
#  'tervel',
#  'taoudenni',
#  'nizhniy odes',
#  'tkvarcheli',
#  'bengkulu',
#  'morondava',
#  'cayenne',
#  'najran',
#  'barawe',
#  'bonavista',
#  'princeton',
#  'saint-joseph',
#  'cockburn harbour',
#  'neryungri',
#  'visakhapatnam',
#  'katha',
#  'kamina',
#  'nguiu',
#  'chokurdakh',
#  'tuy hoa',
#  'gollere',
#  'kavaratti',
#  'ouargaye',
#  'fort nelson',
#  'adrar',
#  'lavrentiya',
#  'sedelnikovo',
#  'eyemouth',
#  'cilegon',
#  'naryan-mar',
#  'sorong',
#  'pareora',
#  'kasane',
#  'sorland',
#  'lebu',
#  'hamilton',
#  'santa maria da vitoria',
#  'lolua',
#  'rudnyy',
#  'maragogi',
#  'sentyabrskiy',
#  'praia',
#  'angoche',
#  'amapa',
#  'petropavlovsk-kamchatskiy',
#  'myitkyina',
#  'peniche',
#  'madoc',
#  'chatakonda',
#  'husavik',
#  'tasiilaq',
#  'locri',
#  'tiksi',
#  'kalaleh',
#  'batemans bay',
#  'beringovskiy',
#  'nome',
#  'hovd',
#  'rawson',
#  'clyde river',
#  'kuche',
#  'narsaq',
#  'upata',
#  'hualmay',
#  'touros',
#  'naron',
#  'aliwal north',
#  'chuy',
#  'tecoanapa',
#  'shache',
#  'karakendzha',
#  'beloha',
#  'fethiye',
#  'zabol',
#  'valparaiso',
#  'krasnoselkup',
#  'padang',
#  'samalaeulu',
#  'ivdel',
#  'lufilufi',
#  'vao',
#  'canatlan',
#  'vestmanna',
#  'aquiraz',
#  'bethel',
#  'airai',
#  'viedma',
#  'alberton',
#  'jutai',
#  'milkovo',
#  'kirakira',
#  'uklana mandi',
#  'uzumlu',
#  'champerico',
#  'henties bay',
#  'progreso',
#  'impfondo',
#  'inirida',
#  'liaozhong',
#  'isabela',
#  'umzimvubu',
#  'maceio',
#  'bone',
#  'bubaque',
#  'mudanjiang',
#  'tilichiki',
#  'eugene',
#  'huarmey',
#  'nanjing',
#  'mandan',
#  'harper',
#  'miles city',
#  'castro',
#  'dalinghe',
#  'lorengau',
#  'bismarck',
#  'daru',
#  'dali',
#  'inhambane',
#  'westport',
#  'bitung',
#  'codrington',
#  'linxia',
#  'petropavl',
#  'sept-iles',
#  'deqing',
#  'kingman',
#  'litovko',
#  'maldonado',
#  'santa cruz cabralia',
#  'khowst',
#  'sydney',
#  'nacogdoches',
#  'kayes',
#  'meulaboh',
#  'ponta do sol',
#  'joshimath',
#  'san carlos de bariloche',
#  'argir',
#  'baturaja',
#  'qaqortoq',
#  'sorel',
#  'opuwo',
#  'longyearbyen',
#  'mount gambier',
#  'jesup',
#  'tigil',
#  'lanquin',
#  'mogadishu',
#  'saleaula',
#  'wukari',
#  'seoul',
#  'lusambo',
#  'thenzawl',
#  'namatanai',
#  'tosya',
#  'mecca',
#  'kruisfontein',
#  'atasu',
#  'bandar-e lengeh',
#  'maarianhamina',
#  'dingle',
#  'surt',
#  'bambanglipuro',
#  'waipawa',
#  'la paz',
#  'teluknaga',
#  'carnduff',
#  'hammonton',
#  'phan rang',
#  'vanimo',
#  'makung',
#  'guelengdeng',
#  'nikolayevsk-na-amure',
#  'am timan',
#  'kaniama',
#  'poum',
#  'lhuntshi',
#  'ylivieska',
#  'kalmar',
#  'mufulira',
#  'tra vinh',
#  'biak',
#  'santa marta',
#  'flin flon',
#  'komsomolskiy',
#  'dicabisagan',
#  'northam',
#  'meyungs',
#  'micheweni',
#  'bindi',
#  'takoradi',
#  'sahuaripa',
#  'viransehir',
#  'keningau',
#  'tuggurt',
#  'jalu',
#  'denpasar',
#  'minot',
#  'dzilam gonzalez',
#  'fairbanks',
#  'roald',
#  'ayan',
#  'hebertville',
#  'warqla',
#  'tura',
#  'palabuhanratu',
#  'gizo',
#  'santa clara',
#  'nerchinskiy zavod',
#  'gannan',
#  'trelew',
#  'riberalta',
#  'sitka',
#  'isangel',
#  'staunton',
#  'sao miguel do araguaia',
#  'gamba',
#  'dongying',
#  'andselv',
#  'lar',
#  'nago',
#  'port lincoln',
#  'barra do garcas',
#  'sargur',
#  'darnah',
#  'moultrie',
#  'kholtoson',
#  'ishigaki',
#  'mangai',
#  'kieta',
#  'thinadhoo',
#  'berberati',
#  'barbar',
#  'bichena',
#  'iglesias',
#  'grand gaube',
#  'komoro',
#  'labuan',
#  'anori',
#  'caernarfon',
#  'kokkola',
#  'luwuk',
#  'talcahuano',
#  'varhaug',
#  'sao geraldo do araguaia',
#  'constitucion',
#  'nipawin',
#  'iranshahr',
#  'yanam',
#  'kununurra',
#  'eureka',
#  'sobolevo',
#  'coos bay',
#  'sarangani',
#  'ilobu',
#  'bereda',
#  'limbang',
#  'lazaro cardenas',
#  'wonthaggi',
#  'steinbach',
#  'bur gabo',
#  'benguela',
#  'quelimane',
#  'madridejos',
#  'aparecida do taboado',
#  'north bend',
#  'lavumisa',
#  'lucapa',
#  'moree',
#  'amfiklia',
#  'bayir',
#  'manokwari',
#  'half moon bay',
#  'yirol',
#  'moron',
#  'makat',
#  'koslan',
#  'sakakah',
#  'kirkuk',
#  'mutsamudu',
#  'la seyne-sur-mer',
#  'batagay',
#  'pergamino',
#  'sisimiut',
#  'rania',
#  'dire dawa',
#  'naraina',
#  'manicore',
#  'oranjemund',
#  'murindo',
#  'san cristobal',
#  'matay',
#  'pinos',
#  'pa sang',
#  'spassk',
#  'balyaga',
#  'luanda',
#  'agadez',
#  'batagay-alyta',
#  'aracati',
#  'tianpeng',
#  'napier',
#  'guaratinga',
#  'jamsa',
#  'morgan city',
#  'ingham',
#  'macusani',
#  'vostok',
#  'katobu',
#  'tweed',
#  'lewistown',
#  'groningen',
#  'formosa',
#  'owando',
#  'tromso',
#  'riyadh',
#  'deputatskiy',
#  'xocali',
#  'axim',
#  'aden',
#  'livingston',
#  'san felipe del progreso',
#  'malaryta',
#  'mirabad',
#  'kloulklubed',
#  'la ronge',
#  'wabana',
#  'gashua',
#  'grindavik',
#  'vila velha',
#  'camacha',
#  'kuito',
#  'the valley',
#  'dutlwe',
#  'pitimbu',
#  'karamea',
#  'mount isa',
#  'kangaatsiaq',
#  'cumaribo',
#  'beyneu',
#  'derzhavinsk',
#  'codajas',
#  'nishihara',
#  'ambon',
#  'baglung',
#  'narasapur',
#  'mabaruma',
#  'richards bay',
#  'lawton',
#  'rumoi',
#  'vestmannaeyjar',
#  'saint-pierre',
#  'aflu',
#  'matara',
#  'cubuk',
#  'abalak',
#  'khonuu',
#  'singarayakonda',
#  'burica',
#  'ust-koksa',
#  'namibe',
#  'lamar',
#  'whitianga',
#  'tahta',
#  'ejido',
#  'tabiauea',
#  'lashio',
#  'xai-xai',
#  'amuntai',
#  'boditi',
#  'shenjiamen',
#  'sergeyevka',
#  'mandiana',
#  'shwebo',
#  'seydisehir',
#  'nagapattinam',
#  'sfantu gheorghe',
#  'sao gabriel da cachoeira',
#  'kusk',
#  'chino valley',
#  'malatya',
#  'acarau',
#  'broome',
#  'san vicente',
#  'san jose',
#  'trujillo',
#  'bafata',
#  'twin falls',
#  'les cayes',
#  'brae',
#  'prince albert',
#  'jimeta',
#  'kigoma',
#  'haines junction',
#  'nianzishan',
#  'garoua',
#  'buala',
#  'nicoya',
#  'homberg',
#  'colares',
#  'kathu',
#  'matagami',
#  'buon me thuot',
#  'jumla',
#  'makariv',
#  'cap malheureux',
#  'banda aceh',
#  'guasdualito',
#  'scarborough',
#  'san rafael',
#  'visby',
#  'conde',
#  'oum hadjer',
#  'touba',
#  'bournemouth',
#  'caravelas',
#  'wuning',
#  'porto novo',
#  'sokolow podlaski',
#  'zhezkazgan',
#  'jiwani',
#  'sechura',
#  'belaya gora',
#  'kiunga',
#  'moses lake',
#  'bardiyah',
#  'nenjiang',
#  'ahipara',
#  'road town',
#  'auki',
#  'san ramon',
#  'salta',
#  'midland',
#  'almaznyy',
#  'wodonga',
#  'aktash']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]    
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_database.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | te anau
# Processing Record 2 of Set 1 | ucluelet
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | kidal
# Processing Record 5 of Set 1 | iracoubo
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | kulhudhuffushi
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | mackay
# Processing Record 13 of Set 1 | kincardine
# Processing Record 14 of Set 1 | kachikau
# City not found. Skipping...
# Processing Record 15 of Set 1 | loiza
# Processing Record 16 of Set 1 | saint-georges
# Processing Record 17 of Set 1 | egvekinot
# Processing Record 18 of Set 1 | grande prairie
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | saldanha
# Processing Record 21 of Set 1 | susurluk
# Processing Record 22 of Set 1 | iowa city
# Processing Record 23 of Set 1 | sabang
# Processing Record 24 of Set 1 | bilma
# Processing Record 25 of Set 1 | san patricio
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | nanortalik
# Processing Record 31 of Set 1 | gat
# Processing Record 32 of Set 1 | kulu
# Processing Record 33 of Set 1 | balikpapan
# Processing Record 34 of Set 1 | paranaiba
# Processing Record 35 of Set 1 | saint anthony
# Processing Record 36 of Set 1 | palmer
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | lagoa
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | altay
# Processing Record 44 of Set 1 | shingu
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | cockburn town
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | baruun-urt
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | wasilla
# Processing Record 4 of Set 2 | tandalti
# Processing Record 5 of Set 2 | quatre cocos
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | kutum
# Processing Record 8 of Set 2 | reynosa
# Processing Record 9 of Set 2 | le port
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | chipinge
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | athabasca
# Processing Record 16 of Set 2 | puerto narino
# Processing Record 17 of Set 2 | faanui
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | vardo
# Processing Record 22 of Set 2 | bac lieu
# Processing Record 23 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 2 | ust-ilimsk
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | melfort
# Processing Record 27 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 2 | debre zeyit
# Processing Record 30 of Set 2 | zhigansk
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | novopskov
# Processing Record 33 of Set 2 | turbat
# Processing Record 34 of Set 2 | piedras negras
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | mutoko
# Processing Record 37 of Set 2 | goderich
# Processing Record 38 of Set 2 | tiznit
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | smithers
# Processing Record 41 of Set 2 | ewa beach
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | itaituba
# Processing Record 44 of Set 2 | naze
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | roma
# Processing Record 48 of Set 2 | kilrush
# Processing Record 49 of Set 2 | pevek
# Processing Record 50 of Set 2 | arandis
# Processing Record 1 of Set 3 | kavieng
# Processing Record 2 of Set 3 | obregon
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | barranca
# Processing Record 5 of Set 3 | itarema
# Processing Record 6 of Set 3 | muisne
# Processing Record 7 of Set 3 | oltu
# Processing Record 8 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | adilcevaz
# Processing Record 17 of Set 3 | sao joao da barra
# Processing Record 18 of Set 3 | fort abbas
# Processing Record 19 of Set 3 | pacific grove
# Processing Record 20 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | punta arenas
# Processing Record 28 of Set 3 | port hardy
# Processing Record 29 of Set 3 | arlit
# Processing Record 30 of Set 3 | matadi
# Processing Record 31 of Set 3 | acapulco
# Processing Record 32 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 3 | hithadhoo
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | hohhot
# Processing Record 37 of Set 3 | alofi
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 40 of Set 3 | erdemli
# Processing Record 41 of Set 3 | alice springs
# Processing Record 42 of Set 3 | rio gallegos
# Processing Record 43 of Set 3 | nantucket
# Processing Record 44 of Set 3 | carutapera
# Processing Record 45 of Set 3 | varkaus
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | jay
# Processing Record 48 of Set 3 | victoria
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | toba
# Processing Record 1 of Set 4 | bilibino
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | vitimskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 4 | shelburne
# Processing Record 7 of Set 4 | cardoso
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | oranjestad
# Processing Record 10 of Set 4 | oriximina
# Processing Record 11 of Set 4 | aykhal
# Processing Record 12 of Set 4 | yulara
# Processing Record 13 of Set 4 | cherskiy
# Processing Record 14 of Set 4 | melville
# Processing Record 15 of Set 4 | sao filipe
# Processing Record 16 of Set 4 | salalah
# Processing Record 17 of Set 4 | mumford
# Processing Record 18 of Set 4 | dubuque
# Processing Record 19 of Set 4 | shebalino
# Processing Record 20 of Set 4 | cabo san lucas
# Processing Record 21 of Set 4 | guerrero negro
# Processing Record 22 of Set 4 | nemuro
# Processing Record 23 of Set 4 | rancho cucamonga
# Processing Record 24 of Set 4 | luau
# Processing Record 25 of Set 4 | konakovo
# Processing Record 26 of Set 4 | broken hill
# Processing Record 27 of Set 4 | chumikan
# Processing Record 28 of Set 4 | shieli
# Processing Record 29 of Set 4 | anadyr
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | ushtobe
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | vila
# Processing Record 34 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 4 | iqaluit
# Processing Record 36 of Set 4 | sovetskiy
# Processing Record 37 of Set 4 | safaqis
# City not found. Skipping...
# Processing Record 38 of Set 4 | nortelandia
# Processing Record 39 of Set 4 | treinta y tres
# Processing Record 40 of Set 4 | makakilo city
# Processing Record 41 of Set 4 | shimoda
# Processing Record 42 of Set 4 | comodoro rivadavia
# Processing Record 43 of Set 4 | vilsbiburg
# Processing Record 44 of Set 4 | carballo
# Processing Record 45 of Set 4 | talnakh
# Processing Record 46 of Set 4 | telsiai
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | grahamstown
# Processing Record 49 of Set 4 | pokhara
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | hays
# Processing Record 2 of Set 5 | mar del plata
# Processing Record 3 of Set 5 | port hedland
# Processing Record 4 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | sioux lookout
# Processing Record 7 of Set 5 | nikolskoye
# Processing Record 8 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 5 | la asuncion
# Processing Record 10 of Set 5 | nagornyy
# Processing Record 11 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 5 | indramayu
# Processing Record 13 of Set 5 | mayumba
# Processing Record 14 of Set 5 | high level
# Processing Record 15 of Set 5 | asau
# Processing Record 16 of Set 5 | teguldet
# Processing Record 17 of Set 5 | orlik
# Processing Record 18 of Set 5 | nouadhibou
# Processing Record 19 of Set 5 | tbilisskaya
# Processing Record 20 of Set 5 | calabozo
# Processing Record 21 of Set 5 | kodiak
# Processing Record 22 of Set 5 | yar-sale
# Processing Record 23 of Set 5 | kota kinabalu
# Processing Record 24 of Set 5 | labuhan
# Processing Record 25 of Set 5 | benghazi
# Processing Record 26 of Set 5 | parangan
# Processing Record 27 of Set 5 | coahuayana
# Processing Record 28 of Set 5 | chara
# Processing Record 29 of Set 5 | piotrkow trybunalski
# Processing Record 30 of Set 5 | hirado
# Processing Record 31 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 5 | sao sebastiao
# Processing Record 33 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 34 of Set 5 | san quintin
# Processing Record 35 of Set 5 | raozan
# City not found. Skipping...
# Processing Record 36 of Set 5 | berlevag
# Processing Record 37 of Set 5 | ranau
# Processing Record 38 of Set 5 | halifax
# Processing Record 39 of Set 5 | talaya
# Processing Record 40 of Set 5 | araouane
# Processing Record 41 of Set 5 | christchurch
# Processing Record 42 of Set 5 | hermanus
# Processing Record 43 of Set 5 | sokolo
# Processing Record 44 of Set 5 | tadine
# Processing Record 45 of Set 5 | san julian
# Processing Record 46 of Set 5 | faya
# Processing Record 47 of Set 5 | tolaga bay
# Processing Record 48 of Set 5 | la grande
# Processing Record 49 of Set 5 | bathsheba
# Processing Record 50 of Set 5 | corinto
# Processing Record 1 of Set 6 | olafsvik
# Processing Record 2 of Set 6 | whitehorse
# Processing Record 3 of Set 6 | nurota
# Processing Record 4 of Set 6 | alta floresta
# Processing Record 5 of Set 6 | dukat
# Processing Record 6 of Set 6 | neuquen
# Processing Record 7 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 6 | kamenka
# Processing Record 9 of Set 6 | darhan
# Processing Record 10 of Set 6 | helena
# Processing Record 11 of Set 6 | hirara
# Processing Record 12 of Set 6 | mponela
# Processing Record 13 of Set 6 | katangli
# Processing Record 14 of Set 6 | rio grande
# Processing Record 15 of Set 6 | tautira
# Processing Record 16 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 6 | kahului
# Processing Record 18 of Set 6 | puerto escondido
# Processing Record 19 of Set 6 | soavinandriana
# Processing Record 20 of Set 6 | ca mau
# Processing Record 21 of Set 6 | forio
# Processing Record 22 of Set 6 | kannangad
# Processing Record 23 of Set 6 | ulladulla
# Processing Record 24 of Set 6 | north platte
# Processing Record 25 of Set 6 | gushikawa
# Processing Record 26 of Set 6 | provideniya
# Processing Record 27 of Set 6 | manono
# Processing Record 28 of Set 6 | pemba
# Processing Record 29 of Set 6 | aberdeen
# Processing Record 30 of Set 6 | yerbogachen
# Processing Record 31 of Set 6 | pangody
# Processing Record 32 of Set 6 | pangnirtung
# Processing Record 33 of Set 6 | kjollefjord
# Processing Record 34 of Set 6 | gafanha da encarnacao
# Processing Record 35 of Set 6 | souillac
# Processing Record 36 of Set 6 | dudinka
# Processing Record 37 of Set 6 | ternate
# Processing Record 38 of Set 6 | awbari
# Processing Record 39 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 40 of Set 6 | buraydah
# Processing Record 41 of Set 6 | gorom-gorom
# Processing Record 42 of Set 6 | muros
# Processing Record 43 of Set 6 | kenai
# Processing Record 44 of Set 6 | berdigestyakh
# Processing Record 45 of Set 6 | moose factory
# Processing Record 46 of Set 6 | luganville
# Processing Record 47 of Set 6 | dickinson
# Processing Record 48 of Set 6 | dunedin
# Processing Record 49 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 50 of Set 6 | marsh harbour
# Processing Record 1 of Set 7 | mlonggo
# Processing Record 2 of Set 7 | shakawe
# Processing Record 3 of Set 7 | bandarbeyla
# Processing Record 4 of Set 7 | mrakovo
# Processing Record 5 of Set 7 | tuatapere
# Processing Record 6 of Set 7 | allapalli
# Processing Record 7 of Set 7 | ixtapa
# Processing Record 8 of Set 7 | tervel
# Processing Record 9 of Set 7 | taoudenni
# Processing Record 10 of Set 7 | nizhniy odes
# Processing Record 11 of Set 7 | tkvarcheli
# City not found. Skipping...
# Processing Record 12 of Set 7 | bengkulu
# Processing Record 13 of Set 7 | morondava
# Processing Record 14 of Set 7 | cayenne
# Processing Record 15 of Set 7 | najran
# Processing Record 16 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 7 | bonavista
# Processing Record 18 of Set 7 | princeton
# Processing Record 19 of Set 7 | saint-joseph
# Processing Record 20 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 21 of Set 7 | neryungri
# Processing Record 22 of Set 7 | visakhapatnam
# Processing Record 23 of Set 7 | katha
# City not found. Skipping...
# Processing Record 24 of Set 7 | kamina
# Processing Record 25 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 7 | chokurdakh
# Processing Record 27 of Set 7 | tuy hoa
# Processing Record 28 of Set 7 | gollere
# City not found. Skipping...
# Processing Record 29 of Set 7 | kavaratti
# Processing Record 30 of Set 7 | ouargaye
# Processing Record 31 of Set 7 | fort nelson
# Processing Record 32 of Set 7 | adrar
# Processing Record 33 of Set 7 | lavrentiya
# Processing Record 34 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 7 | eyemouth
# Processing Record 36 of Set 7 | cilegon
# Processing Record 37 of Set 7 | naryan-mar
# Processing Record 38 of Set 7 | sorong
# Processing Record 39 of Set 7 | pareora
# Processing Record 40 of Set 7 | kasane
# Processing Record 41 of Set 7 | sorland
# Processing Record 42 of Set 7 | lebu
# Processing Record 43 of Set 7 | hamilton
# Processing Record 44 of Set 7 | santa maria da vitoria
# Processing Record 45 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 7 | rudnyy
# Processing Record 47 of Set 7 | maragogi
# Processing Record 48 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | praia
# Processing Record 50 of Set 7 | angoche
# Processing Record 1 of Set 8 | amapa
# Processing Record 2 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 8 | myitkyina
# Processing Record 4 of Set 8 | peniche
# Processing Record 5 of Set 8 | madoc
# Processing Record 6 of Set 8 | chatakonda
# Processing Record 7 of Set 8 | husavik
# Processing Record 8 of Set 8 | tasiilaq
# Processing Record 9 of Set 8 | locri
# Processing Record 10 of Set 8 | tiksi
# Processing Record 11 of Set 8 | kalaleh
# Processing Record 12 of Set 8 | batemans bay
# Processing Record 13 of Set 8 | beringovskiy
# Processing Record 14 of Set 8 | nome
# Processing Record 15 of Set 8 | hovd
# Processing Record 16 of Set 8 | rawson
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 8 | narsaq
# Processing Record 20 of Set 8 | upata
# Processing Record 21 of Set 8 | hualmay
# Processing Record 22 of Set 8 | touros
# Processing Record 23 of Set 8 | naron
# Processing Record 24 of Set 8 | aliwal north
# Processing Record 25 of Set 8 | chuy
# Processing Record 26 of Set 8 | tecoanapa
# Processing Record 27 of Set 8 | shache
# Processing Record 28 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 29 of Set 8 | beloha
# Processing Record 30 of Set 8 | fethiye
# Processing Record 31 of Set 8 | zabol
# Processing Record 32 of Set 8 | valparaiso
# Processing Record 33 of Set 8 | krasnoselkup
# Processing Record 34 of Set 8 | padang
# Processing Record 35 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 8 | ivdel
# Processing Record 37 of Set 8 | lufilufi
# Processing Record 38 of Set 8 | vao
# Processing Record 39 of Set 8 | canatlan
# Processing Record 40 of Set 8 | vestmanna
# Processing Record 41 of Set 8 | aquiraz
# Processing Record 42 of Set 8 | bethel
# Processing Record 43 of Set 8 | airai
# Processing Record 44 of Set 8 | viedma
# Processing Record 45 of Set 8 | alberton
# Processing Record 46 of Set 8 | jutai
# Processing Record 47 of Set 8 | milkovo
# Processing Record 48 of Set 8 | kirakira
# Processing Record 49 of Set 8 | uklana mandi
# Processing Record 50 of Set 8 | uzumlu
# City not found. Skipping...
# Processing Record 1 of Set 9 | champerico
# Processing Record 2 of Set 9 | henties bay
# Processing Record 3 of Set 9 | progreso
# Processing Record 4 of Set 9 | impfondo
# Processing Record 5 of Set 9 | inirida
# Processing Record 6 of Set 9 | liaozhong
# Processing Record 7 of Set 9 | isabela
# Processing Record 8 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 9 | maceio
# Processing Record 10 of Set 9 | bone
# Processing Record 11 of Set 9 | bubaque
# Processing Record 12 of Set 9 | mudanjiang
# Processing Record 13 of Set 9 | tilichiki
# Processing Record 14 of Set 9 | eugene
# Processing Record 15 of Set 9 | huarmey
# Processing Record 16 of Set 9 | nanjing
# Processing Record 17 of Set 9 | mandan
# Processing Record 18 of Set 9 | harper
# Processing Record 19 of Set 9 | miles city
# Processing Record 20 of Set 9 | castro
# Processing Record 21 of Set 9 | dalinghe
# City not found. Skipping...
# Processing Record 22 of Set 9 | lorengau
# Processing Record 23 of Set 9 | bismarck
# Processing Record 24 of Set 9 | daru
# Processing Record 25 of Set 9 | dali
# Processing Record 26 of Set 9 | inhambane
# Processing Record 27 of Set 9 | westport
# Processing Record 28 of Set 9 | bitung
# Processing Record 29 of Set 9 | codrington
# Processing Record 30 of Set 9 | linxia
# Processing Record 31 of Set 9 | petropavl
# Processing Record 32 of Set 9 | sept-iles
# Processing Record 33 of Set 9 | deqing
# Processing Record 34 of Set 9 | kingman
# Processing Record 35 of Set 9 | litovko
# Processing Record 36 of Set 9 | maldonado
# Processing Record 37 of Set 9 | santa cruz cabralia
# Processing Record 38 of Set 9 | khowst
# Processing Record 39 of Set 9 | sydney
# Processing Record 40 of Set 9 | nacogdoches
# Processing Record 41 of Set 9 | kayes
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | ponta do sol
# Processing Record 44 of Set 9 | joshimath
# Processing Record 45 of Set 9 | san carlos de bariloche
# Processing Record 46 of Set 9 | argir
# Processing Record 47 of Set 9 | baturaja
# Processing Record 48 of Set 9 | qaqortoq
# Processing Record 49 of Set 9 | sorel
# Processing Record 50 of Set 9 | opuwo
# Processing Record 1 of Set 10 | longyearbyen
# Processing Record 2 of Set 10 | mount gambier
# Processing Record 3 of Set 10 | jesup
# Processing Record 4 of Set 10 | tigil
# Processing Record 5 of Set 10 | lanquin
# Processing Record 6 of Set 10 | mogadishu
# Processing Record 7 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 10 | wukari
# Processing Record 9 of Set 10 | seoul
# Processing Record 10 of Set 10 | lusambo
# Processing Record 11 of Set 10 | thenzawl
# Processing Record 12 of Set 10 | namatanai
# Processing Record 13 of Set 10 | tosya
# Processing Record 14 of Set 10 | mecca
# Processing Record 15 of Set 10 | kruisfontein
# Processing Record 16 of Set 10 | atasu
# Processing Record 17 of Set 10 | bandar-e lengeh
# Processing Record 18 of Set 10 | maarianhamina
# Processing Record 19 of Set 10 | dingle
# Processing Record 20 of Set 10 | surt
# Processing Record 21 of Set 10 | bambanglipuro
# Processing Record 22 of Set 10 | waipawa
# Processing Record 23 of Set 10 | la paz
# Processing Record 24 of Set 10 | teluknaga
# Processing Record 25 of Set 10 | carnduff
# Processing Record 26 of Set 10 | hammonton
# Processing Record 27 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 10 | vanimo
# Processing Record 29 of Set 10 | makung
# City not found. Skipping...
# Processing Record 30 of Set 10 | guelengdeng
# City not found. Skipping...
# Processing Record 31 of Set 10 | nikolayevsk-na-amure
# Processing Record 32 of Set 10 | am timan
# Processing Record 33 of Set 10 | kaniama
# Processing Record 34 of Set 10 | poum
# Processing Record 35 of Set 10 | lhuntshi
# City not found. Skipping...
# Processing Record 36 of Set 10 | ylivieska
# Processing Record 37 of Set 10 | kalmar
# Processing Record 38 of Set 10 | mufulira
# Processing Record 39 of Set 10 | tra vinh
# Processing Record 40 of Set 10 | biak
# Processing Record 41 of Set 10 | santa marta
# Processing Record 42 of Set 10 | flin flon
# Processing Record 43 of Set 10 | komsomolskiy
# Processing Record 44 of Set 10 | dicabisagan
# Processing Record 45 of Set 10 | northam
# Processing Record 46 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 10 | micheweni
# Processing Record 48 of Set 10 | bindi
# Processing Record 49 of Set 10 | takoradi
# Processing Record 50 of Set 10 | sahuaripa
# Processing Record 1 of Set 11 | viransehir
# Processing Record 2 of Set 11 | keningau
# Processing Record 3 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 11 | jalu
# Processing Record 5 of Set 11 | denpasar
# Processing Record 6 of Set 11 | minot
# Processing Record 7 of Set 11 | dzilam gonzalez
# Processing Record 8 of Set 11 | fairbanks
# Processing Record 9 of Set 11 | roald
# Processing Record 10 of Set 11 | ayan
# Processing Record 11 of Set 11 | hebertville
# City not found. Skipping...
# Processing Record 12 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 11 | tura
# Processing Record 14 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 11 | gizo
# Processing Record 16 of Set 11 | santa clara
# Processing Record 17 of Set 11 | nerchinskiy zavod
# Processing Record 18 of Set 11 | gannan
# Processing Record 19 of Set 11 | trelew
# Processing Record 20 of Set 11 | riberalta
# Processing Record 21 of Set 11 | sitka
# Processing Record 22 of Set 11 | isangel
# Processing Record 23 of Set 11 | staunton
# Processing Record 24 of Set 11 | sao miguel do araguaia
# Processing Record 25 of Set 11 | gamba
# Processing Record 26 of Set 11 | dongying
# Processing Record 27 of Set 11 | andselv
# City not found. Skipping...
# Processing Record 28 of Set 11 | lar
# Processing Record 29 of Set 11 | nago
# Processing Record 30 of Set 11 | port lincoln
# Processing Record 31 of Set 11 | barra do garcas
# Processing Record 32 of Set 11 | sargur
# Processing Record 33 of Set 11 | darnah
# Processing Record 34 of Set 11 | moultrie
# Processing Record 35 of Set 11 | kholtoson
# Processing Record 36 of Set 11 | ishigaki
# Processing Record 37 of Set 11 | mangai
# Processing Record 38 of Set 11 | kieta
# Processing Record 39 of Set 11 | thinadhoo
# Processing Record 40 of Set 11 | berberati
# Processing Record 41 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 11 | bichena
# Processing Record 43 of Set 11 | iglesias
# Processing Record 44 of Set 11 | grand gaube
# Processing Record 45 of Set 11 | komoro
# Processing Record 46 of Set 11 | labuan
# Processing Record 47 of Set 11 | anori
# Processing Record 48 of Set 11 | caernarfon
# Processing Record 49 of Set 11 | kokkola
# Processing Record 50 of Set 11 | luwuk
# Processing Record 1 of Set 12 | talcahuano
# Processing Record 2 of Set 12 | varhaug
# Processing Record 3 of Set 12 | sao geraldo do araguaia
# Processing Record 4 of Set 12 | constitucion
# Processing Record 5 of Set 12 | nipawin
# Processing Record 6 of Set 12 | iranshahr
# Processing Record 7 of Set 12 | yanam
# Processing Record 8 of Set 12 | kununurra
# Processing Record 9 of Set 12 | eureka
# Processing Record 10 of Set 12 | sobolevo
# Processing Record 11 of Set 12 | coos bay
# Processing Record 12 of Set 12 | sarangani
# Processing Record 13 of Set 12 | ilobu
# Processing Record 14 of Set 12 | bereda
# Processing Record 15 of Set 12 | limbang
# Processing Record 16 of Set 12 | lazaro cardenas
# Processing Record 17 of Set 12 | wonthaggi
# Processing Record 18 of Set 12 | steinbach
# Processing Record 19 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 12 | benguela
# Processing Record 21 of Set 12 | quelimane
# Processing Record 22 of Set 12 | madridejos
# Processing Record 23 of Set 12 | aparecida do taboado
# Processing Record 24 of Set 12 | north bend
# Processing Record 25 of Set 12 | lavumisa
# Processing Record 26 of Set 12 | lucapa
# Processing Record 27 of Set 12 | moree
# Processing Record 28 of Set 12 | amfiklia
# Processing Record 29 of Set 12 | bayir
# Processing Record 30 of Set 12 | manokwari
# Processing Record 31 of Set 12 | half moon bay
# Processing Record 32 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 12 | moron
# Processing Record 34 of Set 12 | makat
# Processing Record 35 of Set 12 | koslan
# Processing Record 36 of Set 12 | sakakah
# Processing Record 37 of Set 12 | kirkuk
# Processing Record 38 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 12 | la seyne-sur-mer
# Processing Record 40 of Set 12 | batagay
# Processing Record 41 of Set 12 | pergamino
# Processing Record 42 of Set 12 | sisimiut
# Processing Record 43 of Set 12 | rania
# Processing Record 44 of Set 12 | dire dawa
# Processing Record 45 of Set 12 | naraina
# Processing Record 46 of Set 12 | manicore
# Processing Record 47 of Set 12 | oranjemund
# Processing Record 48 of Set 12 | murindo
# Processing Record 49 of Set 12 | san cristobal
# Processing Record 50 of Set 12 | matay
# Processing Record 1 of Set 13 | pinos
# Processing Record 2 of Set 13 | pa sang
# Processing Record 3 of Set 13 | spassk
# Processing Record 4 of Set 13 | balyaga
# Processing Record 5 of Set 13 | luanda
# Processing Record 6 of Set 13 | agadez
# Processing Record 7 of Set 13 | batagay-alyta
# Processing Record 8 of Set 13 | aracati
# Processing Record 9 of Set 13 | tianpeng
# Processing Record 10 of Set 13 | napier
# Processing Record 11 of Set 13 | guaratinga
# Processing Record 12 of Set 13 | jamsa
# Processing Record 13 of Set 13 | morgan city
# Processing Record 14 of Set 13 | ingham
# Processing Record 15 of Set 13 | macusani
# Processing Record 16 of Set 13 | vostok
# Processing Record 17 of Set 13 | katobu
# Processing Record 18 of Set 13 | tweed
# Processing Record 19 of Set 13 | lewistown
# Processing Record 20 of Set 13 | groningen
# Processing Record 21 of Set 13 | formosa
# Processing Record 22 of Set 13 | owando
# Processing Record 23 of Set 13 | tromso
# Processing Record 24 of Set 13 | riyadh
# Processing Record 25 of Set 13 | deputatskiy
# Processing Record 26 of Set 13 | xocali
# Processing Record 27 of Set 13 | axim
# Processing Record 28 of Set 13 | aden
# Processing Record 29 of Set 13 | livingston
# Processing Record 30 of Set 13 | san felipe del progreso
# Processing Record 31 of Set 13 | malaryta
# Processing Record 32 of Set 13 | mirabad
# Processing Record 33 of Set 13 | kloulklubed
# Processing Record 34 of Set 13 | la ronge
# Processing Record 35 of Set 13 | wabana
# Processing Record 36 of Set 13 | gashua
# Processing Record 37 of Set 13 | grindavik
# Processing Record 38 of Set 13 | vila velha
# Processing Record 39 of Set 13 | camacha
# Processing Record 40 of Set 13 | kuito
# Processing Record 41 of Set 13 | the valley
# Processing Record 42 of Set 13 | dutlwe
# Processing Record 43 of Set 13 | pitimbu
# Processing Record 44 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 45 of Set 13 | mount isa
# Processing Record 46 of Set 13 | kangaatsiaq
# Processing Record 47 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 48 of Set 13 | beyneu
# Processing Record 49 of Set 13 | derzhavinsk
# Processing Record 50 of Set 13 | codajas
# Processing Record 1 of Set 14 | nishihara
# Processing Record 2 of Set 14 | ambon
# Processing Record 3 of Set 14 | baglung
# Processing Record 4 of Set 14 | narasapur
# Processing Record 5 of Set 14 | mabaruma
# Processing Record 6 of Set 14 | richards bay
# Processing Record 7 of Set 14 | lawton
# Processing Record 8 of Set 14 | rumoi
# Processing Record 9 of Set 14 | vestmannaeyjar
# Processing Record 10 of Set 14 | saint-pierre
# Processing Record 11 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 14 | matara
# Processing Record 13 of Set 14 | cubuk
# Processing Record 14 of Set 14 | abalak
# Processing Record 15 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 14 | singarayakonda
# Processing Record 17 of Set 14 | burica
# City not found. Skipping...
# Processing Record 18 of Set 14 | ust-koksa
# Processing Record 19 of Set 14 | namibe
# Processing Record 20 of Set 14 | lamar
# Processing Record 21 of Set 14 | whitianga
# Processing Record 22 of Set 14 | tahta
# Processing Record 23 of Set 14 | ejido
# Processing Record 24 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 14 | lashio
# Processing Record 26 of Set 14 | xai-xai
# Processing Record 27 of Set 14 | amuntai
# Processing Record 28 of Set 14 | boditi
# Processing Record 29 of Set 14 | shenjiamen
# Processing Record 30 of Set 14 | sergeyevka
# Processing Record 31 of Set 14 | mandiana
# Processing Record 32 of Set 14 | shwebo
# Processing Record 33 of Set 14 | seydisehir
# Processing Record 34 of Set 14 | nagapattinam
# Processing Record 35 of Set 14 | sfantu gheorghe
# Processing Record 36 of Set 14 | sao gabriel da cachoeira
# Processing Record 37 of Set 14 | kusk
# City not found. Skipping...
# Processing Record 38 of Set 14 | chino valley
# Processing Record 39 of Set 14 | malatya
# Processing Record 40 of Set 14 | acarau
# Processing Record 41 of Set 14 | broome
# Processing Record 42 of Set 14 | san vicente
# Processing Record 43 of Set 14 | san jose
# Processing Record 44 of Set 14 | trujillo
# Processing Record 45 of Set 14 | bafata
# Processing Record 46 of Set 14 | twin falls
# Processing Record 47 of Set 14 | les cayes
# Processing Record 48 of Set 14 | brae
# Processing Record 49 of Set 14 | prince albert
# Processing Record 50 of Set 14 | jimeta
# Processing Record 1 of Set 15 | kigoma
# Processing Record 2 of Set 15 | haines junction
# Processing Record 3 of Set 15 | nianzishan
# Processing Record 4 of Set 15 | garoua
# Processing Record 5 of Set 15 | buala
# Processing Record 6 of Set 15 | nicoya
# Processing Record 7 of Set 15 | homberg
# Processing Record 8 of Set 15 | colares
# Processing Record 9 of Set 15 | kathu
# Processing Record 10 of Set 15 | matagami
# Processing Record 11 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 12 of Set 15 | jumla
# Processing Record 13 of Set 15 | makariv
# Processing Record 14 of Set 15 | cap malheureux
# Processing Record 15 of Set 15 | banda aceh
# Processing Record 16 of Set 15 | guasdualito
# Processing Record 17 of Set 15 | scarborough
# Processing Record 18 of Set 15 | san rafael
# Processing Record 19 of Set 15 | visby
# Processing Record 20 of Set 15 | conde
# Processing Record 21 of Set 15 | oum hadjer
# Processing Record 22 of Set 15 | touba
# Processing Record 23 of Set 15 | bournemouth
# Processing Record 24 of Set 15 | caravelas
# Processing Record 25 of Set 15 | wuning
# Processing Record 26 of Set 15 | porto novo
# Processing Record 27 of Set 15 | sokolow podlaski
# Processing Record 28 of Set 15 | zhezkazgan
# Processing Record 29 of Set 15 | jiwani
# Processing Record 30 of Set 15 | sechura
# Processing Record 31 of Set 15 | belaya gora
# Processing Record 32 of Set 15 | kiunga
# Processing Record 33 of Set 15 | moses lake
# Processing Record 34 of Set 15 | bardiyah
# Processing Record 35 of Set 15 | nenjiang
# Processing Record 36 of Set 15 | ahipara
# Processing Record 37 of Set 15 | road town
# Processing Record 38 of Set 15 | auki
# Processing Record 39 of Set 15 | san ramon
# Processing Record 40 of Set 15 | salta
# Processing Record 41 of Set 15 | midland
# Processing Record 42 of Set 15 | almaznyy
# Processing Record 43 of Set 15 | wodonga
# Processing Record 44 of Set 15 | aktash
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_database
# Out:
# [{'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 63.32,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'NZ',
#   'Date': '2022-01-02 20:32:19'},
#  {'City': 'Ucluelet',
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 46.71,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:32:19'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 64.47,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Country': 'NZ',
#   'Date': '2022-01-02 20:23:06'},
#  {'City': 'Kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 64.92,
#   'Humidity': 24,
#   'Cloudiness': 16,
#   'Wind Speed': 11.25,
#   'Country': 'ML',
#   'Date': '2022-01-02 20:32:20'},
#  {'City': 'Iracoubo',
#   'Lat': 5.4802,
#   'Lng': -53.2011,
#   'Max Temp': 77.61,
#   'Humidity': 82,
#   'Cloudiness': 23,
#   'Wind Speed': 10.8,
#   'Country': 'GF',
#   'Date': '2022-01-02 20:32:21'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 81.63,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-01-02 20:32:21'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.36,
#   'Humidity': 72,
#   'Cloudiness': 21,
#   'Wind Speed': 8.79,
#   'Country': 'PF',
#   'Date': '2022-01-02 20:32:22'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 57.65,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:32:23'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 73.71,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:32:23'},
#  {'City': 'Kulhudhuffushi',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp': 81.03,
#   'Humidity': 76,
#   'Cloudiness': 9,
#   'Wind Speed': 7.25,
#   'Country': 'MV',
#   'Date': '2022-01-02 20:32:24'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.24,
#   'Humidity': 74,
#   'Cloudiness': 15,
#   'Wind Speed': 20.87,
#   'Country': 'PF',
#   'Date': '2022-01-02 20:32:24'},
#  {'City': 'Mackay',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 79.68,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:32:25'},
#  {'City': 'Kincardine',
#   'Lat': 56.0667,
#   'Lng': -3.7167,
#   'Max Temp': 49.51,
#   'Humidity': 87,
#   'Cloudiness': 91,
#   'Wind Speed': 21.14,
#   'Country': 'GB',
#   'Date': '2022-01-02 20:32:26'},
#  {'City': 'Loiza',
#   'Lat': 18.4313,
#   'Lng': -65.8802,
#   'Max Temp': 82.38,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'PR',
#   'Date': '2022-01-02 20:32:27'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 83.88,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'GD',
#   'Date': '2022-01-02 20:32:28'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 14.77,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:30:01'},
#  {'City': 'Grande Prairie',
#   'Lat': 55.1667,
#   'Lng': -118.8027,
#   'Max Temp': -12.82,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:32:29'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.64,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 11.14,
#   'Country': 'KI',
#   'Date': '2022-01-02 20:32:29'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 62.65,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 21.27,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:32:30'},
#  {'City': 'Susurluk',
#   'Lat': 39.9136,
#   'Lng': 28.1578,
#   'Max Temp': 45.84,
#   'Humidity': 92,
#   'Cloudiness': 10,
#   'Wind Speed': 1.52,
#   'Country': 'TR',
#   'Date': '2022-01-02 20:32:30'},
#  {'City': 'Iowa City',
#   'Lat': 41.6611,
#   'Lng': -91.5302,
#   'Max Temp': 8.33,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2022-01-02 20:32:31'},
#  {'City': 'Sabang',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 80.31,
#   'Humidity': 78,
#   'Cloudiness': 45,
#   'Wind Speed': 21.52,
#   'Country': 'ID',
#   'Date': '2022-01-02 20:32:31'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 59.85,
#   'Humidity': 38,
#   'Cloudiness': 7,
#   'Wind Speed': 0.76,
#   'Country': 'NE',
#   'Date': '2022-01-02 20:32:32'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 53.69,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 23.44,
#   'Country': 'US',
#   'Date': '2022-01-02 20:32:33'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -50.98,
#   'Humidity': 99,
#   'Cloudiness': 71,
#   'Wind Speed': 3.29,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:22:59'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -38.47,
#   'Humidity': 94,
#   'Cloudiness': 23,
#   'Wind Speed': 10.92,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:32:35'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 26.87,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 13.35,
#   'Country': 'GL',
#   'Date': '2022-01-02 20:32:36'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 57.4,
#   'Humidity': 100,
#   'Cloudiness': 45,
#   'Wind Speed': 2.8,
#   'Country': 'IL',
#   'Date': '2022-01-02 20:32:36'},
#  {'City': 'Kulu',
#   'Lat': 39.0951,
#   'Lng': 33.0799,
#   'Max Temp': 32.76,
#   'Humidity': 86,
#   'Cloudiness': 6,
#   'Wind Speed': 8.9,
#   'Country': 'TR',
#   'Date': '2022-01-02 20:32:37'},
#  {'City': 'Balikpapan',
#   'Lat': -1.2675,
#   'Lng': 116.8289,
#   'Max Temp': 74.82,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.84,
#   'Country': 'ID',
#   'Date': '2022-01-02 20:30:00'},
#  {'City': 'Paranaiba',
#   'Lat': -19.6772,
#   'Lng': -51.1908,
#   'Max Temp': 83.98,
#   'Humidity': 65,
#   'Cloudiness': 59,
#   'Wind Speed': 4.52,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:32:38'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 6.15,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2022-01-02 20:32:39'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 48.67,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-02 20:32:39'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 57.04,
#   'Humidity': 89,
#   'Cloudiness': 62,
#   'Wind Speed': 11.68,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:32:40'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 55.99,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 30.18,
#   'Country': 'PT',
#   'Date': '2022-01-02 20:32:40'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 75.49,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MU',
#   'Date': '2022-01-02 20:26:19'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.46,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 35.68,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:19:27'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 65.43,
#   'Humidity': 64,
#   'Cloudiness': 58,
#   'Wind Speed': 9.08,
#   'Country': 'CL',
#   'Date': '2022-01-02 20:32:38'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 57.04,
#   'Humidity': 87,
#   'Cloudiness': 4,
#   'Wind Speed': 9.55,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:32:42'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 12.07,
#   'Humidity': 69,
#   'Cloudiness': 14,
#   'Wind Speed': 7.47,
#   'Country': 'CN',
#   'Date': '2022-01-02 20:32:43'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 38.8,
#   'Humidity': 80,
#   'Cloudiness': 4,
#   'Wind Speed': 6.02,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:32:44'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 30.09,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Date': '2022-01-02 20:32:44'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.89,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Date': '2022-01-02 20:32:45'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 36.64,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2022-01-02 20:32:45'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 80.56,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'TC',
#   'Date': '2022-01-02 20:32:46'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 75.22,
#   'Humidity': 80,
#   'Cloudiness': 43,
#   'Wind Speed': 11.36,
#   'Country': 'RE',
#   'Date': '2022-01-02 20:23:03'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.96,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'TO',
#   'Date': '2022-01-02 20:26:19'},
#  {'City': 'Baruun-Urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': -3.75,
#   'Humidity': 77,
#   'Cloudiness': 6,
#   'Wind Speed': 7.16,
#   'Country': 'MN',
#   'Date': '2022-01-02 20:33:47'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 25.29,
#   'Humidity': 69,
#   'Cloudiness': 87,
#   'Wind Speed': 10.87,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:33:48'},
#  {'City': 'Wasilla',
#   'Lat': 61.5814,
#   'Lng': -149.4394,
#   'Max Temp': 7.75,
#   'Humidity': 40,
#   'Cloudiness': 90,
#   'Wind Speed': 61,
#   'Country': 'US',
#   'Date': '2022-01-02 20:33:49'},
#  {'City': 'Tandalti',
#   'Lat': 13.0167,
#   'Lng': 31.8667,
#   'Max Temp': 67.98,
#   'Humidity': 23,
#   'Cloudiness': 79,
#   'Wind Speed': 13.31,
#   'Country': 'SD',
#   'Date': '2022-01-02 20:33:49'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 75.31,
#   'Humidity': 74,
#   'Cloudiness': 24,
#   'Wind Speed': 7.65,
#   'Country': 'MU',
#   'Date': '2022-01-02 20:33:50'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 70.93,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Country': 'NZ',
#   'Date': '2022-01-02 20:33:50'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 55.33,
#   'Humidity': 39,
#   'Cloudiness': 55,
#   'Wind Speed': 14.27,
#   'Country': 'SD',
#   'Date': '2022-01-02 20:33:51'},
#  {'City': 'Reynosa',
#   'Lat': 26.0833,
#   'Lng': -98.2833,
#   'Max Temp': 60.64,
#   'Humidity': 22,
#   'Cloudiness': 1,
#   'Wind Speed': 23.02,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:33:51'},
#  {'City': 'Le Port',
#   'Lat': -20.9373,
#   'Lng': 55.2919,
#   'Max Temp': 75.61,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 6.98,
#   'Country': 'RE',
#   'Date': '2022-01-02 20:33:52'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 58.01,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:33:52'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 75.45,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MU',
#   'Date': '2022-01-02 20:33:54'},
#  {'City': 'Chipinge',
#   'Lat': -20.1883,
#   'Lng': 32.6236,
#   'Max Temp': 64.89,
#   'Humidity': 88,
#   'Cloudiness': 89,
#   'Wind Speed': 4.41,
#   'Country': 'ZW',
#   'Date': '2022-01-02 20:33:54'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 65.8,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83,
#   'Country': 'NZ',
#   'Date': '2022-01-02 20:33:55'},
#  {'City': 'Athabasca',
#   'Lat': 54.7169,
#   'Lng': -113.2854,
#   'Max Temp': 3.02,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 12.15,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:33:55'},
#  {'City': 'Puerto Narino',
#   'Lat': -3.7703,
#   'Lng': -70.3831,
#   'Max Temp': 87.75,
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 3.51,
#   'Country': 'CO',
#   'Date': '2022-01-02 20:33:56'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.17,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 3.85,
#   'Country': 'PF',
#   'Date': '2022-01-02 20:33:56'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -23.8,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:33:57'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 82.36,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:33:58'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -23.78,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2022-01-02 20:33:58'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 22.98,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'NO',
#   'Date': '2022-01-02 20:33:59'},
#  {'City': 'Bac Lieu',
#   'Lat': 9.285,
#   'Lng': 105.7244,
#   'Max Temp': 77.34,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 14.32,
#   'Country': 'VN',
#   'Date': '2022-01-02 20:33:59'},
#  {'City': 'Ust-Ilimsk',
#   'Lat': 58.0006,
#   'Lng': 102.6619,
#   'Max Temp': 6.51,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.34,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:34:01'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 63.28,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:34:01'},
#  {'City': 'Melfort',
#   'Lat': 52.8667,
#   'Lng': -104.6177,
#   'Max Temp': 5.13,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:34:02'},
#  {'City': 'Debre Zeyit',
#   'Lat': 8.75,
#   'Lng': 38.9833,
#   'Max Temp': 65.34,
#   'Humidity': 52,
#   'Cloudiness': 67,
#   'Wind Speed': 1.66,
#   'Country': 'ET',
#   'Date': '2022-01-02 20:34:04'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': -49.25,
#   'Humidity': 98,
#   'Cloudiness': 61,
#   'Wind Speed': 5.97,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:34:04'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -28.68,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:34:05'},
#  {'City': 'Novopskov',
#   'Lat': 49.5464,
#   'Lng': 39.0899,
#   'Max Temp': 11.07,
#   'Humidity': 94,
#   'Cloudiness': 76,
#   'Wind Speed': 5.21,
#   'Country': 'UA',
#   'Date': '2022-01-02 20:34:06'},
#  {'City': 'Turbat',
#   'Lat': 26.0023,
#   'Lng': 63.044,
#   'Max Temp': 65.71,
#   'Humidity': 56,
#   'Cloudiness': 30,
#   'Wind Speed': 3.27,
#   'Country': 'PK',
#   'Date': '2022-01-02 20:34:06'},
#  {'City': 'Piedras Negras',
#   'Lat': 28.7,
#   'Lng': -100.5167,
#   'Max Temp': 51.66,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:34:07'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 39.27,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 26.46,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:34:07'},
#  {'City': 'Mutoko',
#   'Lat': -17.397,
#   'Lng': 32.2268,
#   'Max Temp': 63.61,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Country': 'ZW',
#   'Date': '2022-01-02 20:34:08'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 24.91,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:34:08'},
#  {'City': 'Tiznit',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 60.67,
#   'Humidity': 42,
#   'Cloudiness': 6,
#   'Wind Speed': 2.13,
#   'Country': 'MA',
#   'Date': '2022-01-02 20:34:09'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 74.19,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2022-01-02 20:34:10'},
#  {'City': 'Smithers',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 19.72,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:34:10'},
#  {'City': 'Ewa Beach',
#   'Lat': 21.3156,
#   'Lng': -158.0072,
#   'Max Temp': 73.44,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2022-01-02 20:34:11'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.81,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:34:11'},
#  {'City': 'Itaituba',
#   'Lat': -4.2761,
#   'Lng': -55.9836,
#   'Max Temp': 78.96,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:30:11'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 57.4,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 11.25,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:34:12'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 66.72,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 4.81,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:34:13'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 27,
#   'Humidity': 54,
#   'Cloudiness': 2,
#   'Wind Speed': 13.47,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:34:13'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 26.96,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2022-01-02 20:29:20'},
#  {'City': 'Kilrush',
#   'Lat': 52.6397,
#   'Lng': -9.4833,
#   'Max Temp': 49.75,
#   'Humidity': 78,
#   'Cloudiness': 5,
#   'Wind Speed': 27.04,
#   'Country': 'IE',
#   'Date': '2022-01-02 20:34:14'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 23.63,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 21.61,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:33:00'},
#  {'City': 'Arandis',
#   'Lat': -22.4167,
#   'Lng': 14.9667,
#   'Max Temp': 56.46,
#   'Humidity': 82,
#   'Cloudiness': 2,
#   'Wind Speed': 2.75,
#   'Country': 'NA',
#   'Date': '2022-01-02 20:34:15'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 9.04,
#   'Country': 'PG',
#   'Date': '2022-01-02 20:26:26'},
#  {'City': 'Obregon',
#   'Lat': 11.9566,
#   'Lng': -85.9636,
#   'Max Temp': 91.87,
#   'Humidity': 46,
#   'Cloudiness': 65,
#   'Wind Speed': 10.2,
#   'Country': 'NI',
#   'Date': '2022-01-02 20:35:17'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 63.1,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:35:17'},
#  {'City': 'Barranca',
#   'Lat': -10.75,
#   'Lng': -77.7667,
#   'Max Temp': 72.5,
#   'Humidity': 74,
#   'Cloudiness': 21,
#   'Wind Speed': 9.57,
#   'Country': 'PE',
#   'Date': '2022-01-02 20:35:18'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 30,
#   'Wind Speed': 13.11,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:35:19'},
#  {'City': 'Muisne',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp': 84.31,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.81,
#   'Country': 'EC',
#   'Date': '2022-01-02 20:35:19'},
#  {'City': 'Oltu',
#   'Lat': 40.5498,
#   'Lng': 42.0013,
#   'Max Temp': 25.92,
#   'Humidity': 92,
#   'Cloudiness': 71,
#   'Wind Speed': 3.31,
#   'Country': 'TR',
#   'Date': '2022-01-02 20:35:20'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 3.33,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13,
#   'Country': 'GL',
#   'Date': '2022-01-02 20:26:22'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 63.19,
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2022-01-02 20:35:22'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 59.4,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'PT',
#   'Date': '2022-01-02 20:35:23'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 10.42,
#   'Humidity': 48,
#   'Cloudiness': 93,
#   'Wind Speed': 2.3,
#   'Country': 'GL',
#   'Date': '2022-01-02 20:31:17'},
#  {'City': 'Adilcevaz',
#   'Lat': 38.8039,
#   'Lng': 42.7342,
#   'Max Temp': 31.71,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Country': 'TR',
#   'Date': '2022-01-02 20:35:25'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 82.49,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.91,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:35:26'},
#  {'City': 'Fort Abbas',
#   'Lat': 29.1925,
#   'Lng': 72.8536,
#   'Max Temp': 59.59,
#   'Humidity': 21,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Country': 'PK',
#   'Date': '2022-01-02 20:35:26'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 60.15,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-02 20:35:27'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 82.45,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'CK',
#   'Date': '2022-01-02 20:35:28'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 80.56,
#   'Humidity': 79,
#   'Cloudiness': 82,
#   'Wind Speed': 12.46,
#   'Country': 'EC',
#   'Date': '2022-01-02 20:35:29'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 12.43,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:35:29'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -27.36,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:35:30'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 31.12,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 29.62,
#   'Country': 'FO',
#   'Date': '2022-01-02 20:35:31'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 50.11,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 28.77,
#   'Country': 'CL',
#   'Date': '2022-01-02 20:35:32'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 41.76,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 23.02,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:35:32'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 63.39,
#   'Humidity': 27,
#   'Cloudiness': 88,
#   'Wind Speed': 10.22,
#   'Country': 'NE',
#   'Date': '2022-01-02 20:35:33'},
#  {'City': 'Matadi',
#   'Lat': -5.8167,
#   'Lng': 13.45,
#   'Max Temp': 76.89,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Country': 'CD',
#   'Date': '2022-01-02 20:32:41'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 84.02,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:35:34'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.99,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 8.55,
#   'Country': 'MV',
#   'Date': '2022-01-02 20:34:52'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 73.47,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:35:36'},
#  {'City': 'Hohhot',
#   'Lat': 40.8106,
#   'Lng': 111.6522,
#   'Max Temp': -0.11,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'CN',
#   'Date': '2022-01-02 20:35:37'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 78.94,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 19.98,
#   'Country': 'NU',
#   'Date': '2022-01-02 20:34:14'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 52.66,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2022-01-02 20:35:38'},
#  {'City': 'Erdemli',
#   'Lat': 36.605,
#   'Lng': 34.3084,
#   'Max Temp': 53.53,
#   'Humidity': 48,
#   'Cloudiness': 32,
#   'Wind Speed': 7.25,
#   'Country': 'TR',
#   'Date': '2022-01-02 20:35:39'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 72.95,
#   'Humidity': 35,
#   'Cloudiness': 2,
#   'Wind Speed': 0,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:35:40'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 57.25,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 40.29,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:35:40'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 52.03,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2022-01-02 20:35:41'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 76.69,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.23,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:35:42'},
#  {'City': 'Varkaus',
#   'Lat': 62.3153,
#   'Lng': 27.873,
#   'Max Temp': 16.3,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.72,
#   'Country': 'FI',
#   'Date': '2022-01-02 20:35:42'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -2.4,
#   'Humidity': 71,
#   'Cloudiness': 98,
#   'Wind Speed': 8.25,
#   'Country': 'GL',
#   'Date': '2022-01-02 20:35:43'},
#  {'City': 'Jay',
#   'Lat': 44.5039,
#   'Lng': -70.2162,
#   'Max Temp': 36.16,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2022-01-02 20:35:43'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 64.38,
#   'Humidity': 86,
#   'Cloudiness': 72,
#   'Wind Speed': 10,
#   'Country': 'HK',
#   'Date': '2022-01-02 20:35:44'},
#  {'City': 'Toba',
#   'Lat': 34.4833,
#   'Lng': 136.85,
#   'Max Temp': 44.1,
#   'Humidity': 71,
#   'Cloudiness': 33,
#   'Wind Speed': 4,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:35:45'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 11.89,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.34,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:32:01'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -44.46,
#   'Humidity': 100,
#   'Cloudiness': 96,
#   'Wind Speed': 1.97,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:36:46'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 64.98,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 3.69,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:36:47'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 19.13,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:36:49'},
#  {'City': 'Cardoso',
#   'Lat': -20.0819,
#   'Lng': -49.9142,
#   'Max Temp': 80.15,
#   'Humidity': 73,
#   'Cloudiness': 30,
#   'Wind Speed': 2.55,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:36:49'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 74.01,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'PE',
#   'Date': '2022-01-02 20:36:50'},
#  {'City': 'Oranjestad',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Max Temp': 84.15,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'AW',
#   'Date': '2022-01-02 20:36:51'},
#  {'City': 'Oriximina',
#   'Lat': -1.7656,
#   'Lng': -55.8661,
#   'Max Temp': 85.05,
#   'Humidity': 63,
#   'Cloudiness': 96,
#   'Wind Speed': 3.47,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:36:51'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -33.84,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 2.08,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:36:52'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 80.44,
#   'Humidity': 22,
#   'Cloudiness': 11,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:36:52'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -1.89,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 6.13,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:36:54'},
#  {'City': 'Melville',
#   'Lat': 40.7934,
#   'Lng': -73.4151,
#   'Max Temp': 55.35,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2022-01-02 20:36:55'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 77.59,
#   'Humidity': 58,
#   'Cloudiness': 14,
#   'Wind Speed': 10.42,
#   'Country': 'CV',
#   'Date': '2022-01-02 20:36:56'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 75.29,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'OM',
#   'Date': '2022-01-02 20:36:56'},
#  {'City': 'Mumford',
#   'Lat': 5.2618,
#   'Lng': -0.759,
#   'Max Temp': 80.96,
#   'Humidity': 79,
#   'Cloudiness': 15,
#   'Wind Speed': 6.35,
#   'Country': 'GH',
#   'Date': '2022-01-02 20:36:57'},
#  {'City': 'Dubuque',
#   'Lat': 42.4833,
#   'Lng': -90.8668,
#   'Max Temp': 16.72,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2022-01-02 20:36:57'},
#  {'City': 'Shebalino',
#   'Lat': 51.2917,
#   'Lng': 85.6772,
#   'Max Temp': 16.63,
#   'Humidity': 80,
#   'Cloudiness': 46,
#   'Wind Speed': 7.27,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:32:12'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 79.05,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 5.99,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:36:58'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 62.67,
#   'Humidity': 40,
#   'Cloudiness': 82,
#   'Wind Speed': 3.6,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:36:59'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 22.28,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 29.39,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:36:59'},
#  {'City': 'Rancho Cucamonga',
#   'Lat': 34.1064,
#   'Lng': -117.5931,
#   'Max Temp': 65.43,
#   'Humidity': 28,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2022-01-02 20:37:00'},
#  {'City': 'Luau',
#   'Lat': -10.7073,
#   'Lng': 22.2247,
#   'Max Temp': 64.44,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31,
#   'Country': 'AO',
#   'Date': '2022-01-02 20:37:01'},
#  {'City': 'Konakovo',
#   'Lat': 56.7,
#   'Lng': 36.7667,
#   'Max Temp': 2.19,
#   'Humidity': 99,
#   'Cloudiness': 86,
#   'Wind Speed': 3.31,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:34:01'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 71.31,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:37:02'},
#  {'City': 'Chumikan',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': -21.78,
#   'Humidity': 91,
#   'Cloudiness': 20,
#   'Wind Speed': 11.54,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:37:02'},
#  {'City': 'Shieli',
#   'Lat': 44.1667,
#   'Lng': 66.75,
#   'Max Temp': 38.01,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Country': 'KZ',
#   'Date': '2022-01-02 20:37:03'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 34.3,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:32:45'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 45.36,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-02 20:37:04'},
#  {'City': 'Ushtobe',
#   'Lat': 45.2514,
#   'Lng': 77.9838,
#   'Max Temp': 30.24,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Country': 'KZ',
#   'Date': '2022-01-02 20:37:05'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 41.14,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 9.37,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:37:06'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 45.34,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 3.74,
#   'Country': 'PT',
#   'Date': '2022-01-02 20:37:06'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -0.67,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:37:08'},
#  {'City': 'Sovetskiy',
#   'Lat': 61.3614,
#   'Lng': 63.5842,
#   'Max Temp': 15.4,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.7,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:37:08'},
#  {'City': 'Nortelandia',
#   'Lat': -14.4547,
#   'Lng': -56.8028,
#   'Max Temp': 81.93,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 5.26,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:37:09'},
#  {'City': 'Treinta Y Tres',
#   'Lat': -33.2333,
#   'Lng': -54.3833,
#   'Max Temp': 96.48,
#   'Humidity': 26,
#   'Cloudiness': 51,
#   'Wind Speed': 1.92,
#   'Country': 'UY',
#   'Date': '2022-01-02 20:37:10'},
#  {'City': 'Makakilo City',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 72.01,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2022-01-02 20:37:10'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 35.1,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 5.53,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:37:11'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 67.86,
#   'Humidity': 14,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:37:12'},
#  {'City': 'Vilsbiburg',
#   'Lat': 48.45,
#   'Lng': 12.35,
#   'Max Temp': 54.46,
#   'Humidity': 64,
#   'Cloudiness': 88,
#   'Wind Speed': 5.99,
#   'Country': 'DE',
#   'Date': '2022-01-02 20:37:12'},
#  {'City': 'Carballo',
#   'Lat': 43.213,
#   'Lng': -8.691,
#   'Max Temp': 58.01,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Country': 'ES',
#   'Date': '2022-01-02 20:37:13'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -35.9,
#   'Humidity': 94,
#   'Cloudiness': 16,
#   'Wind Speed': 4.09,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:37:13'},
#  {'City': 'Telsiai',
#   'Lat': 55.9814,
#   'Lng': 22.2472,
#   'Max Temp': 37.9,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'LT',
#   'Date': '2022-01-02 20:35:01'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 66.04,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 18.21,
#   'Country': 'NA',
#   'Date': '2022-01-02 20:37:14'},
#  {'City': 'Grahamstown',
#   'Lat': -33.3042,
#   'Lng': 26.5328,
#   'Max Temp': 57.87,
#   'Humidity': 82,
#   'Cloudiness': 94,
#   'Wind Speed': 4.99,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:37:15'},
#  {'City': 'Pokhara',
#   'Lat': 28.2333,
#   'Lng': 83.9833,
#   'Max Temp': 51.39,
#   'Humidity': 52,
#   'Cloudiness': 2,
#   'Wind Speed': 5.1,
#   'Country': 'NP',
#   'Date': '2022-01-02 20:35:35'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 64.81,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:37:16'},
#  {'City': 'Hays',
#   'Lat': 30.0502,
#   'Lng': -98.0336,
#   'Max Temp': 46.92,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 13,
#   'Country': 'US',
#   'Date': '2022-01-02 20:38:16'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 80.62,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 15.99,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:37:15'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 78.85,
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:38:18'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -16.44,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:38:19'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': -9.02,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:38:19'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 17.8,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.4,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:38:20'},
#  {'City': 'La Asuncion',
#   'Lat': 11.0333,
#   'Lng': -63.8628,
#   'Max Temp': 82.13,
#   'Humidity': 65,
#   'Cloudiness': 68,
#   'Wind Speed': 16.11,
#   'Country': 'VE',
#   'Date': '2022-01-02 20:38:21'},
#  {'City': 'Nagornyy',
#   'Lat': 52.7959,
#   'Lng': 83.5498,
#   'Max Temp': 13.35,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 8.1,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:38:21'},
#  {'City': 'Indramayu',
#   'Lat': -6.3264,
#   'Lng': 108.32,
#   'Max Temp': 79.16,
#   'Humidity': 79,
#   'Cloudiness': 80,
#   'Wind Speed': 4.47,
#   'Country': 'ID',
#   'Date': '2022-01-02 20:38:23'},
#  {'City': 'Mayumba',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 77.63,
#   'Humidity': 91,
#   'Cloudiness': 83,
#   'Wind Speed': 4.05,
#   'Country': 'GA',
#   'Date': '2022-01-02 20:38:23'},
#  {'City': 'High Level',
#   'Lat': 58.5169,
#   'Lng': -117.136,
#   'Max Temp': -18.29,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:38:24'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 38.75,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 7.43,
#   'Country': 'RO',
#   'Date': '2022-01-02 20:38:24'},
#  {'City': 'Teguldet',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp': 14.99,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 9.98,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:38:25'},
#  {'City': 'Orlik',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': -13.65,
#   'Humidity': 97,
#   'Cloudiness': 57,
#   'Wind Speed': 2.73,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:38:25'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 76.98,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'MR',
#   'Date': '2022-01-02 20:38:26'},
#  {'City': 'Tbilisskaya',
#   'Lat': 45.3633,
#   'Lng': 40.19,
#   'Max Temp': 29.01,
#   'Humidity': 83,
#   'Cloudiness': 26,
#   'Wind Speed': 6.26,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:38:26'},
#  {'City': 'Calabozo',
#   'Lat': 8.9242,
#   'Lng': -67.4293,
#   'Max Temp': 89.96,
#   'Humidity': 38,
#   'Cloudiness': 34,
#   'Wind Speed': 10.51,
#   'Country': 'VE',
#   'Date': '2022-01-02 20:38:27'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 18.91,
#   'Humidity': 53,
#   'Cloudiness': 90,
#   'Wind Speed': 27.63,
#   'Country': 'US',
#   'Date': '2022-01-02 20:38:28'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': -16.13,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 9.31,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:38:28'},
#  {'City': 'Kota Kinabalu',
#   'Lat': 5.9749,
#   'Lng': 116.0724,
#   'Max Temp': 75.18,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MY',
#   'Date': '2022-01-02 20:38:29'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 76.71,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.62,
#   'Country': 'ID',
#   'Date': '2022-01-02 20:38:29'},
#  {'City': 'Benghazi',
#   'Lat': 32.1167,
#   'Lng': 20.0667,
#   'Max Temp': 61.39,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 11.14,
#   'Country': 'LY',
#   'Date': '2022-01-02 20:38:30'},
#  {'City': 'Parangan',
#   'Lat': 5.0839,
#   'Lng': 119.9383,
#   'Max Temp': 78.31,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Country': 'PH',
#   'Date': '2022-01-02 20:38:30'},
#  {'City': 'Coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 90.88,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 7.16,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:38:31'},
#  {'City': 'Chara',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': -30.44,
#   'Humidity': 83,
#   'Cloudiness': 24,
#   'Wind Speed': 1.92,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:38:32'},
#  {'City': 'Piotrkow Trybunalski',
#   'Lat': 51.4055,
#   'Lng': 19.7032,
#   'Max Temp': 50.76,
#   'Humidity': 10,
#   'Cloudiness': 91,
#   'Wind Speed': 21.77,
#   'Country': 'PL',
#   'Date': '2022-01-02 20:38:32'},
#  {'City': 'Hirado',
#   'Lat': 33.3597,
#   'Lng': 129.5531,
#   'Max Temp': 41.36,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:38:33'},
#  {'City': 'Sao Sebastiao',
#   'Lat': -23.76,
#   'Lng': -45.4097,
#   'Max Temp': 78.24,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 3.69,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:38:34'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 60.31,
#   'Humidity': 38,
#   'Cloudiness': 71,
#   'Wind Speed': 8.03,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:38:35'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 15.75,
#   'Humidity': 67,
#   'Cloudiness': 94,
#   'Wind Speed': 10.36,
#   'Country': 'NO',
#   'Date': '2022-01-02 20:38:36'},
#  {'City': 'Ranau',
#   'Lat': 5.9538,
#   'Lng': 116.6641,
#   'Max Temp': 68.65,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'MY',
#   'Date': '2022-01-02 20:38:38'},
#  {'City': 'Halifax',
#   'Lat': 44.6453,
#   'Lng': -63.5724,
#   'Max Temp': 46.4,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:38:38'},
#  {'City': 'Talaya',
#   'Lat': 61.3833,
#   'Lng': 152.75,
#   'Max Temp': -21.08,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:38:39'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 68.63,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 10.78,
#   'Country': 'ML',
#   'Date': '2022-01-02 20:38:39'},
#  {'City': 'Christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 75.33,
#   'Humidity': 74,
#   'Cloudiness': 92,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2022-01-02 20:38:40'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 63.81,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 6.53,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:38:40'},
#  {'City': 'Sokolo',
#   'Lat': 14.7328,
#   'Lng': -6.1219,
#   'Max Temp': 75.9,
#   'Humidity': 16,
#   'Cloudiness': 47,
#   'Wind Speed': 10.38,
#   'Country': 'ML',
#   'Date': '2022-01-02 20:38:41'},
#  {'City': 'Tadine',
#   'Lat': -21.55,
#   'Lng': 167.8833,
#   'Max Temp': 80.51,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 15.97,
#   'Country': 'NC',
#   'Date': '2022-01-02 20:38:42'},
#  {'City': 'San Julian',
#   'Lat': 21.0167,
#   'Lng': -102.1667,
#   'Max Temp': 74.19,
#   'Humidity': 17,
#   'Cloudiness': 2,
#   'Wind Speed': 4.63,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:38:42'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 53.71,
#   'Humidity': 86,
#   'Cloudiness': 44,
#   'Wind Speed': 6.73,
#   'Country': 'SA',
#   'Date': '2022-01-02 20:38:43'},
#  {'City': 'Tolaga Bay',
#   'Lat': -38.3667,
#   'Lng': 178.3,
#   'Max Temp': 68.29,
#   'Humidity': 66,
#   'Cloudiness': 60,
#   'Wind Speed': 6.15,
#   'Country': 'NZ',
#   'Date': '2022-01-02 20:38:43'},
#  {'City': 'La Grande',
#   'Lat': 45.3246,
#   'Lng': -118.0877,
#   'Max Temp': 27.23,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 14.88,
#   'Country': 'US',
#   'Date': '2022-01-02 20:38:44'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 81.21,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 25.32,
#   'Country': 'BB',
#   'Date': '2022-01-02 20:38:45'},
#  {'City': 'Corinto',
#   'Lat': 37.9407,
#   'Lng': 22.9573,
#   'Max Temp': 56.68,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 1.52,
#   'Country': 'GR',
#   'Date': '2022-01-02 20:37:13'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 26.64,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 13.76,
#   'Country': 'IS',
#   'Date': '2022-01-02 20:39:46'},
#  {'City': 'Whitehorse',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': -13.7,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 13,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:39:23'},
#  {'City': 'Nurota',
#   'Lat': 40.5614,
#   'Lng': 65.6886,
#   'Max Temp': 50.09,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 5.97,
#   'Country': 'UZ',
#   'Date': '2022-01-02 20:39:47'},
#  {'City': 'Alta Floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 87.62,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:39:47'},
#  {'City': 'Dukat',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': -11.97,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:39:49'},
#  {'City': 'Neuquen',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 80.49,
#   'Humidity': 28,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:36:11'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 0.63,
#   'Humidity': 99,
#   'Cloudiness': 82,
#   'Wind Speed': 8.01,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:39:50'},
#  {'City': 'Darhan',
#   'Lat': 49.4867,
#   'Lng': 105.9228,
#   'Max Temp': -8.16,
#   'Humidity': 92,
#   'Cloudiness': 74,
#   'Wind Speed': 4.43,
#   'Country': 'MN',
#   'Date': '2022-01-02 20:39:51'},
#  {'City': 'Helena',
#   'Lat': 46.5927,
#   'Lng': -112.0361,
#   'Max Temp': 34.18,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-02 20:39:52'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 67.42,
#   'Humidity': 76,
#   'Cloudiness': 95,
#   'Wind Speed': 18.79,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:39:52'},
#  {'City': 'Mponela',
#   'Lat': -13.5319,
#   'Lng': 33.7401,
#   'Max Temp': 65.23,
#   'Humidity': 76,
#   'Cloudiness': 76,
#   'Wind Speed': 4.25,
#   'Country': 'MW',
#   'Date': '2022-01-02 20:39:53'},
#  {'City': 'Katangli',
#   'Lat': 51.7102,
#   'Lng': 143.2326,
#   'Max Temp': -17.81,
#   'Humidity': 97,
#   'Cloudiness': 26,
#   'Wind Speed': 7.36,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:39:53'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 80.71,
#   'Humidity': 70,
#   'Cloudiness': 56,
#   'Wind Speed': 17.74,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:39:54'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 84.22,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 12.26,
#   'Country': 'PF',
#   'Date': '2022-01-02 20:39:54'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 83.46,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2022-01-02 20:39:56'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 86.83,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'MX',
#   'Date': '2022-01-02 20:39:56'},
#  {'City': 'Soavinandriana',
#   'Lat': -19.1667,
#   'Lng': 46.7333,
#   'Max Temp': 62.92,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.8,
#   'Country': 'MG',
#   'Date': '2022-01-02 20:39:57'},
#  {'City': 'Ca Mau',
#   'Lat': 9.1769,
#   'Lng': 105.15,
#   'Max Temp': 75.45,
#   'Humidity': 76,
#   'Cloudiness': 88,
#   'Wind Speed': 6.69,
#   'Country': 'VN',
#   'Date': '2022-01-02 20:39:57'},
#  {'City': 'Forio',
#   'Lat': 40.7342,
#   'Lng': 13.8646,
#   'Max Temp': 56.43,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'IT',
#   'Date': '2022-01-02 20:39:59'},
#  {'City': 'Kannangad',
#   'Lat': 12.3081,
#   'Lng': 75.1063,
#   'Max Temp': 75.56,
#   'Humidity': 74,
#   'Cloudiness': 24,
#   'Wind Speed': 5.3,
#   'Country': 'IN',
#   'Date': '2022-01-02 20:39:59'},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 72.88,
#   'Humidity': 90,
#   'Cloudiness': 54,
#   'Wind Speed': 3.04,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:40:00'},
#  {'City': 'North Platte',
#   'Lat': 41.1239,
#   'Lng': -100.7654,
#   'Max Temp': 34.32,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2022-01-02 20:40:00'},
#  {'City': 'Gushikawa',
#   'Lat': 26.3544,
#   'Lng': 127.8686,
#   'Max Temp': 61.83,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:40:04'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 12.06,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 3.27,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:39:01'},
#  {'City': 'Manono',
#   'Lat': -7.3,
#   'Lng': 27.4167,
#   'Max Temp': 70.2,
#   'Humidity': 94,
#   'Cloudiness': 83,
#   'Wind Speed': 2.53,
#   'Country': 'CD',
#   'Date': '2022-01-02 20:40:07'},
#  {'City': 'Pemba',
#   'Lat': -12.974,
#   'Lng': 40.5178,
#   'Max Temp': 79.5,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'MZ',
# ...
#   'Country': 'GY',
#   'Date': '2022-01-02 20:51:48'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 70.88,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Country': 'ZA',
#   'Date': '2022-01-02 20:51:48'},
#  {'City': 'Lawton',
#   'Lat': 34.6087,
#   'Lng': -98.3903,
#   'Max Temp': 34.27,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2022-01-02 20:51:49'},
#  {'City': 'Rumoi',
#   'Lat': 43.9344,
#   'Lng': 141.6428,
#   'Max Temp': 17.91,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 28.32,
#   'Country': 'JP',
#   'Date': '2022-01-02 20:51:49'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 25.05,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 27.81,
#   'Country': 'IS',
#   'Date': '2022-01-02 20:51:50'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 75.29,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'RE',
#   'Date': '2022-01-02 20:48:28'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 74.48,
#   'Humidity': 87,
#   'Cloudiness': 4,
#   'Wind Speed': 8.88,
#   'Country': 'LK',
#   'Date': '2022-01-02 20:51:52'},
#  {'City': 'Cubuk',
#   'Lat': 40.2386,
#   'Lng': 33.0322,
#   'Max Temp': 33.76,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'TR',
#   'Date': '2022-01-02 20:51:52'},
#  {'City': 'Abalak',
#   'Lat': 58.1286,
#   'Lng': 68.5944,
#   'Max Temp': 22.15,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.69,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:51:53'},
#  {'City': 'Singarayakonda',
#   'Lat': 15.25,
#   'Lng': 80.0333,
#   'Max Temp': 73.78,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 7.18,
#   'Country': 'IN',
#   'Date': '2022-01-02 20:51:54'},
#  {'City': 'Ust-Koksa',
#   'Lat': 50.2696,
#   'Lng': 85.6108,
#   'Max Temp': 5.2,
#   'Humidity': 87,
#   'Cloudiness': 45,
#   'Wind Speed': 1.28,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:51:55'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 69.87,
#   'Humidity': 82,
#   'Cloudiness': 70,
#   'Wind Speed': 2.91,
#   'Country': 'AO',
#   'Date': '2022-01-02 20:51:56'},
#  {'City': 'Lamar',
#   'Lat': 33.6668,
#   'Lng': -95.5836,
#   'Max Temp': 36.99,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Date': '2022-01-02 20:51:56'},
#  {'City': 'Whitianga',
#   'Lat': -36.8333,
#   'Lng': 175.7,
#   'Max Temp': 69.96,
#   'Humidity': 64,
#   'Cloudiness': 64,
#   'Wind Speed': 8.03,
#   'Country': 'NZ',
#   'Date': '2022-01-02 20:51:57'},
#  {'City': 'Tahta',
#   'Lat': 26.7693,
#   'Lng': 31.5021,
#   'Max Temp': 51.91,
#   'Humidity': 65,
#   'Cloudiness': 2,
#   'Wind Speed': 6.96,
#   'Country': 'EG',
#   'Date': '2022-01-02 20:51:57'},
#  {'City': 'Ejido',
#   'Lat': 8.5514,
#   'Lng': -71.2375,
#   'Max Temp': 74.62,
#   'Humidity': 76,
#   'Cloudiness': 91,
#   'Wind Speed': 3.29,
#   'Country': 'VE',
#   'Date': '2022-01-02 20:51:58'},
#  {'City': 'Lashio',
#   'Lat': 22.9333,
#   'Lng': 97.75,
#   'Max Temp': 48.4,
#   'Humidity': 84,
#   'Cloudiness': 6,
#   'Wind Speed': 1.3,
#   'Country': 'MM',
#   'Date': '2022-01-02 20:51:59'},
#  {'City': 'Xai-Xai',
#   'Lat': -25.0519,
#   'Lng': 33.6442,
#   'Max Temp': 72.77,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.34,
#   'Country': 'MZ',
#   'Date': '2022-01-02 20:52:00'},
#  {'City': 'Amuntai',
#   'Lat': -2.4177,
#   'Lng': 115.2494,
#   'Max Temp': 74.12,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'ID',
#   'Date': '2022-01-02 20:52:00'},
#  {'City': 'Boditi',
#   'Lat': 6.9667,
#   'Lng': 37.8667,
#   'Max Temp': 66.33,
#   'Humidity': 44,
#   'Cloudiness': 68,
#   'Wind Speed': 3.04,
#   'Country': 'ET',
#   'Date': '2022-01-02 20:52:01'},
#  {'City': 'Shenjiamen',
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp': 47.14,
#   'Humidity': 74,
#   'Cloudiness': 2,
#   'Wind Speed': 3.94,
#   'Country': 'CN',
#   'Date': '2022-01-02 20:52:01'},
#  {'City': 'Sergeyevka',
#   'Lat': 53.88,
#   'Lng': 67.4158,
#   'Max Temp': 17.33,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.96,
#   'Country': 'KZ',
#   'Date': '2022-01-02 20:52:02'},
#  {'City': 'Mandiana',
#   'Lat': 10.6333,
#   'Lng': -8.6833,
#   'Max Temp': 78.21,
#   'Humidity': 15,
#   'Cloudiness': 62,
#   'Wind Speed': 3.83,
#   'Country': 'GN',
#   'Date': '2022-01-02 20:52:02'},
#  {'City': 'Shwebo',
#   'Lat': 22.5667,
#   'Lng': 95.7,
#   'Max Temp': 61.34,
#   'Humidity': 76,
#   'Cloudiness': 21,
#   'Wind Speed': 4.23,
#   'Country': 'MM',
#   'Date': '2022-01-02 20:52:03'},
#  {'City': 'Seydisehir',
#   'Lat': 37.4193,
#   'Lng': 31.8453,
#   'Max Temp': 31.62,
#   'Humidity': 91,
#   'Cloudiness': 40,
#   'Wind Speed': 4.92,
#   'Country': 'TR',
#   'Date': '2022-01-02 20:52:04'},
#  {'City': 'Nagapattinam',
#   'Lat': 10.7667,
#   'Lng': 79.8333,
#   'Max Temp': 75.43,
#   'Humidity': 85,
#   'Cloudiness': 23,
#   'Wind Speed': 12.41,
#   'Country': 'IN',
#   'Date': '2022-01-02 20:52:04'},
#  {'City': 'Sfantu Gheorghe',
#   'Lat': 45.8667,
#   'Lng': 25.7833,
#   'Max Temp': 36.93,
#   'Humidity': 91,
#   'Cloudiness': 78,
#   'Wind Speed': 1.43,
#   'Country': 'RO',
#   'Date': '2022-01-02 20:51:30'},
#  {'City': 'Sao Gabriel Da Cachoeira',
#   'Lat': -0.1303,
#   'Lng': -67.0892,
#   'Max Temp': 80.46,
#   'Humidity': 92,
#   'Cloudiness': 83,
#   'Wind Speed': 2.13,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:52:05'},
#  {'City': 'Chino Valley',
#   'Lat': 34.7575,
#   'Lng': -112.4538,
#   'Max Temp': 48.36,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2022-01-02 20:52:06'},
#  {'City': 'Malatya',
#   'Lat': 38.5,
#   'Lng': 38,
#   'Max Temp': 33.85,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'TR',
#   'Date': '2022-01-02 20:52:07'},
#  {'City': 'Acarau',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 80.82,
#   'Humidity': 77,
#   'Cloudiness': 32,
#   'Wind Speed': 14.83,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:52:08'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 30.02,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Date': '2022-01-02 20:52:08'},
#  {'City': 'San Vicente',
#   'Lat': -26.6167,
#   'Lng': -54.1333,
#   'Max Temp': 94.91,
#   'Humidity': 24,
#   'Cloudiness': 46,
#   'Wind Speed': 1.07,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:52:09'},
#  {'City': 'San Jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 60.78,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2022-01-02 20:50:46'},
#  {'City': 'Trujillo',
#   'Lat': -8.116,
#   'Lng': -79.03,
#   'Max Temp': 69.76,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'PE',
#   'Date': '2022-01-02 20:48:15'},
#  {'City': 'Bafata',
#   'Lat': 12.1667,
#   'Lng': -14.75,
#   'Max Temp': 79.21,
#   'Humidity': 15,
#   'Cloudiness': 94,
#   'Wind Speed': 6.02,
#   'Country': 'GW',
#   'Date': '2022-01-02 20:52:12'},
#  {'City': 'Twin Falls',
#   'Lat': 42.3505,
#   'Lng': -114.6445,
#   'Max Temp': 19.09,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2022-01-02 20:52:13'},
#  {'City': 'Les Cayes',
#   'Lat': 18.2,
#   'Lng': -73.75,
#   'Max Temp': 81.1,
#   'Humidity': 58,
#   'Cloudiness': 2,
#   'Wind Speed': 10.42,
#   'Country': 'HT',
#   'Date': '2022-01-02 20:52:13'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 48.11,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 19.13,
#   'Country': 'GB',
#   'Date': '2022-01-02 20:52:14'},
#  {'City': 'Prince Albert',
#   'Lat': 53.2001,
#   'Lng': -105.7677,
#   'Max Temp': 3.15,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:52:14'},
#  {'City': 'Jimeta',
#   'Lat': 9.2833,
#   'Lng': 12.4667,
#   'Max Temp': 75.58,
#   'Humidity': 20,
#   'Cloudiness': 53,
#   'Wind Speed': 5.21,
#   'Country': 'NG',
#   'Date': '2022-01-02 20:48:45'},
#  {'City': 'Kigoma',
#   'Lat': -4.8769,
#   'Lng': 29.6267,
#   'Max Temp': 73.99,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'TZ',
#   'Date': '2022-01-02 20:53:15'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': -14.85,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:53:16'},
#  {'City': 'Nianzishan',
#   'Lat': 47.5167,
#   'Lng': 122.8833,
#   'Max Temp': -0.24,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Country': 'CN',
#   'Date': '2022-01-02 20:53:16'},
#  {'City': 'Garoua',
#   'Lat': 9.3,
#   'Lng': 13.4,
#   'Max Temp': 75.6,
#   'Humidity': 23,
#   'Cloudiness': 25,
#   'Wind Speed': 6.91,
#   'Country': 'CM',
#   'Date': '2022-01-02 20:48:53'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 81.5,
#   'Humidity': 83,
#   'Cloudiness': 61,
#   'Wind Speed': 6.42,
#   'Country': 'SB',
#   'Date': '2022-01-02 20:53:18'},
#  {'City': 'Nicoya',
#   'Lat': 10.1483,
#   'Lng': -85.452,
#   'Max Temp': 90.95,
#   'Humidity': 46,
#   'Cloudiness': 94,
#   'Wind Speed': 2.15,
#   'Country': 'CR',
#   'Date': '2022-01-02 20:53:18'},
#  {'City': 'Homberg',
#   'Lat': 51.0333,
#   'Lng': 9.4,
#   'Max Temp': 50.04,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'DE',
#   'Date': '2022-01-02 20:53:19'},
#  {'City': 'Colares',
#   'Lat': 38.7992,
#   'Lng': -9.4469,
#   'Max Temp': 58.98,
#   'Humidity': 81,
#   'Cloudiness': 27,
#   'Wind Speed': 3,
#   'Country': 'PT',
#   'Date': '2022-01-02 20:53:19'},
#  {'City': 'Kathu',
#   'Lat': 7.9178,
#   'Lng': 98.3332,
#   'Max Temp': 83.7,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 11.86,
#   'Country': 'TH',
#   'Date': '2022-01-02 20:53:20'},
#  {'City': 'Matagami',
#   'Lat': 49.7502,
#   'Lng': -77.6328,
#   'Max Temp': -5.69,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2022-01-02 20:53:20'},
#  {'City': 'Jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 30.45,
#   'Humidity': 76,
#   'Cloudiness': 9,
#   'Wind Speed': 5.97,
#   'Country': 'NP',
#   'Date': '2022-01-02 20:53:21'},
#  {'City': 'Makariv',
#   'Lat': 50.4641,
#   'Lng': 29.8113,
#   'Max Temp': 30.29,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 16.02,
#   'Country': 'UA',
#   'Date': '2022-01-02 20:53:22'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 75.69,
#   'Humidity': 71,
#   'Cloudiness': 16,
#   'Wind Speed': 3,
#   'Country': 'MU',
#   'Date': '2022-01-02 20:53:22'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 76.46,
#   'Humidity': 84,
#   'Cloudiness': 23,
#   'Wind Speed': 12.35,
#   'Country': 'ID',
#   'Date': '2022-01-02 20:53:23'},
#  {'City': 'Guasdualito',
#   'Lat': 7.2424,
#   'Lng': -70.7324,
#   'Max Temp': 91.4,
#   'Humidity': 43,
#   'Cloudiness': 44,
#   'Wind Speed': 5.75,
#   'Country': 'VE',
#   'Date': '2022-01-02 20:53:24'},
#  {'City': 'Scarborough',
#   'Lat': 54.2797,
#   'Lng': -0.4044,
#   'Max Temp': 50.52,
#   'Humidity': 84,
#   'Cloudiness': 53,
#   'Wind Speed': 7,
#   'Country': 'GB',
#   'Date': '2022-01-02 20:53:24'},
#  {'City': 'San Rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 97.63,
#   'Humidity': 7,
#   'Cloudiness': 15,
#   'Wind Speed': 2.1,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:53:25'},
#  {'City': 'Visby',
#   'Lat': 57.6409,
#   'Lng': 18.296,
#   'Max Temp': 43.02,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'SE',
#   'Date': '2022-01-02 20:53:25'},
#  {'City': 'Conde',
#   'Lat': -7.2597,
#   'Lng': -34.9075,
#   'Max Temp': 81.86,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:53:26'},
#  {'City': 'Oum Hadjer',
#   'Lat': 13.2954,
#   'Lng': 19.6966,
#   'Max Temp': 66.38,
#   'Humidity': 24,
#   'Cloudiness': 40,
#   'Wind Speed': 14.12,
#   'Country': 'TD',
#   'Date': '2022-01-02 20:53:26'},
#  {'City': 'Touba',
#   'Lat': 8.2833,
#   'Lng': -7.6833,
#   'Max Temp': 79.23,
#   'Humidity': 17,
#   'Cloudiness': 93,
#   'Wind Speed': 1.36,
#   'Country': 'CI',
#   'Date': '2022-01-02 20:53:27'},
#  {'City': 'Bournemouth',
#   'Lat': 50.7205,
#   'Lng': -1.8795,
#   'Max Temp': 52.41,
#   'Humidity': 90,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Country': 'GB',
#   'Date': '2022-01-02 20:48:54'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 77.79,
#   'Humidity': 81,
#   'Cloudiness': 96,
#   'Wind Speed': 6.44,
#   'Country': 'BR',
#   'Date': '2022-01-02 20:53:28'},
#  {'City': 'Wuning',
#   'Lat': 29.2589,
#   'Lng': 120.2311,
#   'Max Temp': 39.2,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 1.79,
#   'Country': 'CN',
#   'Date': '2022-01-02 20:53:28'},
#  {'City': 'Porto Novo',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 84.02,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 4.16,
#   'Country': 'BJ',
#   'Date': '2022-01-02 20:53:29'},
#  {'City': 'Sokolow Podlaski',
#   'Lat': 52.4068,
#   'Lng': 22.2531,
#   'Max Temp': 48.07,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 15.95,
#   'Country': 'PL',
#   'Date': '2022-01-02 20:53:29'},
#  {'City': 'Zhezkazgan',
#   'Lat': 47.8043,
#   'Lng': 67.7144,
#   'Max Temp': 24.78,
#   'Humidity': 98,
#   'Cloudiness': 84,
#   'Wind Speed': 4.07,
#   'Country': 'KZ',
#   'Date': '2022-01-02 20:53:30'},
#  {'City': 'Jiwani',
#   'Lat': 25.05,
#   'Lng': 61.7417,
#   'Max Temp': 72.77,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 15.57,
#   'Country': 'PK',
#   'Date': '2022-01-02 20:53:31'},
#  {'City': 'Sechura',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 76.51,
#   'Humidity': 63,
#   'Cloudiness': 39,
#   'Wind Speed': 14.14,
#   'Country': 'PE',
#   'Date': '2022-01-02 20:53:31'},
#  {'City': 'Belaya Gora',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': -28.75,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 0.94,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:52:20'},
#  {'City': 'Kiunga',
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp': 73.56,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'PG',
#   'Date': '2022-01-02 20:53:32'},
#  {'City': 'Moses Lake',
#   'Lat': 47.1301,
#   'Lng': -119.2781,
#   'Max Temp': 23.18,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 1.1,
#   'Country': 'US',
#   'Date': '2022-01-02 20:53:33'},
#  {'City': 'Bardiyah',
#   'Lat': 31.7561,
#   'Lng': 25.0865,
#   'Max Temp': 60.6,
#   'Humidity': 74,
#   'Cloudiness': 2,
#   'Wind Speed': 9.51,
#   'Country': 'LY',
#   'Date': '2022-01-02 20:53:33'},
#  {'City': 'Nenjiang',
#   'Lat': 49.1833,
#   'Lng': 125.2167,
#   'Max Temp': -21.77,
#   'Humidity': 85,
#   'Cloudiness': 4,
#   'Wind Speed': 2.59,
#   'Country': 'CN',
#   'Date': '2022-01-02 20:53:34'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 70.48,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Country': 'NZ',
#   'Date': '2022-01-02 20:53:34'},
#  {'City': 'Road Town',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 82.44,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'VG',
#   'Date': '2022-01-02 20:53:35'},
#  {'City': 'Auki',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 81.23,
#   'Humidity': 85,
#   'Cloudiness': 91,
#   'Wind Speed': 9.64,
#   'Country': 'SB',
#   'Date': '2022-01-02 20:53:36'},
#  {'City': 'San Ramon',
#   'Lat': 37.7799,
#   'Lng': -121.978,
#   'Max Temp': 58.57,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2022-01-02 20:53:36'},
#  {'City': 'Salta',
#   'Lat': -24.7859,
#   'Lng': -65.4117,
#   'Max Temp': 95.59,
#   'Humidity': 31,
#   'Cloudiness': 20,
#   'Wind Speed': 11.01,
#   'Country': 'AR',
#   'Date': '2022-01-02 20:53:37'},
#  {'City': 'Midland',
#   'Lat': 31.9974,
#   'Lng': -102.0779,
#   'Max Temp': 46.47,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2022-01-02 20:53:37'},
#  {'City': 'Almaznyy',
#   'Lat': 48.0448,
#   'Lng': 40.045,
#   'Max Temp': 23.14,
#   'Humidity': 94,
#   'Cloudiness': 89,
#   'Wind Speed': 7.87,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:53:38'},
#  {'City': 'Wodonga',
#   'Lat': -36.1167,
#   'Lng': 146.8833,
#   'Max Temp': 74.97,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'AU',
#   'Date': '2022-01-02 20:53:38'},
#  {'City': 'Aktash',
#   'Lat': 50.3,
#   'Lng': 87.7333,
#   'Max Temp': -7.29,
#   'Humidity': 91,
#   'Cloudiness': 77,
#   'Wind Speed': 4.83,
#   'Country': 'RU',
#   'Date': '2022-01-02 20:53:39'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_database)
city_data_df
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Te Anau -45.4167  167.7167     63.32        68         100        1.79
# 1    Ucluelet  48.9329 -125.5528     46.71        92         100        7.00
# 2     Mataura -46.1927  168.8643     64.47        63         100        1.23
# 3       Kidal  18.4411    1.4078     64.92        24          16       11.25
# 4    Iracoubo   5.4802  -53.2011     77.61        82          23       10.80
# ..        ...      ...       ...       ...       ...         ...         ...
# 670     Salta -24.7859  -65.4117     95.59        31          20       11.01
# 671   Midland  31.9974 -102.0779     46.47        25           1        8.05
# 672  Almaznyy  48.0448   40.0450     23.14        94          89        7.87
# 673   Wodonga -36.1167  146.8833     74.97        91           0        0.00
# 674    Aktash  50.3000   87.7333     -7.29        91          77        4.83
#
#     Country                 Date
# 0        NZ  2022-01-02 20:32:19
# 1        CA  2022-01-02 20:32:19
# 2        NZ  2022-01-02 20:23:06
# 3        ML  2022-01-02 20:32:20
# 4        GF  2022-01-02 20:32:21
# ..      ...                  ...
# 670      AR  2022-01-02 20:53:37
# 671      US  2022-01-02 20:53:37
# 672      RU  2022-01-02 20:53:38
# 673      AU  2022-01-02 20:53:38
# 674      RU  2022-01-02 20:53:39
#
# [675 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
